# %% [markdown]
# <a href="https://colab.research.google.com/github/twhool02/ptm-quantization/blob/main/Quantized_Model_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# This notebook runs evaluation benchmarks on qunatized pre-trained models.
#
# Evaulation of models is carried out using the [Language Model Evaluation Harness ](https://github.com/EleutherAI/lm-evaluation-harness) from [EleutherAI](https://www.eleuther.ai/)
#
# Models are evaluated on:
#
# * MMLU (5-shot)
# * HellaSwag (0-shot)
# * BoolQ (0-shot)
# * BBH (3-shot)
#
# The number of shots for MMLU, HellaSwag and BBH are the same as those used for comparing models in [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Map Google Drive

# %%
import shutil, os, subprocess

# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Log into HuggingFace Hub
#
# This code assumes that the user has a hugging face token setup as a notebook secret called HF_TOKEN

# %%
# Required when interacting with HuggingFace Hub
# !pip install -q --upgrade huggingface_hub

import huggingface_hub

print(f"Hugging Face Version is: {huggingface_hub.__version__}")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 8.3 MB/s eta 0:00:00
# Hugging Face Version is: 0.22.2

# %%
from google.colab import userdata

# using the HF_TOKEN secret, this has write permissions to Hugging Face
hftoken = userdata.get('HF_TOKEN')

# %%
from huggingface_hub import login

# Log into hugging face using the HF_TOKEN secrect
login(hftoken, add_to_git_credential=True)
# Out:
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ### Install Requried Libraries

# %%
# The Transformers library provides APIs and tools to easily download and train pretrained model.
# !pip install -q -U transformers -q

# Accelerate enables the same PyTorch code to be run across any distributed configuration
# !pip install -q -U accelerate -q

# an unsupervised text tokenizer and detokenizer mainly for Neural Network-based text generation systems
# !pip install sentencepiece -q

# 'bitsandbytes' includes quantization primitives for 8-bit & 4-bit operations
# !pip install bitsandbytes -q

# PEFT efficiently adapts large pretrained without fine-tuning all of a model’s parameters
# !pip install peft -q

# trl is short for Transformers Reinforcement Learning, it's used for fine-tuning transformer models using Proximal Policy Optimization.
# !pip install trl -q

# an extension of Transformers that provides a set of performance optimization tools to train and run models
# !pip install -q -U optimum

# used for monitoring the training process.
# !pip install -q -U wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 70.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 69.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 64.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 85.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 29.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 16.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 27.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 17.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 24.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.9/409.9 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 36.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 27.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.1/266.1 kB 31.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.2 MB/s eta 0:00:00

# %%
#print the version of transformers
import transformers
print(f"version of transformers: {transformers.__version__}")

# print the version of the accelerate library
import accelerate
print(f"version of accelerate: {accelerate.__version__}")
# Out:
# version of transformers: 4.39.3
# version of accelerate: 0.28.0

# %% [markdown]
# ### Log into Weights and Biases

# %%
import wandb

wandb_token = userdata.get('wandb_api')
wandb.login(key=wandb_token)
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# ### Create folder for results

# %%
# Create a directory to store results
results_dir = f"/content/drive/MyDrive/Evaluation"
os.makedirs(results_dir, exist_ok=True)

# %%
# Install LM-Eval
# !pip install git+https://github.com/EleutherAI/lm-evaluation-harness.git@big-refactor
# Out:
# Collecting git+https://github.com/EleutherAI/lm-evaluation-harness.git@big-refactor
#   Cloning https://github.com/EleutherAI/lm-evaluation-harness.git (to revision big-refactor) to /tmp/pip-req-build-aeuycbz5
#   Running command git clone --filter=blob:none --quiet https://github.com/EleutherAI/lm-evaluation-harness.git /tmp/pip-req-build-aeuycbz5
#   Running command git checkout -b big-refactor --track origin/big-refactor
#   Switched to a new branch 'big-refactor'
#   Branch 'big-refactor' set up to track remote branch 'big-refactor' from 'origin'.
#   Resolved https://github.com/EleutherAI/lm-evaluation-harness.git to commit 967eb4fa90b80ba4e8cc7a2fd171f44f0e384808
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==1.0.0) (0.28.0)
# Collecting evaluate (from lm_eval==1.0.0)
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==1.0.0) (2.18.0)
# Collecting jsonlines (from lm_eval==1.0.0)
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from lm_eval==1.0.0) (2.9.0)
# Requirement already satisfied: peft>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==1.0.0) (0.10.0)
# Collecting pybind11>=2.6.2 (from lm_eval==1.0.0)
#   Downloading pybind11-2.12.0-py3-none-any.whl (234 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.0/235.0 kB 24.4 MB/s eta 0:00:00
# Collecting pytablewriter (from lm_eval==1.0.0)
#   Downloading pytablewriter-1.2.0-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 17.0 MB/s eta 0:00:00
# Collecting rouge-score>=0.0.4 (from lm_eval==1.0.0)
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu>=1.5.0 (from lm_eval==1.0.0)
#   Downloading sacrebleu-2.4.1-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==1.0.0) (1.2.2)
# Collecting sqlitedict (from lm_eval==1.0.0)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.10/dist-packages (from lm_eval==1.0.0) (2.2.1+cu121)
# Collecting tqdm-multiprocess (from lm_eval==1.0.0)
#   Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: transformers>=4.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==1.0.0) (4.39.3)
# Collecting zstandard (from lm_eval==1.0.0)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 79.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==1.0.0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==1.0.0) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==1.0.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==1.0.0) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==1.0.0) (0.22.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==1.0.0) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm_eval==1.0.0) (3.13.3)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm_eval==1.0.0) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm_eval==1.0.0) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm_eval==1.0.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm_eval==1.0.0) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm_eval==1.0.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm_eval==1.0.0) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm_eval==1.0.0) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm_eval==1.0.0) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm_eval==1.0.0) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm_eval==1.0.0) (3.9.3)
# Collecting responses<0.19 (from evaluate->lm_eval==1.0.0)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==1.0.0) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==1.0.0) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==1.0.0) (1.16.0)
# Collecting portalocker (from sacrebleu>=1.5.0->lm_eval==1.0.0)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==1.0.0) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==1.0.0) (0.9.0)
# Collecting colorama (from sacrebleu>=1.5.0->lm_eval==1.0.0)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==1.0.0) (4.9.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==1.0.0) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==1.0.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==1.0.0) (3.4.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==1.0.0) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8->lm_eval==1.0.0) (12.4.127)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.1->lm_eval==1.0.0) (0.15.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->lm_eval==1.0.0) (23.2.0)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==1.0.0) (67.7.2)
# Collecting DataProperty<2,>=1.0.1 (from pytablewriter->lm_eval==1.0.0)
#   Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter->lm_eval==1.0.0)
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter->lm_eval==1.0.0)
#   Downloading pathvalidate-3.2.0-py3-none-any.whl (23 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter->lm_eval==1.0.0)
#   Downloading tabledata-1.3.3-py3-none-any.whl (11 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter->lm_eval==1.0.0)
#   Downloading tcolorpy-0.1.4-py3-none-any.whl (7.9 kB)
# Collecting typepy[datetime]<2,>=1.3.2 (from pytablewriter->lm_eval==1.0.0)
#   Downloading typepy-1.3.2-py3-none-any.whl (31 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm_eval==1.0.0) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm_eval==1.0.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm_eval==1.0.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm_eval==1.0.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm_eval==1.0.0) (4.0.3)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm_eval==1.0.0) (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.0.0->lm_eval==1.0.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.0.0->lm_eval==1.0.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.0.0->lm_eval==1.0.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.0.0->lm_eval==1.0.0) (2024.2.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==1.0.0) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==1.0.0) (2023.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8->lm_eval==1.0.0) (2.1.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score>=0.0.4->lm_eval==1.0.0) (8.1.7)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.0.0->lm_eval==1.0.0) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8->lm_eval==1.0.0) (1.3.0)
# Building wheels for collected packages: lm_eval, rouge-score, sqlitedict
#   Building wheel for lm_eval (pyproject.toml) ... done
#   Created wheel for lm_eval: filename=lm_eval-1.0.0-py3-none-any.whl size=995255 sha256=adf114e3bc8c3a19f7daaf8d8dc1479c83c9c560af556d3d102c2718458c005d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-foa57hi0/wheels/17/01/26/599c0779e9858a70a73fa8a306699b5b9a868f820c225457b0
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=db3f12509b7d066031e65071018ce5f03d227678e7cff9bea4aabf1835d24ed0
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16862 sha256=6cb3c9d04114c4cce8c8b683ad33c0b7dda4ed4e09462f2cea925747a9058f48
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
# Successfully built lm_eval rouge-score sqlitedict
# Installing collected packages: sqlitedict, zstandard, tcolorpy, pybind11, portalocker, pathvalidate, mbstrdecoder, jsonlines, colorama, typepy, tqdm-multiprocess, sacrebleu, rouge-score, responses, DataProperty, tabledata, evaluate, pytablewriter, lm_eval
# Successfully installed DataProperty-1.0.1 colorama-0.4.6 evaluate-0.4.1 jsonlines-4.0.0 lm_eval-1.0.0 mbstrdecoder-1.1.3 pathvalidate-3.2.0 portalocker-2.8.2 pybind11-2.12.0 pytablewriter-1.2.0 responses-0.18.0 rouge-score-0.1.2 sacrebleu-2.4.1 sqlitedict-2.1.0 tabledata-1.3.3 tcolorpy-0.1.4 tqdm-multiprocess-0.0.11 typepy-1.3.2 zstandard-0.22.0

# %% [markdown]
# ### Import libraries

# %%
# !python3 -c "import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))"
# Out:
# 2024-04-04 12:08:58.543062: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-04 12:08:58.543115: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-04 12:08:58.544933: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-04 12:08:59.586177: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.15.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, ml-dtypes, numpy, opt-einsum, packaging, protobuf, setuptools, six, tensorboard, tensorflow-estimator, tensorflow-io-gcs-filesystem, termcolor, typing-extensions, wrapt
# Required-by: dopamine-rl, tf_keras

# %%
# for interacting with the operating system.
import os

# torch is the main package of PyTorch.
import torch

# Allows loading and preprocessing datasets from the Hugging Face Hub.
from datasets import load_dataset

from transformers import (
    AutoModelForCausalLM, # Generic model class with a causal language modeling head
    AutoTokenizer,# Automatically selects correct tokenizer for a model.
    BitsAndBytesConfig, # Used to configure a BitsAndBytes model.
    HfArgumentParser, # used for parsing command-line arguments.
    TrainingArguments, # defines the arguments used during training.
    pipeline, # Creates a pipeline that applies a model to some input data.
    logging, # Logs events during training and evaluation.
    AutoModelForQuestionAnswering # Used to get a model to perform context-based question answering etc…
)

# used for Parameter-Efficient Fine-Tuning
from peft import LoraConfig, PeftModel

# install SFTTrainer
from trl import SFTTrainer

# allows addition of progress bars to loops and iterable objects
from tqdm import tqdm

# %% [markdown]
# ### Install lm-eval

# %%
# !git clone https://github.com/EleutherAI/lm-evaluation-harness
# !cd lm-evaluation-harness
# Out:
# Cloning into 'lm-evaluation-harness'...
# remote: Enumerating objects: 32695, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 32695 (delta 31), reused 53 (delta 17), pack-reused 32620
# Receiving objects: 100% (32695/32695), 22.81 MiB | 14.86 MiB/s, done.
# Resolving deltas: 100% (22840/22840), done.

# %%
import os

# change directory
os.chdir("lm-evaluation-harness")

# %%
import os
import glob

# get current working dirctory and list files
print(f"current directory is: {os.getcwd()}\n")
# print(os.listdir('.'))

# Get a list of all files and directories in the current directory
files = glob.glob('./*')

# Create a list of tuples, each containing the name of the file/directory and its last modification time
files_with_times = [(file, os.path.getmtime(file)) for file in files]

# Sort the list by the modification time (the second element of each tuple)
files_with_times.sort(key=lambda x: x[1])

# Print the sorted list
print("Files in current directory:")
for file, mtime in files_with_times:
    print(f'{file}: {mtime}')
# Out:
# current directory is: /content/lm-evaluation-harness
#
# Files in current directory:
# ./CITATION.bib: 1712232555.0523531
# ./CODEOWNERS: 1712232555.0523531
# ./LICENSE.md: 1712232555.0523531
# ./README.md: 1712232555.0533533
# ./docs: 1712232555.0553534
# ./examples: 1712232555.0563533
# ./ignore.txt: 1712232555.0563533
# ./pyproject.toml: 1712232555.168361
# ./pile_statistics.json: 1712232555.168361
# ./lm_eval: 1712232555.168361
# ./requirements.txt: 1712232555.168361
# ./mypy.ini: 1712232555.168361
# ./setup.py: 1712232555.170361
# ./scripts: 1712232555.170361
# ./templates: 1712232555.170361
# ./tests: 1712232555.199363

# %%
# !pip install -r requirements.txt
# Out:
# Obtaining file:///content/lm-evaluation-harness (from -r requirements.txt (line 1))
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (0.28.0)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (2.9.0)
# Requirement already satisfied: peft>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: pybind11>=2.6.2 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (2.12.0)
# Requirement already satisfied: pytablewriter in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: rouge-score>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: sacrebleu>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: sqlitedict in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (2.2.1+cu121)
# Requirement already satisfied: tqdm-multiprocess in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (0.0.11)
# Requirement already satisfied: transformers>=4.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (4.39.3)
# Requirement already satisfied: zstandard in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (0.22.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (0.3.8)
# Collecting word2number (from lm_eval==0.4.2->-r requirements.txt (line 1))
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.2->-r requirements.txt (line 1)) (10.1.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (0.22.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (3.13.3)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (3.9.3)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from evaluate->lm_eval==0.4.2->-r requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.2->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.2->-r requirements.txt (line 1)) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.2->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (4.9.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.2->-r requirements.txt (line 1)) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.2->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.2->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.1->lm_eval==0.4.2->-r requirements.txt (line 1)) (0.15.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->lm_eval==0.4.2->-r requirements.txt (line 1)) (23.2.0)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.2->-r requirements.txt (line 1)) (67.7.2)
# Requirement already satisfied: DataProperty<2,>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.2->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: mbstrdecoder<2,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.2->-r requirements.txt (line 1)) (1.1.3)
# Requirement already satisfied: pathvalidate<4,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.2->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: tabledata<2,>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.2->-r requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: tcolorpy<1,>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.2->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: typepy[datetime]<2,>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.2->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm_eval==0.4.2->-r requirements.txt (line 1)) (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (2024.2.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.2->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.2->-r requirements.txt (line 1)) (2023.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score>=0.0.4->lm_eval==0.4.2->-r requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->lm_eval==0.4.2->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8->lm_eval==0.4.2->-r requirements.txt (line 1)) (1.3.0)
# Building wheels for collected packages: lm_eval, word2number
#   Building editable for lm_eval (pyproject.toml) ... done
#   Created wheel for lm_eval: filename=lm_eval-0.4.2-0.editable-py3-none-any.whl size=16122 sha256=d7992e6c42c95373e853f0b15763ea60c43adbb92d67297b3e2611d2c491950d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2cr0vmdy/wheels/dc/8d/a0/ce1a137b6a29fcf5007da91566ee423695e01d20703991091d
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5566 sha256=216a094d607f49816b817348cc2dab0499acfbed08e2e8faae041eae833e3bdb
#   Stored in directory: /root/.cache/pip/wheels/84/ff/26/d3cfbd971e96c5aa3737ecfced81628830d7359b55fbb8ca3b
# Successfully built lm_eval word2number
# Installing collected packages: word2number, lm_eval
#   Attempting uninstall: lm_eval
#     Found existing installation: lm_eval 1.0.0
#     Uninstalling lm_eval-1.0.0:
#       Successfully uninstalled lm_eval-1.0.0
# Successfully installed lm_eval-0.4.2 word2number-1.1

# %%
from lm_eval import api
# Out:
# Downloading builder script:   0%|          | 0.00/5.67k [00:00<?, ?B/s]

# %% [markdown]
# ### Install auto-gptq

# %%
# !pip install -U -q auto-gptq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 60.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 97.4 MB/s eta 0:00:00

# %% [markdown]
# ### Install autoawq

# %%
# !pip install autoawq
# Out:
# Collecting autoawq
#   Downloading autoawq-0.2.4-cp310-cp310-manylinux2014_x86_64.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.2.1+cu121)
# Collecting transformers<=4.38.2,>=4.35.0 (from autoawq)
#   Downloading transformers-4.38.2-py3-none-any.whl (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 82.6 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.15.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from autoawq) (4.10.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.28.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.18.0)
# Requirement already satisfied: zstandard in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.22.0)
# Collecting autoawq-kernels (from autoawq)
#   Downloading autoawq_kernels-0.0.6-cp310-cp310-manylinux2014_x86_64.whl (33.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.4/33.4 MB 48.6 MB/s eta 0:00:00
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.12.1->autoawq) (0.22.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.13.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.1->autoawq) (12.4.127)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.38.2,>=4.35.0->autoawq) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->autoawq) (5.9.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (2.0.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.38.2,>=4.35.0->autoawq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.38.2,>=4.35.0->autoawq) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.38.2,>=4.35.0->autoawq) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<=4.38.2,>=4.35.0->autoawq) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.1->autoawq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.0.1->autoawq) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->autoawq) (1.16.0)
# Installing collected packages: transformers, autoawq-kernels, autoawq
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.39.3
#     Uninstalling transformers-4.39.3:
#       Successfully uninstalled transformers-4.39.3
# Successfully installed autoawq-0.2.4 autoawq-kernels-0.0.6 transformers-4.38.2

# %% [markdown]
# ### lm_eval Help

# %%
# !lm_eval --help
# Out:
# 2024-04-04 12:09:59.369821: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-04 12:09:59.369881: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-04 12:09:59.371431: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-04 12:10:00.628146: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# usage: lm_eval [-h] [--model MODEL] [--tasks task1,task2] [--model_args MODEL_ARGS]
#                [--num_fewshot N] [--batch_size auto|auto:N|N] [--max_batch_size N]
#                [--device DEVICE] [--output_path DIR|DIR/file.json] [--limit N|0<N<1]
#                [--use_cache DIR] [--cache_requests {true,refresh,delete}] [--check_integrity]
#                [--write_out] [--log_samples] [--show_config] [--include_path DIR]
#                [--gen_kwargs GEN_KWARGS] [--verbosity CRITICAL|ERROR|WARNING|INFO|DEBUG]
#                [--wandb_args WANDB_ARGS] [--predict_only] [--seed SEED] [--trust_remote_code]
#
# options:
#   -h, --help            show this help message and exit
#   --model MODEL, -m MODEL
#                         Name of model e.g. `hf`
#   --tasks task1,task2, -t task1,task2
#                         To get full list of tasks, use the command lm-eval --tasks list
#   --model_args MODEL_ARGS, -a MODEL_ARGS
#                         Comma separated string arguments for model, e.g. `pretrained=EleutherAI/pythia-160m,dtype=float32`
#   --num_fewshot N, -f N
#                         Number of examples in few-shot context
#   --batch_size auto|auto:N|N, -b auto|auto:N|N
#                         Acceptable values are 'auto', 'auto:N' or N, where N is an integer. Default 1.
#   --max_batch_size N    Maximal batch size to try with --batch_size auto.
#   --device DEVICE       Device to use (e.g. cuda, cuda:0, cpu).
#   --output_path DIR|DIR/file.json, -o DIR|DIR/file.json
#                         The path to the output file where the result metrics will be saved. If the path is a directory and log_samples is true, the results will be saved in the directory. Else the parent directory will be used.
#   --limit N|0<N<1, -L N|0<N<1
#                         Limit the number of examples per task. If <1, limit is a percentage of the total number of examples.
#   --use_cache DIR, -c DIR
#                         A path to a sqlite db file for caching model responses. `None` if not caching.
#   --cache_requests {true,refresh,delete}
#                         Speed up evaluation by caching the building of dataset requests. `None` if not caching.
#   --check_integrity     Whether to run the relevant part of the test suite for the tasks.
#   --write_out, -w       Prints the prompt for the first few documents.
#   --log_samples, -s     If True, write out all model outputs and documents for per-sample measurement and post-hoc analysis. Use with --output_path.
#   --show_config         If True, shows the the full config of all tasks at the end of the evaluation.
#   --include_path DIR    Additional path to include if there are external tasks to include.
#   --gen_kwargs GEN_KWARGS
#                         String arguments for model generation on greedy_until tasks, e.g. `temperature=0,top_k=0,top_p=0`.
#   --verbosity CRITICAL|ERROR|WARNING|INFO|DEBUG, -v CRITICAL|ERROR|WARNING|INFO|DEBUG
#                         Controls the reported logging error level. Set to DEBUG when testing + adding new task configurations for comprehensive log output.
#   --wandb_args WANDB_ARGS
#                         Comma separated string arguments passed to wandb.init, e.g. `project=lm-eval,job_type=eval
#   --predict_only, -x    Use with --log_samples. Only model outputs will be saved and metrics will not be evaluated.
#   --seed SEED           Set seed for python's random, numpy and torch.
#                         Accepts a comma-separated list of 3 values for python's random, numpy, and torch seeds, respectively, or a single integer to set the same seed for all three.
#                         The values are either an integer or 'None' to not set the seed. Default is `0,1234,1234` (for backward compatibility).
#                         E.g. `--seed 0,None,8` sets `random.seed(0)` and `torch.manual_seed(8)`. Here numpy's seed is not set since the second value is `None`.
#                         E.g, `--seed 42` sets all three seeds to 42.
#   --trust_remote_code   Sets trust_remote_code to True to execute code to create HF Datasets from the Hub

# %% [markdown]
# ## NF4 Evaluation

# %% [markdown]
# ### Evaluate Llama2-7b-chat-HF-NF4

# %% [markdown]
# #### MMLU
#
# 5-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
eval_model = "twhoool02/Llama2-7b-chat-HF-NF4"

# create directory to store results
results_dir = f"/content/drive/MyDrive/Evaluation/{eval_model}"
os.makedirs(results_dir, exist_ok=True)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Llama2-7b-chat-HF-NF4,trust_remote_code=True,do_sample=True \
    --tasks mmlu_stem,mmlu_social_sciences,mmlu_humanities,mmlu_other \
    --num_fewshot 5 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Llama2-7b-chat-HF-NF4-MMLU
# Out:
# 2024-03-27 19:04:03.632021: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-27 19:04:03.632068: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-27 19:04:03.633267: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-27 19:04:04.854018: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240327_190410-8xjx900a
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Llama2-7b-chat-HF-NF4-MMLU
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/8xjx900a/workspace
# 2024-03-27:19:04:11,684 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-27:19:04:17,708 INFO     [__main__.py:335] Selected Tasks: ['mmlu_humanities', 'mmlu_other', 'mmlu_social_sciences', 'mmlu_stem']
# 2024-03-27:19:04:17,709 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-27:19:04:17,709 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Llama2-7b-chat-HF-NF4', 'trust_remote_code': True, 'do_sample': True}
# 2024-03-27:19:04:17,713 INFO     [huggingface.py:163] Using device 'cuda:0'
# config.json: 100% 1.17k/1.17k [00:00<00:00, 3.81MB/s]
# model.safetensors: 100% 3.87G/3.87G [03:04<00:00, 21.0MB/s]
# generation_config.json: 100% 183/183 [00:00<00:00, 700kB/s]
# 2024-03-27:19:07:27,663 WARNING  [big_modeling.py:448] You shouldn't move a model that is dispatched using accelerate hooks.
# tokenizer_config.json: 100% 1.76k/1.76k [00:00<00:00, 6.32MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 11.7MB/s]
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 6.97MB/s]
# special_tokens_map.json: 100% 437/437 [00:00<00:00, 1.34MB/s]
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 5.86k/5.86k [00:00<00:00, 11.1MB/s]
# Downloading readme: 100% 1.11k/1.11k [00:00<00:00, 3.92MB/s]
# Downloading data: 100% 166M/166M [00:01<00:00, 93.5MB/s]
# Generating test split: 237 examples [00:00, 1944.36 examples/s]
# Generating validation split: 26 examples [00:00, 3539.84 examples/s]
# Generating dev split: 5 examples [00:00, 50.69 examples/s]
# Generating test split: 1534 examples [00:00, 8151.34 examples/s]
# Generating validation split: 170 examples [00:00, 10709.24 examples/s]
# Generating dev split: 5 examples [00:00, 58.03 examples/s]
# Generating test split: 108 examples [00:00, 1254.06 examples/s]
# Generating validation split: 11 examples [00:00, 1913.22 examples/s]
# Generating dev split: 5 examples [00:00, 56.24 examples/s]
# Generating test split: 346 examples [00:00, 3308.09 examples/s]
# Generating validation split: 38 examples [00:00, 5107.46 examples/s]
# Generating dev split: 5 examples [00:00, 58.83 examples/s]
# Generating test split: 324 examples [00:00, 3144.55 examples/s]
# Generating validation split: 35 examples [00:00, 5397.08 examples/s]
# Generating dev split: 5 examples [00:00, 59.07 examples/s]
# Generating test split: 311 examples [00:00, 3218.14 examples/s]
# Generating validation split: 34 examples [00:00, 7546.11 examples/s]
# Generating dev split: 5 examples [00:00, 60.42 examples/s]
# Generating test split: 171 examples [00:00, 1886.85 examples/s]
# Generating validation split: 19 examples [00:00, 4174.75 examples/s]
# Generating dev split: 5 examples [00:00, 57.92 examples/s]
# Generating test split: 204 examples [00:00, 2040.06 examples/s]
# Generating validation split: 22 examples [00:00, 3167.79 examples/s]
# Generating dev split: 5 examples [00:00, 57.81 examples/s]
# Generating test split: 165 examples [00:00, 1782.15 examples/s]
# Generating validation split: 18 examples [00:00, 2853.81 examples/s]
# Generating dev split: 5 examples [00:00, 60.01 examples/s]
# Generating test split: 163 examples [00:00, 1893.05 examples/s]
# Generating validation split: 18 examples [00:00, 3614.05 examples/s]
# Generating dev split: 5 examples [00:00, 60.70 examples/s]
# Generating test split: 126 examples [00:00, 1393.54 examples/s]
# Generating validation split: 14 examples [00:00, 3240.27 examples/s]
# Generating dev split: 5 examples [00:00, 58.46 examples/s]
# Generating test split: 121 examples [00:00, 1363.23 examples/s]
# Generating validation split: 13 examples [00:00, 2981.68 examples/s]
# Generating dev split: 5 examples [00:00, 59.49 examples/s]
# Generating test split: 895 examples [00:00, 6762.33 examples/s]
# Generating validation split: 100 examples [00:00, 10844.44 examples/s]
# Generating dev split: 5 examples [00:00, 59.67 examples/s]
# Generating test split: 100 examples [00:00, 1094.36 examples/s]
# Generating validation split: 11 examples [00:00, 3063.16 examples/s]
# Generating dev split: 5 examples [00:00, 57.41 examples/s]
# Generating test split: 306 examples [00:00, 3140.93 examples/s]
# Generating validation split: 33 examples [00:00, 5686.84 examples/s]
# Generating dev split: 5 examples [00:00, 58.36 examples/s]
# Generating test split: 272 examples [00:00, 2702.71 examples/s]
# Generating validation split: 31 examples [00:00, 5025.84 examples/s]
# Generating dev split: 5 examples [00:00, 59.10 examples/s]
# Generating test split: 234 examples [00:00, 2513.16 examples/s]
# Generating validation split: 25 examples [00:00, 4430.91 examples/s]
# Generating dev split: 5 examples [00:00, 59.89 examples/s]
# Generating test split: 100 examples [00:00, 1200.98 examples/s]
# Generating validation split: 10 examples [00:00, 2907.46 examples/s]
# Generating dev split: 5 examples [00:00, 58.45 examples/s]
# Generating test split: 103 examples [00:00, 1193.96 examples/s]
# Generating validation split: 11 examples [00:00, 2379.19 examples/s]
# Generating dev split: 5 examples [00:00, 58.16 examples/s]
# Generating test split: 783 examples [00:00, 6248.77 examples/s]
# Generating validation split: 86 examples [00:00, 11556.78 examples/s]
# Generating dev split: 5 examples [00:00, 58.72 examples/s]
# Generating test split: 100 examples [00:00, 1161.95 examples/s]
# Generating validation split: 11 examples [00:00, 3618.05 examples/s]
# Generating dev split: 5 examples [00:00, 60.06 examples/s]
# Generating test split: 282 examples [00:00, 2835.75 examples/s]
# Generating validation split: 31 examples [00:00, 4349.19 examples/s]
# Generating dev split: 5 examples [00:00, 59.73 examples/s]
# Generating test split: 223 examples [00:00, 2391.32 examples/s]
# Generating validation split: 23 examples [00:00, 4199.05 examples/s]
# Generating dev split: 5 examples [00:00, 58.37 examples/s]
# Generating test split: 173 examples [00:00, 1934.37 examples/s]
# Generating validation split: 22 examples [00:00, 4956.21 examples/s]
# Generating dev split: 5 examples [00:00, 59.03 examples/s]
# Generating test split: 166 examples [00:00, 1905.58 examples/s]
# Generating validation split: 18 examples [00:00, 3651.63 examples/s]
# Generating dev split: 5 examples [00:00, 58.58 examples/s]
# Generating test split: 265 examples [00:00, 2715.30 examples/s]
# Generating validation split: 29 examples [00:00, 5595.24 examples/s]
# Generating dev split: 5 examples [00:00, 59.08 examples/s]
# Generating test split: 110 examples [00:00, 1254.67 examples/s]
# Generating validation split: 12 examples [00:00, 2403.84 examples/s]
# Generating dev split: 5 examples [00:00, 59.12 examples/s]
# Generating test split: 545 examples [00:00, 4982.44 examples/s]
# Generating validation split: 60 examples [00:00, 7482.92 examples/s]
# Generating dev split: 5 examples [00:00, 59.07 examples/s]
# Generating test split: 198 examples [00:00, 2051.22 examples/s]
# Generating validation split: 22 examples [00:00, 5821.38 examples/s]
# Generating dev split: 5 examples [00:00, 57.92 examples/s]
# Generating test split: 245 examples [00:00, 2581.75 examples/s]
# Generating validation split: 27 examples [00:00, 3543.48 examples/s]
# Generating dev split: 5 examples [00:00, 56.82 examples/s]
# Generating test split: 612 examples [00:00, 5223.37 examples/s]
# Generating validation split: 69 examples [00:00, 7754.95 examples/s]
# Generating dev split: 5 examples [00:00, 58.96 examples/s]
# Generating test split: 238 examples [00:00, 2532.91 examples/s]
# Generating validation split: 26 examples [00:00, 4370.82 examples/s]
# Generating dev split: 5 examples [00:00, 60.16 examples/s]
# Generating test split: 114 examples [00:00, 1315.69 examples/s]
# Generating validation split: 12 examples [00:00, 3100.00 examples/s]
# Generating dev split: 5 examples [00:00, 59.48 examples/s]
# Generating test split: 131 examples [00:00, 1482.05 examples/s]
# Generating validation split: 12 examples [00:00, 2587.48 examples/s]
# Generating dev split: 5 examples [00:00, 58.69 examples/s]
# Generating test split: 193 examples [00:00, 2158.92 examples/s]
# Generating validation split: 21 examples [00:00, 4801.33 examples/s]
# Generating dev split: 5 examples [00:00, 58.56 examples/s]
# Generating test split: 390 examples [00:00, 3916.83 examples/s]
# Generating validation split: 43 examples [00:00, 6956.00 examples/s]
# Generating dev split: 5 examples [00:00, 59.98 examples/s]
# Generating test split: 100 examples [00:00, 1112.17 examples/s]
# Generating validation split: 11 examples [00:00, 2630.86 examples/s]
# Generating dev split: 5 examples [00:00, 56.85 examples/s]
# Generating test split: 201 examples [00:00, 2222.53 examples/s]
# Generating validation split: 22 examples [00:00, 3509.61 examples/s]
# Generating dev split: 5 examples [00:00, 58.90 examples/s]
# Generating test split: 310 examples [00:00, 3120.00 examples/s]
# Generating validation split: 32 examples [00:00, 6599.68 examples/s]
# Generating dev split: 5 examples [00:00, 58.43 examples/s]
# Generating test split: 112 examples [00:00, 1194.06 examples/s]
# Generating validation split: 11 examples [00:00, 3093.14 examples/s]
# Generating dev split: 5 examples [00:00, 59.14 examples/s]
# Generating test split: 100 examples [00:00, 1117.14 examples/s]
# Generating validation split: 11 examples [00:00, 2020.91 examples/s]
# Generating dev split: 5 examples [00:00, 57.48 examples/s]
# Generating test split: 235 examples [00:00, 2429.40 examples/s]
# Generating validation split: 26 examples [00:00, 6170.19 examples/s]
# Generating dev split: 5 examples [00:00, 57.27 examples/s]
# Generating test split: 102 examples [00:00, 1145.13 examples/s]
# Generating validation split: 11 examples [00:00, 3185.84 examples/s]
# Generating dev split: 5 examples [00:00, 59.54 examples/s]
# Generating test split: 216 examples [00:00, 2259.25 examples/s]
# Generating validation split: 23 examples [00:00, 4810.46 examples/s]
# Generating dev split: 5 examples [00:00, 58.52 examples/s]
# Generating test split: 144 examples [00:00, 1676.01 examples/s]
# Generating validation split: 16 examples [00:00, 2731.89 examples/s]
# Generating dev split: 5 examples [00:00, 59.10 examples/s]
# Generating test split: 100 examples [00:00, 997.76 examples/s]
# Generating validation split: 11 examples [00:00, 2581.11 examples/s]
# Generating dev split: 5 examples [00:00, 58.44 examples/s]
# Generating test split: 152 examples [00:00, 1756.22 examples/s]
# Generating validation split: 16 examples [00:00, 4848.56 examples/s]
# Generating dev split: 5 examples [00:00, 57.81 examples/s]
# Generating test split: 100 examples [00:00, 1164.21 examples/s]
# Generating validation split: 11 examples [00:00, 2564.33 examples/s]
# Generating dev split: 5 examples [00:00, 59.38 examples/s]
# Generating test split: 100 examples [00:00, 1160.38 examples/s]
# Generating validation split: 9 examples [00:00, 2750.36 examples/s]
# Generating dev split: 5 examples [00:00, 58.04 examples/s]
# Generating test split: 145 examples [00:00, 1649.85 examples/s]
# Generating validation split: 16 examples [00:00, 3623.59 examples/s]
# Generating dev split: 5 examples [00:00, 57.35 examples/s]
# Generating test split: 203 examples [00:00, 2043.71 examples/s]
# Generating validation split: 22 examples [00:00, 3806.40 examples/s]
# Generating dev split: 5 examples [00:00, 59.16 examples/s]
# Generating test split: 270 examples [00:00, 2871.71 examples/s]
# Generating validation split: 29 examples [00:00, 6359.66 examples/s]
# Generating dev split: 5 examples [00:00, 58.31 examples/s]
# Generating test split: 151 examples [00:00, 1671.29 examples/s]
# Generating validation split: 17 examples [00:00, 3485.86 examples/s]
# Generating dev split: 5 examples [00:00, 58.23 examples/s]
# Generating test split: 100 examples [00:00, 1139.67 examples/s]
# Generating validation split: 8 examples [00:00, 1472.46 examples/s]
# Generating dev split: 5 examples [00:00, 57.82 examples/s]
# Generating test split: 378 examples [00:00, 3649.15 examples/s]
# Generating validation split: 41 examples [00:00, 6021.45 examples/s]
# Generating dev split: 5 examples [00:00, 59.30 examples/s]
# Generating test split: 135 examples [00:00, 1568.47 examples/s]
# Generating validation split: 14 examples [00:00, 4197.30 examples/s]
# Generating dev split: 5 examples [00:00, 61.39 examples/s]
# Generating test split: 100 examples [00:00, 1175.05 examples/s]
# Generating validation split: 11 examples [00:00, 2834.16 examples/s]
# Generating dev split: 5 examples [00:00, 58.19 examples/s]
# 2024-03-27:19:12:29,677 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 5
# 2024
Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:02<00:00, 65.80it/s]
# 2024-03-27:19:12:57,722 INFO     [task.py:395] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:01<00:00, 65.80it/s]
# 2024-03-27:19:12:59,247 INFO     [task.py:395] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:02<00:00, 65.32it/s]
# 2024-03-27:19:13:01,459 INFO     [task.py:395] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:03<00:00, 66.03it/s]
# 2024-03-27:19:13:04,742 INFO     [task.py:395] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:01<00:00, 66.85it/s]
# 2024-03-27:19:13:06,273 INFO     [task.py:395] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:03<00:00, 66.43it/s]
# 2024-03-27:19:13:09,822 INFO     [task.py:395] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 65.56it/s]
# 2024-03-27:19:13:11,353 INFO     [task.py:395] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:01<00:00, 64.89it/s]
# 2024-03-27:19:13:13,085 INFO     [task.py:395] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:04<00:00, 65.40it/s]
# 2024-03-27:19:13:17,841 INFO     [task.py:395] Building contexts for mmlu_sociology on rank 0...
# 100% 201/201 [00:03<00:00, 66.18it/s]
# 2024-03-27:19:13:20,889 INFO     [task.py:395] Building contexts for mmlu_us_foreign_policy on rank 0...
# 100% 100/100 [00:01<00:00, 66.76it/s]
# 2024-03-27:19:13:22,392 INFO     [task.py:395] Building contexts for mmlu_high_school_macroeconomics on rank 0...
# 100% 390/390 [00:05<00:00, 66.37it/s]
# 2024-03-27:19:13:28,286 INFO     [task.py:395] Building contexts for mmlu_high_school_government_and_politics on rank 0...
# 100% 193/193 [00:02<00:00, 65.64it/s]
# 2024-03-27:19:13:31,236 INFO     [task.py:395] Building contexts for mmlu_human_sexuality on rank 0...
# 100% 131/131 [00:01<00:00, 65.79it/s]
# 2024-03-27:19:13:33,235 INFO     [task.py:395] Building contexts for mmlu_econometrics on rank 0...
# 100% 114/114 [00:01<00:00, 66.06it/s]
# 2024-03-27:19:13:34,967 INFO     [task.py:395] Building contexts for mmlu_high_school_microeconomics on rank 0...
# 100% 238/238 [00:03<00:00, 64.95it/s]
# 2024-03-27:19:13:38,643 INFO     [task.py:395] Building contexts for mmlu_professional_psychology on rank 0...
# 100% 612/612 [00:09<00:00, 66.13it/s]
# 2024-03-27:19:13:47,926 INFO     [task.py:395] Building contexts for mmlu_security_studies on rank 0...
# 100% 245/245 [00:03<00:00, 64.95it/s]
# 2024-03-27:19:13:51,711 INFO     [task.py:395] Building contexts for mmlu_high_school_geography on rank 0...
# 100% 198/198 [00:03<00:00, 65.91it/s]
# 2024-03-27:19:13:54,725 INFO     [task.py:395] Building contexts for mmlu_high_school_psychology on rank 0...
# 100% 545/545 [00:08<00:00, 65.56it/s]
# 2024-03-27:19:14:03,064 INFO     [task.py:395] Building contexts for mmlu_public_relations on rank 0...
# 100% 110/110 [00:01<00:00, 66.61it/s]
# 2024-03-27:19:14:04,721 INFO     [task.py:395] Building contexts for mmlu_clinical_knowledge on rank 0...
# 100% 265/265 [00:03<00:00, 66.34it/s]
# 2024-03-27:19:14:08,728 INFO     [task.py:395] Building contexts for mmlu_virology on rank 0...
# 100% 166/166 [00:02<00:00, 65.66it/s]
# 2024-03-27:19:14:11,265 INFO     [task.py:395] Building contexts for mmlu_college_medicine on rank 0...
# 100% 173/173 [00:02<00:00, 64.75it/s]
# 2024-03-27:19:14:13,946 INFO     [task.py:395] Building contexts for mmlu_human_aging on rank 0...
# 100% 223/223 [00:03<00:00, 65.60it/s]
# 2024-03-27:19:14:17,357 INFO     [task.py:395] Building contexts for mmlu_professional_accounting on rank 0...
# 100% 282/282 [00:04<00:00, 65.92it/s]
# 2024-03-27:19:14:21,649 INFO     [task.py:395] Building contexts for mmlu_medical_genetics on rank 0...
# 100% 100/100 [00:01<00:00, 66.23it/s]
# 2024-03-27:19:14:23,165 INFO     [task.py:395] Building contexts for mmlu_miscellaneous on rank 0...
# 100% 783/783 [00:11<00:00, 65.80it/s]
# 2024-03-27:19:14:35,100 INFO     [task.py:395] Building contexts for mmlu_management on rank 0...
# 100% 103/103 [00:01<00:00, 64.21it/s]
# 2024-03-27:19:14:36,710 INFO     [task.py:395] Building contexts for mmlu_global_facts on rank 0...
# 100% 100/100 [00:01<00:00, 64.58it/s]
# 2024-03-27:19:14:38,265 INFO     [task.py:395] Building contexts for mmlu_marketing on rank 0...
# 100% 234/234 [00:03<00:00, 65.79it/s]
# 2024-03-27:19:14:41,833 INFO     [task.py:395] Building contexts for mmlu_professional_medicine on rank 0...
# 100% 272/272 [00:04<00:00, 66.20it/s]
# 2024-03-27:19:14:45,956 INFO     [task.py:395] Building contexts for mmlu_nutrition on rank 0...
# 100% 306/306 [00:04<00:00, 65.42it/s]
# 2024-03-27:19:14:50,648 INFO     [task.py:395] Building contexts for mmlu_business_ethics on rank 0...
# 100% 100/100 [00:01<00:00, 52.44it/s]
# 2024-03-27:19:14:52,560 INFO     [task.py:395] Building contexts for mmlu_moral_scenarios on rank 0...
# 100% 895/895 [00:13<00:00, 65.13it/s]
# 2024-03-27:19:15:06,343 INFO     [task.py:395] Building contexts for mmlu_international_law on rank 0...
# 100% 121/121 [00:01<00:00, 66.07it/s]
# 2024-03-27:19:15:08,181 INFO     [task.py:395] Building contexts for mmlu_formal_logic on rank 0...
# 100% 126/126 [00:01<00:00, 64.91it/s]
# 2024-03-27:19:15:10,129 INFO     [task.py:395] Building contexts for mmlu_logical_fallacies on rank 0...
# 100% 163/163 [00:02<00:00, 64.27it/s]
# 2024-03-27:19:15:12,674 INFO     [task.py:395] Building contexts for mmlu_high_school_european_history on rank 0...
# 100% 165/165 [00:02<00:00, 65.22it/s]
# 2024-03-27:19:15:15,213 INFO     [task.py:395] Building contexts for mmlu_high_school_us_history on rank 0...
# 100% 204/204 [00:03<00:00, 65.66it/s]
# 2024-03-27:19:15:18,331 INFO     [task.py:395] Building contexts for mmlu_world_religions on rank 0...
# 100% 171/171 [00:02<00:00, 65.79it/s]
# 2024-03-27:19:15:20,939 INFO     [task.py:395] Building contexts for mmlu_philosophy on rank 0...
# 100% 311/311 [00:04<00:00, 65.91it/s]
# 2024-03-27:19:15:25,673 INFO     [task.py:395] Building contexts for mmlu_prehistory on rank 0...
# 100% 324/324 [00:04<00:00, 65.88it/s]
# 2024-03-27:19:15:30,607 INFO     [task.py:395] Building contexts for mmlu_moral_disputes on rank 0...
# 100% 346/346 [00:05<00:00, 65.26it/s]
# 2024-03-27:19:15:35,925 INFO     [task.py:395] Building contexts for mmlu_jurisprudence on rank 0...
# 100% 108/108 [00:01<00:00, 64.12it/s]
# 2024-03-27:19:15:37,616 INFO     [task.py:395] Building contexts for mmlu_professional_law on rank 0...
# 100% 1534/1534 [00:23<00:00, 65.18it/s]
# 2024-03-27:19:16:01,220 INFO     [task.py:395] Building contexts for mmlu_high_school_world_history on rank 0...
# 100% 237/237 [00:03<00:00, 65.54it/s]
# 2024-03-27:19:16:04,850 INFO     [evaluator.py:379] Running loglikelihood requests
# Running loglikelihood requests:   0% 0/56168 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 8
# Running loglikelihood requests:  25% 13953/56168 [09:10<11:44, 59.93it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Running loglikelihood requests:  25% 13984/56168 [09:21<11:43, 59.93it/s]Determined largest batch size: 32
# Running loglikelihood requests:  50% 27825/56168 [12:37<05:44, 82.33it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 32
# Running loglikelihood requests:  75% 41985/56168 [15:22<02:13, 106.04it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests: 100% 56168/56168 [17:21<00:00, 53.92it/s]
# hf (pretrained=twhoool02/Llama2-7b-chat-HF-NF4,trust_remote_code=True,do_sample=True), gen_kwargs: (None), limit: None, num_fewshot: 5, batch_size: auto:4 (8,32,32,64,64)
# |                Tasks                 |Version|Filter|n-shot|Metric|Value |   |Stderr|
# |--------------------------------------|-------|------|-----:|------|-----:|---|-----:|
# |stem                                  |N/A    |none  |     5|acc   |0.3650|±  |0.0084|
# | - abstract_algebra                   |      0|none  |     5|acc   |0.2900|±  |0.0456|
# | - anatomy                            |      0|none  |     5|acc   |0.4148|±  |0.0426|
# | - astronomy                          |      0|none  |     5|acc   |0.4605|±  |0.0406|
# | - college_biology                    |      0|none  |     5|acc   |0.4861|±  |0.0418|
# | - college_chemistry                  |      0|none  |     5|acc   |0.2700|±  |0.0446|
# | - college_computer_science           |      0|none  |     5|acc   |0.3800|±  |0.0488|
# | - college_mathematics                |      0|none  |     5|acc   |0.3500|±  |0.0479|
# | - college_physics                    |      0|none  |     5|acc   |0.2255|±  |0.0416|
# | - computer_security                  |      0|none  |     5|acc   |0.5700|±  |0.0498|
# | - conceptual_physics                 |      0|none  |     5|acc   |0.3915|±  |0.0319|
# | - electrical_engineering             |      0|none  |     5|acc   |0.4138|±  |0.0410|
# | - elementary_mathematics             |      0|none  |     5|acc   |0.2910|±  |0.0234|
# | - high_school_biology                |      0|none  |     5|acc   |0.5000|±  |0.0284|
# | - high_school_chemistry              |      0|none  |     5|acc   |0.3645|±  |0.0339|
# | - high_school_computer_science       |      0|none  |     5|acc   |0.4100|±  |0.0494|
# | - high_school_mathematics            |      0|none  |     5|acc   |0.2481|±  |0.0263|
# | - high_school_physics                |      0|none  |     5|acc   |0.2848|±  |0.0368|
# | - high_school_statistics             |      0|none  |     5|acc   |0.3009|±  |0.0313|
# | - machine_learning                   |      0|none  |     5|acc   |0.3482|±  |0.0452|
# |social_sciences                       |N/A    |none  |     5|acc   |0.5245|±  |0.0089|
# | - econometrics                       |      0|none  |     5|acc   |0.3772|±  |0.0456|
# | - high_school_geography              |      0|none  |     5|acc   |0.5455|±  |0.0355|
# | - high_school_government_and_politics|      0|none  |     5|acc   |0.6891|±  |0.0334|
# | - high_school_macroeconomics         |      0|none  |     5|acc   |0.4103|±  |0.0249|
# | - high_school_microeconomics         |      0|none  |     5|acc   |0.4328|±  |0.0322|
# | - high_school_psychology             |      0|none  |     5|acc   |0.6349|±  |0.0206|
# | - human_sexuality                    |      0|none  |     5|acc   |0.5420|±  |0.0437|
# | - professional_psychology            |      0|none  |     5|acc   |0.4641|±  |0.0202|
# | - public_relations                   |      0|none  |     5|acc   |0.5182|±  |0.0479|
# | - security_studies                   |      0|none  |     5|acc   |0.4816|±  |0.0320|
# | - sociology                          |      0|none  |     5|acc   |0.6119|±  |0.0345|
# | - us_foreign_policy                  |      0|none  |     5|acc   |0.6800|±  |0.0469|
# |other                                 |N/A    |none  |     5|acc   |0.5323|±  |0.0087|
# | - business_ethics                    |      0|none  |     5|acc   |0.4800|±  |0.0502|
# | - clinical_knowledge                 |      0|none  |     5|acc   |0.5170|±  |0.0308|
# | - college_medicine                   |      0|none  |     5|acc   |0.3988|±  |0.0373|
# | - global_facts                       |      0|none  |     5|acc   |0.3400|±  |0.0476|
# | - human_aging                        |      0|none  |     5|acc   |0.5695|±  |0.0332|
# | - management                         |      0|none  |     5|acc   |0.6117|±  |0.0483|
# | - marketing                          |      0|none  |     5|acc   |0.6966|±  |0.0301|
# | - medical_genetics                   |      0|none  |     5|acc   |0.4500|±  |0.0500|
# | - miscellaneous                      |      0|none  |     5|acc   |0.6616|±  |0.0169|
# | - nutrition                          |      0|none  |     5|acc   |0.5196|±  |0.0286|
# | - professional_accounting            |      0|none  |     5|acc   |0.3652|±  |0.0287|
# | - professional_medicine              |      0|none  |     5|acc   |0.4449|±  |0.0302|
# | - virology                           |      0|none  |     5|acc   |0.4036|±  |0.0382|
# |humanities                            |N/A    |none  |     5|acc   |0.4287|±  |0.0069|
# | - formal_logic                       |      0|none  |     5|acc   |0.2460|±  |0.0385|
# | - high_school_european_history       |      0|none  |     5|acc   |0.5939|±  |0.0383|
# | - high_school_us_history             |      0|none  |     5|acc   |0.6520|±  |0.0334|
# | - high_school_world_history          |      0|none  |     5|acc   |0.6034|±  |0.0318|
# | - international_law                  |      0|none  |     5|acc   |0.6529|±  |0.0435|
# | - jurisprudence                      |      0|none  |     5|acc   |0.5741|±  |0.0478|
# | - logical_fallacies                  |      0|none  |     5|acc   |0.5276|±  |0.0392|
# | - moral_disputes                     |      0|none  |     5|acc   |0.5231|±  |0.0269|
# | - moral_scenarios                    |      0|none  |     5|acc   |0.2447|±  |0.0144|
# | - philosophy                         |      0|none  |     5|acc   |0.5498|±  |0.0283|
# | - prehistory                         |      0|none  |     5|acc   |0.5432|±  |0.0277|
# | - professional_law                   |      0|none  |     5|acc   |0.3377|±  |0.0121|
# | - world_religions                    |      0|none  |     5|acc   |0.7018|±  |0.0351|
#
# |    Groups     |Version|Filter|n-shot|Metric|Value |   |Stderr|
# |---------------|-------|------|-----:|------|-----:|---|-----:|
# |stem           |N/A    |none  |     5|acc   |0.3650|±  |0.0084|
# |social_sciences|N/A    |none  |     5|acc   |0.5245|±  |0.0089|
# |other          |N/A    |none  |     5|acc   |0.5323|±  |0.0087|
# |humanities     |N/A    |none  |     5|acc   |0.4287|±  |0.0069|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:                           mmlu_abstract_algebra/acc ▁
# wandb:                    mmlu_abstract_algebra/acc_stderr ▁
# wandb:                                    mmlu_anatomy/acc ▁
# wandb:                             mmlu_anatomy/acc_stderr ▁
# wandb:                                  mmlu_astronomy/acc ▁
# wandb:                           mmlu_astronomy/acc_stderr ▁
# wandb:                            mmlu_business_ethics/acc ▁
# wandb:                     mmlu_business_ethics/acc_stderr ▁
# wandb:                         mmlu_clinical_knowledge/acc ▁
# wandb:                  mmlu_clinical_knowledge/acc_stderr ▁
# wandb:                            mmlu_college_biology/acc ▁
# wandb:                     mmlu_college_biology/acc_stderr ▁
# wandb:                          mmlu_college_chemistry/acc ▁
# wandb:                   mmlu_college_chemistry/acc_stderr ▁
# wandb:                   mmlu_college_computer_science/acc ▁
# wandb:            mmlu_college_computer_science/acc_stderr ▁
# wandb:                        mmlu_college_mathematics/acc ▁
# wandb:                 mmlu_college_mathematics/acc_stderr ▁
# wandb:                           mmlu_college_medicine/acc ▁
# wandb:                    mmlu_college_medicine/acc_stderr ▁
# wandb:                            mmlu_college_physics/acc ▁
# wandb:                     mmlu_college_physics/acc_stderr ▁
# wandb:                          mmlu_computer_security/acc ▁
# wandb:                   mmlu_computer_security/acc_stderr ▁
# wandb:                         mmlu_conceptual_physics/acc ▁
# wandb:                  mmlu_conceptual_physics/acc_stderr ▁
# wandb:                               mmlu_econometrics/acc ▁
# wandb:                        mmlu_econometrics/acc_stderr ▁
# wandb:                     mmlu_electrical_engineering/acc ▁
# wandb:              mmlu_electrical_engineering/acc_stderr ▁
# wandb:                     mmlu_elementary_mathematics/acc ▁
# wandb:              mmlu_elementary_mathematics/acc_stderr ▁
# wandb:                               mmlu_formal_logic/acc ▁
# wandb:                        mmlu_formal_logic/acc_stderr ▁
# wandb:                               mmlu_global_facts/acc ▁
# wandb:                        mmlu_global_facts/acc_stderr ▁
# wandb:                        mmlu_high_school_biology/acc ▁
# wandb:                 mmlu_high_school_biology/acc_stderr ▁
# wandb:                      mmlu_high_school_chemistry/acc ▁
# wandb:               mmlu_high_school_chemistry/acc_stderr ▁
# wandb:               mmlu_high_school_computer_science/acc ▁
# wandb:        mmlu_high_school_computer_science/acc_stderr ▁
# wandb:               mmlu_high_school_european_history/acc ▁
# wandb:        mmlu_high_school_european_history/acc_stderr ▁
# wandb:                      mmlu_high_school_geography/acc ▁
# wandb:               mmlu_high_school_geography/acc_stderr ▁
# wandb:        mmlu_high_school_government_and_politics/acc ▁
# wandb: mmlu_high_school_government_and_politics/acc_stderr ▁
# wandb:                 mmlu_high_school_macroeconomics/acc ▁
# wandb:          mmlu_high_school_macroeconomics/acc_stderr ▁
# wandb:                    mmlu_high_school_mathematics/acc ▁
# wandb:             mmlu_high_school_mathematics/acc_stderr ▁
# wandb:                 mmlu_high_school_microeconomics/acc ▁
# wandb:          mmlu_high_school_microeconomics/acc_stderr ▁
# wandb:                        mmlu_high_school_physics/acc ▁
# wandb:                 mmlu_high_school_physics/acc_stderr ▁
# wandb:                     mmlu_high_school_psychology/acc ▁
# wandb:              mmlu_high_school_psychology/acc_stderr ▁
# wandb:                     mmlu_high_school_statistics/acc ▁
# wandb:              mmlu_high_school_statistics/acc_stderr ▁
# wandb:                     mmlu_high_school_us_history/acc ▁
# wandb:              mmlu_high_school_us_history/acc_stderr ▁
# wandb:                  mmlu_high_school_world_history/acc ▁
# wandb:           mmlu_high_school_world_history/acc_stderr ▁
# wandb:                                mmlu_human_aging/acc ▁
# wandb:                         mmlu_human_aging/acc_stderr ▁
# wandb:                            mmlu_human_sexuality/acc ▁
# wandb:                     mmlu_human_sexuality/acc_stderr ▁
# wandb:                                 mmlu_humanities/acc ▁
# wandb:                          mmlu_humanities/acc_stderr ▁
# wandb:                          mmlu_international_law/acc ▁
# wandb:                   mmlu_international_law/acc_stderr ▁
# wandb:                              mmlu_jurisprudence/acc ▁
# wandb:                       mmlu_jurisprudence/acc_stderr ▁
# wandb:                          mmlu_logical_fallacies/acc ▁
# wandb:                   mmlu_logical_fallacies/acc_stderr ▁
# wandb:                           mmlu_machine_learning/acc ▁
# wandb:                    mmlu_machine_learning/acc_stderr ▁
# wandb:                                 mmlu_management/acc ▁
# wandb:                          mmlu_management/acc_stderr ▁
# wandb:                                  mmlu_marketing/acc ▁
# wandb:                           mmlu_marketing/acc_stderr ▁
# wandb:                           mmlu_medical_genetics/acc ▁
# wandb:                    mmlu_medical_genetics/acc_stderr ▁
# wandb:                              mmlu_miscellaneous/acc ▁
# wandb:                       mmlu_miscellaneous/acc_stderr ▁
# wandb:                             mmlu_moral_disputes/acc ▁
# wandb:                      mmlu_moral_disputes/acc_stderr ▁
# wandb:                            mmlu_moral_scenarios/acc ▁
# wandb:                     mmlu_moral_scenarios/acc_stderr ▁
# wandb:                                  mmlu_nutrition/acc ▁
# wandb:                           mmlu_nutrition/acc_stderr ▁
# wandb:                                      mmlu_other/acc ▁
# wandb:                               mmlu_other/acc_stderr ▁
# wandb:                                 mmlu_philosophy/acc ▁
# wandb:                          mmlu_philosophy/acc_stderr ▁
# wandb:                                 mmlu_prehistory/acc ▁
# wandb:                          mmlu_prehistory/acc_stderr ▁
# wandb:                    mmlu_professional_accounting/acc ▁
# wandb:             mmlu_professional_accounting/acc_stderr ▁
# wandb:                           mmlu_professional_law/acc ▁
# wandb:                    mmlu_professional_law/acc_stderr ▁
# wandb:                      mmlu_professional_medicine/acc ▁
# wandb:               mmlu_professional_medicine/acc_stderr ▁
# wandb:                    mmlu_professional_psychology/acc ▁
# wandb:             mmlu_professional_psychology/acc_stderr ▁
# wandb:                           mmlu_public_relations/acc ▁
# wandb:                    mmlu_public_relations/acc_stderr ▁
# wandb:                           mmlu_security_studies/acc ▁
# wandb:                    mmlu_security_studies/acc_stderr ▁
# wandb:                            mmlu_social_sciences/acc ▁
# wandb:                     mmlu_social_sciences/acc_stderr ▁
# wandb:                                  mmlu_sociology/acc ▁
# wandb:                           mmlu_sociology/acc_stderr ▁
# wandb:                                       mmlu_stem/acc ▁
# wandb:                                mmlu_stem/acc_stderr ▁
# wandb:                          mmlu_us_foreign_policy/acc ▁
# wandb:                   mmlu_us_foreign_policy/acc_stderr ▁
# wandb:                                   mmlu_virology/acc ▁
# wandb:                            mmlu_virology/acc_stderr ▁
# wandb:                            mmlu_world_religions/acc ▁
# wandb:                     mmlu_world_religions/acc_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:                           mmlu_abstract_algebra/acc 0.29
# wandb:                    mmlu_abstract_algebra/acc_stderr 0.0456
# wandb:                         mmlu_abstract_algebra/alias  - abstract_algebra
# wandb:                                    mmlu_anatomy/acc 0.41481
# wandb:                             mmlu_anatomy/acc_stderr 0.04256
# wandb:                                  mmlu_anatomy/alias  - anatomy
# wandb:                                  mmlu_astronomy/acc 0.46053
# wandb:                           mmlu_astronomy/acc_stderr 0.04056
# wandb:                                mmlu_astronomy/alias  - astronomy
# wandb:                            mmlu_business_ethics/acc 0.48
# wandb:                     mmlu_business_ethics/acc_stderr 0.05021
# wandb:                          mmlu_business_ethics/alias  - business_ethics
# wandb:                         mmlu_clinical_knowledge/acc 0.51698
# wandb:                  mmlu_clinical_knowledge/acc_stderr 0.03076
# wandb:                       mmlu_clinical_knowledge/alias  - clinical_knowledg...
# wandb:                            mmlu_college_biology/acc 0.48611
# wandb:                     mmlu_college_biology/acc_stderr 0.0418
# wandb:                          mmlu_college_biology/alias  - college_biology
# wandb:                          mmlu_college_chemistry/acc 0.27
# wandb:                   mmlu_college_chemistry/acc_stderr 0.04462
# wandb:                        mmlu_college_chemistry/alias  - college_chemistry...
# wandb:                   mmlu_college_computer_science/acc 0.38
# wandb:            mmlu_college_computer_science/acc_stderr 0.04878
# wandb:                 mmlu_college_computer_science/alias  - college_computer_...
# wandb:                        mmlu_college_mathematics/acc 0.35
# wandb:                 mmlu_college_mathematics/acc_stderr 0.04794
# wandb:                      mmlu_college_mathematics/alias  - college_mathemati...
# wandb:                           mmlu_college_medicine/acc 0.39884
# wandb:                    mmlu_college_medicine/acc_stderr 0.03734
# wandb:                         mmlu_college_medicine/alias  - college_medicine
# wandb:                            mmlu_college_physics/acc 0.22549
# wandb:                     mmlu_college_physics/acc_stderr 0.04158
# wandb:                          mmlu_college_physics/alias  - college_physics
# wandb:                          mmlu_computer_security/acc 0.57
# wandb:                   mmlu_computer_security/acc_stderr 0.04976
# wandb:                        mmlu_computer_security/alias  - computer_security...
# wandb:                         mmlu_conceptual_physics/acc 0.39149
# wandb:              mmlu_high_school_statistics/acc_stderr 0.03128
# wandb:                   mmlu_high_school_statistics/alias  - high_school_stati...
# wandb:                     mmlu_high_school_us_history/acc 0.65196
# wandb:              mmlu_high_school_us_history/acc_stderr 0.03343
# wandb:                   mmlu_high_school_us_history/alias  - high_school_us_hi...
# wandb:                  mmlu_high_school_world_history/acc 0.60338
# wandb:           mmlu_high_school_world_history/acc_stderr 0.03184
# wandb:                mmlu_high_school_world_history/alias  - high_school_world...
# wandb:                                mmlu_human_aging/acc 0.56951
# wandb:                         mmlu_human_aging/acc_stderr 0.03323
# wandb:                              mmlu_human_aging/alias  - human_aging
# wandb:                            mmlu_human_sexuality/acc 0.54198
# wandb:                     mmlu_human_sexuality/acc_stderr 0.0437
# wandb:                          mmlu_human_sexuality/alias  - human_sexuality
# wandb:                                 mmlu_humanities/acc 0.42869
# wandb:                          mmlu_humanities/acc_stderr 0.00689
# wandb:                               mmlu_humanities/alias humanities
# wandb:                          mmlu_international_law/acc 0.65289
# wandb:                   mmlu_international_law/acc_stderr 0.04346
# wandb:                        mmlu_international_law/alias  - international_law...
# wandb:                              mmlu_jurisprudence/acc 0.57407
# wandb:                       mmlu_jurisprudence/acc_stderr 0.0478
# wandb:                            mmlu_jurisprudence/alias  - jurisprudence
# wandb:                          mmlu_logical_fallacies/acc 0.52761
# wandb:                   mmlu_logical_fallacies/acc_stderr 0.03922
# wandb:                        mmlu_logical_fallacies/alias  - logical_fallacies...
# wandb:                           mmlu_machine_learning/acc 0.34821
# wandb:                    mmlu_machine_learning/acc_stderr 0.04522
# wandb:                         mmlu_machine_learning/alias  - machine_learning
# wandb:                                 mmlu_management/acc 0.61165
# wandb:                          mmlu_management/acc_stderr 0.04826
# wandb:                               mmlu_management/alias  - management
# wandb:                                  mmlu_marketing/acc 0.69658
# wandb:                           mmlu_marketing/acc_stderr 0.03012
# wandb:                                mmlu_marketing/alias  - marketing
# wandb:                           mmlu_medical_genetics/acc 0.45
# wandb:                    mmlu_medical_genetics/acc_stderr 0.05
# wandb:                         mmlu_medical_genetics/alias  - medical_genetics
# wandb:                              mmlu_miscellaneous/acc 0.66156
# wandb:                       mmlu_miscellaneous/acc_stderr 0.01692
# wandb:                            mmlu_miscellaneous/alias  - miscellaneous
# wandb:                             mmlu_moral_disputes/acc 0.52312
# wandb:                      mmlu_moral_disputes/acc_stderr 0.02689
# wandb:                           mmlu_moral_disputes/alias  - moral_disputes
# wandb:                            mmlu_moral_scenarios/acc 0.24469
# wandb:                     mmlu_moral_scenarios/acc_stderr 0.01438
# wandb:                          mmlu_moral_scenarios/alias  - moral_scenarios
# wandb:                                  mmlu_nutrition/acc 0.51961
# wandb:                           mmlu_nutrition/acc_stderr 0.02861
# wandb:                                mmlu_nutrition/alias  - nutrition
# wandb:                                      mmlu_other/acc 0.53235
# wandb:                               mmlu_other/acc_stderr 0.00873
# wandb:                                    mmlu_other/alias other
# wandb:                                 mmlu_philosophy/acc 0.54984
# wandb:                          mmlu_philosophy/acc_stderr 0.02826
# wandb:                               mmlu_philosophy/alias  - philosophy
# wandb:                                 mmlu_prehistory/acc 0.54321
# wandb:                          mmlu_prehistory/acc_stderr 0.02772
# wandb:                               mmlu_prehistory/alias  - prehistory
# wandb:                    mmlu_professional_accounting/acc 0.36525
# wandb:             mmlu_professional_accounting/acc_stderr 0.02872
# wandb:                  mmlu_professional_accounting/alias  - professional_acco...
# wandb:                           mmlu_professional_law/acc 0.33768
# wandb:                    mmlu_professional_law/acc_stderr 0.01208
# wandb:                         mmlu_professional_law/alias  - professional_law
# wandb:                      mmlu_professional_medicine/acc 0.44485
# wandb:               mmlu_professional_medicine/acc_stderr 0.03019
# wandb:                    mmlu_professional_medicine/alias  - professional_medi...
# wandb:                    mmlu_professional_psychology/acc 0.46405
# wandb:             mmlu_professional_psychology/acc_stderr 0.02018
# wandb:                  mmlu_professional_psychology/alias  - professional_psyc...
# wandb:                           mmlu_public_relations/acc 0.51818
# wandb:                    mmlu_public_relations/acc_stderr 0.04786
# wandb:                         mmlu_public_relations/alias  - public_relations
# wandb:                           mmlu_security_studies/acc 0.48163
# wandb:                    mmlu_security_studies/acc_stderr 0.03199
# wandb:                         mmlu_security_studies/alias  - security_studies
# wandb:                            mmlu_social_sciences/acc 0.52454
# wandb:                     mmlu_social_sciences/acc_stderr 0.00885
# wandb:                          mmlu_social_sciences/alias social_sciences
# wandb:                                  mmlu_sociology/acc 0.61194
# wandb:                           mmlu_sociology/acc_stderr 0.03446
# wandb:                                mmlu_sociology/alias  - sociology
# wandb:                                       mmlu_stem/acc 0.36505
# wandb:                                mmlu_stem/acc_stderr 0.00845
# wandb:                                     mmlu_stem/alias stem
# wandb:                          mmlu_us_foreign_policy/acc 0.68
# wandb:                   mmlu_us_foreign_policy/acc_stderr 0.04688
# wandb:                        mmlu_us_foreign_policy/alias  - us_foreign_policy...
# wandb:                                   mmlu_virology/acc 0.40361
# wandb:                            mmlu_virology/acc_stderr 0.03819
# wandb:                                 mmlu_virology/alias  - virology
# wandb:                            mmlu_world_religions/acc 0.70175
# wandb:                     mmlu_world_religions/acc_stderr 0.03509
# wandb:                          mmlu_world_religions/alias  - world_religions
# wandb:
# wandb: 🚀 View run Llama2-7b-chat-HF-NF4-MMLU at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/8xjx900a/workspace
# wandb: Synced 5 W&B file(s), 6 media file(s), 7 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240327_190410-8xjx900a/logs

# %% [markdown]
# #### HellaSwag
#
# 0-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Llama2-7b-chat-HF-NF4,trust_remote_code=True, \
    --tasks hellaswag \
    --num_fewshot 0 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Llama2-7b-chat-HF-NF4-Hellaswag
# Out:
# 2024-03-27 19:37:53.191273: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-27 19:37:53.191331: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-27 19:37:53.192783: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-27 19:37:54.472871: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240327_193800-w3hb23f6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Llama2-7b-chat-HF-NF4-Hellaswag
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/w3hb23f6/workspace
# 2024-03-27:19:38:01,260 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-27:19:38:07,168 WARNING  [__main__.py:316] File results_dir/results.json already exists. Results will be overwritten.
# 2024-03-27:19:38:07,169 INFO     [__main__.py:335] Selected Tasks: ['hellaswag']
# 2024-03-27:19:38:07,169 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-27:19:38:07,170 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Llama2-7b-chat-HF-NF4', 'trust_remote_code': True}
# 2024-03-27:19:38:07,174 INFO     [huggingface.py:163] Using device 'cuda:0'
# 2024-03-27:19:38:11,341 WARNING  [big_modeling.py:448] You shouldn't move a model that is dispatched using accelerate hooks.
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 4.36k/4.36k [00:00<00:00, 11.4MB/s]
# Downloading metadata: 100% 2.53k/2.53k [00:00<00:00, 8.30MB/s]
# Downloading readme: 100% 6.84k/6.84k [00:00<00:00, 16.9MB/s]
# Downloading data: 47.5MB [00:00, 73.5MB/s]
# Downloading data: 11.8MB [00:00, 64.1MB/s]
# Downloading data: 12.2MB [00:00, 64.9MB/s]
# Generating train split: 100% 39905/39905 [00:04<00:00, 9123.83 examples/s]
# Generating test split: 100% 10003/10003 [00:01<00:00, 9283.75 examples/s]
# Generating validation split: 100% 10042/10042 [00:01<00:00, 9183.05 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 6121.00 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 6670.13 examples/s]
# 2024-03-27:19:38:43,781 WARNING  [evaluator.py:239] Overwriting default num_fewshot of hellaswag from None to 0
# 2024-03-27:19:38:43,783 INFO     [task.py:395] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:04<00:00, 2084.36it/s]
# 2024-03-27:19:38:49,733 INFO     [evaluator.py:379] Running loglikelihood requests
# Running loglikelihood requests:   0% 0/40168 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests:  25% 9930/40168 [01:51<04:54, 102.73it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests: 100% 40168/40168 [05:19<00:00, 125.59it/s]
# hf (pretrained=twhoool02/Llama2-7b-chat-HF-NF4,trust_remote_code=True,), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: auto:4 (64,64,64,64,64)
# |  Tasks  |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |---------|------:|------|-----:|--------|-----:|---|-----:|
# |hellaswag|      1|none  |     0|acc     |0.5731|±  |0.0049|
# |         |       |none  |     0|acc_norm|0.7500|±  |0.0043|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:             hellaswag/acc ▁
# wandb:        hellaswag/acc_norm ▁
# wandb: hellaswag/acc_norm_stderr ▁
# wandb:      hellaswag/acc_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:             hellaswag/acc 0.57309
# wandb:        hellaswag/acc_norm 0.74995
# wandb: hellaswag/acc_norm_stderr 0.00432
# wandb:      hellaswag/acc_stderr 0.00494
# wandb:           hellaswag/alias hellaswag
# wandb:
# wandb: 🚀 View run Llama2-7b-chat-HF-NF4-Hellaswag at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/w3hb23f6/workspace
# wandb: Synced 5 W&B file(s), 2 media file(s), 3 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240327_193800-w3hb23f6/logs

# %% [markdown]
# #### BoolQ
#
# 0-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Llama2-7b-chat-HF-NF4,trust_remote_code=True,do_sample=True \
    --tasks boolq \
    --num_fewshot 0 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Llama2-7b-chat-HF-NF4-boolq \
    --use_cache results_dir \
    --cache_requests true \
    --show_config
# Out:
# 2024-03-28 10:39:30.323005: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-28 10:39:30.323054: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-28 10:39:30.324821: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-28 10:39:31.578142: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240328_103937-lpwenptx
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Llama2-7b-chat-HF-NF4-boolq
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/lpwenptx/workspace
# 2024-03-28:10:39:38,491 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-28:10:39:44,474 INFO     [__main__.py:335] Selected Tasks: ['boolq']
# 2024-03-28:10:39:44,476 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-28:10:39:44,476 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Llama2-7b-chat-HF-NF4', 'trust_remote_code': True, 'do_sample': True}
# 2024-03-28:10:39:44,480 INFO     [huggingface.py:163] Using device 'cuda:0'
# config.json: 100% 1.17k/1.17k [00:00<00:00, 3.98MB/s]
# model.safetensors: 100% 3.87G/3.87G [00:14<00:00, 274MB/s]
# generation_config.json: 100% 183/183 [00:00<00:00, 420kB/s]
# 2024-03-28:10:40:04,059 WARNING  [big_modeling.py:448] You shouldn't move a model that is dispatched using accelerate hooks.
# tokenizer_config.json: 100% 1.76k/1.76k [00:00<00:00, 4.52MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 87.4MB/s]
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 3.74MB/s]
# special_tokens_map.json: 100% 437/437 [00:00<00:00, 1.17MB/s]
# 2024-03-28:10:40:07,499 INFO     [evaluator.py:195] Using cache at results_dir_rank0.db
# 2024-03-28:10:40:07,503 WARNING  [task.py:763] [Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# 2024-03-28:10:40:07,504 WARNING  [task.py:775] [Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# Downloading data: 100% 3.85M/3.85M [00:00<00:00, 10.6MB/s]
# Downloading data: 100% 1.31M/1.31M [00:00<00:00, 4.69MB/s]
# Downloading data: 100% 1.31M/1.31M [00:00<00:00, 4.67MB/s]
# Generating train split: 100% 9427/9427 [00:00<00:00, 165682.80 examples/s]
# Generating validation split: 100% 3270/3270 [00:00<00:00, 288526.05 examples/s]
# Generating test split: 100% 3245/3245 [00:00<00:00, 324013.63 examples/s]
# 2024-03-28:10:40:18,189 WARNING  [evaluator.py:239] Overwriting default num_fewshot of boolq from None to 0
# 2024-03-28:10:40:18,190 INFO     [task.py:395] Building contexts for boolq on rank 0...
# 100% 3270/3270 [00:01<00:00, 1730.60it/s]
# 2024-03-28:10:40:20,797 INFO     [evaluator.py:379] Running loglikelihood requests
# 2024-03-28:10:40:20,799 INFO     [model.py:225] Loading 'loglikelihood' responses from cache 'results_dir_rank0.db' where possible...
# Checking cached requests: 100% 6540/6540 [00:00<00:00, 7302.75it/s]
# 2024-03-28:10:40:21,695 INFO     [model.py:249] Cached requests: 0, Requests remaining: 6540
# Running loglikelihood requests:   0% 0/6540 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 16
# Running loglikelihood requests:  24% 1601/6540 [00:39<00:49, 100.47it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests: 100% 6540/6540 [01:15<00:00, 86.43it/s]
# {
#   "results": {
#     "boolq": {
#       "acc,none": 0.7948012232415902,
#       "acc_stderr,none": 0.007063324955682799,
#       "alias": "boolq"
#     }
#   },
#   "group_subtasks": {
#     "boolq": []
#   },
#   "configs": {
#     "boolq": {
#       "task": "boolq",
#       "group": [
#         "super-glue-lm-eval-v1"
#       ],
#       "dataset_path": "super_glue",
#       "dataset_name": "boolq",
#       "training_split": "train",
#       "validation_split": "validation",
#       "doc_to_text": "{{passage}}\nQuestion: {{question}}?\nAnswer:",
#       "doc_to_target": "label",
#       "doc_to_choice": [
#         "no",
#         "yes"
#       ],
#       "description": "",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "acc"
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": true,
#       "doc_to_decontamination_query": "passage",
#       "metadata": {
#         "version": 2.0
#       }
#     }
#   },
#   "versions": {
#     "boolq": 2.0
#   },
#   "n-shot": {
#     "boolq": 0
#   },
#   "config": {
#     "model": "hf",
#     "model_args": "pretrained=twhoool02/Llama2-7b-chat-HF-NF4,trust_remote_code=True,do_sample=True",
#     "batch_size": "auto:4",
#     "batch_sizes": [
#       16,
#       64,
#       64,
#       64,
#       64
#     ],
#     "device": "cuda:0",
#     "use_cache": "results_dir",
#     "limit": null,
#     "bootstrap_iters": 100000,
#     "gen_kwargs": null
#   },
#   "git_hash": "0dffdbb4",
#   "date": 1711622384.4756913,
#   "pretty_env_info": "PyTorch version: 2.2.1+cu121\nIs debug build: False\nCUDA used to build PyTorch: 12.1\nROCM used to build PyTorch: N/A\n\nOS: Ubuntu 22.04.3 LTS (x86_64)\nGCC version: (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0\nClang version: 14.0.0-1ubuntu1.1\nCMake version: version 3.27.9\nLibc version: glibc-2.35\n\nPython version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0] (64-bit runtime)\nPython platform: Linux-6.1.58+-x86_64-with-glibc2.35\nIs CUDA available: True\nCUDA runtime version: 12.2.140\nCUDA_MODULE_LOADING set to: LAZY\nGPU models and configuration: GPU 0: NVIDIA A100-SXM4-40GB\nNvidia driver version: 535.104.05\ncuDNN version: Probably one of the following:\n/usr/lib/x86_64-linux-gnu/libcudnn.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_train.so.8.9.6\nHIP runtime version: N/A\nMIOpen runtime version: N/A\nIs XNNPACK available: True\n\nCPU:\nArchitecture:                       x86_64\nCPU op-mode(s):                     32-bit, 64-bit\nAddress sizes:                      46 bits physical, 48 bits virtual\nByte Order:                         Little Endian\nCPU(s):                             12\nOn-line CPU(s) list:                0-11\nVendor ID:                          GenuineIntel\nModel name:                         Intel(R) Xeon(R) CPU @ 2.20GHz\nCPU family:                         6\nModel:                              85\nThread(s) per core:                 2\nCore(s) per socket:                 6\nSocket(s):                          1\nStepping:                           7\nBogoMIPS:                           4400.41\nFlags:                              fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp ibrs_enhanced fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat avx512_vnni md_clear arch_capabilities\nHypervisor vendor:                  KVM\nVirtualization type:                full\nL1d cache:                          192 KiB (6 instances)\nL1i cache:                          192 KiB (6 instances)\nL2 cache:                           6 MiB (6 instances)\nL3 cache:                           38.5 MiB (1 instance)\nNUMA node(s):                       1\nNUMA node0 CPU(s):                  0-11\nVulnerability Gather data sampling: Not affected\nVulnerability Itlb multihit:        Not affected\nVulnerability L1tf:                 Not affected\nVulnerability Mds:                  Vulnerable; SMT Host state unknown\nVulnerability Meltdown:             Not affected\nVulnerability Mmio stale data:      Vulnerable\nVulnerability Retbleed:             Vulnerable\nVulnerability Spec rstack overflow: Not affected\nVulnerability Spec store bypass:    Vulnerable\nVulnerability Spectre v1:           Vulnerable: __user pointer sanitization and usercopy barriers only; no swapgs barriers\nVulnerability Spectre v2:           Vulnerable, IBPB: disabled, STIBP: disabled, PBRSB-eIBRS: Vulnerable\nVulnerability Srbds:                Not affected\nVulnerability Tsx async abort:      Vulnerable\n\nVersions of relevant libraries:\n[pip3] numpy==1.25.2\n[pip3] torch==2.2.1+cu121\n[pip3] torchaudio==2.2.1+cu121\n[pip3] torchdata==0.7.1\n[pip3] torchsummary==1.5.1\n[pip3] torchtext==0.17.1\n[pip3] torchvision==0.17.1+cu121\n[pip3] triton==2.2.0\n[conda] Could not collect",
#   "transformers_version": "4.38.2",
#   "upper_git_hash": null
# }
# hf (pretrained=twhoool02/Llama2-7b-chat-HF-NF4,trust_remote_code=True,do_sample=True), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: auto:4 (16,64,64,64,64)
# |Tasks|Version|Filter|n-shot|Metric|Value |   |Stderr|
# |-----|------:|------|-----:|------|-----:|---|-----:|
# |boolq|      2|none  |     0|acc   |0.7948|±  |0.0071|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:        boolq/acc ▁
# wandb: boolq/acc_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:        boolq/acc 0.7948
# wandb: boolq/acc_stderr 0.00706
# wandb:      boolq/alias boolq
# wandb:
# wandb: 🚀 View run Llama2-7b-chat-HF-NF4-boolq at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/lpwenptx/workspace
# wandb: Synced 5 W&B file(s), 2 media file(s), 3 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240328_103937-lpwenptx/logs

# %% [markdown]
# #### BBH
#
# 3-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Llama2-7b-chat-HF-NF4,trust_remote_code=True,do_sample=True \
    --tasks bbh_fewshot \
    --num_fewshot 3 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Llama2-7b-chat-HF-NF4-bbh \
    --use_cache results_dir \
    --cache_requests true
# Out:
# 2024-03-27 19:47:27.656472: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-27 19:47:27.656523: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-27 19:47:27.657943: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-27 19:47:28.889790: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240327_194734-slf8nnqc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Llama2-7b-chat-HF-NF4-bbh
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/slf8nnqc/workspace
# 2024-03-27:19:47:35,695 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-27:19:47:41,787 WARNING  [__main__.py:316] File results_dir/results.json already exists. Results will be overwritten.
# 2024-03-27:19:47:41,787 INFO     [__main__.py:335] Selected Tasks: ['bbh_fewshot']
# 2024-03-27:19:47:41,788 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-27:19:47:41,788 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Llama2-7b-chat-HF-NF4', 'trust_remote_code': True, 'do_sample': True}
# 2024-03-27:19:47:41,792 INFO     [huggingface.py:163] Using device 'cuda:0'
# 2024-03-27:19:47:45,194 WARNING  [big_modeling.py:448] You shouldn't move a model that is dispatched using accelerate hooks.
# 2024-03-27:19:47:45,546 INFO     [evaluator.py:195] Using cache at results_dir_rank0.db
# Downloading data: 100% 37.1k/37.1k [00:01<00:00, 21.6kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 47701.57 examples/s]
# 2024-03-27:19:47:53,254 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_five_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-27:19:47:53,254 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_five_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 25.1k/25.1k [00:01<00:00, 16.2kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 94628.28 examples/s]
# 2024-03-27:19:48:00,258 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_three_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-27:19:48:00,259 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_three_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.4k/10.4k [00:01<00:00, 7.77kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 106877.59 examples/s]
# 2024-03-27:19:48:06,671 WARNING  [task.py:322] [Task: bbh_fewshot_hyperbaton] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-27:19:48:06,671 WARNING  [task.py:322] [Task: bbh_fewshot_hyperbaton] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.6k/10.6k [00:01<00:00, 8.10kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 108988.25 examples/s]
# 2024-03-27:19:48:13,252 WARNING  [task.py:322] [Task: bbh_fewshot_object_counting] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-27:19:48:13,253 WARNING  [task.py:322] [Task: bbh_fewshot_object_counting] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 15.6k/15.6k [00:01<00:00, 9.93kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 94500.36 examples/s]
# 2024-03-27:19:48:19,855 WARNING  [task.py:322] [Task: bbh_fewshot_web_of_lies] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-27:19:48:19,855 WARNING  [task.py:322] [Task: bbh_fewshot_web_of_lies] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 21.7k/21.7k [00:01<00:00, 13.8kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 106411.20 examples/s]
# 2024-03-27:19:48:26,710 WARNING  [task.py:322] [Task: bbh_fewshot_movie_recommendation] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-27:19:48:26,710 WARNING  [task.py:322] [Task: bbh_fewshot_movie_recommendation] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 56.9k/56.9k [00:01<00:00, 31.2kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 72848.13 examples/s]
# 2024-03-27:19:48:33,906 WARNING  [task.py:322] [Task: bbh_fewshot_salient_translation_error_detection] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-27:19:48:33,906 WARNING  [task.py:322] [Task: bbh_fewshot_salient_translation_error_detection] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 35.6k/35.6k [00:01<00:00, 22.2kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 90246.66 examples/s]
# 2024-03-27:19:48:41,099 WARNING  [task.py:322] [Task: bbh_fewshot_temporal_sequences] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-27:19:48:41,099 WARNING  [task.py:322] [Task: bbh_fewshot_temporal_sequences] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 8.16k/8.16k [00:01<00:00, 6.22kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 90277.74 examples/s]
# 2024-03-27:19:48:47,444 WARNING  [task.py:322] [Task: bbh_fewshot_sports_understanding] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-27:19:48:47,444 WARNING  [task.py:322] [Task: bbh_fewshot_sports_understanding] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 21.6k/21.6k [00:01<00:00, 13.9kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 98670.93 examples/s]
# 2024-03-27:19:48:54,021 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_three_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-27:19:48:54,021 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_three_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 33.5k/33.5k [00:01<00:00, 21.4kB/s]
# Generating test split: 100% 250/250 [00:00<00:00,
has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 16.7k/16.7k [00:01<00:00, 10.2kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 92975.35 examples/s]
# 2024-03-27:19:50:28,849 WARNING  [task.py:322] [Task: bbh_fewshot_disambiguation_qa] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-27:19:50:28,850 WARNING  [task.py:322] [Task: bbh_fewshot_disambiguation_qa] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 7.55k/7.55k [00:01<00:00, 5.91kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 100805.23 examples/s]
# 2024-03-27:19:50:35,361 WARNING  [task.py:322] [Task: bbh_fewshot_multistep_arithmetic_two] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-27:19:50:35,362 WARNING  [task.py:322] [Task: bbh_fewshot_multistep_arithmetic_two] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 44.0k/44.0k [00:01<00:00, 27.1kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 88412.82 examples/s]
# 2024-03-27:19:50:42,216 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-27:19:50:42,216 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.7k/10.7k [00:01<00:00, 7.91kB/s]
# Generating test split: 100% 146/146 [00:00<00:00, 50928.84 examples/s]
# 2024-03-27:19:50:49,143 WARNING  [task.py:322] [Task: bbh_fewshot_penguins_in_a_table] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-27:19:50:49,143 WARNING  [task.py:322] [Task: bbh_fewshot_penguins_in_a_table] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-27:19:50:49,148 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_penguins_in_a_table in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,149 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_logical_deduction_seven_objects in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,149 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_multistep_arithmetic_two in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,149 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_disambiguation_qa in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,149 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_causal_judgement in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,149 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_dyck_languages in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,149 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_snarks in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,150 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_boolean_expressions in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,150 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_formal_fallacies in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,150 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_date_understanding in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,150 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_navigate in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,150 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_reasoning_about_colored_objects in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,150 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_word_sorting in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,150 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_ruin_names in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,151 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_tracking_shuffled_objects_seven_objects in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,151 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_geometric_shapes in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,151 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_logical_deduction_five_objects in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,151 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_logical_deduction_three_objects in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,151 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_sports_understanding in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,151 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_temporal_sequences in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,151 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_salient_translation_error_detection in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,151 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_movie_recommendation in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,152 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_web_of_lies in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,152 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_object_counting in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,152 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_hyperbaton in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,152 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_tracking_shuffled_objects_three_objects in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,152 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_tracking_shuffled_objects_five_objects in its config. Manual configuration will be ignored.
# 2024-03-27:19:50:49,156 INFO     [task.py:395] Building contexts for bbh_fewshot_penguins_in_a_table on rank 0...
# 100% 146/146 [00:00<00:00, 1026.70it/s]
# 2024-03-27:19:50:49,321 INFO     [task.py:395] Building contexts for bbh_fewshot_logical_deduction_seven_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1044.78it/s]
# 2024-03-27:19:50:49,598 INFO     [task.py:395] Building contexts for bbh_fewshot_multistep_arithmetic_two on rank 0...
# 100% 250/250 [00:00<00:00, 1234.16it/s]
# 2024-03-27:19:50:49,837 INFO     [task.py:395] Building contexts for bbh_fewshot_disambiguation_qa on rank 0...
# 100% 250/250 [00:00<00:00, 1099.86it/s]
# 2024-03-27:19:50:50,102 INFO     [task.py:395] Building contexts for bbh_fewshot_causal_judgement on rank 0...
# 100% 187/187 [00:00<00:00, 960.40it/s]
# 2024-03-27:19:50:50,326 INFO     [task.py:395] Building contexts for bbh_fewshot_dyck_languages on rank 0...
# 100% 250/250 [00:00<00:00, 1180.60it/s]
# 2024-03-27:19:50:50,574 INFO     [task.py:395] Building contexts for bbh_fewshot_snarks on rank 0...
# 100% 178/178 [00:00<00:00, 1070.76it/s]
# 2024-03-27:19:50:50,766 INFO     [task.py:395] Building contexts for bbh_fewshot_boolean_expressions on rank 0...
# 100% 250/250 [00:00<00:00, 1219.77it/s]
# 2024-03-27:19:50:51,007 INFO     [task.py:395] Building contexts for bbh_fewshot_formal_fallacies on rank 0...
# 100% 250/250 [00:00<00:00, 1005.21it/s]
# 2024-03-27:19:50:51,294 INFO     [task.py:395] Building contexts for bbh_fewshot_date_understanding on rank 0...
# 100% 250/250 [00:00<00:00, 1137.48it/s]
# 2024-03-27:19:50:51,550 INFO     [task.py:395] Building contexts for bbh_fewshot_navigate on rank 0...
# 100% 250/250 [00:00<00:00, 1140.03it/s]
# 2024-03-27:19:50:51,806 INFO     [task.py:395] Building contexts for bbh_fewshot_reasoning_about_colored_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1028.08it/s]
# 2024-03-27:19:50:52,086 INFO     [task.py:395] Building contexts for bbh_fewshot_word_sorting on rank 0...
# 100% 250/250 [00:00<00:00, 1181.22it/s]
# 2024-03-27:19:50:52,335 INFO     [task.py:395] Building contexts for bbh_fewshot_ruin_names on rank 0...
# 100% 250/250 [00:00<00:00, 1130.48it/s]
# 2024-03-27:19:50:52,592 INFO     [task.py:395] Building contexts for bbh_fewshot_tracking_shuffled_objects_seven_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1032.45it/s]
# 2024-03-27:19:50:52,874 INFO     [task.py:395] Building contexts for bbh_fewshot_geometric_shapes on rank 0...
# 100% 250/250 [00:00<00:00, 1085.89it/s]
# 2024-03-27:19:50:53,141 INFO     [task.py:395] Building contexts for bbh_fewshot_logical_deduction_five_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1051.50it/s]
# 2024-03-27:19:50:53,418 INFO     [task.py:395] Building contexts for bbh_fewshot_logical_deduction_three_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1051.02it/s]
# 2024-03-27:19:50:53,693 INFO     [task.py:395] Building contexts for bbh_fewshot_sports_understanding on rank 0...
# 100% 250/250 [00:00<00:00, 1196.97it/s]
# 2024-03-27:19:50:53,938 INFO     [task.py:395] Building contexts for bbh_fewshot_temporal_sequences on rank 0...
# 100% 250/250 [00:00<00:00, 964.96it/s]
# 2024-03-27:19:50:54,235 INFO     [task.py:395] Building contexts for bbh_fewshot_salient_translation_error_detection on rank 0...
# 100% 250/250 [00:00<00:00, 749.76it/s]
# 2024-03-27:19:50:54,609 INFO     [task.py:395] Building contexts for bbh_fewshot_movie_recommendation on rank 0...
# 100% 250/250 [00:00<00:00, 1122.41it/s]
# 2024-03-27:19:50:54,868 INFO     [task.py:395] Building contexts for bbh_fewshot_web_of_lies on rank 0...
# 100% 250/250 [00:00<00:00, 1148.04it/s]
# 2024-03-27:19:50:55,123 INFO     [task.py:395] Building contexts for bbh_fewshot_object_counting on rank 0...
# 100% 250/250 [00:00<00:00, 1172.92it/s]
# 2024-03-27:19:50:55,372 INFO     [task.py:395] Building contexts for bbh_fewshot_hyperbaton on rank 0...
# 100% 250/250 [00:00<00:00, 1175.56it/s]
# 2024-03-27:19:50:55,621 INFO     [task.py:395] Building contexts for bbh_fewshot_tracking_shuffled_objects_three_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1034.09it/s]
# 2024-03-27:19:50:55,900 INFO     [task.py:395] Building contexts for bbh_fewshot_tracking_shuffled_objects_five_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1025.21it/s]
# 2024-03-27:19:50:56,181 INFO     [evaluator.py:379] Running generate_until requests
# 2024-03-27:19:50:56,184 INFO     [model.py:225] Loading 'generate_until' responses from cache 'results_dir_rank0.db' where possible...
# Checking cached requests: 100% 6511/6511 [00:01<00:00, 6104.01it/s]
# 2024-03-27:19:50:57,251 INFO     [model.py:249] Cached requests: 0, Requests remaining: 6511
# Running generate_until requests:   0% 0/6511 [00:00<?, ?it/s]Passed argument batch_size = auto. Detecting largest batch size
# Determined Largest batch size: 8
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:410: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:415: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Running generate_until requests: 100% 6511/6511 [59:22<00:00,  1.83it/s]
# hf (pretrained=twhoool02/Llama2-7b-chat-HF-NF4,trust_remote_code=True,do_sample=True), gen_kwargs: (None), limit: None, num_fewshot: 3, batch_size: auto:4
# |                        Tasks                         |Version|Filter|n-shot|  Metric   |Value |   |Stderr|
# |------------------------------------------------------|-------|------|-----:|-----------|-----:|---|-----:|
# |bbh_fewshot                                           |N/A    |none  |     3|exact_match|0.3353|±  |0.0054|
# | - bbh_fewshot_boolean_expressions                    |      1|none  |     3|exact_match|0.7040|±  |0.0289|
# | - bbh_fewshot_causal_judgement                       |      1|none  |     3|exact_match|0.5401|±  |0.0365|
# | - bbh_fewshot_date_understanding                     |      1|none  |     3|exact_match|0.3440|±  |0.0301|
# | - bbh_fewshot_disambiguation_qa                      |      1|none  |     3|exact_match|0.4120|±  |0.0312|
# | - bbh_fewshot_dyck_languages                         |      1|none  |     3|exact_match|0.0440|±  |0.0130|
# | - bbh_fewshot_formal_fallacies                       |      1|none  |     3|exact_match|0.4680|±  |0.0316|
# | - bbh_fewshot_geometric_shapes                       |      1|none  |     3|exact_match|0.2920|±  |0.0288|
# | - bbh_fewshot_hyperbaton                             |      1|none  |     3|exact_match|0.5440|±  |0.0316|
# | - bbh_fewshot_logical_deduction_five_objects         |      1|none  |     3|exact_match|0.2600|±  |0.0278|
# | - bbh_fewshot_logical_deduction_seven_objects        |      1|none  |     3|exact_match|0.1960|±  |0.0252|
# | - bbh_fewshot_logical_deduction_three_objects        |      1|none  |     3|exact_match|0.3520|±  |0.0303|
# | - bbh_fewshot_movie_recommendation                   |      1|none  |     3|exact_match|0.5920|±  |0.0311|
# | - bbh_fewshot_multistep_arithmetic_two               |      1|none  |     3|exact_match|0.0080|±  |0.0056|
# | - bbh_fewshot_navigate                               |      1|none  |     3|exact_match|0.4600|±  |0.0316|
# | - bbh_fewshot_object_counting                        |      1|none  |     3|exact_match|0.3200|±  |0.0296|
# | - bbh_fewshot_penguins_in_a_table                    |      1|none  |     3|exact_match|0.3014|±  |0.0381|
# | - bbh_fewshot_reasoning_about_colored_objects        |      1|none  |     3|exact_match|0.1960|±  |0.0252|
# | - bbh_fewshot_ruin_names                             |      1|none  |     3|exact_match|0.2120|±  |0.0259|
# | - bbh_fewshot_salient_translation_error_detection    |      1|none  |     3|exact_match|0.2800|±  |0.0285|
# | - bbh_fewshot_snarks                                 |      1|none  |     3|exact_match|0.5393|±  |0.0375|
# | - bbh_fewshot_sports_understanding                   |      1|none  |     3|exact_match|0.5960|±  |0.0311|
# | - bbh_fewshot_temporal_sequences                     |      1|none  |     3|exact_match|0.1240|±  |0.0209|
# | - bbh_fewshot_tracking_shuffled_objects_five_objects |      1|none  |     3|exact_match|0.1800|±  |0.0243|
# | - bbh_fewshot_tracking_shuffled_objects_seven_objects|      1|none  |     3|exact_match|0.1600|±  |0.0232|
# | - bbh_fewshot_tracking_shuffled_objects_three_objects|      1|none  |     3|exact_match|0.3120|±  |0.0294|
# | - bbh_fewshot_web_of_lies                            |      1|none  |     3|exact_match|0.4880|±  |0.0317|
# | - bbh_fewshot_word_sorting                           |      1|none  |     3|exact_match|0.2240|±  |0.0264|
#
# |  Groups   |Version|Filter|n-shot|  Metric   |Value |   |Stderr|
# |-----------|-------|------|-----:|-----------|-----:|---|-----:|
# |bbh_fewshot|N/A    |none  |     3|exact_match|0.3353|±  |0.0054|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:                                                bbh_fewshot/exact_match ▁
# wandb:                                         bbh_fewshot/exact_match_stderr ▁
# wandb:                            bbh_fewshot_boolean_expressions/exact_match ▁
# wandb:                     bbh_fewshot_boolean_expressions/exact_match_stderr ▁
# wandb:                               bbh_fewshot_causal_judgement/exact_match ▁
# wandb:                        bbh_fewshot_causal_judgement/exact_match_stderr ▁
# wandb:                             bbh_fewshot_date_understanding/exact_match ▁
# wandb:                      bbh_fewshot_date_understanding/exact_match_stderr ▁
# wandb:                              bbh_fewshot_disambiguation_qa/exact_match ▁
# wandb:                       bbh_fewshot_disambiguation_qa/exact_match_stderr ▁
# wandb:                                 bbh_fewshot_dyck_languages/exact_match ▁
# wandb:                          bbh_fewshot_dyck_languages/exact_match_stderr ▁
# wandb:                               bbh_fewshot_formal_fallacies/exact_match ▁
# wandb:                        bbh_fewshot_formal_fallacies/exact_match_stderr ▁
# wandb:                               bbh_fewshot_geometric_shapes/exact_match ▁
# wandb:                        bbh_fewshot_geometric_shapes/exact_match_stderr ▁
# wandb:                                     bbh_fewshot_hyperbaton/exact_match ▁
# wandb:                              bbh_fewshot_hyperbaton/exact_match_stderr ▁
# wandb:                 bbh_fewshot_logical_deduction_five_objects/exact_match ▁
# wandb:          bbh_fewshot_logical_deduction_five_objects/exact_match_stderr ▁
# wandb:                bbh_fewshot_logical_deduction_seven_objects/exact_match ▁
# wandb:         bbh_fewshot_logical_deduction_seven_objects/exact_match_stderr ▁
# wandb:                bbh_fewshot_logical_deduction_three_objects/exact_match ▁
# wandb:         bbh_fewshot_logical_deduction_three_objects/exact_match_stderr ▁
# wandb:                           bbh_fewshot_movie_recommendation/exact_match ▁
# wandb:                    bbh_fewshot_movie_recommendation/exact_match_stderr ▁
# wandb:                       bbh_fewshot_multistep_arithmetic_two/exact_match ▁
# wandb:                bbh_fewshot_multistep_arithmetic_two/exact_match_stderr ▁
# wandb:                                       bbh_fewshot_navigate/exact_match ▁
# wandb:                                bbh_fewshot_navigate/exact_match_stderr ▁
# wandb:                                bbh_fewshot_object_counting/exact_match ▁
# wandb:                         bbh_fewshot_object_counting/exact_match_stderr ▁
# wandb:                            bbh_fewshot_penguins_in_a_table/exact_match ▁
# wandb:                     bbh_fewshot_penguins_in_a_table/exact_match_stderr ▁
# wandb:                bbh_fewshot_reasoning_about_colored_objects/exact_match ▁
# wandb:         bbh_fewshot_reasoning_about_colored_objects/exact_match_stderr ▁
# wandb:                                     bbh_fewshot_ruin_names/exact_match ▁
# wandb:                              bbh_fewshot_ruin_names/exact_match_stderr ▁
# wandb:            bbh_fewshot_salient_translation_error_detection/exact_match ▁
# wandb:     bbh_fewshot_salient_translation_error_detection/exact_match_stderr ▁
# wandb:                                         bbh_fewshot_snarks/exact_match ▁
# wandb:                                  bbh_fewshot_snarks/exact_match_stderr ▁
# wandb:                           bbh_fewshot_sports_understanding/exact_match ▁
# wandb:                    bbh_fewshot_sports_understanding/exact_match_stderr ▁
# wandb:                             bbh_fewshot_temporal_sequences/exact_match ▁
# wandb:                      bbh_fewshot_temporal_sequences/exact_match_stderr ▁
# wandb:         bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match ▁
# wandb:  bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match_stderr ▁
# wandb:        bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match ▁
# wandb: bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match_stderr ▁
# wandb:        bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match ▁
# wandb: bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match_stderr ▁
# wandb:                                    bbh_fewshot_web_of_lies/exact_match ▁
# wandb:                             bbh_fewshot_web_of_lies/exact_match_stderr ▁
# wandb:                                   bbh_fewshot_word_sorting/exact_match ▁
# wandb:                            bbh_fewshot_word_sorting/exact_match_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:                                                      bbh_fewshot/alias bbh_fewshot
# wandb:                                                bbh_fewshot/exact_match 0.33528
# wandb:                                         bbh_fewshot/exact_match_stderr 0.00544
# wandb:                                  bbh_fewshot_boolean_expressions/alias  - bbh_fewshot_boole...
# wandb:                            bbh_fewshot_boolean_expressions/exact_match 0.704
# wandb:                     bbh_fewshot_boolean_expressions/exact_match_stderr 0.02893
# wandb:                                     bbh_fewshot_causal_judgement/alias  - bbh_fewshot_causa...
# wandb:                               bbh_fewshot_causal_judgement/exact_match 0.54011
# wandb:                        bbh_fewshot_causal_judgement/exact_match_stderr 0.03654
# wandb:                                   bbh_fewshot_date_understanding/alias  - bbh_fewshot_date_...
# wandb:                             bbh_fewshot_date_understanding/exact_match 0.344
# wandb:                      bbh_fewshot_date_understanding/exact_match_stderr 0.0301
# wandb:                                    bbh_fewshot_disambiguation_qa/alias  - bbh_fewshot_disam...
# wandb:                              bbh_fewshot_disambiguation_qa/exact_match 0.412
# wandb:                       bbh_fewshot_disambiguation_qa/exact_match_stderr 0.03119
# wandb:                                       bbh_fewshot_dyck_languages/alias  - bbh_fewshot_dyck_...
# wandb:                                 bbh_fewshot_dyck_languages/exact_match 0.044
# wandb:                          bbh_fewshot_dyck_languages/exact_match_stderr 0.013
# wandb:                                     bbh_fewshot_formal_fallacies/alias  - bbh_fewshot_forma...
# wandb:                               bbh_fewshot_formal_fallacies/exact_match 0.468
# wandb:                        bbh_fewshot_formal_fallacies/exact_match_stderr 0.03162
# wandb:                                     bbh_fewshot_geometric_shapes/alias  - bbh_fewshot_geome...
# wandb:                               bbh_fewshot_geometric_shapes/exact_match 0.292
# wandb:                        bbh_fewshot_geometric_shapes/exact_match_stderr 0.02881
# wandb:                                           bbh_fewshot_hyperbaton/alias  - bbh_fewshot_hyper...
# wandb:                                     bbh_fewshot_hyperbaton/exact_match 0.544
# wandb:                              bbh_fewshot_hyperbaton/exact_match_stderr 0.03156
# wandb:                       bbh_fewshot_logical_deduction_five_objects/alias  - bbh_fewshot_logic...
# wandb:                 bbh_fewshot_logical_deduction_five_objects/exact_match 0.26
# wandb:          bbh_fewshot_logical_deduction_five_objects/exact_match_stderr 0.0278
bh_fewshot_tracking_shuffled_objects_five_objects/exact_match 0.18
# wandb:  bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match_stderr 0.02435
# wandb:              bbh_fewshot_tracking_shuffled_objects_seven_objects/alias  - bbh_fewshot_track...
# wandb:        bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match 0.16
# wandb: bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match_stderr 0.02323
# wandb:              bbh_fewshot_tracking_shuffled_objects_three_objects/alias  - bbh_fewshot_track...
# wandb:        bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match 0.312
# wandb: bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match_stderr 0.02936
# wandb:                                          bbh_fewshot_web_of_lies/alias  - bbh_fewshot_web_o...
# wandb:                                    bbh_fewshot_web_of_lies/exact_match 0.488
# wandb:                             bbh_fewshot_web_of_lies/exact_match_stderr 0.03168
# wandb:                                         bbh_fewshot_word_sorting/alias  - bbh_fewshot_word_...
# wandb:                                   bbh_fewshot_word_sorting/exact_match 0.224
# wandb:                            bbh_fewshot_word_sorting/exact_match_stderr 0.02642
# wandb:
# wandb: 🚀 View run Llama2-7b-chat-HF-NF4-bbh at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/slf8nnqc/workspace
# wandb: Synced 5 W&B file(s), 3 media file(s), 14 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240327_194734-slf8nnqc/logs

# %% [markdown]
# ### Evaluate Falcon 7B Instruct NF4

# %%
eval_model = "twhoool02/Falcon-7B-instruct-NF4"

# create directory to store results
results_dir = f"/content/drive/MyDrive/Evaluation/{eval_model}"
os.makedirs(results_dir, exist_ok=True)

# %% [markdown]
# #### MMLU
#
# 5-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)
#
# revision number is used in the code to ensure a newer version of falcon is not downloaded automatically

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Falcon-7B-instruct-NF4,revision="60aea9b60738dcc3b7cb04b76de4bff38706a397" \
    --tasks mmlu_stem,mmlu_social_sciences,mmlu_humanities,mmlu_other\
    --num_fewshot 5 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Falcon-7B-instruct-NF4-MMLU \
    --use_cache results_dir \
    --cache_requests true \
    --show_config
# Out:
# 2024-03-29 19:29:49.999981: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-29 19:29:50.000041: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-29 19:29:50.001660: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-29 19:29:51.259125: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240329_192957-6txf8er2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Falcon-7B-instruct-NF4-MMLU
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/6txf8er2/workspace
# 2024-03-29:19:29:58,179 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-29:19:30:04,015 INFO     [__main__.py:335] Selected Tasks: ['mmlu_humanities', 'mmlu_other', 'mmlu_social_sciences', 'mmlu_stem']
# 2024-03-29:19:30:04,016 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-29:19:30:04,017 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Falcon-7B-instruct-NF4', 'revision': '60aea9b60738dcc3b7cb04b76de4bff38706a397'}
# 2024-03-29:19:30:04,021 INFO     [huggingface.py:163] Using device 'cuda:0'
# 2024-03-29:19:30:06,413 WARNING  [big_modeling.py:448] You shouldn't move a model that is dispatched using accelerate hooks.
# 2024-03-29:19:30:06,509 INFO     [evaluator.py:195] Using cache at results_dir_rank0.db
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 5.86k/5.86k [00:00<00:00, 14.3MB/s]
# Downloading readme: 100% 1.11k/1.11k [00:00<00:00, 4.15MB/s]
# Downloading data: 100% 166M/166M [00:01<00:00, 85.6MB/s]
# Generating test split: 108 examples [00:00, 1123.91 examples/s]
# Generating validation split: 11 examples [00:00, 1942.30 examples/s]
# Generating dev split: 5 examples [00:00, 49.34 examples/s]
# Generating test split: 1534 examples [00:00, 7752.51 examples/s]
# Generating validation split: 170 examples [00:00, 10378.46 examples/s]
# Generating dev split: 5 examples [00:00, 55.93 examples/s]
# Generating test split: 165 examples [00:00, 1794.53 examples/s]
# Generating validation split: 18 examples [00:00, 2736.31 examples/s]
# Generating dev split: 5 examples [00:00, 59.11 examples/s]
# Generating test split: 126 examples [00:00, 1378.94 examples/s]
# Generating validation split: 14 examples [00:00, 3198.45 examples/s]
# Generating dev split: 5 examples [00:00, 58.71 examples/s]
# Generating test split: 237 examples [00:00, 2359.73 examples/s]
# Generating validation split: 26 examples [00:00, 3729.16 examples/s]
# Generating dev split: 5 examples [00:00, 57.57 examples/s]
# Generating test split: 121 examples [00:00, 1323.58 examples/s]
# Generating validation split: 13 examples [00:00, 2919.42 examples/s]
# Generating dev split: 5 examples [00:00, 58.48 examples/s]
# Generating test split: 346 examples [00:00, 3260.07 examples/s]
# Generating validation split: 38 examples [00:00, 5126.85 examples/s]
# Generating dev split: 5 examples [00:00, 59.15 examples/s]
# Generating test split: 324 examples [00:00, 3158.87 examples/s]
# Generating validation split: 35 examples [00:00, 5844.21 examples/s]
# Generating dev split: 5 examples [00:00, 58.74 examples/s]
# Generating test split: 163 examples [00:00, 1829.02 examples/s]
# Generating validation split: 18 examples [00:00, 3368.92 examples/s]
# Generating dev split: 5 examples [00:00, 59.56 examples/s]
# Generating test split: 895 examples [00:00, 6633.52 examples/s]
# Generating validation split: 100 examples [00:00, 10513.36 examples/s]
# Generating dev split: 5 examples [00:00, 58.66 examples/s]
# Generating test split: 311 examples [00:00, 3135.59 examples/s]
# Generating validation split: 34 examples [00:00, 6932.40 examples/s]
# Generating dev split: 5 examples [00:00, 59.02 examples/s]
# Generating test split: 204 examples [00:00, 2128.48 examples/s]
# Generating validation split: 22 examples [00:00, 3282.75 examples/s]
# Generating dev split: 5 examples [00:00, 57.55 examples/s]
# Generating test split: 171 examples [00:00, 1895.09 examples/s]
# Generating validation split: 19 examples [00:00, 4350.23 examples/s]
# Generating dev split: 5 examples [00:00, 57.39 examples/s]
# Generating test split: 272 examples [00:00, 2705.36 examples/s]
# Generating validation split: 31 examples [00:00, 5017.88 examples/s]
# Generating dev split: 5 examples [00:00, 58.70 examples/s]
# Generating test split: 282 examples [00:00, 2814.81 examples/s]
# Generating validation split: 31 examples [00:00, 4417.61 examples/s]
# Generating dev split: 5 examples [00:00, 58.89 examples/s]
# Generating test split: 103 examples [00:00, 1195.56 examples/s]
# Generating validation split: 11 examples [00:00, 2505.83 examples/s]
# Generating dev split: 5 examples [00:00, 56.81 examples/s]
# Generating test split: 173 examples [00:00, 1897.31 examples/s]
# Generating validation split: 22 examples [00:00, 5030.24 examples/s]
# Generating dev split: 5 examples [00:00, 60.14 examples/s]
# Generating test split: 783 examples [00:00, 6191.70 examples/s]
# Generating validation split: 86 examples [00:00, 11409.10 examples/s]
# Generating dev split: 5 examples [00:00, 57.59 examples/s]
# Generating test split: 166 examples [00:00, 1842.91 examples/s]
# Generating validation split: 18 examples [00:00, 3528.74 examples/s]
# Generating dev split: 5 examples [00:00, 57.16 examples/s]
# Generating test split: 234 examples [00:00, 2433.67 examples/s]
# Generating validation split: 25 examples [00:00, 4472.11 examples/s]
# Generating dev split: 5 examples [00:00, 59.18 examples/s]
# Generating test split: 223 examples [00:00, 2406.47 examples/s]
# Generating validation split: 23 examples [00:00, 4398.15 examples/s]
# Generating dev split: 5 examples [00:00, 58.55 examples/s]
# Generating test split: 100 examples [00:00, 1141.91 examples/s]
# Generating validation split: 11 examples [00:00, 3554.49 examples/s]
# Generating dev split: 5 examples [00:00, 58.66 examples/s]
# Generating test split: 100 examples [00:00, 1077.67 examples/s]
# Generating validation split: 11 examples [00:00, 3278.66 examples/s]
# Generating dev split: 5 examples [00:00, 58.82 examples/s]
# Generating test split: 100 examples [00:00, 1164.74 examples/s]
# Generating validation split: 10 examples [00:00, 3103.90 examples/s]
# Generating dev split: 5 examples [00:00, 58.30 examples/s]
# Generating test split: 265 examples [00:00, 2583.29 examples/s]
# Generating validation split: 29 examples [00:00, 5774.54 examples/s]
# Generating dev split: 5 examples [00:00, 60.38 examples/s]
# Generating test split: 306 examples [00:00, 3151.34 examples/s]
# Generating validation split: 33 examples [00:00, 5739.19 examples/s]
# Generating dev split: 5 examples [00:00, 58.52 examples/s]
# Generating test split: 238 examples [00:00, 2400.71 examples/s]
# Generating validation split: 26 examples [00:00, 4317.01 examples/s]
# Generating dev split: 5 examples [00:00, 57.82 examples/s]
# Generating test split: 131 examples [00:00, 1416.81 examples/s]
# Generating validation split: 12 examples [00:00, 2464.22 examples/s]
# Generating dev split: 5 examples [00:00, 56.26 examples/s]
# Generating test split: 390 examples [00:00, 3798.28 examples/s]
# Generating validation split: 43 examples [00:00, 7163.20 examples/s]
# Generating dev split: 5 examples [00:00, 58.50 examples/s]
# Generating test split: 100 examples [00:00, 1122.77 examples/s]
# Generating validation split: 11 examples [00:00, 2750.04 examples/s]
# Generating dev split: 5 examples [00:00, 58.49 examples/s]
# Generating test split: 201 examples [00:00, 2213.65 examples/s]
# Generating validation split: 22 examples [00:00, 3575.43 examples/s]
# Generating dev split: 5 examples [00:00, 58.31 examples/s]
# Generating test split: 114 examples [00:00, 1308.07 examples/s]
# Generating validation split: 12 examples [00:00, 2888.80 examples/s]
# Generating dev split: 5 examples [00:00, 57.70 examples/s]
# Generating test split: 245 examples [00:00, 2543.59 examples/s]
# Generating validation split: 27 examples [00:00, 3887.48 examples/s]
# Generating dev split: 5 examples [00:00, 58.59 examples/s]
# Generating test split: 612 examples [00:00, 5198.46 examples/s]
# Generating validation split: 69 examples [00:00, 7862.18 examples/s]
# Generating dev split: 5 examples [00:00, 57.46 examples/s]
# Generating test split: 193 examples [00:00, 2125.69 examples/s]
# Generating validation split: 21 examples [00:00, 5112.04 examples/s]
# Generating dev split: 5 examples [00:00, 59.37 examples/s]
# Generating test split: 545 examples [00:00, 4968.98 examples/s]
# Generating validation split: 60 examples [00:00, 7290.00 examples/s]
# Generating dev split: 5 examples [00:00, 58.17 examples/s]
# Generating test split: 110 examples [00:00, 1268.99 examples/s]
# Generating validation split: 12 examples [00:00, 2386.52 examples/s]
# Generating dev split: 5 examples [00:00, 59.04 examples/s]
# Generating test split: 198 examples [00:00, 2073.94 examples/s]
# Generating validation split: 22 examples [00:00, 5801.25 examples/s]
# Generating dev split: 5 examples [00:00, 59.07 examples/s]
# Generating test split: 135 examples [00:00, 1485.91 examples/s]
# Generating validation split: 14 examples [00:00, 3839.68 examples/s]
# Generating dev split: 5 examples [00:00, 58.84 examples/s]
# Generating test split: 203 examples [00:00, 2222.98 examples/s]
# Generating validation split: 22 examples [00:00, 3866.20 examples/s]
# Generating dev split: 5 examples [00:00, 59.29 examples/s]
# Generating test split: 144 examples [00:00, 1616.43 examples/s]
# Generating validation split: 16 examples [00:00, 2798.77 examples/s]
# Generating dev split: 5 examples [00:00, 58.44 examples/s]
# Generating test split: 100 examples [00:00, 1173.14 examples/s]
# Generating validation split: 11 examples [00:00, 3022.03 examples/s]
# Generating dev split: 5 examples [00:00, 58.05 examples/s]
# Generating test split: 378 examples [00:00, 3611.61 examples/s]
# Generating validation split: 41 examples [00:00, 6111.76 examples/s]
# Generating dev split: 5 examples [00:00, 59.34 examples/s]
# Generating test split: 216 examples [00:00, 2249.07 examples/s]
# Generating validation split: 23 examples [00:00, 4553.00 examples/s]
# Generating dev split: 5 examples [00:00, 58.29 examples/s]
# Generating test split: 100 examples [00:00, 1148.66 examples/s]
# Generating validation split: 11 examples [00:00, 2384.85 examples/s]
# Generating dev split: 5 examples [00:00, 57.81 examples/s]
# Generating test split: 145 examples [00:00, 1652.45 examples/s]
# Generating validation split: 16 examples [00:00, 3722.69 examples/s]
# Generating dev split: 5 examples [00:00, 57.20 examples/s]
# Generating test split: 235 examples [00:00, 2311.33 examples/s]
# Generating validation split: 26 examples [00:00, 6779.31 examples/s]
# Generating dev split: 5 examples [00:00, 58.27 examples/s]
# Generating test split: 100 examples [00:00, 1102.68 examples/s]
# Generating validation split: 11 examples [00:00, 2255.99 examples/s]
# Generating dev split: 5 examples [00:00, 58.55 examples/s]
# Generating test split: 112 examples [00:00, 1281.94 examples/s]
# Generating validation split: 11 examples [00:00, 2981.03 examples/s]
# Generating dev split: 5 examples [00:00, 58.63 examples/s]
# Generating test split: 102 examples [00:00, 1147.73 examples/s]
# Generating validation split: 11 examples [00:00, 3135.61 examples/s]
# Generating dev split: 5 examples [00:00, 58.15 examples/s]
# Generating test split: 100 examples [00:00, 1033.38 examples/s]
# Generating validation split: 11 examples [00:00, 2673.54 examples/s]
# Generating dev split: 5 examples [00:00, 59.63 examples/s]
# Generating test split: 100 examples [00:00, 1160.03 examples/s]
# Generating validation split: 9 examples [00:00, 2799.94 examples/s]
# Generating dev split: 5 examples [00:00, 59.64 examples/s]
# Generating test split: 152 examples [00:00, 1726.46 examples/s]
# Generating validation split: 16 examples [00:00, 4459.95 examples/s]
# Generating dev split: 5 examples [00:00, 57.29 examples/s]
# Generating test split: 270 examples [00:00, 2830.11 examples/s]
# Generating validation split: 29 examples [00:00, 6285.71 examples/s]
# Generating dev split: 5 examples [00:00, 58.77 examples/s]
# Generating test split: 310 examples [00:00, 3101.55 examples/s]
# Generating validation split: 32 examples [00:00, 6571.57 examples/s]
# Generating dev split: 5 examples [00:00, 58.52 examples/s]
# Generating test split: 100 examples [00:00, 1150.68 examples/s]
# Generating validation split: 8 examples [00:00, 1542.73 examples/s]
# Generating dev split: 5 examples [00:00, 57.94 examples/s]
# Generating test split: 151 examples [00:00, 1670.86 examples/s]
# Generating validation split: 17 examples [00:00, 3591.01 examples/s]
# Generating dev split: 5 examples [00:00, 57.56 examples/s]
# 2024-03-29:19:35:07,833 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_physics from None to 5
# 2024-03-29:19:35:07,833 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_chemistry from None to 5
# 2024-03-29:19:35:07,833 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_biology from None to 5
# 2024-03-29:19:35:07,833 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 5
# 2024-03-29:19:35:07,834 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_astronomy from None to 5
# 2024-03-29:19:35:07,834 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 5
# 2024-03-29:19:35:07,834 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_mathematics from None to 5
# 2024-03-29:19:35:07,834 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_physics from None to 5
# 2024-03-29:19:35:07,834 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_machine_learning from None to 5
# 2024-03-29:19:35:07,834 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_computer_science from None to 5
# 2024-03-29:19:35:07,834 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 5
# 2024-03-29:19:35:07,834 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 5
# 2024-03-29:19:35:07,834 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_computer_security from None to 5
# 2024-03-29:19:35:07,834 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 5
# 2024-03-29:19:35:07,834 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 5
# 2024-03-29:19:35:07,835 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 5
# 2024-03-29:19:35:07,835 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_biology from None to 5
# 2024-03-29:19:35:07,835 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 5
# 2024-03-29:19:35:07,835 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_anatomy from None to 5
# 2024-03-29:19:35:07,835 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_geography from None to 5
# 2024-03-29:19:35:07,835 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_public_relations from None to 5
# 2024-03-29:19:35:07,835 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_psychology from None to 5
# 2024-03-29:19:35:07,835 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_government_and_politics from None to 5
# 2024-03-29:19:35:07,835 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_psychology from None to 5
# 2024-03-29:19:35:07,835 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_security_studies from None to 5
# 2024-03-29:19:35:07,835 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_econometrics from None to 5
# 2024-03-29:19:35:07,835 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_sociology from None to 5
# 2024-03-29:19:35:07,836 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_us_foreign_policy from None to 5
# 2024-03-29:19:35:07,836 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_macroeconomics from None to 5
# 2024-03-29:19:35:07,836 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_human_sexuality from None to 5
# 2024-03-29:19:35:07,836 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_microeconomics from None to 5
# 2024-03-29:19:35:07,836 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_nutrition from None to 5
# 2024-03-29:19:35:07,836 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_clinical_knowledge from None to 5
# 2024-03-29:19:35:07,836 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_global_facts from None to 5
# 2024-03-29:19:35:07,836 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_business_ethics from None to 5
# 2024-03-29:19:35:07,836 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_medical_genetics from None to 5
# 2024-03-29:19:35:07,836 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_human_aging from None to 5
# 2024-03-29:19:35:07,836 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_marketing from None to 5
# 2024-03-29:19:35:07,837 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_virology from None to 5
# 2024-03-29:19:35:07,837 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_miscellaneous from None to 5
# 2024-03-29:19:35:07,837 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_medicine from None to 5
# 2024-03-29:19:35:07,837 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_management from None to 5
# 2024-03-29:19:35:07,837 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_accounting from None to 5
# 2024-03-29:19:35:07,837 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_medicine from None to 5
# 2024-03-29:19:35:07,837 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_world_religions from None to 5
# 2024-03-29:19:35:07,837 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_us_history from None to 5
# 2024-03-29:19:35:07,837 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_philosophy from None to 5
# 2024-03-29:19:35:07,837 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_moral_scenarios from None to 5
# 2024-03-29:19:35:07,837 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_logical_fallacies from None to 5
# 2024-03-29:19:35:07,837 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_prehistory from None to 5
# 2024-03-29:19:35:07,838 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_moral_disputes from None to 5
# 2024-03-29:19:35:07,838 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_international_law from None to 5
# 2024-03-29:19:35:07,838 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_world_history from None to 5
# 2024-03-29:19:35:07,838 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_formal_logic from None to 5
# 2024-03-29:19:35:07,838 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_european_history from None to 5
# 2024-03-29:19:35:07,838 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_law from None to 5
# 2024-03-29:19:35:07,838 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_jurisprudence from None to 5
# 2024-03-29:19:35:07,844 INFO     [task.py:395] Building contexts for mmlu_high_school_physics on rank 0...
# 100% 151/151 [00:02<00:00, 65.89it/s]
# 2024-03-29:19:35:10,196 INFO     [task.py:395] Building contexts for mmlu_college_chemistry on rank 0...
# 100% 100/100 [00:01<00:00, 66.26it/s]
# 2024-03-29:19:35:11,745 INFO     [task.py:395] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:04<00:00, 66.22it/s]
# 2024-03-29:19:35:16,545 INFO     [task.py:395] Building contexts for mmlu_high_school_mathematics on rank 0...
# 100% 270/270 [00:04<00:00, 66.45it/s]
# 2024-03-29:19:35:20,711 INFO     [task.py:395] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:02<00:00, 66.20it/s]
# 2024-03-29:19:35:23,066 INFO     [task.py:395] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 66.37it/s]
# 2024-03-29:19:35:24,613 INFO     [task.py:395] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:01<00:00, 66.62it/s]
# 2024-03-29:19:35:26,153 INFO     [task.py:395] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:01<00:00, 66.75it/s]
# 2024-03-29:19:35:27,722 INFO     [task.py:395] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:01<00:00, 66.43it/s]
# 2024-03-29:19:35:29,452 INFO     [task.py:395] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 66.68it/s]
# 2024-03-29:19:35:30,992 INFO     [task.py:395] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:03<00:00, 66.11it/s]
# 2024-03-29:19:35:34,641 INFO     [task.py:395] Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:02<00:00, 64.95it/s]
# 2024-03-29:19:35:36,930 INFO     [task.py:395] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:01<00:00, 66.35it/s]
# 2024-03-29:19:35:38,476 INFO     [task.py:395] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:03<00:00, 66.41it/s]
# 2024-03-29:19:35:41,814 INFO     [task.py:395] Building contexts for mmlu_elementary_mathematics on rank 0...
# 100% 378/378 [00:05<00:00, 66.53it/s]
# 2024-03-29:19:35:47,642 INFO     [task.py:395] Building contexts for mmlu_abstract_algebra on rank 0...
# 100% 100/100 [00:01<00:00, 66.77it/s]
# 2024-03-29:19:35:49,179 INFO     [task.py:395] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:02<00:00, 66.56it/s]
# 2024-03-29:19:35:51,398 INFO     [task.py:395] Building contexts for mmlu_high_school_chemistry on rank 0...
# 100% 203/203 [00:03<00:00, 66.65it/s]
# 2024-03-29:19:35:54,521 INFO     [task.py:395] Building contexts for mmlu_anatomy on rank 0...
# 100% 135/135 [00:02<00:00, 66.34it/s]
# 2024-03-29:19:35:56,607 INFO     [task.py:395] Building contexts for mmlu_high_school_geography on rank 0...
# 100% 198/198 [00:02<00:00, 66.31it/s]
# 2024-03-29:19:35:59,670 INFO     [task.py:395] Building contexts for mmlu_public_relations on rank 0...
# 100% 110/110 [00:01<00:00, 67.03it/s]
# 2024-03-29:19:36:01,353 INFO     [task.py:395] Building contexts for mmlu_high_school_psychology on rank 0...
# 100% 545/545 [00:08<00:00, 66.94it/s]
# 2024-03-29:19:36:09,704 INFO     [task.py:395] Building contexts for mmlu_high_school_government_and_politics on rank 0...
# 100% 193/193 [00:02<00:00, 66.46it/s]
# 2024-03-29:19:36:12,683 INFO     [task.py:395] Building contexts for mmlu_professional_psychology on rank 0...
# 100% 612/612 [00:09<00:00, 66.24it/s]
# 2024-03-29:19:36:22,155 INFO     [task.py:395] Building contexts for mmlu_security_studies on rank 0...
# 100% 245/245 [00:03<00:00, 66.34it/s]
# 2024-03-29:19:36:25,945 INFO     [task.py:395] Building contexts for mmlu_econometrics on rank 0...
# 100% 114/114 [00:01<00:00, 66.86it/s]
# 2024-03-29:19:36:27,694 INFO     [task.py:395] Building contexts for mmlu_sociology on rank 0...
# 100% 201/201 [00:03<00:00, 66.66it/s]
# 2024-03-29:19:36:30,785 INFO     [task.py:395] Building contexts for mmlu_us_foreign_policy on rank 0...
# 100% 100/100 [00:01<00:00, 66.60it/s]
# 2024-03-29:19:36:32,326 INFO     [task.py:395] Building contexts for mmlu_high_school_macroeconomics on rank 0...
# 100% 390/390 [00:05<00:00, 66.08it/s]
# 2024-03-29:19:36:38,377 INFO     [task.py:395] Building contexts for mmlu_human_sexuality on rank 0...
# 100% 131/131 [00:01<00:00, 67.01it/s]
# 2024-03-29:19:36:40,701 INFO     [task.py:395] Building contexts for mmlu_high_school_microeconomics on rank 0...
# 100% 238/238 [00:03<00:00, 66.13it/s]
# 2024-03-29:19:36:44,390 INFO     [task.py:395] Building contexts for mmlu_nutrition on rank 0...
# 100% 306/306 [00:04<00:00, 65.53it/s]
# 2024-03-29:19:36:49,177 INFO     [task.py:395] Building contexts for mmlu_clinical_knowledge on rank 0...
# 100% 265/265 [00:03<00:00, 66.74it/s]
# 2024-03-29:19:36:53,248 INFO     [task.py:395] Building contexts for mmlu_global_facts on rank 0...
# 100% 100/100 [00:01<00:00, 66.67it/s]
# 2024-03-29:19:36:54,787 INFO     [task.py:395] Building contexts for mmlu_business_ethics on rank 0...
# 100% 100/100 [00:01<00:00, 66.62it/s]
# 2024-03-29:19:36:56,328 INFO     [task.py:395] Building contexts for mmlu_medical_genetics on rank 0...
# 100% 100/100 [00:01<00:00, 66.83it/s]
# 2024-03-29:19:36:57,864 INFO     [task.py:395] Building contexts for mmlu_human_aging on rank 0...
# 100% 223/223 [00:03<00:00, 66.65it/s]
# 2024-03-29:19:37:01,294 INFO     [task.py:395] Building contexts for mmlu_marketing on rank 0...
# 100% 234/234 [00:03<00:00, 66.85it/s]
# 2024-03-29:19:37:04,882 INFO     [task.py:395] Building contexts for mmlu_virology on rank 0...
# 100% 166/166 [00:02<00:00, 66.47it/s]
# 2024-03-29:19:37:07,443 INFO     [task.py:395] Building contexts for mmlu_miscellaneous on rank 0...
# 100% 783/783 [00:11<00:00, 66.78it/s]
# 2024-03-29:19:37:19,462 INFO     [task.py:395] Building contexts for mmlu_college_medicine on rank 0...
# 100% 173/173 [00:02<00:00, 66.03it/s]
# 2024-03-29:19:37:22,149 INFO     [task.py:395] Building contexts for mmlu_management on rank 0...
# 100% 103/103 [00:01<00:00, 66.59it/s]
# 2024-03-29:19:37:23,736 INFO     [task.py:395] Building contexts for mmlu_professional_accounting on rank 0...
# 100% 282/282 [00:04<00:00, 66.72it/s]
# 2024-03-29:19:37:28,072 INFO     [task.py:395] Building contexts for mmlu_professional_medicine on rank 0...
# 100% 272/272 [00:04<00:00, 66.35it/s]
# 2024-03-29:19:37:32,278 INFO     [task.py:395] Building contexts for mmlu_world_religions on rank 0...
# 100% 171/171 [00:02<00:00, 66.11it/s]
# 2024-03-29:19:37:34,931 INFO     [task.py:395] Building contexts for mmlu_high_school_us_history on rank 0...
# 100% 204/204 [00:03<00:00, 66.65it/s]
# 2024-03-29:19:37:38,075 INFO     [task.py:395] Building contexts for mmlu_philosophy on rank 0...
# 100% 311/311 [00:04<00:00, 66.76it/s]
# 2024-03-29:19:37:42,856 INFO     [task.py:395] Building contexts for mmlu_moral_scenarios on rank 0...
# 100% 895/895 [00:13<00:00, 66.21it/s]
# 2024-03-29:19:37:56,714 INFO     [task.py:395] Building contexts for mmlu_logical_fallacies on rank 0...
# 100% 163/163 [00:02<00:00, 65.40it/s]
# 2024-03-29:19:37:59,270 INFO     [task.py:395] Building contexts for mmlu_prehistory on rank 0...
# 100% 324/324 [00:04<00:00, 65.95it/s]
# 2024-03-29:19:38:04,307 INFO     [task.py:395] Building contexts for mmlu_moral_disputes on rank 0...
# 100% 346/346 [00:05<00:00, 66.10it/s]
# 2024-03-29:19:38:09,682 INFO     [task.py:395] Building contexts for mmlu_international_law on rank 0...
# 100% 121/121 [00:01<00:00, 66.11it/s]
# 2024-03-29:19:38:11,560 INFO     [task.py:395] Building contexts for mmlu_high_school_world_history on rank 0...
# 100% 237/237 [00:03<00:00, 66.50it/s]
# 2024-03-29:19:38:15,220 INFO     [task.py:395] Building contexts for mmlu_formal_logic on rank 0...
# 100% 126/126 [00:01<00:00, 66.29it/s]
# 2024-03-29:19:38:17,170 INFO     [task.py:395] Building contexts for mmlu_high_school_european_history on rank 0...
# 100% 165/165 [00:02<00:00, 66.38it/s]
# 2024-03-29:19:38:19,730 INFO     [task.py:395] Building contexts for mmlu_professional_law on rank 0...
# 100% 1534/1534 [00:23<00:00, 65.13it/s]
# 2024-03-29:19:38:43,906 INFO     [task.py:395] Building contexts for mmlu_jurisprudence on rank 0...
# 100% 108/108 [00:01<00:00, 65.46it/s]
# 2024-03-29:19:38:45,601 INFO     [evaluator.py:379] Running loglikelihood requests
# 2024-03-29:19:38:45,624 INFO     [model.py:225] Loading 'loglikelihood' responses from cache 'results_dir_rank0.db' where possible...
# Checking cached requests: 100% 56168/56168 [00:09<00:00, 6237.58it/s]
# 2024-03-29:19:38:54,629 INFO     [model.py:249] Cached requests: 0, Requests remaining: 56168
# Token indices sequence length is longer than the specified maximum sequence length for this model (2228 > 2048). Running this sequence through the model will result in indexing errors
# Running loglikelihood requests:   0% 0/56168 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 16
# Running loglikelihood requests:  25% 13889/56168 [11:25<12:29, 56.43it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Running loglikelihood requests:  25% 13952/56168 [11:37<12:28, 56.43it/s]Determined largest batch size: 64
# Running loglikelihood requests: 100% 56168/56168 [19:42<00:00, 47.48it/s]
# {
#   "results": {
#     "mmlu_stem": {
#       "alias": "stem",
#       "acc,none": 0.22993973993022518,
#       "acc_stderr,none": 0.0074674599475831735
#     },
#     "mmlu_abstract_algebra": {
#       "alias": " - abstract_algebra",
#       "acc,none": 0.29,
#       "acc_stderr,none": 0.04560480215720683
#     },
#     "mmlu_anatomy": {
#       "alias": " - anatomy",
#       "acc,none": 0.1925925925925926,
#       "acc_stderr,none": 0.03406542058502653
#     },
#     "mmlu_astronomy": {
#       "alias": " - astronomy",
#       "acc,none": 0.24342105263157895,
#       "acc_stderr,none": 0.034923496688842384
#     },
#     "mmlu_college_biology": {
#       "alias": " - college_biology",
#       "acc,none": 0.2569444444444444,
#       "acc_stderr,none": 0.03653946969442099
#     },
#     "mmlu_college_chemistry": {
#       "alias": " - college_chemistry",
#       "acc,none": 0.19,
#       "acc_stderr,none": 0.039427724440366234
#     },
#     "mmlu_college_computer_science": {
#       "alias": " - college_computer_science",
#       "acc,none": 0.34,
#       "acc_stderr,none": 0.04760952285695236
#     },
#     "mmlu_college_mathematics": {
#       "alias": " - college_mathematics",
#       "acc,none": 0.27,
#       "acc_stderr,none": 0.0446196043338474
#     },
#     "mmlu_college_physics": {
#       "alias": " - college_physics",
#       "acc,none": 0.20588235294117646,
#       "acc_stderr,none": 0.040233822736177476
#     },
#     "mmlu_computer_security": {
#       "alias": " - computer_security",
#       "acc,none": 0.29,
#       "acc_stderr,none": 0.045604802157206845
#     },
#     "mmlu_conceptual_physics": {
#       "alias": " - conceptual_physics",
#       "acc,none": 0.28085106382978725,
#       "acc_stderr,none": 0.029379170464124825
#       "mmlu_public_relations",
#       "mmlu_high_school_psychology",
#       "mmlu_high_school_government_and_politics",
#       "mmlu_professional_psychology",
#       "mmlu_security_studies",
#       "mmlu_econometrics",
#       "mmlu_sociology",
#       "mmlu_us_foreign_policy",
#       "mmlu_high_school_macroeconomics",
#       "mmlu_human_sexuality",
#       "mmlu_high_school_microeconomics"
#     ],
#     "mmlu_stem": [
#       "mmlu_high_school_physics",
#       "mmlu_college_chemistry",
#       "mmlu_high_school_biology",
#       "mmlu_high_school_mathematics",
#       "mmlu_astronomy",
#       "mmlu_high_school_computer_science",
#       "mmlu_college_mathematics",
#       "mmlu_college_physics",
#       "mmlu_machine_learning",
#       "mmlu_college_computer_science",
#       "mmlu_conceptual_physics",
#       "mmlu_electrical_engineering",
#       "mmlu_computer_security",
#       "mmlu_high_school_statistics",
#       "mmlu_elementary_mathematics",
#       "mmlu_abstract_algebra",
#       "mmlu_college_biology",
#       "mmlu_high_school_chemistry",
#       "mmlu_anatomy"
#     ]
#   },
#   "configs": {
#     "mmlu_abstract_algebra": {
#       "task": "mmlu_abstract_algebra",
#       "task_alias": "abstract_algebra",
#       "group": "mmlu_stem",
#       "group_alias": "stem",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "abstract_algebra",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about abstract algebra.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
#     "mmlu_anatomy": {
#       "task": "mmlu_anatomy",
#       "task_alias": "anatomy",
#       "group": "mmlu_stem",
#       "group_alias": "stem",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "anatomy",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about anatomy.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
#     "mmlu_astronomy": {
#       "task": "mmlu_astronomy",
#       "task_alias": "astronomy",
#       "group": "mmlu_stem",
#       "group_alias": "stem",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "astronomy",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about astronomy.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
#     "mmlu_business_ethics": {
#       "task": "mmlu_business_ethics",
#       "task_alias": "business_ethics",
#       "group": "mmlu_other",
#       "group_alias": "other",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "business_ethics",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about business ethics.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
#     "mmlu_clinical_knowledge": {
#       "task": "mmlu_clinical_knowledge",
#       "task_alias": "clinical_knowledge",
#       "group": "mmlu_other",
#       "group_alias": "other",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "clinical_knowledge",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about clinical knowledge.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
# ...
# wandb:                    mmlu_machine_learning/acc_stderr ▁
# wandb:                                 mmlu_management/acc ▁
# wandb:                          mmlu_management/acc_stderr ▁
# wandb:                                  mmlu_marketing/acc ▁
# wandb:                           mmlu_marketing/acc_stderr ▁
# wandb:                           mmlu_medical_genetics/acc ▁
# wandb:                    mmlu_medical_genetics/acc_stderr ▁
# wandb:                              mmlu_miscellaneous/acc ▁
# wandb:                       mmlu_miscellaneous/acc_stderr ▁
# wandb:                             mmlu_moral_disputes/acc ▁
# wandb:                      mmlu_moral_disputes/acc_stderr ▁
# wandb:                            mmlu_moral_scenarios/acc ▁
# wandb:                     mmlu_moral_scenarios/acc_stderr ▁
# wandb:                                  mmlu_nutrition/acc ▁
# wandb:                           mmlu_nutrition/acc_stderr ▁
# wandb:                                      mmlu_other/acc ▁
# wandb:                               mmlu_other/acc_stderr ▁
# wandb:                                 mmlu_philosophy/acc ▁
# wandb:                          mmlu_philosophy/acc_stderr ▁
# wandb:                                 mmlu_prehistory/acc ▁
# wandb:                          mmlu_prehistory/acc_stderr ▁
# wandb:                    mmlu_professional_accounting/acc ▁
# wandb:             mmlu_professional_accounting/acc_stderr ▁
# wandb:                           mmlu_professional_law/acc ▁
# wandb:                    mmlu_professional_law/acc_stderr ▁
# wandb:                      mmlu_professional_medicine/acc ▁
# wandb:               mmlu_professional_medicine/acc_stderr ▁
# wandb:                    mmlu_professional_psychology/acc ▁
# wandb:             mmlu_professional_psychology/acc_stderr ▁
# wandb:                           mmlu_public_relations/acc ▁
# wandb:                    mmlu_public_relations/acc_stderr ▁
# wandb:                           mmlu_security_studies/acc ▁
# wandb:                    mmlu_security_studies/acc_stderr ▁
# wandb:                            mmlu_social_sciences/acc ▁
# wandb:                     mmlu_social_sciences/acc_stderr ▁
# wandb:                                  mmlu_sociology/acc ▁
# wandb:                           mmlu_sociology/acc_stderr ▁
# wandb:                                       mmlu_stem/acc ▁
# wandb:                                mmlu_stem/acc_stderr ▁
# wandb:                          mmlu_us_foreign_policy/acc ▁
# wandb:                   mmlu_us_foreign_policy/acc_stderr ▁
# wandb:                                   mmlu_virology/acc ▁
# wandb:                            mmlu_virology/acc_stderr ▁
# wandb:                            mmlu_world_religions/acc ▁
# wandb:                     mmlu_world_religions/acc_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:                           mmlu_abstract_algebra/acc 0.29
# wandb:                    mmlu_abstract_algebra/acc_stderr 0.0456
# wandb:                         mmlu_abstract_algebra/alias  - abstract_algebra
# wandb:                                    mmlu_anatomy/acc 0.19259
# wandb:                             mmlu_anatomy/acc_stderr 0.03407
# wandb:                                  mmlu_anatomy/alias  - anatomy
# wandb:                                  mmlu_astronomy/acc 0.24342
# wandb:                           mmlu_astronomy/acc_stderr 0.03492
# wandb:                                mmlu_astronomy/alias  - astronomy
# wandb:                            mmlu_business_ethics/acc 0.29
# wandb:                     mmlu_business_ethics/acc_stderr 0.0456
# wandb:                          mmlu_business_ethics/alias  - business_ethics
# wandb:                         mmlu_clinical_knowledge/acc 0.2566
# wandb:                  mmlu_clinical_knowledge/acc_stderr 0.02688
# wandb:                       mmlu_clinical_knowledge/alias  - clinical_knowledg...
# wandb:                            mmlu_college_biology/acc 0.25694
# wandb:                     mmlu_college_biology/acc_stderr 0.03654
# wandb:                          mmlu_college_biology/alias  - college_biology
# wandb:                          mmlu_college_chemistry/acc 0.19
# wandb:                   mmlu_college_chemistry/acc_stderr 0.03943
# wandb:                        mmlu_college_chemistry/alias  - college_chemistry...
# wandb:                   mmlu_college_computer_science/acc 0.34
# wandb:            mmlu_college_computer_science/acc_stderr 0.04761
# wandb:                 mmlu_college_computer_science/alias  - college_computer_...
# wandb:                        mmlu_college_mathematics/acc 0.27
# wandb:                 mmlu_college_mathematics/acc_stderr 0.04462
# wandb:                      mmlu_college_mathematics/alias  - college_mathemati...
# wandb:                           mmlu_college_medicine/acc 0.2659
# wandb:                    mmlu_college_medicine/acc_stderr 0.03369
# wandb:                         mmlu_college_medicine/alias  - college_medicine
# wandb:                            mmlu_college_physics/acc 0.20588
# wandb:                     mmlu_college_physics/acc_stderr 0.04023
# wandb:                          mmlu_college_physics/alias  - college_physics
# wandb:                          mmlu_computer_security/acc 0.29
# wandb:                   mmlu_computer_security/acc_stderr 0.0456
# wandb:                        mmlu_computer_security/alias  - computer_security...
# wandb:                         mmlu_conceptual_physics/acc 0.28085
# wandb:              mmlu_high_school_statistics/acc_stderr 0.02454
# wandb:                   mmlu_high_school_statistics/alias  - high_school_stati...
# wandb:                     mmlu_high_school_us_history/acc 0.20588
# wandb:              mmlu_high_school_us_history/acc_stderr 0.02838
# wandb:                   mmlu_high_school_us_history/alias  - high_school_us_hi...
# wandb:                  mmlu_high_school_world_history/acc 0.27426
# wandb:           mmlu_high_school_world_history/acc_stderr 0.02904
# wandb:                mmlu_high_school_world_history/alias  - high_school_world...
# wandb:                                mmlu_human_aging/acc 0.33184
# wandb:                         mmlu_human_aging/acc_stderr 0.0316
# wandb:                              mmlu_human_aging/alias  - human_aging
# wandb:                            mmlu_human_sexuality/acc 0.26718
# wandb:                     mmlu_human_sexuality/acc_stderr 0.03881
# wandb:                          mmlu_human_sexuality/alias  - human_sexuality
# wandb:                                 mmlu_humanities/acc 0.2525
# wandb:                          mmlu_humanities/acc_stderr 0.00634
# wandb:                               mmlu_humanities/alias humanities
# wandb:                          mmlu_international_law/acc 0.23967
# wandb:                   mmlu_international_law/acc_stderr 0.03897
# wandb:                        mmlu_international_law/alias  - international_law...
# wandb:                              mmlu_jurisprudence/acc 0.25926
# wandb:                       mmlu_jurisprudence/acc_stderr 0.04237
# wandb:                            mmlu_jurisprudence/alias  - jurisprudence
# wandb:                          mmlu_logical_fallacies/acc 0.22086
# wandb:                   mmlu_logical_fallacies/acc_stderr 0.03259
# wandb:                        mmlu_logical_fallacies/alias  - logical_fallacies...
# wandb:                           mmlu_machine_learning/acc 0.33036
# wandb:                    mmlu_machine_learning/acc_stderr 0.04464
# wandb:                         mmlu_machine_learning/alias  - machine_learning
# wandb:                                 mmlu_management/acc 0.29126
# wandb:                          mmlu_management/acc_stderr 0.04499
# wandb:                               mmlu_management/alias  - management
# wandb:                                  mmlu_marketing/acc 0.29915
# wandb:                           mmlu_marketing/acc_stderr 0.03
# wandb:                                mmlu_marketing/alias  - marketing
# wandb:                           mmlu_medical_genetics/acc 0.32
# wandb:                    mmlu_medical_genetics/acc_stderr 0.04688
# wandb:                         mmlu_medical_genetics/alias  - medical_genetics
# wandb:                              mmlu_miscellaneous/acc 0.27458
# wandb:                       mmlu_miscellaneous/acc_stderr 0.01596
# wandb:                            mmlu_miscellaneous/alias  - miscellaneous
# wandb:                             mmlu_moral_disputes/acc 0.25434
# wandb:                      mmlu_moral_disputes/acc_stderr 0.02345
# wandb:                           mmlu_moral_disputes/alias  - moral_disputes
# wandb:                            mmlu_moral_scenarios/acc 0.25475
# wandb:                     mmlu_moral_scenarios/acc_stderr 0.01457
# wandb:                          mmlu_moral_scenarios/alias  - moral_scenarios
# wandb:                                  mmlu_nutrition/acc 0.22549
# wandb:                           mmlu_nutrition/acc_stderr 0.02393
# wandb:                                mmlu_nutrition/alias  - nutrition
# wandb:                                      mmlu_other/acc 0.27969
# wandb:                               mmlu_other/acc_stderr 0.00804
# wandb:                                    mmlu_other/alias other
# wandb:                                 mmlu_philosophy/acc 0.25723
# wandb:                          mmlu_philosophy/acc_stderr 0.02483
# wandb:                               mmlu_philosophy/alias  - philosophy
# wandb:                                 mmlu_prehistory/acc 0.24691
# wandb:                          mmlu_prehistory/acc_stderr 0.02399
# wandb:                               mmlu_prehistory/alias  - prehistory
# wandb:                    mmlu_professional_accounting/acc 0.24468
# wandb:             mmlu_professional_accounting/acc_stderr 0.02565
# wandb:                  mmlu_professional_accounting/alias  - professional_acco...
# wandb:                           mmlu_professional_law/acc 0.24837
# wandb:                    mmlu_professional_law/acc_stderr 0.01104
# wandb:                         mmlu_professional_law/alias  - professional_law
# wandb:                      mmlu_professional_medicine/acc 0.34559
# wandb:               mmlu_professional_medicine/acc_stderr 0.02889
# wandb:                    mmlu_professional_medicine/alias  - professional_medi...
# wandb:                    mmlu_professional_psychology/acc 0.22549
# wandb:             mmlu_professional_psychology/acc_stderr 0.01691
# wandb:                  mmlu_professional_psychology/alias  - professional_psyc...
# wandb:                           mmlu_public_relations/acc 0.30909
# wandb:                    mmlu_public_relations/acc_stderr 0.04426
# wandb:                         mmlu_public_relations/alias  - public_relations
# wandb:                           mmlu_security_studies/acc 0.19184
# wandb:                    mmlu_security_studies/acc_stderr 0.02521
# wandb:                         mmlu_security_studies/alias  - security_studies
# wandb:                            mmlu_social_sciences/acc 0.23562
# wandb:                     mmlu_social_sciences/acc_stderr 0.00764
# wandb:                          mmlu_social_sciences/alias social_sciences
# wandb:                                  mmlu_sociology/acc 0.24876
# wandb:                           mmlu_sociology/acc_stderr 0.03057
# wandb:                                mmlu_sociology/alias  - sociology
# wandb:                                       mmlu_stem/acc 0.22994
# wandb:                                mmlu_stem/acc_stderr 0.00747
# wandb:                                     mmlu_stem/alias stem
# wandb:                          mmlu_us_foreign_policy/acc 0.36
# wandb:                   mmlu_us_foreign_policy/acc_stderr 0.04824
# wandb:                        mmlu_us_foreign_policy/alias  - us_foreign_policy...
# wandb:                                   mmlu_virology/acc 0.3012
# wandb:                            mmlu_virology/acc_stderr 0.03572
# wandb:                                 mmlu_virology/alias  - virology
# wandb:                            mmlu_world_religions/acc 0.32749
# wandb:                     mmlu_world_religions/acc_stderr 0.03599
# wandb:                          mmlu_world_religions/alias  - world_religions
# wandb:
# wandb: 🚀 View run Falcon-7B-instruct-NF4-MMLU at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/6txf8er2/workspace
# wandb: Synced 5 W&B file(s), 6 media file(s), 25 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240329_192957-6txf8er2/logs

# %% [markdown]
# #### HellaSwag
#
# 0-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Falcon-7B-instruct-NF4,revision="60aea9b60738dcc3b7cb04b76de4bff38706a397" \
    --tasks hellaswag \
    --num_fewshot 0 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir_hellaswag \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Falcon-7B-instruct-NF4-Hellaswag \
    --use_cache results_dir_hellaswag \
    --cache_requests true \
    --show_config
# Out:
# 2024-03-29 20:24:42.233366: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-29 20:24:42.233419: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-29 20:24:42.235078: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-29 20:24:43.418407: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240329_202448-b9q0sfwh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Falcon-7B-instruct-NF4-Hellaswag
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/b9q0sfwh/workspace
# 2024-03-29:20:24:50,196 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-29:20:24:56,233 INFO     [__main__.py:335] Selected Tasks: ['hellaswag']
# 2024-03-29:20:24:56,234 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-29:20:24:56,234 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Falcon-7B-instruct-NF4', 'revision': '60aea9b60738dcc3b7cb04b76de4bff38706a397'}
# 2024-03-29:20:24:56,238 INFO     [huggingface.py:163] Using device 'cuda:0'
# 2024-03-29:20:24:58,349 WARNING  [big_modeling.py:448] You shouldn't move a model that is dispatched using accelerate hooks.
# 2024-03-29:20:24:58,451 INFO     [evaluator.py:195] Using cache at results_dir_hellaswag_rank0.db
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2024-03-29:20:25:09,629 WARNING  [evaluator.py:239] Overwriting default num_fewshot of hellaswag from None to 0
# 2024-03-29:20:25:10,191 INFO     [evaluator.py:379] Running loglikelihood requests
# 2024-03-29:20:25:10,208 INFO     [model.py:225] Loading 'loglikelihood' responses from cache 'results_dir_hellaswag_rank0.db' where possible...
# Checking cached requests: 100% 40168/40168 [00:06<00:00, 6329.58it/s]
# 2024-03-29:20:25:16,555 INFO     [model.py:249] Cached requests: 0, Requests remaining: 40168
# Running loglikelihood requests:   0% 0/40168 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests:  25% 9930/40168 [01:37<04:21, 115.75it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests: 100% 40168/40168 [04:46<00:00, 140.39it/s]
# {
#   "results": {
#     "hellaswag": {
#       "acc,none": 0.5121489743079068,
#       "acc_stderr,none": 0.004988308234687276,
#       "acc_norm,none": 0.6916948814977096,
#       "acc_norm_stderr,none": 0.00460849546986036,
#       "alias": "hellaswag"
#     }
#   },
#   "group_subtasks": {
#     "hellaswag": []
#   },
#   "configs": {
#     "hellaswag": {
#       "task": "hellaswag",
#       "group": [
#         "multiple_choice"
#       ],
#       "dataset_path": "hellaswag",
#       "training_split": "train",
#       "validation_split": "validation",
#       "process_docs": "def process_docs(dataset: datasets.Dataset) -> datasets.Dataset:\n    def _process_doc(doc):\n        ctx = doc[\"ctx_a\"] + \" \" + doc[\"ctx_b\"].capitalize()\n        out_doc = {\n            \"query\": preprocess(doc[\"activity_label\"] + \": \" + ctx),\n            \"choices\": [preprocess(ending) for ending in doc[\"endings\"]],\n            \"gold\": int(doc[\"label\"]),\n        }\n        return out_doc\n\n    return dataset.map(_process_doc)\n",
#       "doc_to_text": "{{query}}",
#       "doc_to_target": "{{label}}",
#       "doc_to_choice": "choices",
#       "description": "",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         },
#         {
#           "metric": "acc_norm",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0
#       }
#     }
#   },
#   "versions": {
#     "hellaswag": 1.0
#   },
#   "n-shot": {
#     "hellaswag": 0
#   },
#   "config": {
#     "model": "hf",
#     "model_args": "pretrained=twhoool02/Falcon-7B-instruct-NF4,revision=60aea9b60738dcc3b7cb04b76de4bff38706a397",
#     "batch_size": "auto:4",
#     "batch_sizes": [
#       64,
#       64,
#       64,
#       64,
#       64
#     ],
#     "device": "cuda:0",
#     "use_cache": "results_dir_hellaswag",
#     "limit": null,
#     "bootstrap_iters": 100000,
#     "gen_kwargs": null
#   },
#   "git_hash": "ab7cc6b1",
#   "date": 1711743896.2338846,
#   "pretty_env_info": "PyTorch version: 2.2.1+cu121\nIs debug build: False\nCUDA used to build PyTorch: 12.1\nROCM used to build PyTorch: N/A\n\nOS: Ubuntu 22.04.3 LTS (x86_64)\nGCC version: (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0\nClang version: 14.0.0-1ubuntu1.1\nCMake version: version 3.27.9\nLibc version: glibc-2.35\n\nPython version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0] (64-bit runtime)\nPython platform: Linux-6.1.58+-x86_64-with-glibc2.35\nIs CUDA available: True\nCUDA runtime version: 12.2.140\nCUDA_MODULE_LOADING set to: LAZY\nGPU models and configuration: GPU 0: NVIDIA A100-SXM4-40GB\nNvidia driver version: 535.104.05\ncuDNN version: Probably one of the following:\n/usr/lib/x86_64-linux-gnu/libcudnn.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_train.so.8.9.6\nHIP runtime version: N/A\nMIOpen runtime version: N/A\nIs XNNPACK available: True\n\nCPU:\nArchitecture:                       x86_64\nCPU op-mode(s):                     32-bit, 64-bit\nAddress sizes:                      46 bits physical, 48 bits virtual\nByte Order:                         Little Endian\nCPU(s):                             12\nOn-line CPU(s) list:                0-11\nVendor ID:                          GenuineIntel\nModel name:                         Intel(R) Xeon(R) CPU @ 2.20GHz\nCPU family:                         6\nModel:                              85\nThread(s) per core:                 2\nCore(s) per socket:                 6\nSocket(s):                          1\nStepping:                           7\nBogoMIPS:                           4400.31\nFlags:                              fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp ibrs_enhanced fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat avx512_vnni md_clear arch_capabilities\nHypervisor vendor:                  KVM\nVirtualization type:                full\nL1d cache:                          192 KiB (6 instances)\nL1i cache:                          192 KiB (6 instances)\nL2 cache:                           6 MiB (6 instances)\nL3 cache:                           38.5 MiB (1 instance)\nNUMA node(s):                       1\nNUMA node0 CPU(s):                  0-11\nVulnerability Gather data sampling: Not affected\nVulnerability Itlb multihit:        Not affected\nVulnerability L1tf:                 Not affected\nVulnerability Mds:                  Vulnerable; SMT Host state unknown\nVulnerability Meltdown:             Not affected\nVulnerability Mmio stale data:      Vulnerable\nVulnerability Retbleed:             Vulnerable\nVulnerability Spec rstack overflow: Not affected\nVulnerability Spec store bypass:    Vulnerable\nVulnerability Spectre v1:           Vulnerable: __user pointer sanitization and usercopy barriers only; no swapgs barriers\nVulnerability Spectre v2:           Vulnerable, IBPB: disabled, STIBP: disabled, PBRSB-eIBRS: Vulnerable\nVulnerability Srbds:                Not affected\nVulnerability Tsx async abort:      Vulnerable\n\nVersions of relevant libraries:\n[pip3] numpy==1.25.2\n[pip3] torch==2.2.1+cu121\n[pip3] torchaudio==2.2.1+cu121\n[pip3] torchdata==0.7.1\n[pip3] torchsummary==1.5.1\n[pip3] torchtext==0.17.1\n[pip3] torchvision==0.17.1+cu121\n[pip3] triton==2.2.0\n[conda] Could not collect",
#   "transformers_version": "4.38.2",
#   "upper_git_hash": null
# }
# hf (pretrained=twhoool02/Falcon-7B-instruct-NF4,revision=60aea9b60738dcc3b7cb04b76de4bff38706a397), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: auto:4 (64,64,64,64,64)
# |  Tasks  |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |---------|------:|------|-----:|--------|-----:|---|-----:|
# |hellaswag|      1|none  |     0|acc     |0.5121|±  |0.0050|
# |         |       |none  |     0|acc_norm|0.6917|±  |0.0046|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:             hellaswag/acc ▁
# wandb:        hellaswag/acc_norm ▁
# wandb: hellaswag/acc_norm_stderr ▁
# wandb:      hellaswag/acc_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:             hellaswag/acc 0.51215
# wandb:        hellaswag/acc_norm 0.69169
# wandb: hellaswag/acc_norm_stderr 0.00461
# wandb:      hellaswag/acc_stderr 0.00499
# wandb:           hellaswag/alias hellaswag
# wandb:
# wandb: 🚀 View run Falcon-7B-instruct-NF4-Hellaswag at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/b9q0sfwh/workspace
# wandb: Synced 5 W&B file(s), 2 media file(s), 3 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240329_202448-b9q0sfwh/logs

# %% [markdown]
# #### BoolQ
#
# 0-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Falcon-7B-instruct-NF4,revision="60aea9b60738dcc3b7cb04b76de4bff38706a397" \
    --tasks boolq \
    --num_fewshot 0 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir_boolq \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Falcon-7B-instruct-NF4-BoolQ \
    --use_cache results_dir_boolq \
    --cache_requests true \
    --show_config
# Out:
# 2024-03-29 20:31:20.465992: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-29 20:31:20.466045: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-29 20:31:20.467493: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-29 20:31:21.679162: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240329_203127-odc7rrpp
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Falcon-7B-instruct-NF4-BoolQ
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/odc7rrpp/workspace
# 2024-03-29:20:31:28,715 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-29:20:31:34,615 INFO     [__main__.py:335] Selected Tasks: ['boolq']
# 2024-03-29:20:31:34,616 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-29:20:31:34,617 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Falcon-7B-instruct-NF4', 'revision': '60aea9b60738dcc3b7cb04b76de4bff38706a397'}
# 2024-03-29:20:31:34,621 INFO     [huggingface.py:163] Using device 'cuda:0'
# 2024-03-29:20:31:36,771 WARNING  [big_modeling.py:448] You shouldn't move a model that is dispatched using accelerate hooks.
# 2024-03-29:20:31:36,875 INFO     [evaluator.py:195] Using cache at results_dir_boolq_rank0.db
# 2024-03-29:20:31:36,879 WARNING  [task.py:763] [Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# 2024-03-29:20:31:36,880 WARNING  [task.py:775] [Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# 2024-03-29:20:31:42,125 WARNING  [evaluator.py:239] Overwriting default num_fewshot of boolq from None to 0
# 2024-03-29:20:31:42,152 INFO     [evaluator.py:379] Running loglikelihood requests
# 2024-03-29:20:31:42,154 INFO     [model.py:225] Loading 'loglikelihood' responses from cache 'results_dir_boolq_rank0.db' where possible...
# Checking cached requests: 100% 6540/6540 [00:01<00:00, 5522.46it/s]
# 2024-03-29:20:31:43,339 INFO     [model.py:249] Cached requests: 0, Requests remaining: 6540
# Running loglikelihood requests:   0% 0/6540 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 32
# Running loglikelihood requests:  24% 1537/6540 [00:50<00:42, 118.81it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests: 100% 6540/6540 [01:21<00:00, 79.96it/s]
# {
#   "results": {
#     "boolq": {
#       "acc,none": 0.7125382262996942,
#       "acc_stderr,none": 0.007915651663295328,
#       "alias": "boolq"
#     }
#   },
#   "group_subtasks": {
#     "boolq": []
#   },
#   "configs": {
#     "boolq": {
#       "task": "boolq",
#       "group": [
#         "super-glue-lm-eval-v1"
#       ],
#       "dataset_path": "super_glue",
#       "dataset_name": "boolq",
#       "training_split": "train",
#       "validation_split": "validation",
#       "doc_to_text": "{{passage}}\nQuestion: {{question}}?\nAnswer:",
#       "doc_to_target": "label",
#       "doc_to_choice": [
#         "no",
#         "yes"
#       ],
#       "description": "",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "acc"
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": true,
#       "doc_to_decontamination_query": "passage",
#       "metadata": {
#         "version": 2.0
#       }
#     }
#   },
#   "versions": {
#     "boolq": 2.0
#   },
#   "n-shot": {
#     "boolq": 0
#   },
#   "config": {
#     "model": "hf",
#     "model_args": "pretrained=twhoool02/Falcon-7B-instruct-NF4,revision=60aea9b60738dcc3b7cb04b76de4bff38706a397",
#     "batch_size": "auto:4",
#     "batch_sizes": [
#       32,
#       64,
#       64,
#       64,
#       64
#     ],
#     "device": "cuda:0",
#     "use_cache": "results_dir_boolq",
#     "limit": null,
#     "bootstrap_iters": 100000,
#     "gen_kwargs": null
#   },
#   "git_hash": "ab7cc6b1",
#   "date": 1711744294.6165152,
#   "pretty_env_info": "PyTorch version: 2.2.1+cu121\nIs debug build: False\nCUDA used to build PyTorch: 12.1\nROCM used to build PyTorch: N/A\n\nOS: Ubuntu 22.04.3 LTS (x86_64)\nGCC version: (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0\nClang version: 14.0.0-1ubuntu1.1\nCMake version: version 3.27.9\nLibc version: glibc-2.35\n\nPython version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0] (64-bit runtime)\nPython platform: Linux-6.1.58+-x86_64-with-glibc2.35\nIs CUDA available: True\nCUDA runtime version: 12.2.140\nCUDA_MODULE_LOADING set to: LAZY\nGPU models and configuration: GPU 0: NVIDIA A100-SXM4-40GB\nNvidia driver version: 535.104.05\ncuDNN version: Probably one of the following:\n/usr/lib/x86_64-linux-gnu/libcudnn.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_train.so.8.9.6\nHIP runtime version: N/A\nMIOpen runtime version: N/A\nIs XNNPACK available: True\n\nCPU:\nArchitecture:                       x86_64\nCPU op-mode(s):                     32-bit, 64-bit\nAddress sizes:                      46 bits physical, 48 bits virtual\nByte Order:                         Little Endian\nCPU(s):                             12\nOn-line CPU(s) list:                0-11\nVendor ID:                          GenuineIntel\nModel name:                         Intel(R) Xeon(R) CPU @ 2.20GHz\nCPU family:                         6\nModel:                              85\nThread(s) per core:                 2\nCore(s) per socket:                 6\nSocket(s):                          1\nStepping:                           7\nBogoMIPS:                           4400.31\nFlags:                              fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp ibrs_enhanced fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat avx512_vnni md_clear arch_capabilities\nHypervisor vendor:                  KVM\nVirtualization type:                full\nL1d cache:                          192 KiB (6 instances)\nL1i cache:                          192 KiB (6 instances)\nL2 cache:                           6 MiB (6 instances)\nL3 cache:                           38.5 MiB (1 instance)\nNUMA node(s):                       1\nNUMA node0 CPU(s):                  0-11\nVulnerability Gather data sampling: Not affected\nVulnerability Itlb multihit:        Not affected\nVulnerability L1tf:                 Not affected\nVulnerability Mds:                  Vulnerable; SMT Host state unknown\nVulnerability Meltdown:             Not affected\nVulnerability Mmio stale data:      Vulnerable\nVulnerability Retbleed:             Vulnerable\nVulnerability Spec rstack overflow: Not affected\nVulnerability Spec store bypass:    Vulnerable\nVulnerability Spectre v1:           Vulnerable: __user pointer sanitization and usercopy barriers only; no swapgs barriers\nVulnerability Spectre v2:           Vulnerable, IBPB: disabled, STIBP: disabled, PBRSB-eIBRS: Vulnerable\nVulnerability Srbds:                Not affected\nVulnerability Tsx async abort:      Vulnerable\n\nVersions of relevant libraries:\n[pip3] numpy==1.25.2\n[pip3] torch==2.2.1+cu121\n[pip3] torchaudio==2.2.1+cu121\n[pip3] torchdata==0.7.1\n[pip3] torchsummary==1.5.1\n[pip3] torchtext==0.17.1\n[pip3] torchvision==0.17.1+cu121\n[pip3] triton==2.2.0\n[conda] Could not collect",
#   "transformers_version": "4.38.2",
#   "upper_git_hash": null
# }
# hf (pretrained=twhoool02/Falcon-7B-instruct-NF4,revision=60aea9b60738dcc3b7cb04b76de4bff38706a397), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: auto:4 (32,64,64,64,64)
# |Tasks|Version|Filter|n-shot|Metric|Value |   |Stderr|
# |-----|------:|------|-----:|------|-----:|---|-----:|
# |boolq|      2|none  |     0|acc   |0.7125|±  |0.0079|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:        boolq/acc ▁
# wandb: boolq/acc_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:        boolq/acc 0.71254
# wandb: boolq/acc_stderr 0.00792
# wandb:      boolq/alias boolq
# wandb:
# wandb: 🚀 View run Falcon-7B-instruct-NF4-BoolQ at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/odc7rrpp/workspace
# wandb: Synced 5 W&B file(s), 2 media file(s), 3 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240329_203127-odc7rrpp/logs

# %% [markdown]
# #### BBH - no score returned
#
# 3-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Falcon-7B-instruct-NF4,revision="60aea9b60738dcc3b7cb04b76de4bff38706a397",do_sample=True \
    --tasks bbh_fewshot \
    --num_fewshot 3 \
    --device cuda:0 \
    --batch_size 2 \
    --verbosity INFO \
    --output_path results_dir_falcon_bbh \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Falcon-7B-instruct-NF4-BBH \
    --use_cache results_dir_falcon_bbh \
    --cache_requests true \
    --write_out \
    --show_config
# Out:
# 2024-04-04 12:10:11.198989: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-04 12:10:11.199047: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-04 12:10:11.200987: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-04 12:10:12.465036: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.6
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240404_121017-ymp3km50
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Falcon-7B-instruct-NF4-BBH
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/ymp3km50
# 2024-04-04:12:10:19,062 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-04-04:12:10:25,246 INFO     [__main__.py:335] Selected Tasks: ['bbh_fewshot']
# 2024-04-04:12:10:25,247 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-04-04:12:10:25,247 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Falcon-7B-instruct-NF4', 'revision': '60aea9b60738dcc3b7cb04b76de4bff38706a397', 'do_sample': True}
# 2024-04-04:12:10:25,252 INFO     [huggingface.py:163] Using device 'cuda:0'
# config.json: 100% 1.87k/1.87k [00:00<00:00, 4.57MB/s]
# model.safetensors: 100% 4.01G/4.01G [03:58<00:00, 16.8MB/s]
# generation_config.json: 100% 113/113 [00:00<00:00, 376kB/s]
# 2024-04-04:12:14:29,152 WARNING  [big_modeling.py:448] You shouldn't move a model that is dispatched using accelerate hooks.
# tokenizer_config.json: 100% 2.64k/2.64k [00:00<00:00, 7.76MB/s]
# tokenizer.json: 100% 2.73M/2.73M [00:00<00:00, 5.51MB/s]
# special_tokens_map.json: 100% 427/427 [00:00<00:00, 1.35MB/s]
# 2024-04-04:12:14:32,279 INFO     [evaluator.py:195] Using cache at results_dir_falcon_bbh_rank0.db
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for lukaemon/bbh contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/lukaemon/bbh
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 4.54k/4.54k [00:00<00:00, 10.3MB/s]
# Downloading readme: 100% 6.77k/6.77k [00:00<00:00, 13.9MB/s]
# Downloading data: 85.3kB [00:00, 68.6MB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 9623.94 examples/s]
# 2024-04-04:12:15:04,550 WARNING  [task.py:322] [Task: bbh_fewshot_disambiguation_qa] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:15:04,551 WARNING  [task.py:322] [Task: bbh_fewshot_disambiguation_qa] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.4k/10.4k [00:00<00:00, 26.5kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 17637.35 examples/s]
# 2024-04-04:12:15:16,258 WARNING  [task.py:322] [Task: bbh_fewshot_hyperbaton] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:15:16,258 WARNING  [task.py:322] [Task: bbh_fewshot_hyperbaton] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.0k/10.0k [00:00<00:00, 26.4kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 118751.53 examples/s]
# 2024-04-04:12:15:24,042 WARNING  [task.py:322] [Task: bbh_fewshot_dyck_languages] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:15:24,043 WARNING  [task.py:322] [Task: bbh_fewshot_dyck_languages] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 35.8k/35.8k [00:00<00:00, 129kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 72858.25 examples/s]
# 2024-04-04:12:15:31,557 WARNING  [task.py:322] [Task: bbh_fewshot_formal_fallacies] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:15:31,557 WARNING  [task.py:322] [Task: bbh_fewshot_formal_fallacies] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 49.1k/49.1k [00:00<00:00, 96.9kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 79836.76 examples/s]
# 2024-04-04:12:15:37,999 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:15:37,999 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 21.7k/21.7k [00:00<00:00, 79.5kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 114573.43 examples/s]
# 2024-04-04:12:15:43,554 WARNING  [task.py:322] [Task: bbh_fewshot_movie_recommendation] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:15:43,554 WARNING  [task.py:322] [Task: bbh_fewshot_movie_recommendation] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 25.1k/25.1k [00:00<00:00, 75.9kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 107601.44 examples/s]
# 2024-04-04:12:15:48,519 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_three_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:15:48,519 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_three_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 44.0k/44.0k [00:00<00:00, 86.5kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 71726.93 examples/s]
# 2024-04-04:12:15:54,577 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:15:54,578 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 33.5k/33.5k [00:00<00:00, 118kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 68288.90 examples/s]
# 2024-04-04:12:16:01,984 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_five_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:16:01,984 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_five_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 44.6k/44.6k [00:00<00:00, 160kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 114611.00 examples/s]
# 2024-04-04:12:16:07,375 WARNING  [task.py:322] [Task: bbh_fewshot_word_sorting] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:16:07,375 WARNING  [task.py:322] [Task: bbh_fewshot_word_sorting] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 16.4k/16.4k [00:00<00:00, 58.0kB/s]
# Generating test split: 100% 178/178 [00:00<00:00, 43690.67 examples/s]
# 2024-04-04:12:16:50,009 WARNING  [task.py:322] [Task: bbh_fewshot_snarks] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:16:50,009 WARNING  [task.py:322] [Task: bbh_fewshot_snarks] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 15.6k/15.6k [00:00<00:00, 57.5kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 100160.09 examples/s]
# 2024-04-04:12:16:55,706 WARNING  [task.py:322] [Task: bbh_fewshot_ruin_names] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:16:55,706 WARNING  [task.py:322] [Task: bbh_fewshot_ruin_names] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 69.5k/69.5k [00:00<00:00, 226kB/s]
# Generating test split: 100% 187/187 [00:00<00:00, 51093.40 examples/s]
# 2024-04-04:12:17:01,959 WARNING  [task.py:322] [Task: bbh_fewshot_causal_judgement] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:17:01,959 WARNING  [task.py:322] [Task: bbh_fewshot_causal_judgement] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 18.0k/18.0k [00:00<00:00, 65.3kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 116057.11 examples/s]
# 2024-04-04:12:17:08,221 WARNING  [task.py:322] [Task: bbh_fewshot_date_understanding] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:17:08,221 WARNING  [task.py:322] [Task: bbh_fewshot_date_understanding] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 56.9k/56.9k [00:00<00:00, 192kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 70511.47 examples/s]
# 2024-04-04:12:17:14,263 WARNING  [task.py:322] [Task: bbh_fewshot_salient_translation_error_detection] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:17:14,264 WARNING  [task.py:322] [Task: bbh_fewshot_salient_translation_error_detection] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.6k/10.6k [00:00<00:00, 38.8kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 100169.66 examples/s]
# 2024-04-04:12:17:20,815 WARNING  [task.py:322] [Task: bbh_fewshot_object_counting] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:17:20,816 WARNING  [task.py:322] [Task: bbh_fewshot_object_counting] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 35.6k/35.6k [00:00<00:00, 126kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 70782.77 examples/s]
# 2024-04-04:12:17:27,367 WARNING  [task.py:322] [Task: bbh_fewshot_temporal_sequences] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:17:27,367 WARNING  [task.py:322] [Task: bbh_fewshot_temporal_sequences] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 55.2kB [00:00, 58.0MB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 30543.12 examples/s]
# 2024-04-04:12:17:37,282 WARNING  [task.py:322] [Task: bbh_fewshot_navigate] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:17:37,282 WARNING  [task.py:322] [Task: bbh_fewshot_navigate] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 20.4k/20.4k [00:00<00:00, 71.1kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 95961.93 examples/s]
# 2024-04-04:12:17:42,165 WARNING  [task.py:322] [Task: bbh_fewshot_reasoning_about_colored_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:17:42,165 WARNING  [task.py:322] [Task: bbh_fewshot_reasoning_about_colored_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 21.6k/21.6k [00:00<00:00, 77.5kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 58426.26 examples/s]
# 2024-04-04:12:17:47,523 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_three_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:17:47,524 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_three_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 20.2k/20.2k [00:00<00:00, 70.2kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 109649.27 examples/s]
# 2024-04-04:12:17:51,852 WARNING  [task.py:322] [Task: bbh_fewshot_geometric_shapes] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:17:51,852 WARNING  [task.py:322] [Task: bbh_fewshot_geometric_shapes] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 15.6k/15.6k [00:00<00:00, 55.1kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 114124.51 examples/s]
# 2024-04-04:12:17:58,225 WARNING  [task.py:322] [Task: bbh_fewshot_web_of_lies] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:17:58,225 WARNING  [task.py:322] [Task: bbh_fewshot_web_of_lies] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.7k/10.7k [00:00<00:00, 27.3kB/s]
# Generating test split: 100% 146/146 [00:00<00:00, 64486.98 examples/s]
# 2024-04-04:12:18:04,168 WARNING  [task.py:322] [Task: bbh_fewshot_penguins_in_a_table] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:18:04,169 WARNING  [task.py:322] [Task: bbh_fewshot_penguins_in_a_table] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 8.16k/8.16k [00:00<00:00, 29.0kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 67070.23 examples/s]
# 2024-04-04:12:18:09,999 WARNING  [task.py:322] [Task: bbh_fewshot_sports_understanding] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:18:09,999 WARNING  [task.py:322] [Task: bbh_fewshot_sports_understanding] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 7.55k/7.55k [00:00<00:00, 10.3kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 100246.27 examples/s]
# 2024-04-04:12:18:16,135 WARNING  [task.py:322] [Task: bbh_fewshot_multistep_arithmetic_two] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:18:16,135 WARNING  [task.py:322] [Task: bbh_fewshot_multistep_arithmetic_two] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 37.1k/37.1k [00:00<00:00, 135kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 93731.65 examples/s]
# 2024-04-04:12:18:22,080 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_five_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:18:22,080 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_five_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 4.70k/4.70k [00:00<00:00, 16.9kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 116366.22 examples/s]
# 2024-04-04:12:18:26,531 WARNING  [task.py:322] [Task: bbh_fewshot_boolean_expressions] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:18:26,531 WARNING  [task.py:322] [Task: bbh_fewshot_boolean_expressions] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-04:12:18:26,539 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_boolean_expressions in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,539 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_tracking_shuffled_objects_five_objects in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,539 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_multistep_arithmetic_two in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,539 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_sports_understanding in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,539 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_penguins_in_a_table in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,539 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_web_of_lies in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,540 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_geometric_shapes in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,540 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_logical_deduction_three_objects in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,540 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_reasoning_about_colored_objects in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,540 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_navigate in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,540 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_temporal_sequences in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,541 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_object_counting in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,541 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_salient_translation_error_detection in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,541 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_date_understanding in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,541 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_causal_judgement in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,542 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_ruin_names in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,542 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_snarks in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,542 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_word_sorting in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,542 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_logical_deduction_five_objects in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,542 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_logical_deduction_seven_objects in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,542 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_tracking_shuffled_objects_three_objects in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,542 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_movie_recommendation in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,543 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_tracking_shuffled_objects_seven_objects in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,543 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_formal_fallacies in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,543 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_dyck_languages in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,543 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_hyperbaton in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,543 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_disambiguation_qa in its config. Manual configuration will be ignored.
# 2024-04-04:12:18:26,547 INFO     [task.py:395] Building contexts for bbh_fewshot_boolean_expressions on rank 0...
# 100% 250/250 [00:00<00:00, 1196.54it/s]
# 2024-04-04:12:18:26,795 INFO     [evaluator_utils.py:138] Task: ConfigurableTask(task_name=bbh_fewshot_boolean_expressions,group_name=bbh_fewshot,output_type=generate_until,num_fewshot=0,num_samples=250); document 0; context prompt (starting on next line):
# Evaluate the result of a random Boolean expression.
# Q: not ( ( not not True ) ) is
# A: False
#
# Q: True and False and not True and True is
# A: False
#
# Q: not not ( not ( False ) ) is
# A: True
#
# Q: not ( True ) and ( True ) is
# A:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# False
# (end of target on previous line)
# 2024-04-04:12:18:26,795 INFO     [evaluator_utils.py:142] Request: Instance(request_type='generate_until', doc={'input': 'not ( True ) and ( True ) is', 'target': 'False'}, arguments=('Evaluate the result of a random Boolean expression.\nQ: not ( ( not not True ) ) is\nA: False\n\nQ: True and False and not True and True is\nA: False\n\nQ: not not ( not ( False ) ) is\nA: True\n\nQ: not ( True ) and ( True ) is\nA:', {'until': ['</s>', 'Q', '\n\n'], 'do_sample': False, 'temperature': 0.0}), idx=0, metadata=('bbh_fewshot_boolean_expressions', 0, 1), resps=[], filtered_resps={}, task_name='bbh_fewshot_boolean_expressions', doc_id=0, repeats=1)
# 2024-04-04:12:18:26,796 INFO     [task.py:395] Building contexts for bbh_fewshot_tracking_shuffled_objects_five_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1001.92it/s]
# 2024-04-04:12:18:27,085 INFO     [evaluator_utils.py:138] Task: ConfigurableTask(task_name=bbh_fewshot_tracking_shuffled_objects_five_objects,group_name=bbh_fewshot,output_type=generate_until,num_fewshot=0,num_samples=250); document 0; context prompt (starting on next line):
# A task requiring determining the final positions of a set of objects given their initial positions and a description of a sequence of swaps.
# Q: Alice, Bob, and Claire are playing a game. At the start of the game, they are each holding a ball: Alice has a yellow ball, Bob has a blue ball, and Claire has a pink ball.
# As the game progresses, pairs of players trade balls. First, Claire and Alice swap balls. Then, Alice and Bob swap balls. Finally, Claire and Bob swap balls. At the end of the game, Bob has the
# Options:
# (A) yellow ball
# (B) blue ball
# (C) pink ball
# A: (A)
#
# Q: Alice, Bob, and Claire are playing a game. At the start of the game, they are each holding a ball: Alice has a white ball, Bob has a purple ball, and Claire has a pink ball.
# As the game progresses, pairs of players trade balls. First, Bob and Alice swap balls. Then, Bob and Claire swap balls. Finally, Bob and Alice swap balls. At the end of the game, Alice has the
# Options:
# (A) white ball
# (B) purple ball
# (C) pink ball
# A: (C)
#
# Q: Alice, Bob, and Claire are dancers at a square dance. At the start of a song, they each have a partner: Alice is dancing with Lola, Bob is dancing with Rodrigo, and Claire is dancing with Patrick.
# Throughout the song, the dancers often trade partners. First, Alice and Bob switch partners. Then, Claire and Bob switch partners. Finally, Bob and Alice switch partners. At the end of the dance, Alice is dancing with
# Options:
# (A) Lola
# (B) Rodrigo
# (C) Patrick
# A: (C)
#
# Q: Alice, Bob, Claire, Dave, and Eve are dancers at a square dance. At the start of a song, they each have a partner: Alice is dancing with Patrick, Bob is dancing with Sam, Claire is dancing with Jamie, Dave is dancing with Lola, and Eve is dancing with Melissa.
# Throughout the song, the dancers often trade partners. First, Dave and Eve switch partners. Then, Dave and Alice switch partners. Then, Eve and Alice switch partners. Then, Claire and Bob switch partners. Finally, Dave and Alice switch partners. At the end of the dance, Alice is dancing with
# Options:
# (A) Patrick
# (B) Sam
# (C) Jamie
# (D) Lola
# (E) Melissa
# A:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# (A)
# (end of target on previous line)
# 2024-04-04:12:18:27,085 INFO     [evaluator_utils.py:142] Request: Instance(request_type='generate_until', doc={'input': 'Alice, Bob, Claire, Dave, and Eve are dancers at a square dance. At the start of a song, they each have a partner: Alice is dancing with Patrick, Bob is dancing with Sam, Claire is dancing with Jamie, Dave is dancing with Lola, and Eve is dancing with Melissa.\nThroughout the song, the dancers often trade partners. First, Dave and Eve switch partners. Then, Dave and Alice switch partners. Then, Eve and Alice switch partners. Then, Claire and Bob switch partners. Finally, Dave and Alice switch partners. At the end of the dance, Alice is dancing with\nOptions:\n(A) Patrick\n(B) Sam\n(C) Jamie\n(D) Lola\n(E) Melissa', 'target': '(A)'}, arguments=('A task requiring determining the final positions of a set of objects given their initial positions and a description of a sequence of swaps.\nQ: Alice, Bob, and Claire are playing a game. At the start of the game, they are each holding a ball: Alice has a yellow ball, Bob has a blue ball, and Claire has a pink ball.\nAs the game progresses, pairs of players trade balls. First, Claire and Alice swap balls. Then, Alice and Bob swap balls. Finally, Claire and Bob swap balls. At the end of the game, Bob has the\nOptions:\n(A) yellow ball\n(B) blue ball\n(C) pink ball\nA: (A)\n\nQ: Alice, Bob, and Claire are playing a game. At the start of the game, they are each holding a ball: Alice has a white ball, Bob has a purple ball, and Claire has a pink ball.\nAs the game progresses, pairs of players trade balls. First, Bob and Alice swap balls. Then, Bob and Claire swap balls. Finally, Bob and Alice swap balls. At the end of the game, Alice has the\nOptions:\n(A) white ball\n(B) purple ball\n(C) pink ball\nA: (C)\n\nQ: Alice, Bob, and Claire are dancers at a square dance. At the start of a song, they each have a partner: Alice is dancing with Lola, Bob is dancing with Rodrigo, and Claire is dancing with Patrick.\nThroughout the song, the dancers often trade partners. First, Alice and Bob switch partners. Then, Claire and Bob switch partners. Finally, Bob and Alice switch partners. At the end of the dance, Alice is dancing with\nOptions:\n(A) Lola\n(B) Rodrigo\n(C) Patrick\nA: (C)\n\nQ: Alice, Bob, Claire, Dave, and Eve are dancers at a square dance. At the start of a song, they each have a partner: Alice is dancing with Patrick, Bob is dancing with Sam, Claire is dancing with Jamie, Dave is dancing with Lola, and Eve is dancing with Melissa.\nThroughout the song, the dancers often trade partners. First, Dave and Eve switch partners. Then, Dave and Alice switch partners. Then, Eve and Alice switch partners. Then, Claire and Bob switch partners. Finally, Dave and Alice switch partners. At the end of the dance, Alice is dancing with\nOptions:\n(A) Patrick\n(B) Sam\n(C) Jamie\n(D) Lola\n(E) Melissa\nA:', {'until': ['</s>', 'Q', '\n\n'], 'do_sample': False, 'temperature': 0.0}), idx=0, metadata=('bbh_fewshot_tracking_shuffled_objects_five_objects', 0, 1), resps=[], filtered_resps={}, task_name='bbh_fewshot_tracking_shuffled_objects_five_objects', doc_id=0, repeats=1)
# 2024-04-04:12:18:27,086 INFO     [task.py:395] Building contexts for bbh_fewshot_multistep_arithmetic_two on rank 0...
# 100% 250/250 [00:00<00:00, 1217.49it/s]
# 2024-04-04:12:18:27,328 INFO     [evaluator_utils.py:138] Task: ConfigurableTask(task_name=bbh_fewshot_multistep_arithmetic_two,group_name=bbh_fewshot,output_type=generate_until,num_fewshot=0,num_samples=250); document 0; context prompt (starting on next line):
# Solve multi-step arithmetic problems.
# Q: ((-5 + 9 * -4 - 0) * (4 + -7 + 0 * -5)) =
# A: 123
#
# Q: ((-9 * 7 * 7 * -9) + (4 * -9 - 8 - -4)) =
# A: 3929
#
# Q: ((-3 + 5 * 8 * -4) - (9 - 8 * -7 + -9)) =
# A: -219
#
# Q: ((-1 + 2 + 9 * 5) - (-2 + -4 + -4 * -7)) =
# A:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# 24
# (end of target on previous line)
# 2024-04-04:12:18:27,328 INFO     [evaluator_utils.py:142] Request: Instance(request_type='generate_until', doc={'input': '((-1 + 2 + 9 * 5) - (-2 + -4 + -4 * -7)) =', 'target': '24'}, arguments=('Solve multi-step arithmetic problems.\nQ: ((-5 + 9 * -4 - 0) * (4 + -7 + 0 * -5)) =\nA: 123\n\nQ: ((-9 * 7 * 7 * -9) + (4 * -9 - 8 - -4)) =\nA: 3929\n\nQ: ((-3 + 5 * 8 * -4) - (9 - 8 * -7 + -9)) =\nA: -219\n\nQ: ((-1 + 2 + 9 * 5) - (-2 + -4 + -4 * -7)) =\nA:', {'until': ['</s>', 'Q', '\n\n'], 'do_sample': False, 'temperature': 0.0}), idx=0, metadata=('bbh_fewshot_multistep_arithmetic_two', 0, 1), resps=[], filtered_resps={}, task_name='bbh_fewshot_multistep_arithmetic_two', doc_id=0, repeats=1)
# 2024-04-04:12:18:27,329 INFO     [task.py:395] Building contexts for bbh_fewshot_sports_understanding on rank 0...
# 100% 250/250 [00:00<00:00, 1190.13it/s]
# 2024-04-04:12:18:27,576 INFO     [evaluator_utils.py:138] Task: ConfigurableTask(task_name=bbh_fewshot_sports_understanding,group_name=bbh_fewshot,output_type=generate_until,num_fewshot=0,num_samples=250); document 0; context prompt (starting on next line):
# Determine whether an artificially constructed sentence relating to sports is plausible or not.
# Q: Is the following sentence plausible? "Bam Adebayo scored a reverse layup in the Western Conference Finals."
# A: yes
#
# Q: Is the following sentence plausible? "Santi Cazorla scored a touchdown."
# A: no
#
# Q: Is the following sentence plausible? "DeMar DeRozan was called for the goal tend."
# A: yes
#
# Q: Is the following sentence plausible? "Elias Lindholm beat the buzzer."
# A:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# no
# (end of target on previous line)
# 2024-04-04:12:18:27,577 INFO     [evaluator_utils.py:142] Request: Instance(request_type='generate_until', doc={'input': 'Is the following sentence plausible? "Elias Lindholm beat the buzzer."', 'target': 'no'}, arguments=('Determine whether an artificially constructed sentence relating to sports is plausible or not.\nQ: Is the following sentence plausible? "Bam Adebayo scored a reverse layup in the Western Conference Finals."\nA: yes\n\nQ: Is the following sentence plausible? "Santi Cazorla scored a touchdown."\nA: no\n\nQ: Is the following sentence plausible? "DeMar DeRozan was called for the goal tend."\nA: yes\n\nQ: Is the following sentence plausible? "Elias Lindholm beat the buzzer."\nA:', {'until': ['</s>', 'Q', '\n\n'], 'do_sample': False, 'temperature': 0.0}), idx=0, metadata=('bbh_fewshot_sports_understanding', 0, 1), resps=[], filtered_resps={}, task_name='bbh_fewshot_sports_understanding', doc_id=0, repeats=1)
# 2024-04-04:12:18:27,577 INFO     [task.py:395] Building contexts for bbh_fewshot_penguins_in_a_table on rank 0...
# 100% 146/146 [00:00<00:00, 1050.76it/s]
# 2024-04-04:12:18:27,740 INFO     [evaluator_utils.py:138] Task: ConfigurableTask(task_name=bbh_fewshot_penguins_in_a_table,group_name=bbh_fewshot,output_type=generate_until,num_fewshot=0,num_samples=146); document 0; context prompt (starting on next line):
# Answer questions about a table of penguins and their attributes.
# Q: Here is a table where the first line is a header and each subsequent line is a penguin:  name, age, height (cm), weight (kg) Louis, 7, 50, 11 Bernard, 5, 80, 13 Vincent, 9, 60, 11 Gwen, 8, 70, 15  For example: the age of Louis is 7, the weight of Gwen is 15 kg, the height of Bernard is 80 cm.  We now add a penguin to the table:
# James, 12, 90, 12
# How many penguins are less than 8 years old?
# Options:
# (A) 1
# (B) 2
# (C) 3
# (D) 4
# (E) 5
# A: (B)
#
# Q: Here is a table where the first line is a header and each subsequent line is a penguin:  name, age, height (cm), weight (kg) Louis, 7, 50, 11 Bernard, 5, 80, 13 Vincent, 9, 60, 11 Gwen, 8, 70, 15  For example: the age of Louis is 7, the weight of Gwen is 15 kg, the height of Bernard is 80 cm.  Which is the youngest penguin?
# Options:
# (A) Louis
# (B) Bernard
# (C) Vincent
# (D) Gwen
# (E) James
# A: (B)
#
# Q: Here is a table where the first line is a header and each subsequent line is a penguin:  name, age, height (cm), weight (kg) Louis, 7, 50, 11 Bernard, 5, 80, 13 Vincent, 9, 60, 11 Gwen, 8, 70, 15  For example: the age of Louis is 7, the weight of Gwen is 15 kg, the height of Bernard is 80 cm.  What is the name of the second penguin sorted by alphabetic order?
# Options:
# (A) Louis
# (B) Bernard
# (C) Vincent
# (D) Gwen
# (E) James
# A: (D)
#
# Q: Here is a table where the first line is a header and each subsequent line is a penguin:  name, age, height (cm), weight (kg) Louis, 7, 50, 11 Bernard, 5, 80, 13 Vincent, 9, 60, 11 Gwen, 8, 70, 15  For example: the age of Louis is 7, the weight of Gwen is 15 kg, the height of Bernard is 80 cm.  We now add a penguin to the table:
# James, 12, 90, 12
# And here is a similar table, but listing giraffes:
# name, age, height (cm), weight (kg)
# Jody, 5, 430, 620
# Gladys, 10, 420, 590
# Marian, 2, 310, 410
# Donna, 9, 440, 650
# Which is the oldest penguin?
# Options:
# (A) Louis
# (B) Bernard
# (C) Vincent
# (D) Gwen
# (E) James
# A:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# (E)
# (end of target on previous line)
# 2024-04-04:12:18:27,740 INFO     [evaluator_utils.py:142] Request: Instance(request_type='generate_until', doc={'input': 'Here is a table where the first line is a header and each subsequent line is a penguin:  name, age, height (cm), weight (kg) Louis, 7, 50, 11 Bernard, 5, 80, 13 Vincent, 9, 60, 11 Gwen, 8, 70, 15  For example: the age of Louis is 7, the weight of Gwen is 15 kg, the height of Bernard is 80 cm.  We now add a penguin to the table:\nJames, 12, 90, 12\nAnd here is a similar table, but listing giraffes:\nname, age, height (cm), weight (kg)\nJody, 5, 430, 620\nGladys, 10, 420, 590\nMarian, 2, 310, 410\nDonna, 9, 440, 650\nWhich is the oldest penguin?\nOptions:\n(A) Louis\n(B) Bernard\n(C) Vincent\n(D) Gwen\n(E) James', 'target': '(E)'}, arguments=('Answer questions about a table of penguins and their attributes.\nQ: Here is a table where the first line is a header and each subsequent line is a penguin:  name, age, height (cm), weight (kg) Louis, 7, 50, 11 Bernard, 5, 80, 13 Vincent, 9, 60, 11 Gwen, 8, 70, 15  For example: the age of Louis is 7, the weight of Gwen is 15 kg, the height of Bernard is 80 cm.  We now add a penguin to the table:\nJames, 12, 90, 12\nHow many penguins are less than 8 years old?\nOptions:\n(A) 1\n(B) 2\n(C) 3\n(D) 4\n(E) 5\nA: (B)\n\nQ: Here is a table where the first line is a header and each subsequent line is a penguin:  name, age, height (cm), weight (kg) Louis, 7, 50, 11 Bernard, 5, 80, 13 Vincent, 9, 60, 11 Gwen, 8, 70, 15  For example: the age of Louis is 7, the weight of Gwen is 15 kg, the height of Bernard is 80 cm.  Which is the youngest penguin?\nOptions:\n(A) Louis\n(B) Bernard\n(C) Vincent\n(D) Gwen\n(E) James\nA: (B)\n\nQ: Here is a table where the first line is a header and each subsequent line is a penguin:  name, age, height (cm), weight (kg) Louis, 7, 50, 11 Bernard, 5, 80, 13 Vincent, 9, 60, 11 Gwen, 8, 70, 15  For example: the age of Louis is 7, the weight of Gwen is 15 kg, the height of Bernard is 80 cm.  What is the name of the second penguin sorted by alphabetic order?\nOptions:\n(A) Louis\n(B) Bernard\n(C) Vincent\n(D) Gwen\n(E) James\nA: (D)\n\nQ: Here is a table where the first line is a header and each subsequent line is a penguin:  name, age, height (cm), weight (kg) Louis, 7, 50, 11 Bernard, 5, 80, 13 Vincent, 9, 60, 11 Gwen, 8, 70, 15  For example: the age of Louis is 7, the weight of Gwen is 15 kg, the height of Bernard is 80 cm.  We now add a penguin to the table:\nJames, 12, 90, 12\nAnd here is a similar table, but listing giraffes:\nname, age, height (cm), weight (kg)\nJody, 5, 430, 620\nGladys, 10, 420, 590\nMarian, 2, 310, 410\nDonna, 9, 440, 650\nWhich is the oldest penguin?\nOptions:\n(A) Louis\n(B) Bernard\n(C) Vincent\n(D) Gwen\n(E) James\nA:', {'until': ['</s>', 'Q', '\n\n'], 'do_sample': False, 'temperature': 0.0}), idx=0, metadata=('bbh_fewshot_penguins_in_a_table', 0, 1), resps=[], filtered_resps={}, task_name='bbh_fewshot_penguins_in_a_table', doc_id=0, repeats=1)
# 2024-04-04:12:18:27,741 INFO     [task.py:395] Building contexts for bbh_fewshot_web_of_lies on rank 0...
# 100% 250/250 [00:00<00:00, 1153.21it/s]
# 2024-04-04:12:18:27,996 INFO     [evaluator_utils.py:138] Task: ConfigurableTask(task_name=bbh_fewshot_web_of_lies,group_name=bbh_fewshot,output_type=generate_until,num_fewshot=0,num_samples=250); document 0; context prompt (starting on next line):
# Evaluate a random boolean function expressed as a word problem.
# Q: Question: Fidel tells the truth. Jerry says Fidel tells the truth. Vina says Jerry tells the truth. Millicent says Vina lies. Raymond says Millicent lies. Does Raymond tell the truth?
# A: Yes
#
# Q: Question: Kristian lies. Millie says Kristian lies. Maybelle says Millie tells the truth. Fidel says Maybelle lies. Leda says Fidel lies. Does Leda tell the truth?
# A: Yes
#
# Q: Question: Kristian tells the truth. Michaela says Kristian lies. Raymond says Michaela tells the truth. Osvaldo says Raymond tells the truth. Jamey says Osvaldo tells the truth. Does Jamey tell the truth?
# A: No
#
# Q: Question: Sherrie tells the truth. Vernell says Sherrie tells the truth. Alexis says Vernell lies. Michaela says Alexis tells the truth. Elanor says Michaela tells the truth. Does Elanor tell the truth?
# A:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# No
# (end of target on previous line)
# 2024-04-04:12:18:27,996 INFO     [evaluator_utils.py:142] Request: Instance(request_type='generate_until', doc={'input': 'Question: Sherrie tells the truth. Vernell says Sherrie tells the truth. Alexis says Vernell lies. Michaela says Alexis tells the truth. Elanor says Michaela tells the truth. Does Elanor tell the truth?', 'target': 'No'}, arguments=('Evaluate a random boolean function expressed as a word problem.\nQ: Question: Fidel tells the truth. Jerry says Fidel tells the truth. Vina says Jerry tells the truth. Millicent says Vina lies. Raymond says Millicent lies. Does Raymond tell the truth?\nA: Yes\n\nQ: Question: Kristian lies. Millie says Kristian lies. Maybelle says Millie tells the truth. Fidel says Maybelle lies. Leda says Fidel lies. Does Leda tell the truth?\nA: Yes\n\nQ: Question: Kristian tells the truth. Michaela says Kristian lies. Raymond says Michaela tells the truth. Osvaldo says Raymond tells the truth. Jamey says Osvaldo tells the truth. Does Jamey tell the truth?\nA: No\n\nQ: Question: Sherrie tells the truth. Vernell says Sherrie tells the truth. Alexis says Vernell lies. Michaela says Alexis tells the truth. Elanor says Michaela tells the truth. Does Elanor tell the truth?\nA:', {'until': ['</s>', 'Q', '\n\n'], 'do_sample': False, 'temperature': 0.0}), idx=0, metadata=('bbh_fewshot_web_of_lies', 0, 1), resps=[], filtered_resps={}, task_name='bbh_fewshot_web_of_lies', doc_id=0, repeats=1)
# 2024-04-04:12:18:27,996 INFO     [task.py:395] Building contexts for bbh_fewshot_geometric_shapes on rank 0...
# 100% 250/250 [00:00<00:00, 1097.23it/s]
# 2024-04-04:12:18:28,263 INFO     [evaluator_utils.py:138] Task: ConfigurableTask(task_name=bbh_fewshot_geometric_shapes,group_name=bbh_fewshot,output_type=generate_until,num_fewshot=0,num_samples=250); document 0; context prompt (starting on next line):
# Name geometric shapes from their SVG paths.
# Q: This SVG path element <path d="M 31.00,73.00 L 32.00,59.00 L 44.00,50.00 L 49.00,41.00 L 64.00,37.00 L 71.00,55.00 L 64.00,76.00 L 52.00,61.00 L 31.00,73.00"/> draws a
# Options:
# (A) circle
# (B) heptagon
# (C) hexagon
# (D) kite
# (E) line
# (F) octagon
# (G) pentagon
# (H) rectangle
# (I) sector
# (J) triangle
# A: (F)
#
# Q: This SVG path element <path d="M 14.19,26.04 L 51.43,39.21 L 58.44,36.69 L 56.63,30.17 L 48.53,26.66 L 14.19,26.04"/> draws a
# Options:
# (A) circle
# (B) heptagon
# (C) hexagon
# (D) kite
# (E) line
# (F) octagon
# (G) pentagon
# (H) rectangle
# (I) sector
# (J) triangle
# A: (G)
#
# Q: This SVG path element <path d="M 41.00,43.00 L 37.00,34.00 L 41.00,33.00 L 45.00,34.00 L 41.00,43.00"/> draws a
# Options:
# (A) circle
# (B) heptagon
# (C) hexagon
# (D) kite
# (E) line
# (F) octagon
# (G) pentagon
# (H) rectangle
# (I) sector
# (J) triangle
# A: (D)
#
# Q: This SVG path element <path d="M 55.57,80.69 L 57.38,65.80 M 57.38,65.80 L 48.90,57.46 M 48.90,57.46 L 45.58,47.78 M 45.58,47.78 L 53.25,36.07 L 66.29,48.90 L 78.69,61.09 L 55.57,80.69"/> draws a
# Options:
# (A) circle
# (B) heptagon
# (C) hexagon
# (D) kite
# (E) line
# (F) octagon
# (G) pentagon
# (H) rectangle
# (I) sector
# (J) triangle
# A:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# (B)
# (end of target on previous line)
# 2024-04-04:12:18:28,263 INFO     [evaluator_utils.py:142] Request: Instance(request_type='generate_until', doc={'input': 'This SVG path element <path d="M 55.57,80.69 L 57.38,65.80 M 57.38,65.80 L 48.90,57.46 M 48.90,57.46 L 45.58,47.78 M 45.58,47.78 L 53.25,36.07 L 66.29,48.90 L 78.69,61.09 L 55.57,80.69"/> draws a\nOptions:\n(A) circle\n(B) heptagon\n(C) hexagon\n(D) kite\n(E) line\n(F) octagon\n(G) pentagon\n(H) rectangle\n(I) sector\n(J) triangle', 'target': '(B)'}, arguments=('Name geometric shapes from their SVG paths.\nQ: This SVG path element <path d="M 31.00,73.00 L 32.00,59.00 L 44.00,50.00 L 49.00,41.00 L 64.00,37.00 L 71.00,55.00 L 64.00,76.00 L 52.00,61.00 L 31.00,73.00"/> draws a\nOptions:\n(A) circle\n(B) heptagon\n(C) hexagon\n(D) kite\n(E) line\n(F) octagon\n(G) pentagon\n(H) rectangle\n(I) sector\n(J) triangle\nA: (F)\n\nQ: This SVG path element <path d="M 14.19,26.04 L 51.43,39.21 L 58.44,36.69 L 56.63,30.17 L 48.53,26.66 L 14.19,26.04"/> draws a\nOptions:\n(A) circle\n(B) heptagon\n(C) hexagon\n(D) kite\n(E) line\n(F) octagon\n(G) pentagon\n(H) rectangle\n(I) sector\n(J) triangle\nA: (G)\n\nQ: This SVG path element <path d="M 41.00,43.00 L 37.00,34.00 L 41.00,33.00 L 45.00,34.00 L 41.00,43.00"/> draws a\nOptions:\n(A) circle\n(B) heptagon\n(C) hexagon\n(D) kite\n(E) line\n(F) octagon\n(G) pentagon\n(H) rectangle\n(I) sector\n(J) triangle\nA: (D)\n\nQ: This SVG path element <path d="M 55.57,80.69 L 57.38,65.80 M 57.38,65.80 L 48.90,57.46 M 48.90,57.46 L 45.58,47.78 M 45.58,47.78 L 53.25,36.07 L 66.29,48.90 L 78.69,61.09 L 55.57,80.69"/> draws a\nOptions:\n(A) circle\n(B) heptagon\n(C) hexagon\n(D) kite\n(E) line\n(F) octagon\n(G) pentagon\n(H) rectangle\n(I) sector\n(J) triangle\nA:', {'until': ['</s>', 'Q', '\n\n'], 'do_sample': False, 'temperature': 0.0}), idx=0, metadata=('bbh_fewshot_geometric_shapes', 0, 1), resps=[], filtered_resps={}, task_name='bbh_fewshot_geometric_shapes', doc_id=0, repeats=1)
# 2024-04-04:12:18:28,263 INFO     [task.py:395] Building contexts for bbh_fewshot_logical_deduction_three_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1038.91it/s]
# 2024-04-04:12:18:28,543 INFO     [evaluator_utils.py:138] Task: ConfigurableTask(task_name=bbh_fewshot_logical_deduction_three_objects,group_name=bbh_fewshot,output_type=generate_until,num_fewshot=0,num_samples=250); document 0; context prompt (starting on next line):
# A logical deduction task which requires deducing the order of a sequence of objects.
# Q: The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In a golf tournament, there were three golfers: Amy, Eli, and Eve. Eve finished above Amy. Eli finished below Amy.
# Options:
# (A) Amy finished last
# (B) Eli finished last
# (C) Eve finished last
# A: (B)
#
# Q: The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a shelf, there are three books: a white book, a green book, and an orange book. The green book is to the right of the white book. The orange book is the rightmost.
# Options:
# (A) The white book is the leftmost
# (B) The green book is the leftmost
# (C) The orange book is the leftmost
# A: (A)
#
# Q: The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a shelf, there are three books: a red book, a gray book, and a white book. The white book is to the left of the gray book. The red book is the second from the left.
# Options:
# (A) The red book is the leftmost
# (B) The gray book is the leftmost
# (C) The white book is the leftmost
# A: (C)
#
# Q: The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a branch, there are three birds: a blue jay, a quail, and a falcon. The falcon is to the right of the blue jay. The blue jay is to the right of the quail.
# Options:
# (A) The blue jay is the second from the left
# (B) The quail is the second from the left
# (C) The falcon is the second from the left
# A:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# (A)
# (end of target on previous line)
# ...
# |                        Tasks                         |Version|Filter|n-shot|  Metric   |Value|   |Stderr|
# |------------------------------------------------------|-------|------|-----:|-----------|----:|---|-----:|
# |bbh_fewshot                                           |N/A    |none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_boolean_expressions                    |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_causal_judgement                       |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_date_understanding                     |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_disambiguation_qa                      |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_dyck_languages                         |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_formal_fallacies                       |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_geometric_shapes                       |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_hyperbaton                             |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_logical_deduction_five_objects         |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_logical_deduction_seven_objects        |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_logical_deduction_three_objects        |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_movie_recommendation                   |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_multistep_arithmetic_two               |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_navigate                               |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_object_counting                        |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_penguins_in_a_table                    |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_reasoning_about_colored_objects        |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_ruin_names                             |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_salient_translation_error_detection    |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_snarks                                 |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_sports_understanding                   |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_temporal_sequences                     |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_tracking_shuffled_objects_five_objects |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_tracking_shuffled_objects_seven_objects|      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_tracking_shuffled_objects_three_objects|      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_web_of_lies                            |      1|none  |     3|exact_match|    0|±  |     0|
# | - bbh_fewshot_word_sorting                           |      1|none  |     3|exact_match|    0|±  |     0|
#
# |  Groups   |Version|Filter|n-shot|  Metric   |Value|   |Stderr|
# |-----------|-------|------|-----:|-----------|----:|---|-----:|
# |bbh_fewshot|N/A    |none  |     3|exact_match|    0|±  |     0|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:                                                bbh_fewshot/exact_match ▁
# wandb:                                         bbh_fewshot/exact_match_stderr ▁
# wandb:                            bbh_fewshot_boolean_expressions/exact_match ▁
# wandb:                     bbh_fewshot_boolean_expressions/exact_match_stderr ▁
# wandb:                               bbh_fewshot_causal_judgement/exact_match ▁
# wandb:                        bbh_fewshot_causal_judgement/exact_match_stderr ▁
# wandb:                             bbh_fewshot_date_understanding/exact_match ▁
# wandb:                      bbh_fewshot_date_understanding/exact_match_stderr ▁
# wandb:                              bbh_fewshot_disambiguation_qa/exact_match ▁
# wandb:                       bbh_fewshot_disambiguation_qa/exact_match_stderr ▁
# wandb:                                 bbh_fewshot_dyck_languages/exact_match ▁
# wandb:                          bbh_fewshot_dyck_languages/exact_match_stderr ▁
# wandb:                               bbh_fewshot_formal_fallacies/exact_match ▁
# wandb:                        bbh_fewshot_formal_fallacies/exact_match_stderr ▁
# wandb:                               bbh_fewshot_geometric_shapes/exact_match ▁
# wandb:                        bbh_fewshot_geometric_shapes/exact_match_stderr ▁
# wandb:                                     bbh_fewshot_hyperbaton/exact_match ▁
# wandb:                              bbh_fewshot_hyperbaton/exact_match_stderr ▁
# wandb:                 bbh_fewshot_logical_deduction_five_objects/exact_match ▁
# wandb:          bbh_fewshot_logical_deduction_five_objects/exact_match_stderr ▁
# wandb:                bbh_fewshot_logical_deduction_seven_objects/exact_match ▁
# wandb:         bbh_fewshot_logical_deduction_seven_objects/exact_match_stderr ▁
# wandb:                bbh_fewshot_logical_deduction_three_objects/exact_match ▁
# wandb:         bbh_fewshot_logical_deduction_three_objects/exact_match_stderr ▁
# wandb:                           bbh_fewshot_movie_recommendation/exact_match ▁
# wandb:                    bbh_fewshot_movie_recommendation/exact_match_stderr ▁
# wandb:                       bbh_fewshot_multistep_arithmetic_two/exact_match ▁
# wandb:                bbh_fewshot_multistep_arithmetic_two/exact_match_stderr ▁
# wandb:                                       bbh_fewshot_navigate/exact_match ▁
# wandb:                                bbh_fewshot_navigate/exact_match_stderr ▁
# wandb:                                bbh_fewshot_object_counting/exact_match ▁
# wandb:                         bbh_fewshot_object_counting/exact_match_stderr ▁
# wandb:                            bbh_fewshot_penguins_in_a_table/exact_match ▁
# wandb:                     bbh_fewshot_penguins_in_a_table/exact_match_stderr ▁
# wandb:                bbh_fewshot_reasoning_about_colored_objects/exact_match ▁
# wandb:         bbh_fewshot_reasoning_about_colored_objects/exact_match_stderr ▁
# wandb:                                     bbh_fewshot_ruin_names/exact_match ▁
# wandb:                              bbh_fewshot_ruin_names/exact_match_stderr ▁
# wandb:            bbh_fewshot_salient_translation_error_detection/exact_match ▁
# wandb:     bbh_fewshot_salient_translation_error_detection/exact_match_stderr ▁
# wandb:                                         bbh_fewshot_snarks/exact_match ▁
# wandb:                                  bbh_fewshot_snarks/exact_match_stderr ▁
# wandb:                           bbh_fewshot_sports_understanding/exact_match ▁
# wandb:                    bbh_fewshot_sports_understanding/exact_match_stderr ▁
# wandb:                             bbh_fewshot_temporal_sequences/exact_match ▁
# wandb:                      bbh_fewshot_temporal_sequences/exact_match_stderr ▁
# wandb:         bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match ▁
# wandb:  bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match_stderr ▁
# wandb:        bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match ▁
# wandb: bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match_stderr ▁
# wandb:        bbh_fewshot_tracking_shuffled_objects_three_objects/exact_
bh_fewshot_tracking_shuffled_objects_three_objects/exact_match_stderr 0.0
# wandb:                                          bbh_fewshot_web_of_lies/alias  - bbh_fewshot_web_o...
# wandb:                                    bbh_fewshot_web_of_lies/exact_match 0.0
# wandb:                             bbh_fewshot_web_of_lies/exact_match_stderr 0.0
# wandb:                                         bbh_fewshot_word_sorting/alias  - bbh_fewshot_word_...
# wandb:                                   bbh_fewshot_word_sorting/exact_match 0.0
# wandb:                            bbh_fewshot_word_sorting/exact_match_stderr 0.0
# wandb:
# wandb: 🚀 View run Falcon-7B-instruct-NF4-BBH at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/ymp3km50
# wandb: ⭐️ View project at: https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: Synced 5 W&B file(s), 3 media file(s), 4 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240404_121017-ymp3km50/logs

# %% [markdown]
# ### Evaluate Mistral-7B-Instruct-NF4

# %%
eval_model = "twhoool02/Mistral-7B-Instruct-NF4"

# create directory to store results
results_dir = f"/content/drive/MyDrive/Evaluation/{eval_model}"
os.makedirs(results_dir, exist_ok=True)

# %% [markdown]
# #### MMLU
#
# 5-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)
#
# revision number is used in the code to ensure an newer version of falcon is not downloaded automatically

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Mistral-7B-Instruct-NF4,trust_remote_code=True,revision="d09342dee0fb90a04bcad6cb0e7bb41dc86179e1" \
    --tasks mmlu_stem,mmlu_social_sciences,mmlu_humanities,mmlu_other\
    --num_fewshot 5 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir_mistral_mmlu \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Mistral-7B-Instruct-NF4-MMLU \
    --use_cache results_dir_mistral_mmlu \
    --cache_requests true \
    --show_config
# Out:
# 2024-03-28 17:05:22.783597: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-28 17:05:22.783653: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-28 17:05:22.784853: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-28 17:05:24.021946: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240328_170529-t0283alp
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Mistral-7B-Instruct-NF4-MMLU
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/t0283alp/workspace
# 2024-03-28:17:05:30,749 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-28:17:05:36,988 INFO     [__main__.py:335] Selected Tasks: ['mmlu_humanities', 'mmlu_other', 'mmlu_social_sciences', 'mmlu_stem']
# 2024-03-28:17:05:36,990 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-28:17:05:36,990 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Mistral-7B-Instruct-NF4', 'trust_remote_code': True, 'revision': 'd09342dee0fb90a04bcad6cb0e7bb41dc86179e1'}
# 2024-03-28:17:05:36,995 INFO     [huggingface.py:163] Using device 'cuda:0'
# config.json: 100% 1.16k/1.16k [00:00<00:00, 3.16MB/s]
# model.safetensors: 100% 4.13G/4.13G [00:16<00:00, 245MB/s]
# generation_config.json: 100% 111/111 [00:00<00:00, 258kB/s]
# 2024-03-28:17:05:59,434 WARNING  [big_modeling.py:448] You shouldn't move a model that is dispatched using accelerate hooks.
# tokenizer_config.json: 100% 1.46k/1.46k [00:00<00:00, 3.67MB/s]
# tokenizer.model: 100% 493k/493k [00:00<00:00, 146MB/s]
# tokenizer.json: 100% 1.80M/1.80M [00:00<00:00, 3.61MB/s]
# special_tokens_map.json: 100% 437/437 [00:00<00:00, 1.16MB/s]
# 2024-03-28:17:06:02,555 INFO     [evaluator.py:195] Using cache at results_dir_mistral_mmlu_rank0.db
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 5.86k/5.86k [00:00<00:00, 10.7MB/s]
# Downloading readme: 100% 1.11k/1.11k [00:00<00:00, 3.74MB/s]
# Downloading data: 100% 166M/166M [00:01<00:00, 94.0MB/s]
# Generating test split: 237 examples [00:00, 1957.67 examples/s]
# Generating validation split: 26 examples [00:00, 3589.48 examples/s]
# Generating dev split: 5 examples [00:00, 49.92 examples/s]
# Generating test split: 1534 examples [00:00, 8120.61 examples/s]
# Generating validation split: 170 examples [00:00, 10755.92 examples/s]
# Generating dev split: 5 examples [00:00, 56.70 examples/s]
# Generating test split: 108 examples [00:00, 1207.34 examples/s]
# Generating validation split: 11 examples [00:00, 1982.61 examples/s]
# Generating dev split: 5 examples [00:00, 56.01 examples/s]
# Generating test split: 346 examples [00:00, 3050.07 examples/s]
# Generating validation split: 38 examples [00:00, 5194.35 examples/s]
# Generating dev split: 5 examples [00:00, 58.53 examples/s]
# Generating test split: 324 examples [00:00, 3126.51 examples/s]
# Generating validation split: 35 examples [00:00, 5762.99 examples/s]
# Generating dev split: 5 examples [00:00, 57.91 examples/s]
# Generating test split: 311 examples [00:00, 3166.03 examples/s]
# Generating validation split: 34 examples [00:00, 7482.75 examples/s]
# Generating dev split: 5 examples [00:00, 58.75 examples/s]
# Generating test split: 171 examples [00:00, 1885.36 examples/s]
# Generating validation split: 19 examples [00:00, 4332.25 examples/s]
# Generating dev split: 5 examples [00:00, 57.66 examples/s]
# Generating test split: 204 examples [00:00, 2128.07 examples/s]
# Generating validation split: 22 examples [00:00, 3314.23 examples/s]
# Generating dev split: 5 examples [00:00, 58.08 examples/s]
# Generating test split: 165 examples [00:00, 1796.05 examples/s]
# Generating validation split: 18 examples [00:00, 2801.81 examples/s]
# Generating dev split: 5 examples [00:00, 59.28 examples/s]
# Generating test split: 163 examples [00:00, 1838.27 examples/s]
# Generating validation split: 18 examples [00:00, 3540.33 examples/s]
# Generating dev split: 5 examples [00:00, 59.43 examples/s]
# Generating test split: 126 examples [00:00, 1373.59 examples/s]
# Generating validation split: 14 examples [00:00, 3254.28 examples/s]
# Generating dev split: 5 examples [00:00, 58.56 examples/s]
# Generating test split: 121 examples [00:00, 1360.76 examples/s]
# Generating validation split: 13 examples [00:00, 2843.30 examples/s]
# Generating dev split: 5 examples [00:00, 58.79 examples/s]
# Generating test split: 895 examples [00:00, 6481.15 examples/s]
# Generating validation split: 100 examples [00:00, 10624.14 examples/s]
# Generating dev split: 5 examples [00:00, 57.64 examples/s]
# Generating test split: 100 examples [00:00, 1117.50 examples/s]
# Generating validation split: 11 examples [00:00, 3364.50 examples/s]
# Generating dev split: 5 examples [00:00, 57.19 examples/s]
# Generating test split: 306 examples [00:00, 3152.84 examples/s]
# Generating validation split: 33 examples [00:00, 5956.02 examples/s]
# Generating dev split: 5 examples [00:00, 59.39 examples/s]
# Generating test split: 272 examples [00:00, 2687.17 examples/s]
# Generating validation split: 31 examples [00:00, 5029.92 examples/s]
# Generating dev split: 5 examples [00:00, 57.67 examples/s]
# Generating test split: 234 examples [00:00, 2452.78 examples/s]
# Generating validation split: 25 examples [00:00, 4444.25 examples/s]
# Generating dev split: 5 examples [00:00, 59.20 examples/s]
# Generating test split: 100 examples [00:00, 1186.14 examples/s]
# Generating validation split: 10 examples [00:00, 3150.53 examples/s]
# Generating dev split: 5 examples [00:00, 55.64 examples/s]
# Generating test split: 103 examples [00:00, 1148.89 examples/s]
# Generating validation split: 11 examples [00:00, 2476.11 examples/s]
# Generating dev split: 5 examples [00:00, 56.74 examples/s]
# Generating test split: 783 examples [00:00, 6119.59 examples/s]
# Generating validation split: 86 examples [00:00, 10565.62 examples/s]
# Generating dev split: 5 examples [00:00, 57.11 examples/s]
# Generating test split: 100 examples [00:00, 1137.50 examples/s]
# Generating validation split: 11 examples [00:00, 3499.23 examples/s]
# Generating dev split: 5 examples [00:00, 57.96 examples/s]
# Generating test split: 282 examples [00:00, 2795.20 examples/s]
# Generating validation split: 31 examples [00:00, 4371.12 examples/s]
# Generating dev split: 5 examples [00:00, 59.15 examples/s]
# Generating test split: 223 examples [00:00, 2415.23 examples/s]
# Generating validation split: 23 examples [00:00, 4420.52 examples/s]
# Generating dev split: 5 examples [00:00, 59.08 examples/s]
# Generating test split: 173 examples [00:00, 1834.71 examples/s]
# Generating validation split: 22 examples [00:00, 5070.04 examples/s]
# Generating dev split: 5 examples [00:00, 58.66 examples/s]
# Generating test split: 166 examples [00:00, 1847.34 examples/s]
# Generating validation split: 18 examples [00:00, 3523.80 examples/s]
# Generating dev split: 5 examples [00:00, 58.08 examples/s]
# Generating test split: 265 examples [00:00, 2659.14 examples/s]
# Generating validation split: 29 examples [00:00, 5896.30 examples/s]
# Generating dev split: 5 examples [00:00, 58.69 examples/s]
# Generating test split: 110 examples [00:00, 1272.41 examples/s]
# Generating validation split: 12 examples [00:00, 2479.51 examples/s]
# Generating dev split: 5 examples [00:00, 59.10 examples/s]
# Generating test split: 545 examples [00:00, 4735.64 examples/s]
# Generating validation split: 60 examples [00:00, 7002.18 examples/s]
# Generating dev split: 5 examples [00:00, 54.41 examples/s]
# Generating test split: 198 examples [00:00, 2087.27 examples/s]
# Generating validation split: 22 examples [00:00, 5677.74 examples/s]
# Generating dev split: 5 examples [00:00, 53.66 examples/s]
# Generating test split: 245 examples [00:00, 2614.14 examples/s]
# Generating validation split: 27 examples [00:00, 3921.81 examples/s]
# Generating dev split: 5 examples [00:00, 58.59 examples/s]
# Generating test split: 612 examples [00:00, 5184.88 examples/s]
# Generating validation split: 69 examples [00:00, 7955.77 examples/s]
# Generating dev split: 5 examples [00:00, 57.16 examples/s]
# Generating test split: 238 examples [00:00, 2418.96 examples/s]
# Generating validation split: 26 examples [00:00, 4378.89 examples/s]
# Generating dev split: 5 examples [00:00, 57.18 examples/s]
# Generating test split: 114 examples [00:00, 1165.26 examples/s]
# Generating validation split: 12 examples [00:00, 2863.49 examples/s]
# Generating dev split: 5 examples [00:00, 52.30 examples/s]
# Generating test split: 131 examples [00:00, 1473.84 examples/s]
# Generating validation split: 12 examples [00:00, 2588.14 examples/s]
# Generating dev split: 5 examples [00:00, 57.65 examples/s]
# Generating test split: 193 examples [00:00, 2125.12 examples/s]
# Generating validation split: 21 examples [00:00, 5330.45 examples/s]
# Generating dev split: 5 examples [00:00, 58.48 examples/s]
# Generating test split: 390 examples [00:00, 3822.00 examples/s]
# Generating validation split: 43 examples [00:00, 7200.95 examples/s]
# Generating dev split: 5 examples [00:00, 59.25 examples/s]
# Generating test split: 100 examples [00:00, 1109.34 examples/s]
# Generating validation split: 11 examples [00:00, 2770.68 examples/s]
# Generating dev split: 5 examples [00:00, 58.63 examples/s]
# Generating test split: 201 examples [00:00, 2190.56 examples/s]
# Generating validation split: 22 examples [00:00, 3612.38 examples/s]
# Generating dev split: 5 examples [00:00, 58.71 examples/s]
# Generating test split: 310 examples [00:00, 3155.28 examples/s]
# Generating validation split: 32 examples [00:00, 6522.07 examples/s]
# Generating dev split: 5 examples [00:00, 55.62 examples/s]
# Generating test split: 112 examples [00:00, 1255.53 examples/s]
# Generating validation split: 11 examples [00:00, 3112.97 examples/s]
# Generating dev split: 5 examples [00:00, 59.65 examples/s]
# Generating test split: 100 examples [00:00, 1094.38 examples/s]
# Generating validation split: 11 examples [00:00, 2207.11 examples/s]
# Generating dev split: 5 examples [00:00, 57.83 examples/s]
# Generating test split: 235 examples [00:00, 2514.42 examples/s]
# Generating validation split: 26 examples [00:00, 6789.86 examples/s]
# Generating dev split: 5 examples [00:00, 57.39 examples/s]
# Generating test split: 102 examples [00:00, 1088.50 examples/s]
# Generating validation split: 11 examples [00:00, 3128.59 examples/s]
# Generating dev split: 5 examples [00:00, 56.75 examples/s]
# Generating test split: 216 examples [00:00, 2260.66 examples/s]
# Generating validation split: 23 examples [00:00, 4777.11 examples/s]
# Generating dev split: 5 examples [00:00, 56.79 examples/s]
# Generating test split: 144 examples [00:00, 1645.69 examples/s]
# Generating validation split: 16 examples [00:00, 2876.51 examples/s]
# Generating dev split: 5 examples [00:00, 58.05 examples/s]
# Generating test split: 100 examples [00:00, 1119.39 examples/s]
# Generating validation split: 11 examples [00:00, 2708.86 examples/s]
# Generating dev split: 5 examples [00:00, 59.52 examples/s]
# Generating test split: 152 examples [00:00, 1723.03 examples/s]
# Generating validation split: 16 examples [00:00, 4687.03 examples/s]
# Generating dev split: 5 examples [00:00, 56.47 examples/s]
# Generating test split: 100 examples [00:00, 1140.64 examples/s]
# Generating validation split: 11 examples [00:00, 2408.25 examples/s]
# Generating dev split: 5 examples [00:00, 57.64 examples/s]
# Generating test split: 100 examples [00:00, 1036.61 examples/s]
# Generating validation split: 9 examples [00:00, 2990.00 examples/s]
# Generating dev split: 5 examples [00:00, 58.31 examples/s]
# Generating test split: 145 examples [00:00, 1630.75 examples/s]
# Generating validation split: 16 examples [00:00, 3687.91 examples/s]
# Generating dev split: 5 examples [00:00, 58.16 examples/s]
# Generating test split: 203 examples [00:00, 2163.11 examples/s]
# Generating validation split: 22 examples [00:00, 3879.04 examples/s]
# Generating dev split: 5 examples [00:00, 51.71 examples/s]
# Generating test split: 270 examples [00:00, 2815.38 examples/s]
# Generating validation split: 29 examples [00:00, 6153.74 examples/s]
# Generating dev split: 5 examples [00:00, 58.63 examples/s]
# Generating test split: 151 examples [00:00, 1637.26 examples/s]
# Generating validation split: 17 examples [00:00, 3740.59 examples/s]
# Generating dev split: 5 examples [00:00, 57.52 examples/s]
# Generating test split: 100 examples [00:00, 1161.18 examples/s]
# Generating validation split: 8 examples [00:00, 1544.72 examples/s]
# Generating dev split: 5 examples [00:00, 53.29 examples/s]
# Generating test split: 378 examples [00:00, 3536.36 examples/s]
# Generating validation split: 41 examples [00:00, 6303.06 examples/s]
Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:02<00:00, 66.68it/s]
# 2024-03-28:17:11:22,938 INFO     [task.py:395] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 66.04it/s]
# 2024-03-28:17:11:24,492 INFO     [task.py:395] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:01<00:00, 66.73it/s]
# 2024-03-28:17:11:26,030 INFO     [task.py:395] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:02<00:00, 66.74it/s]
# 2024-03-28:17:11:28,366 INFO     [task.py:395] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:01<00:00, 66.50it/s]
# 2024-03-28:17:11:29,909 INFO     [task.py:395] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:02<00:00, 66.66it/s]
# 2024-03-28:17:11:32,124 INFO     [task.py:395] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:03<00:00, 66.45it/s]
# 2024-03-28:17:11:35,460 INFO     [task.py:395] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:01<00:00, 66.05it/s]
# 2024-03-28:17:11:37,044 INFO     [task.py:395] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:03<00:00, 66.53it/s]
# 2024-03-28:17:11:40,668 INFO     [task.py:395] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 66.57it/s]
# 2024-03-28:17:11:42,209 INFO     [task.py:395] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:01<00:00, 66.63it/s]
# 2024-03-28:17:11:43,934 INFO     [task.py:395] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:04<00:00, 66.11it/s]
# 2024-03-28:17:11:48,741 INFO     [task.py:395] Building contexts for mmlu_sociology on rank 0...
# 100% 201/201 [00:03<00:00, 66.73it/s]
# 2024-03-28:17:11:51,829 INFO     [task.py:395] Building contexts for mmlu_us_foreign_policy on rank 0...
# 100% 100/100 [00:01<00:00, 66.68it/s]
# 2024-03-28:17:11:53,367 INFO     [task.py:395] Building contexts for mmlu_high_school_macroeconomics on rank 0...
# 100% 390/390 [00:05<00:00, 66.64it/s]
# 2024-03-28:17:11:59,369 INFO     [task.py:395] Building contexts for mmlu_high_school_government_and_politics on rank 0...
# 100% 193/193 [00:02<00:00, 66.20it/s]
# 2024-03-28:17:12:02,359 INFO     [task.py:395] Building contexts for mmlu_human_sexuality on rank 0...
# 100% 131/131 [00:01<00:00, 66.57it/s]
# 2024-03-28:17:12:04,378 INFO     [task.py:395] Building contexts for mmlu_econometrics on rank 0...
# 100% 114/114 [00:01<00:00, 66.85it/s]
# 2024-03-28:17:12:06,126 INFO     [task.py:395] Building contexts for mmlu_high_school_microeconomics on rank 0...
# 100% 238/238 [00:03<00:00, 66.71it/s]
# 2024-03-28:17:12:09,783 INFO     [task.py:395] Building contexts for mmlu_professional_psychology on rank 0...
# 100% 612/612 [00:09<00:00, 66.59it/s]
# 2024-03-28:17:12:19,211 INFO     [task.py:395] Building contexts for mmlu_security_studies on rank 0...
# 100% 245/245 [00:03<00:00, 66.62it/s]
# 2024-03-28:17:12:22,984 INFO     [task.py:395] Building contexts for mmlu_high_school_geography on rank 0...
# 100% 198/198 [00:02<00:00, 66.81it/s]
# 2024-03-28:17:12:26,022 INFO     [task.py:395] Building contexts for mmlu_high_school_psychology on rank 0...
# 100% 545/545 [00:08<00:00, 66.69it/s]
# 2024-03-28:17:12:34,717 INFO     [task.py:395] Building contexts for mmlu_public_relations on rank 0...
# 100% 110/110 [00:01<00:00, 66.00it/s]
# 2024-03-28:17:12:36,426 INFO     [task.py:395] Building contexts for mmlu_clinical_knowledge on rank 0...
# 100% 265/265 [00:03<00:00, 66.44it/s]
# 2024-03-28:17:12:40,513 INFO     [task.py:395] Building contexts for mmlu_virology on rank 0...
# 100% 166/166 [00:02<00:00, 66.54it/s]
# 2024-03-28:17:12:43,071 INFO     [task.py:395] Building contexts for mmlu_college_medicine on rank 0...
# 100% 173/173 [00:02<00:00, 66.76it/s]
# 2024-03-28:17:12:45,728 INFO     [task.py:395] Building contexts for mmlu_human_aging on rank 0...
# 100% 223/223 [00:03<00:00, 66.17it/s]
# 2024-03-28:17:12:49,182 INFO     [task.py:395] Building contexts for mmlu_professional_accounting on rank 0...
# 100% 282/282 [00:04<00:00, 66.45it/s]
# 2024-03-28:17:12:53,534 INFO     [task.py:395] Building contexts for mmlu_medical_genetics on rank 0...
# 100% 100/100 [00:01<00:00, 66.69it/s]
# 2024-03-28:17:12:55,072 INFO     [task.py:395] Building contexts for mmlu_miscellaneous on rank 0...
# 100% 783/783 [00:11<00:00, 66.77it/s]
# 2024-03-28:17:13:07,101 INFO     [task.py:395] Building contexts for mmlu_management on rank 0...
# 100% 103/103 [00:01<00:00, 67.09it/s]
# 2024-03-28:17:13:08,676 INFO     [task.py:395] Building contexts for mmlu_global_facts on rank 0...
# 100% 100/100 [00:01<00:00, 66.93it/s]
# 2024-03-28:17:13:10,209 INFO     [task.py:395] Building contexts for mmlu_marketing on rank 0...
# 100% 234/234 [00:03<00:00, 66.34it/s]
# 2024-03-28:17:13:13,824 INFO     [task.py:395] Building contexts for mmlu_professional_medicine on rank 0...
# 100% 272/272 [00:04<00:00, 66.83it/s]
# 2024-03-28:17:13:17,998 INFO     [task.py:395] Building contexts for mmlu_nutrition on rank 0...
# 100% 306/306 [00:04<00:00, 66.56it/s]
# 2024-03-28:17:13:22,711 INFO     [task.py:395] Building contexts for mmlu_business_ethics on rank 0...
# 100% 100/100 [00:01<00:00, 66.29it/s]
# 2024-03-28:17:13:24,260 INFO     [task.py:395] Building contexts for mmlu_moral_scenarios on rank 0...
# 100% 895/895 [00:13<00:00, 66.30it/s]
# 2024-03-28:17:13:38,103 INFO     [task.py:395] Building contexts for mmlu_international_law on rank 0...
# 100% 121/121 [00:01<00:00, 66.43it/s]
# 2024-03-28:17:13:39,972 INFO     [task.py:395] Building contexts for mmlu_formal_logic on rank 0...
# 100% 126/126 [00:01<00:00, 66.40it/s]
# 2024-03-28:17:13:41,918 INFO     [task.py:395] Building contexts for mmlu_logical_fallacies on rank 0...
# 100% 163/163 [00:02<00:00, 66.33it/s]
# 2024-03-28:17:13:44,439 INFO     [task.py:395] Building contexts for mmlu_high_school_european_history on rank 0...
# 100% 165/165 [00:02<00:00, 64.92it/s]
# 2024-03-28:17:13:47,049 INFO     [task.py:395] Building contexts for mmlu_high_school_us_history on rank 0...
# 100% 204/204 [00:03<00:00, 66.19it/s]
# 2024-03-28:17:13:50,217 INFO     [task.py:395] Building contexts for mmlu_world_religions on rank 0...
# 100% 171/171 [00:02<00:00, 66.27it/s]
# 2024-03-28:17:13:52,863 INFO     [task.py:395] Building contexts for mmlu_philosophy on rank 0...
# 100% 311/311 [00:04<00:00, 66.60it/s]
# 2024-03-28:17:13:57,653 INFO     [task.py:395] Building contexts for mmlu_prehistory on rank 0...
# 100% 324/324 [00:04<00:00, 66.11it/s]
# 2024-03-28:17:14:02,677 INFO     [task.py:395] Building contexts for mmlu_moral_disputes on rank 0...
# 100% 346/346 [00:05<00:00, 66.39it/s]
# 2024-03-28:17:14:08,020 INFO     [task.py:395] Building contexts for mmlu_jurisprudence on rank 0...
# 100% 108/108 [00:01<00:00, 65.79it/s]
# 2024-03-28:17:14:09,704 INFO     [task.py:395] Building contexts for mmlu_professional_law on rank 0...
# 100% 1534/1534 [00:23<00:00, 66.11it/s]
# 2024-03-28:17:14:33,887 INFO     [task.py:395] Building contexts for mmlu_high_school_world_history on rank 0...
# 100% 237/237 [00:03<00:00, 65.74it/s]
# 2024-03-28:17:14:37,589 INFO     [evaluator.py:379] Running loglikelihood requests
# 2024-03-28:17:14:37,612 INFO     [model.py:225] Loading 'loglikelihood' responses from cache 'results_dir_mistral_mmlu_rank0.db' where possible...
# Checking cached requests: 100% 56168/56168 [00:09<00:00, 6097.50it/s]
# 2024-03-28:17:14:46,824 INFO     [model.py:249] Cached requests: 0, Requests remaining: 56168
# Running loglikelihood requests:   0% 0/56168 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 16
# Running loglikelihood requests:  25% 13889/56168 [08:20<11:10, 63.07it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Running loglikelihood requests:  25% 13952/56168 [08:35<11:09, 63.07it/s]Determined largest batch size: 64
# Running loglikelihood requests: 100% 56168/56168 [16:17<00:00, 57.46it/s]
# {
#   "results": {
#     "mmlu_stem": {
#       "alias": "stem",
#       "acc,none": 0.4900095147478592,
#       "acc_stderr,none": 0.008653770930628447
#     },
#     "mmlu_abstract_algebra": {
#       "alias": " - abstract_algebra",
#       "acc,none": 0.31,
#       "acc_stderr,none": 0.046482319871173156
#     },
#     "mmlu_anatomy": {
#       "alias": " - anatomy",
#       "acc,none": 0.5703703703703704,
#       "acc_stderr,none": 0.04276349494376599
#     },
#     "mmlu_astronomy": {
#       "alias": " - astronomy",
#       "acc,none": 0.631578947368421,
#       "acc_stderr,none": 0.039255233810529325
#     },
#     "mmlu_college_biology": {
#       "alias": " - college_biology",
#       "acc,none": 0.6597222222222222,
#       "acc_stderr,none": 0.03962135573486219
#     },
#     "mmlu_college_chemistry": {
#       "alias": " - college_chemistry",
#       "acc,none": 0.38,
#       "acc_stderr,none": 0.04878317312145633
#     },
#     "mmlu_college_computer_science": {
#       "alias": " - college_computer_science",
#       "acc,none": 0.48,
#       "acc_stderr,none": 0.050211673156867795
#     },
#     "mmlu_college_mathematics": {
#       "alias": " - college_mathematics",
#       "acc,none": 0.38,
#       "acc_stderr,none": 0.048783173121456344
#     },
#     "mmlu_college_physics": {
#       "alias": " - college_physics",
#       "mmlu_human_aging",
#       "mmlu_professional_accounting",
#       "mmlu_medical_genetics",
#       "mmlu_miscellaneous",
#       "mmlu_management",
#       "mmlu_global_facts",
#       "mmlu_marketing",
#       "mmlu_professional_medicine",
#       "mmlu_nutrition",
#       "mmlu_business_ethics"
#     ],
#     "mmlu_social_sciences": [
#       "mmlu_sociology",
#       "mmlu_us_foreign_policy",
#       "mmlu_high_school_macroeconomics",
#       "mmlu_high_school_government_and_politics",
#       "mmlu_human_sexuality",
#       "mmlu_econometrics",
#       "mmlu_high_school_microeconomics",
#       "mmlu_professional_psychology",
#       "mmlu_security_studies",
#       "mmlu_high_school_geography",
#       "mmlu_high_school_psychology",
#       "mmlu_public_relations"
#     ],
#     "mmlu_stem": [
#       "mmlu_abstract_algebra",
#       "mmlu_anatomy",
#       "mmlu_elementary_mathematics",
#       "mmlu_college_chemistry",
#       "mmlu_high_school_physics",
#       "mmlu_high_school_mathematics",
#       "mmlu_high_school_chemistry",
#       "mmlu_electrical_engineering",
#       "mmlu_high_school_computer_science",
#       "mmlu_computer_security",
#       "mmlu_astronomy",
#       "mmlu_college_mathematics",
#       "mmlu_college_biology",
#       "mmlu_high_school_statistics",
#       "mmlu_college_physics",
#       "mmlu_conceptual_physics",
#       "mmlu_college_computer_science",
#       "mmlu_machine_learning",
#       "mmlu_high_school_biology"
#     ]
#   },
#   "configs": {
#     "mmlu_abstract_algebra": {
#       "task": "mmlu_abstract_algebra",
#       "task_alias": "abstract_algebra",
#       "group": "mmlu_stem",
#       "group_alias": "stem",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "abstract_algebra",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about abstract algebra.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
#     "mmlu_anatomy": {
#       "task": "mmlu_anatomy",
#       "task_alias": "anatomy",
#       "group": "mmlu_stem",
#       "group_alias": "stem",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "anatomy",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about anatomy.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
#     "mmlu_astronomy": {
#       "task": "mmlu_astronomy",
#       "task_alias": "astronomy",
#       "group": "mmlu_stem",
#       "group_alias": "stem",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "astronomy",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about astronomy.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
#     "mmlu_business_ethics": {
#       "task": "mmlu_business_ethics",
#       "task_alias": "business_ethics",
#       "group": "mmlu_other",
#       "group_alias": "other",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "business_ethics",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about business ethics.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
#     "mmlu_clinical_knowledge": {
#       "task": "mmlu_clinical_knowledge",
#       "task_alias": "clinical_knowledge",
#       "group": "mmlu_other",
#       "group_alias": "other",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "clinical_knowledge",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about clinical knowledge.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
# ...
# wandb:                    mmlu_machine_learning/acc_stderr ▁
# wandb:                                 mmlu_management/acc ▁
# wandb:                          mmlu_management/acc_stderr ▁
# wandb:                                  mmlu_marketing/acc ▁
# wandb:                           mmlu_marketing/acc_stderr ▁
# wandb:                           mmlu_medical_genetics/acc ▁
# wandb:                    mmlu_medical_genetics/acc_stderr ▁
# wandb:                              mmlu_miscellaneous/acc ▁
# wandb:                       mmlu_miscellaneous/acc_stderr ▁
# wandb:                             mmlu_moral_disputes/acc ▁
# wandb:                      mmlu_moral_disputes/acc_stderr ▁
# wandb:                            mmlu_moral_scenarios/acc ▁
# wandb:                     mmlu_moral_scenarios/acc_stderr ▁
# wandb:                                  mmlu_nutrition/acc ▁
# wandb:                           mmlu_nutrition/acc_stderr ▁
# wandb:                                      mmlu_other/acc ▁
# wandb:                               mmlu_other/acc_stderr ▁
# wandb:                                 mmlu_philosophy/acc ▁
# wandb:                          mmlu_philosophy/acc_stderr ▁
# wandb:                                 mmlu_prehistory/acc ▁
# wandb:                          mmlu_prehistory/acc_stderr ▁
# wandb:                    mmlu_professional_accounting/acc ▁
# wandb:             mmlu_professional_accounting/acc_stderr ▁
# wandb:                           mmlu_professional_law/acc ▁
# wandb:                    mmlu_professional_law/acc_stderr ▁
# wandb:                      mmlu_professional_medicine/acc ▁
# wandb:               mmlu_professional_medicine/acc_stderr ▁
# wandb:                    mmlu_professional_psychology/acc ▁
# wandb:             mmlu_professional_psychology/acc_stderr ▁
# wandb:                           mmlu_public_relations/acc ▁
# wandb:                    mmlu_public_relations/acc_stderr ▁
# wandb:                           mmlu_security_studies/acc ▁
# wandb:                    mmlu_security_studies/acc_stderr ▁
# wandb:                            mmlu_social_sciences/acc ▁
# wandb:                     mmlu_social_sciences/acc_stderr ▁
# wandb:                                  mmlu_sociology/acc ▁
# wandb:                           mmlu_sociology/acc_stderr ▁
# wandb:                                       mmlu_stem/acc ▁
# wandb:                                mmlu_stem/acc_stderr ▁
# wandb:                          mmlu_us_foreign_policy/acc ▁
# wandb:                   mmlu_us_foreign_policy/acc_stderr ▁
# wandb:                                   mmlu_virology/acc ▁
# wandb:                            mmlu_virology/acc_stderr ▁
# wandb:                            mmlu_world_religions/acc ▁
# wandb:                     mmlu_world_religions/acc_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:                           mmlu_abstract_algebra/acc 0.31
# wandb:                    mmlu_abstract_algebra/acc_stderr 0.04648
# wandb:                         mmlu_abstract_algebra/alias  - abstract_algebra
# wandb:                                    mmlu_anatomy/acc 0.57037
# wandb:                             mmlu_anatomy/acc_stderr 0.04276
# wandb:                                  mmlu_anatomy/alias  - anatomy
# wandb:                                  mmlu_astronomy/acc 0.63158
# wandb:                           mmlu_astronomy/acc_stderr 0.03926
# wandb:                                mmlu_astronomy/alias  - astronomy
# wandb:                            mmlu_business_ethics/acc 0.57
# wandb:                     mmlu_business_ethics/acc_stderr 0.04976
# wandb:                          mmlu_business_ethics/alias  - business_ethics
# wandb:                         mmlu_clinical_knowledge/acc 0.66415
# wandb:                  mmlu_clinical_knowledge/acc_stderr 0.02907
# wandb:                       mmlu_clinical_knowledge/alias  - clinical_knowledg...
# wandb:                            mmlu_college_biology/acc 0.65972
# wandb:                     mmlu_college_biology/acc_stderr 0.03962
# wandb:                          mmlu_college_biology/alias  - college_biology
# wandb:                          mmlu_college_chemistry/acc 0.38
# wandb:                   mmlu_college_chemistry/acc_stderr 0.04878
# wandb:                        mmlu_college_chemistry/alias  - college_chemistry...
# wandb:                   mmlu_college_computer_science/acc 0.48
# wandb:            mmlu_college_computer_science/acc_stderr 0.05021
# wandb:                 mmlu_college_computer_science/alias  - college_computer_...
# wandb:                        mmlu_college_mathematics/acc 0.38
# wandb:                 mmlu_college_mathematics/acc_stderr 0.04878
# wandb:                      mmlu_college_mathematics/alias  - college_mathemati...
# wandb:                           mmlu_college_medicine/acc 0.57225
# wandb:                    mmlu_college_medicine/acc_stderr 0.03772
# wandb:                         mmlu_college_medicine/alias  - college_medicine
# wandb:                 mmlu_high_school_physics/acc_stderr 0.0388
# wandb:                      mmlu_high_school_physics/alias  - high_school_physi...
# wandb:                     mmlu_high_school_psychology/acc 0.79817
# wandb:              mmlu_high_school_psychology/acc_stderr 0.01721
# wandb:                   mmlu_high_school_psychology/alias  - high_school_psych...
# wandb:                     mmlu_high_school_statistics/acc 0.44444
# wandb:              mmlu_high_school_statistics/acc_stderr 0.03389
# wandb:                   mmlu_high_school_statistics/alias  - high_school_stati...
# wandb:                     mmlu_high_school_us_history/acc 0.7549
# wandb:              mmlu_high_school_us_history/acc_stderr 0.03019
# wandb:                   mmlu_high_school_us_history/alias  - high_school_us_hi...
# wandb:                  mmlu_high_school_world_history/acc 0.74684
# wandb:           mmlu_high_school_world_history/acc_stderr 0.0283
# wandb:                mmlu_high_school_world_history/alias  - high_school_world...
# wandb:                                mmlu_human_aging/acc 0.60987
# wandb:                         mmlu_human_aging/acc_stderr 0.03274
# wandb:                              mmlu_human_aging/alias  - human_aging
# wandb:                            mmlu_human_sexuality/acc 0.69466
# wandb:                     mmlu_human_sexuality/acc_stderr 0.04039
# wandb:                          mmlu_human_sexuality/alias  - human_sexuality
# wandb:                                 mmlu_humanities/acc 0.5509
# wandb:                          mmlu_humanities/acc_stderr 0.00689
# wandb:                               mmlu_humanities/alias humanities
# wandb:                          mmlu_international_law/acc 0.78512
# wandb:                   mmlu_international_law/acc_stderr 0.03749
# wandb:                        mmlu_international_law/alias  - international_law...
# wandb:                              mmlu_jurisprudence/acc 0.7037
# wandb:                       mmlu_jurisprudence/acc_stderr 0.04414
# wandb:                            mmlu_jurisprudence/alias  - jurisprudence
# wandb:                          mmlu_logical_fallacies/acc 0.7362
# wandb:                   mmlu_logical_fallacies/acc_stderr 0.03462
# wandb:                        mmlu_logical_fallacies/alias  - logical_fallacies...
# wandb:                           mmlu_machine_learning/acc 0.46429
# wandb:                    mmlu_machine_learning/acc_stderr 0.04734
# wandb:                         mmlu_machine_learning/alias  - machine_learning
# wandb:                                 mmlu_management/acc 0.74757
# wandb:                          mmlu_management/acc_stderr 0.04301
# wandb:                               mmlu_management/alias  - management
# wandb:                                  mmlu_marketing/acc 0.87607
# wandb:                           mmlu_marketing/acc_stderr 0.02159
# wandb:                                mmlu_marketing/alias  - marketing
# wandb:                           mmlu_medical_genetics/acc 0.67
# wandb:                    mmlu_medical_genetics/acc_stderr 0.04726
# wandb:                         mmlu_medical_genetics/alias  - medical_genetics
# wandb:                              mmlu_miscellaneous/acc 0.76756
# wandb:                       mmlu_miscellaneous/acc_stderr 0.0151
# wandb:                            mmlu_miscellaneous/alias  - miscellaneous
# wandb:                             mmlu_moral_disputes/acc 0.67052
# wandb:                      mmlu_moral_disputes/acc_stderr 0.02531
# wandb:                           mmlu_moral_disputes/alias  - moral_disputes
# wandb:                            mmlu_moral_scenarios/acc 0.38212
# wandb:                     mmlu_moral_scenarios/acc_stderr 0.01625
# wandb:                          mmlu_moral_scenarios/alias  - moral_scenarios
# wandb:                                  mmlu_nutrition/acc 0.66993
# wandb:                           mmlu_nutrition/acc_stderr 0.02693
# wandb:                                mmlu_nutrition/alias  - nutrition
# wandb:                                      mmlu_other/acc 0.65562
# wandb:                               mmlu_other/acc_stderr 0.00825
# wandb:                                    mmlu_other/alias other
# wandb:                                 mmlu_philosophy/acc 0.67846
# wandb:                          mmlu_philosophy/acc_stderr 0.02653
# wandb:                               mmlu_philosophy/alias  - philosophy
# wandb:                                 mmlu_prehistory/acc 0.67593
# wandb:                          mmlu_prehistory/acc_stderr 0.02604
# wandb:                               mmlu_prehistory/alias  - prehistory
# wandb:                    mmlu_professional_accounting/acc 0.46454
# wandb:             mmlu_professional_accounting/acc_stderr 0.02975
# wandb:                  mmlu_professional_accounting/alias  - professional_acco...
# wandb:                           mmlu_professional_law/acc 0.42894
# wandb:                    mmlu_professional_law/acc_stderr 0.01264
# wandb:                         mmlu_professional_law/alias  - professional_law
# wandb:                      mmlu_professional_medicine/acc 0.60294
# wandb:               mmlu_professional_medicine/acc_stderr 0.02972
# wandb:                    mmlu_professional_medicine/alias  - professional_medi...
# wandb:                    mmlu_professional_psychology/acc 0.60784
# wandb:             mmlu_professional_psychology/acc_stderr 0.01975
# wandb:                  mmlu_professional_psychology/alias  - professional_psyc...
# wandb:                           mmlu_public_relations/acc 0.69091
# wandb:                    mmlu_public_relations/acc_stderr 0.04426
# wandb:                         mmlu_public_relations/alias  - public_relations
# wandb:                           mmlu_security_studies/acc 0.73469
# wandb:                    mmlu_security_studies/acc_stderr 0.02826
# wandb:                         mmlu_security_studies/alias  - security_studies
# wandb:                            mmlu_social_sciences/acc 0.68508
# wandb:                     mmlu_social_sciences/acc_stderr 0.00817
# wandb:                          mmlu_social_sciences/alias social_sciences
# wandb:                                  mmlu_sociology/acc 0.73632
# wandb:                           mmlu_sociology/acc_stderr 0.03116
# wandb:                                mmlu_sociology/alias  - sociology
# wandb:                                       mmlu_stem/acc 0.49001
# wandb:                                mmlu_stem/acc_stderr 0.00865
# wandb:                                     mmlu_stem/alias stem
# wandb:                          mmlu_us_foreign_policy/acc 0.8
# wandb:                   mmlu_us_foreign_policy/acc_stderr 0.0402
# wandb:                        mmlu_us_foreign_policy/alias  - us_foreign_policy...
# wandb:                                   mmlu_virology/acc 0.48193
# wandb:                            mmlu_virology/acc_stderr 0.0389
# wandb:                                 mmlu_virology/alias  - virology
# wandb:                            mmlu_world_religions/acc 0.80702
# wandb:                     mmlu_world_religions/acc_stderr 0.03027
# wandb:                          mmlu_world_religions/alias  - world_religions
# wandb:
# wandb: 🚀 View run Mistral-7B-Instruct-NF4-MMLU at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/t0283alp/workspace
# wandb: Synced 5 W&B file(s), 6 media file(s), 51 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240328_170529-t0283alp/logs

# %% [markdown]
# #### HellaSwag
#
# 0-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Mistral-7B-Instruct-NF4,trust_remote_code=True,revision="d09342dee0fb90a04bcad6cb0e7bb41dc86179e1" \
    --tasks hellaswag \
    --num_fewshot 0 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir_mistral_hellaswag \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Mistral-7B-Instruct-NF4-hellaswag \
    --use_cache results_dir_mistral_hellaswag \
    --cache_requests true \
    --show_config
# Out:
# 2024-03-28 17:38:30.386636: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-28 17:38:30.386687: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-28 17:38:30.388185: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-28 17:38:31.615028: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240328_173837-f7n6rdh2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Mistral-7B-Instruct-NF4-hellaswag
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/f7n6rdh2/workspace
# 2024-03-28:17:38:38,326 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-28:17:38:44,174 INFO     [__main__.py:335] Selected Tasks: ['hellaswag']
# 2024-03-28:17:38:44,175 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-28:17:38:44,175 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Mistral-7B-Instruct-NF4', 'trust_remote_code': True, 'revision': 'd09342dee0fb90a04bcad6cb0e7bb41dc86179e1'}
# 2024-03-28:17:38:44,179 INFO     [huggingface.py:163] Using device 'cuda:0'
# 2024-03-28:17:38:47,885 WARNING  [big_modeling.py:448] You shouldn't move a model that is dispatched using accelerate hooks.
# 2024-03-28:17:38:47,956 INFO     [evaluator.py:195] Using cache at results_dir_mistral_hellaswag_rank0.db
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 4.36k/4.36k [00:00<00:00, 10.6MB/s]
# Downloading metadata: 100% 2.53k/2.53k [00:00<00:00, 8.60MB/s]
# Downloading readme: 100% 6.84k/6.84k [00:00<00:00, 12.0MB/s]
# Downloading data: 47.5MB [00:00, 74.4MB/s]
# Downloading data: 11.8MB [00:00, 64.6MB/s]
# Downloading data: 12.2MB [00:00, 65.8MB/s]
# Generating train split: 100% 39905/39905 [00:04<00:00, 9586.79 examples/s]
# Generating test split: 100% 10003/10003 [00:01<00:00, 9581.51 examples/s]
# Generating validation split: 100% 10042/10042 [00:01<00:00, 9584.81 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 6220.86 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 6630.84 examples/s]
# 2024-03-28:17:39:19,372 WARNING  [evaluator.py:239] Overwriting default num_fewshot of hellaswag from None to 0
# 2024-03-28:17:39:19,374 INFO     [task.py:395] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:04<00:00, 2344.84it/s]
# 2024-03-28:17:39:29,489 INFO     [evaluator.py:379] Running loglikelihood requests
# 2024-03-28:17:39:29,499 INFO     [model.py:225] Loading 'loglikelihood' responses from cache 'results_dir_mistral_hellaswag_rank0.db' where possible...
# Checking cached requests: 100% 40168/40168 [00:05<00:00, 6842.83it/s]
# 2024-03-28:17:39:35,370 INFO     [model.py:249] Cached requests: 0, Requests remaining: 40168
# Running loglikelihood requests:   0% 0/40168 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests:  25% 9929/40168 [01:51<04:59, 100.87it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests: 100% 40168/40168 [05:24<00:00, 123.69it/s]
# {
#   "results": {
#     "hellaswag": {
#       "acc,none": 0.6557458673571002,
#       "acc_stderr,none": 0.004741534106470301,
#       "acc_norm,none": 0.8333001394144592,
#       "acc_norm_stderr,none": 0.003719459738399085,
#       "alias": "hellaswag"
#     }
#   },
#   "group_subtasks": {
#     "hellaswag": []
#   },
#   "configs": {
#     "hellaswag": {
#       "task": "hellaswag",
#       "group": [
#         "multiple_choice"
#       ],
#       "dataset_path": "hellaswag",
#       "training_split": "train",
#       "validation_split": "validation",
#       "process_docs": "def process_docs(dataset: datasets.Dataset) -> datasets.Dataset:\n    def _process_doc(doc):\n        ctx = doc[\"ctx_a\"] + \" \" + doc[\"ctx_b\"].capitalize()\n        out_doc = {\n            \"query\": preprocess(doc[\"activity_label\"] + \": \" + ctx),\n            \"choices\": [preprocess(ending) for ending in doc[\"endings\"]],\n            \"gold\": int(doc[\"label\"]),\n        }\n        return out_doc\n\n    return dataset.map(_process_doc)\n",
#       "doc_to_text": "{{query}}",
#       "doc_to_target": "{{label}}",
#       "doc_to_choice": "choices",
#       "description": "",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         },
#         {
#           "metric": "acc_norm",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0
#       }
#     }
#   },
#   "versions": {
#     "hellaswag": 1.0
#   },
#   "n-shot": {
#     "hellaswag": 0
#   },
#   "config": {
#     "model": "hf",
#     "model_args": "pretrained=twhoool02/Mistral-7B-Instruct-NF4,trust_remote_code=True,revision=d09342dee0fb90a04bcad6cb0e7bb41dc86179e1",
#     "batch_size": "auto:4",
#     "batch_sizes": [
#       64,
#       64,
#       64,
#       64,
#       64
#     ],
#     "device": "cuda:0",
#     "use_cache": "results_dir_mistral_hellaswag",
#     "limit": null,
#     "bootstrap_iters": 100000,
#     "gen_kwargs": null
#   },
#   "git_hash": "ab7cc6b1",
#   "date": 1711647524.1748354,
#   "pretty_env_info": "PyTorch version: 2.2.1+cu121\nIs debug build: False\nCUDA used to build PyTorch: 12.1\nROCM used to build PyTorch: N/A\n\nOS: Ubuntu 22.04.3 LTS (x86_64)\nGCC version: (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0\nClang version: 14.0.0-1ubuntu1.1\nCMake version: version 3.27.9\nLibc version: glibc-2.35\n\nPython version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0] (64-bit runtime)\nPython platform: Linux-6.1.58+-x86_64-with-glibc2.35\nIs CUDA available: True\nCUDA runtime version: 12.2.140\nCUDA_MODULE_LOADING set to: LAZY\nGPU models and configuration: GPU 0: NVIDIA A100-SXM4-40GB\nNvidia driver version: 535.104.05\ncuDNN version: Probably one of the following:\n/usr/lib/x86_64-linux-gnu/libcudnn.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_train.so.8.9.6\nHIP runtime version: N/A\nMIOpen runtime version: N/A\nIs XNNPACK available: True\n\nCPU:\nArchitecture:                       x86_64\nCPU op-mode(s):                     32-bit, 64-bit\nAddress sizes:                      46 bits physical, 48 bits virtual\nByte Order:                         Little Endian\nCPU(s):                             12\nOn-line CPU(s) list:                0-11\nVendor ID:                          GenuineIntel\nModel name:                         Intel(R) Xeon(R) CPU @ 2.20GHz\nCPU family:                         6\nModel:                              85\nThread(s) per core:                 2\nCore(s) per socket:                 6\nSocket(s):                          1\nStepping:                           7\nBogoMIPS:                           4400.33\nFlags:                              fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp ibrs_enhanced fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat avx512_vnni md_clear arch_capabilities\nHypervisor vendor:                  KVM\nVirtualization type:                full\nL1d cache:                          192 KiB (6 instances)\nL1i cache:                          192 KiB (6 instances)\nL2 cache:                           6 MiB (6 instances)\nL3 cache:                           38.5 MiB (1 instance)\nNUMA node(s):                       1\nNUMA node0 CPU(s):                  0-11\nVulnerability Gather data sampling: Not affected\nVulnerability Itlb multihit:        Not affected\nVulnerability L1tf:                 Not affected\nVulnerability Mds:                  Vulnerable; SMT Host state unknown\nVulnerability Meltdown:             Not affected\nVulnerability Mmio stale data:      Vulnerable\nVulnerability Retbleed:             Vulnerable\nVulnerability Spec rstack overflow: Not affected\nVulnerability Spec store bypass:    Vulnerable\nVulnerability Spectre v1:           Vulnerable: __user pointer sanitization and usercopy barriers only; no swapgs barriers\nVulnerability Spectre v2:           Vulnerable, IBPB: disabled, STIBP: disabled, PBRSB-eIBRS: Vulnerable\nVulnerability Srbds:                Not affected\nVulnerability Tsx async abort:      Vulnerable\n\nVersions of relevant libraries:\n[pip3] numpy==1.25.2\n[pip3] torch==2.2.1+cu121\n[pip3] torchaudio==2.2.1+cu121\n[pip3] torchdata==0.7.1\n[pip3] torchsummary==1.5.1\n[pip3] torchtext==0.17.1\n[pip3] torchvision==0.17.1+cu121\n[pip3] triton==2.2.0\n[conda] Could not collect",
#   "transformers_version": "4.38.2",
#   "upper_git_hash": null
# }
# hf (pretrained=twhoool02/Mistral-7B-Instruct-NF4,trust_remote_code=True,revision=d09342dee0fb90a04bcad6cb0e7bb41dc86179e1), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: auto:4 (64,64,64,64,64)
# |  Tasks  |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |---------|------:|------|-----:|--------|-----:|---|-----:|
# |hellaswag|      1|none  |     0|acc     |0.6557|±  |0.0047|
# |         |       |none  |     0|acc_norm|0.8333|±  |0.0037|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:             hellaswag/acc ▁
# wandb:        hellaswag/acc_norm ▁
# wandb: hellaswag/acc_norm_stderr ▁
# wandb:      hellaswag/acc_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:             hellaswag/acc 0.65575
# wandb:        hellaswag/acc_norm 0.8333
# wandb: hellaswag/acc_norm_stderr 0.00372
# wandb:      hellaswag/acc_stderr 0.00474
# wandb:           hellaswag/alias hellaswag
# wandb:
# wandb: 🚀 View run Mistral-7B-Instruct-NF4-hellaswag at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/f7n6rdh2/workspace
# wandb: Synced 5 W&B file(s), 2 media file(s), 3 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240328_173837-f7n6rdh2/logs

# %% [markdown]
# #### BoolQ
#
# 0-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Mistral-7B-Instruct-NF4,trust_remote_code=True,revision="d09342dee0fb90a04bcad6cb0e7bb41dc86179e1" \
    --tasks boolq \
    --num_fewshot 0 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir_mistral_boolq \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Mistral-7B-Instruct-NF4-boolq \
    --use_cache results_dir_mistral_boolq \
    --cache_requests true \
    --show_config
# Out:
# 2024-03-28 17:46:06.643397: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-28 17:46:06.643444: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-28 17:46:06.644889: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-28 17:46:07.877955: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240328_174613-w386bjo0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Mistral-7B-Instruct-NF4-boolq
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/w386bjo0/workspace
# 2024-03-28:17:46:14,630 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-28:17:46:20,803 INFO     [__main__.py:335] Selected Tasks: ['boolq']
# 2024-03-28:17:46:20,804 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-28:17:46:20,804 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Mistral-7B-Instruct-NF4', 'trust_remote_code': True, 'revision': 'd09342dee0fb90a04bcad6cb0e7bb41dc86179e1'}
# 2024-03-28:17:46:20,808 INFO     [huggingface.py:163] Using device 'cuda:0'
# 2024-03-28:17:46:24,278 WARNING  [big_modeling.py:448] You shouldn't move a model that is dispatched using accelerate hooks.
# 2024-03-28:17:46:24,348 INFO     [evaluator.py:195] Using cache at results_dir_mistral_boolq_rank0.db
# 2024-03-28:17:46:24,353 WARNING  [task.py:763] [Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# 2024-03-28:17:46:24,354 WARNING  [task.py:775] [Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# Downloading data: 100% 3.85M/3.85M [00:00<00:00, 8.64MB/s]
# Downloading data: 100% 1.31M/1.31M [00:00<00:00, 4.80MB/s]
# Downloading data: 100% 1.31M/1.31M [00:00<00:00, 4.18MB/s]
# Generating train split: 100% 9427/9427 [00:00<00:00, 234282.98 examples/s]
# Generating validation split: 100% 3270/3270 [00:00<00:00, 273405.24 examples/s]
# Generating test split: 100% 3245/3245 [00:00<00:00, 301051.02 examples/s]
# 2024-03-28:17:46:35,345 WARNING  [evaluator.py:239] Overwriting default num_fewshot of boolq from None to 0
# 2024-03-28:17:46:35,346 INFO     [task.py:395] Building contexts for boolq on rank 0...
# 100% 3270/3270 [00:01<00:00, 1747.89it/s]
# 2024-03-28:17:46:37,928 INFO     [evaluator.py:379] Running loglikelihood requests
# 2024-03-28:17:46:37,930 INFO     [model.py:225] Loading 'loglikelihood' responses from cache 'results_dir_mistral_boolq_rank0.db' where possible...
# Checking cached requests: 100% 6540/6540 [00:00<00:00, 6696.10it/s]
# 2024-03-28:17:46:38,908 INFO     [model.py:249] Cached requests: 0, Requests remaining: 6540
# Running loglikelihood requests:   0% 0/6540 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 32
# Running loglikelihood requests:  24% 1537/6540 [00:52<00:47, 105.77it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests: 100% 6540/6540 [01:27<00:00, 74.92it/s]
# {
#   "results": {
#     "boolq": {
#       "acc,none": 0.8504587155963302,
#       "acc_stderr,none": 0.006237344204823627,
#       "alias": "boolq"
#     }
#   },
#   "group_subtasks": {
#     "boolq": []
#   },
#   "configs": {
#     "boolq": {
#       "task": "boolq",
#       "group": [
#         "super-glue-lm-eval-v1"
#       ],
#       "dataset_path": "super_glue",
#       "dataset_name": "boolq",
#       "training_split": "train",
#       "validation_split": "validation",
#       "doc_to_text": "{{passage}}\nQuestion: {{question}}?\nAnswer:",
#       "doc_to_target": "label",
#       "doc_to_choice": [
#         "no",
#         "yes"
#       ],
#       "description": "",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "acc"
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": true,
#       "doc_to_decontamination_query": "passage",
#       "metadata": {
#         "version": 2.0
#       }
#     }
#   },
#   "versions": {
#     "boolq": 2.0
#   },
#   "n-shot": {
#     "boolq": 0
#   },
#   "config": {
#     "model": "hf",
#     "model_args": "pretrained=twhoool02/Mistral-7B-Instruct-NF4,trust_remote_code=True,revision=d09342dee0fb90a04bcad6cb0e7bb41dc86179e1",
#     "batch_size": "auto:4",
#     "batch_sizes": [
#       32,
#       64,
#       64,
#       64,
#       64
#     ],
#     "device": "cuda:0",
#     "use_cache": "results_dir_mistral_boolq",
#     "limit": null,
#     "bootstrap_iters": 100000,
#     "gen_kwargs": null
#   },
#   "git_hash": "ab7cc6b1",
#   "date": 1711647980.8037822,
#   "pretty_env_info": "PyTorch version: 2.2.1+cu121\nIs debug build: False\nCUDA used to build PyTorch: 12.1\nROCM used to build PyTorch: N/A\n\nOS: Ubuntu 22.04.3 LTS (x86_64)\nGCC version: (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0\nClang version: 14.0.0-1ubuntu1.1\nCMake version: version 3.27.9\nLibc version: glibc-2.35\n\nPython version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0] (64-bit runtime)\nPython platform: Linux-6.1.58+-x86_64-with-glibc2.35\nIs CUDA available: True\nCUDA runtime version: 12.2.140\nCUDA_MODULE_LOADING set to: LAZY\nGPU models and configuration: GPU 0: NVIDIA A100-SXM4-40GB\nNvidia driver version: 535.104.05\ncuDNN version: Probably one of the following:\n/usr/lib/x86_64-linux-gnu/libcudnn.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_train.so.8.9.6\nHIP runtime version: N/A\nMIOpen runtime version: N/A\nIs XNNPACK available: True\n\nCPU:\nArchitecture:                       x86_64\nCPU op-mode(s):                     32-bit, 64-bit\nAddress sizes:                      46 bits physical, 48 bits virtual\nByte Order:                         Little Endian\nCPU(s):                             12\nOn-line CPU(s) list:                0-11\nVendor ID:                          GenuineIntel\nModel name:                         Intel(R) Xeon(R) CPU @ 2.20GHz\nCPU family:                         6\nModel:                              85\nThread(s) per core:                 2\nCore(s) per socket:                 6\nSocket(s):                          1\nStepping:                           7\nBogoMIPS:                           4400.33\nFlags:                              fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp ibrs_enhanced fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat avx512_vnni md_clear arch_capabilities\nHypervisor vendor:                  KVM\nVirtualization type:                full\nL1d cache:                          192 KiB (6 instances)\nL1i cache:                          192 KiB (6 instances)\nL2 cache:                           6 MiB (6 instances)\nL3 cache:                           38.5 MiB (1 instance)\nNUMA node(s):                       1\nNUMA node0 CPU(s):                  0-11\nVulnerability Gather data sampling: Not affected\nVulnerability Itlb multihit:        Not affected\nVulnerability L1tf:                 Not affected\nVulnerability Mds:                  Vulnerable; SMT Host state unknown\nVulnerability Meltdown:             Not affected\nVulnerability Mmio stale data:      Vulnerable\nVulnerability Retbleed:             Vulnerable\nVulnerability Spec rstack overflow: Not affected\nVulnerability Spec store bypass:    Vulnerable\nVulnerability Spectre v1:           Vulnerable: __user pointer sanitization and usercopy barriers only; no swapgs barriers\nVulnerability Spectre v2:           Vulnerable, IBPB: disabled, STIBP: disabled, PBRSB-eIBRS: Vulnerable\nVulnerability Srbds:                Not affected\nVulnerability Tsx async abort:      Vulnerable\n\nVersions of relevant libraries:\n[pip3] numpy==1.25.2\n[pip3] torch==2.2.1+cu121\n[pip3] torchaudio==2.2.1+cu121\n[pip3] torchdata==0.7.1\n[pip3] torchsummary==1.5.1\n[pip3] torchtext==0.17.1\n[pip3] torchvision==0.17.1+cu121\n[pip3] triton==2.2.0\n[conda] Could not collect",
#   "transformers_version": "4.38.2",
#   "upper_git_hash": null
# }
# hf (pretrained=twhoool02/Mistral-7B-Instruct-NF4,trust_remote_code=True,revision=d09342dee0fb90a04bcad6cb0e7bb41dc86179e1), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: auto:4 (32,64,64,64,64)
# |Tasks|Version|Filter|n-shot|Metric|Value |   |Stderr|
# |-----|------:|------|-----:|------|-----:|---|-----:|
# |boolq|      2|none  |     0|acc   |0.8505|±  |0.0062|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:        boolq/acc ▁
# wandb: boolq/acc_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:        boolq/acc 0.85046
# wandb: boolq/acc_stderr 0.00624
# wandb:      boolq/alias boolq
# wandb:
# wandb: 🚀 View run Mistral-7B-Instruct-NF4-boolq at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/w386bjo0/workspace
# wandb: Synced 5 W&B file(s), 2 media file(s), 4 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240328_174613-w386bjo0/logs

# %% [markdown]
# #### BBH
#
# 3-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Mistral-7B-Instruct-NF4,trust_remote_code=True,revision="d09342dee0fb90a04bcad6cb0e7bb41dc86179e1" \
    --tasks bbh_fewshot\
    --num_fewshot 3 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir_mistral_bbh \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Mistral-7B-Instruct-NF4-bbh \
    --use_cache results_dir_mistral_bbh \
    --cache_requests true \
    --show_config
# Out:
# 2024-03-28 17:48:39.871466: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-28 17:48:39.871519: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-28 17:48:39.873003: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-28 17:48:41.124189: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240328_174846-yiokzrro
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Mistral-7B-Instruct-NF4-bbh
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/yiokzrro/workspace
# 2024-03-28:17:48:48,075 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-28:17:48:54,265 INFO     [__main__.py:335] Selected Tasks: ['bbh_fewshot']
# 2024-03-28:17:48:54,266 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-28:17:48:54,266 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Mistral-7B-Instruct-NF4', 'trust_remote_code': True, 'revision': 'd09342dee0fb90a04bcad6cb0e7bb41dc86179e1'}
# 2024-03-28:17:48:54,270 INFO     [huggingface.py:163] Using device 'cuda:0'
# 2024-03-28:17:48:57,611 WARNING  [big_modeling.py:448] You shouldn't move a model that is dispatched using accelerate hooks.
# 2024-03-28:17:48:57,683 INFO     [evaluator.py:195] Using cache at results_dir_mistral_bbh_rank0.db
# Downloading data: 100% 37.1k/37.1k [00:00<00:00, 103kB/s]
# Generating test split: 100% 250/250 [00:00<00:00,
] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 20.4k/20.4k [00:00<00:00, 72.9kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 104616.98 examples/s]
# 2024-03-28:17:50:31,270 WARNING  [task.py:322] [Task: bbh_fewshot_reasoning_about_colored_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-28:17:50:31,271 WARNING  [task.py:322] [Task: bbh_fewshot_reasoning_about_colored_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.0k/10.0k [00:00<00:00, 35.7kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 101126.05 examples/s]
# 2024-03-28:17:50:37,030 WARNING  [task.py:322] [Task: bbh_fewshot_navigate] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-28:17:50:37,030 WARNING  [task.py:322] [Task: bbh_fewshot_navigate] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 18.0k/18.0k [00:00<00:00, 64.2kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 95160.72 examples/s]
# 2024-03-28:17:50:43,106 WARNING  [task.py:322] [Task: bbh_fewshot_date_understanding] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-28:17:50:43,106 WARNING  [task.py:322] [Task: bbh_fewshot_date_understanding] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 35.8k/35.8k [00:00<00:00, 128kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 99674.52 examples/s]
# 2024-03-28:17:50:48,738 WARNING  [task.py:322] [Task: bbh_fewshot_formal_fallacies] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-28:17:50:48,738 WARNING  [task.py:322] [Task: bbh_fewshot_formal_fallacies] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 4.70k/4.70k [00:00<00:00, 16.7kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 117290.38 examples/s]
# 2024-03-28:17:50:54,567 WARNING  [task.py:322] [Task: bbh_fewshot_boolean_expressions] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-28:17:50:54,567 WARNING  [task.py:322] [Task: bbh_fewshot_boolean_expressions] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 16.4k/16.4k [00:00<00:00, 32.1kB/s]
# Generating test split: 100% 178/178 [00:00<00:00, 78945.34 examples/s]
# 2024-03-28:17:51:00,400 WARNING  [task.py:322] [Task: bbh_fewshot_snarks] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-28:17:51:00,400 WARNING  [task.py:322] [Task: bbh_fewshot_snarks] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.0k/10.0k [00:00<00:00, 36.1kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 119088.70 examples/s]
# 2024-03-28:17:51:05,943 WARNING  [task.py:322] [Task: bbh_fewshot_dyck_languages] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-28:17:51:05,944 WARNING  [task.py:322] [Task: bbh_fewshot_dyck_languages] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 69.5k/69.5k [00:00<00:00, 252kB/s]
# Generating test split: 100% 187/187 [00:00<00:00, 59284.57 examples/s]
# 2024-03-28:17:51:11,526 WARNING  [task.py:322] [Task: bbh_fewshot_causal_judgement] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-28:17:51:11,526 WARNING  [task.py:322] [Task: bbh_fewshot_causal_judgement] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 16.7k/16.7k [00:00<00:00, 59.0kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 106595.10 examples/s]
# 2024-03-28:17:51:15,971 WARNING  [task.py:322] [Task: bbh_fewshot_disambiguation_qa] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-28:17:51:15,972 WARNING  [task.py:322] [Task: bbh_fewshot_disambiguation_qa] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 7.55k/7.55k [00:00<00:00, 26.8kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 122726.59 examples/s]
# 2024-03-28:17:51:20,632 WARNING  [task.py:322] [Task: bbh_fewshot_multistep_arithmetic_two] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-28:17:51:20,632 WARNING  [task.py:322] [Task: bbh_fewshot_multistep_arithmetic_two] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 44.0k/44.0k [00:00<00:00, 158kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 81284.96 examples/s]
# 2024-03-28:17:51:26,565 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-28:17:51:26,566 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.7k/10.7k [00:00<00:00, 38.6kB/s]
# Generating test split: 100% 146/146 [00:00<00:00, 54278.35 examples/s]
# 2024-03-28:17:51:32,518 WARNING  [task.py:322] [Task: bbh_fewshot_penguins_in_a_table] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-28:17:51:32,519 WARNING  [task.py:322] [Task: bbh_fewshot_penguins_in_a_table] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-28:17:51:32,524 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_penguins_in_a_table in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,524 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_logical_deduction_seven_objects in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,524 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_multistep_arithmetic_two in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,524 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_disambiguation_qa in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,524 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_causal_judgement in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,524 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_dyck_languages in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,524 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_snarks in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,524 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_boolean_expressions in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,524 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_formal_fallacies in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,525 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_date_understanding in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,525 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_navigate in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,525 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_reasoning_about_colored_objects in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,525 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_word_sorting in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,525 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_ruin_names in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,525 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_tracking_shuffled_objects_seven_objects in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,525 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_geometric_shapes in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,525 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_logical_deduction_five_objects in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,525 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_logical_deduction_three_objects in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,525 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_sports_understanding in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,525 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_temporal_sequences in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,525 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_salient_translation_error_detection in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,526 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_movie_recommendation in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,526 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_web_of_lies in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,526 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_object_counting in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,526 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_hyperbaton in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,526 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_tracking_shuffled_objects_three_objects in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,526 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_tracking_shuffled_objects_five_objects in its config. Manual configuration will be ignored.
# 2024-03-28:17:51:32,529 INFO     [task.py:395] Building contexts for bbh_fewshot_penguins_in_a_table on rank 0...
# 100% 146/146 [00:00<00:00, 1017.46it/s]
# 2024-03-28:17:51:32,696 INFO     [task.py:395] Building contexts for bbh_fewshot_logical_deduction_seven_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1020.43it/s]
# 2024-03-28:17:51:32,980 INFO     [task.py:395] Building contexts for bbh_fewshot_multistep_arithmetic_two on rank 0...
# 100% 250/250 [00:00<00:00, 1190.50it/s]
# 2024-03-28:17:51:33,226 INFO     [task.py:395] Building contexts for bbh_fewshot_disambiguation_qa on rank 0...
# 100% 250/250 [00:00<00:00, 1073.69it/s]
# 2024-03-28:17:51:33,497 INFO     [task.py:395] Building contexts for bbh_fewshot_causal_judgement on rank 0...
# 100% 187/187 [00:00<00:00, 938.81it/s]
# 2024-03-28:17:51:33,726 INFO     [task.py:395] Building contexts for bbh_fewshot_dyck_languages on rank 0...
# 100% 250/250 [00:00<00:00, 1189.27it/s]
# 2024-03-28:17:51:33,973 INFO     [task.py:395] Building contexts for bbh_fewshot_snarks on rank 0...
# 100% 178/178 [00:00<00:00, 1031.17it/s]
# 2024-03-28:17:51:34,172 INFO     [task.py:395] Building contexts for bbh_fewshot_boolean_expressions on rank 0...
# 100% 250/250 [00:00<00:00, 1225.12it/s]
# 2024-03-28:17:51:34,413 INFO     [task.py:395] Building contexts for bbh_fewshot_formal_fallacies on rank 0...
# 100% 250/250 [00:00<00:00, 1008.42it/s]
# 2024-03-28:17:51:34,699 INFO     [task.py:395] Building contexts for bbh_fewshot_date_understanding on rank 0...
# 100% 250/250 [00:00<00:00, 1133.13it/s]
# 2024-03-28:17:51:34,957 INFO     [task.py:395] Building contexts for bbh_fewshot_navigate on rank 0...
# 100% 250/250 [00:00<00:00, 1140.06it/s]
# 2024-03-28:17:51:35,213 INFO     [task.py:395] Building contexts for bbh_fewshot_reasoning_about_colored_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1032.83it/s]
# 2024-03-28:17:51:35,493 INFO     [task.py:395] Building contexts for bbh_fewshot_word_sorting on rank 0...
# 100% 250/250 [00:00<00:00, 1187.04it/s]
# 2024-03-28:17:51:35,740 INFO     [task.py:395] Building contexts for bbh_fewshot_ruin_names on rank 0...
# 100% 250/250 [00:00<00:00, 1127.17it/s]
# 2024-03-28:17:51:35,999 INFO     [task.py:395] Building contexts for bbh_fewshot_tracking_shuffled_objects_seven_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1024.66it/s]
# 2024-03-28:17:51:36,282 INFO     [task.py:395] Building contexts for bbh_fewshot_geometric_shapes on rank 0...
# 100% 250/250 [00:00<00:00, 1086.54it/s]
# 2024-03-28:17:51:36,550 INFO     [task.py:395] Building contexts for bbh_fewshot_logical_deduction_five_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1044.45it/s]
# 2024-03-28:17:51:36,827 INFO     [task.py:395] Building contexts for bbh_fewshot_logical_deduction_three_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1038.31it/s]
# 2024-03-28:17:51:37,106 INFO     [task.py:395] Building contexts for bbh_fewshot_sports_understanding on rank 0...
# 100% 250/250 [00:00<00:00, 1173.41it/s]
# 2024-03-28:17:51:37,356 INFO     [task.py:395] Building contexts for bbh_fewshot_temporal_sequences on rank 0...
# 100% 250/250 [00:00<00:00, 964.43it/s]
# 2024-03-28:17:51:37,655 INFO     [task.py:395] Building contexts for bbh_fewshot_salient_translation_error_detection on rank 0...
# 100% 250/250 [00:00<00:00, 736.21it/s]
# 2024-03-28:17:51:38,037 INFO     [task.py:395] Building contexts for bbh_fewshot_movie_recommendation on rank 0...
# 100% 250/250 [00:00<00:00, 1101.00it/s]
# 2024-03-28:17:51:38,301 INFO     [task.py:395] Building contexts for bbh_fewshot_web_of_lies on rank 0...
# 100% 250/250 [00:00<00:00, 1129.94it/s]
# 2024-03-28:17:51:38,560 INFO     [task.py:395] Building contexts for bbh_fewshot_object_counting on rank 0...
# 100% 250/250 [00:00<00:00, 1160.17it/s]
# 2024-03-28:17:51:38,812 INFO     [task.py:395] Building contexts for bbh_fewshot_hyperbaton on rank 0...
# 100% 250/250 [00:00<00:00, 1167.52it/s]
# 2024-03-28:17:51:39,063 INFO     [task.py:395] Building contexts for bbh_fewshot_tracking_shuffled_objects_three_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1022.59it/s]
# 2024-03-28:17:51:39,346 INFO     [task.py:395] Building contexts for bbh_fewshot_tracking_shuffled_objects_five_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1022.82it/s]
# 2024-03-28:17:51:39,628 INFO     [evaluator.py:379] Running generate_until requests
# 2024-03-28:17:51:39,631 INFO     [model.py:225] Loading 'generate_until' responses from cache 'results_dir_mistral_bbh_rank0.db' where possible...
# Checking cached requests: 100% 6511/6511 [00:01<00:00, 6455.76it/s]
# 2024-03-28:17:51:40,640 INFO     [model.py:249] Cached requests: 0, Requests remaining: 6511
# Running generate_until requests:   0% 0/6511 [00:00<?, ?it/s]Passed argument batch_size = auto. Detecting largest batch size
# Determined Largest batch size: 2
# Running generate_until requests: 100% 6511/6511 [51:30<00:00,  2.11it/s]
# {
#   "results": {
#     "bbh_fewshot": {
#       "exact_match,none": 0.40270311780064505,
#       "exact_match_stderr,none": 0.005624097426990939,
#       "alias": "bbh_fewshot"
#     },
#     "bbh_fewshot_boolean_expressions": {
#       "exact_match,none": 0.784,
#       "exact_match_stderr,none": 0.026078657663732727,
#       "alias": " - bbh_fewshot_boolean_expressions"
#     },
#     "bbh_fewshot_causal_judgement": {
#       "exact_match,none": 0.5721925133689839,
#       "exact_match_stderr,none": 0.03627762136497334,
#       "alias": " - bbh_fewshot_causal_judgement"
#     },
#     "bbh_fewshot_date_understanding": {
#       "exact_match,none": 0.352,
#       "exact_match_stderr,none": 0.030266288057359942,
#       "alias": " - bbh_fewshot_date_understanding"
#     },
#     "bbh_fewshot_disambiguation_qa": {
#       "exact_match,none": 0.576,
#       "exact_match_stderr,none": 0.03131803437491614,
#       "alias": " - bbh_fewshot_disambiguation_qa"
#     },
#     "bbh_fewshot_dyck_languages": {
#       "exact_match,none": 0.104,
#       "exact_match_stderr,none": 0.019345100974843873,
#       "alias": " - bbh_fewshot_dyck_languages"
#     },
#     "bbh_fewshot_formal_fallacies": {
#       "exact_match,none": 0.516,
#       "exact_match_stderr,none": 0.03166998503010742,
#       "alias": " - bbh_fewshot_formal_fallacies"
#     },
#     "bbh_fewshot_geometric_shapes": {
#       "exact_match,none": 0.324,
#       "exact_match_stderr,none": 0.029658294924545567,
#       "alias": " - bbh_fewshot_geometric_shapes"
#     },
#     "bbh_fewshot_hyperbaton": {
#       "exact_match,none": 0.62,
#       "exact_match_stderr,none": 0.030760116042626042,
#       "alias": " - bbh_fewshot_hyperbaton"
#     },
#     "bbh_fewshot_logical_deduction_five_objects": {
#       "exact_match,none": 0.324,
#       "exact_match_stderr,none": 0.02965829492454557,
#       "alias": " - bbh_fewshot_logical_deduction_five_objects"
#     },
#     "bbh_fewshot_logical_deduction_seven_objects": {
#       "exact_match,none": 0.28,
#       "exact_match_stderr,none": 0.028454148277832318,
#       "alias": " - bbh_fewshot_logical_deduction_seven_objects"
#     },
#     "bbh_fewshot_logical_deduction_three_objects": {
#       "exact_match,none": 0.472,
#       "exact_match_stderr,none": 0.0316364895315444,
#       "alias": " - bbh_fewshot_logical_deduction_three_objects"
#     },
#     "bbh_fewshot_movie_recommendation": {
#       "exact_match,none": 0.516,
#       "exact_match_stderr,none": 0.03166998503010742,
#       "alias": " - bbh_fewshot_movie_recommendation"
#     },
#     "bbh_fewshot_multistep_arithmetic_two": {
#       "exact_match,none": 0.008,
#       "exact_match_stderr,none": 0.0056454836766901715,
#       "alias": " - bbh_fewshot_multistep_arithmetic_two"
#     },
#     "bbh_fewshot_navigate": {
#       "exact_match,none": 0.524,
#       "exact_match_stderr,none": 0.03164968895968782,
#       "alias": " - bbh_fewshot_navigate"
#     },
#     "bbh_fewshot_object_counting": {
#       "exact_match,none": 0.4,
#       "exact_match_stderr,none": 0.03104602102825325,
#       "alias": " - bbh_fewshot_object_counting"
#     },
#     "bbh_fewshot_penguins_in_a_table": {
#       "exact_match,none": 0.4041095890410959,
#       "exact_match_stderr,none": 0.040751985700393185,
#       "alias": " - bbh_fewshot_penguins_in_a_table"
#     },
#     "bbh_fewshot_reasoning_about_colored_objects": {
#       "exact_match,none": 0.364,
#       "exact_match_stderr,none": 0.030491555220405562,
#       "alias": " - bbh_fewshot_reasoning_about_colored_objects"
#     },
#     "bbh_fewshot_ruin_names": {
#       "exact_match,none": 0.46,
#       "exact_match_stderr,none": 0.03158465389149902,
#       "alias": " - bbh_fewshot_ruin_names"
#     },
#     "bbh_fewshot_salient_translation_error_detection": {
#       "exact_match,none": 0.36,
#       "exact_match_stderr,none": 0.03041876402517498,
#       "alias": " - bbh_fewshot_salient_translation_error_detection"
#     },
#     "bbh_fewshot_snarks": {
#       "exact_match,none": 0.550561797752809,
#       "exact_match_stderr,none": 0.03738964966056965,
#       "alias": " - bbh_fewshot_snarks"
#     },
#     "bbh_fewshot_sports_understanding": {
#       "exact_match,none": 0.788,
#       "exact_match_stderr,none": 0.025901884690541166,
#       "alias": " - bbh_fewshot_sports_understanding"
#     },
#     "bbh_fewshot_temporal_sequences": {
#       "exact_match,none": 0.244,
#       "exact_match_stderr,none": 0.02721799546455318,
#       "alias": " - bbh_fewshot_temporal_sequences"
#     },
#     "bbh_fewshot_tracking_shuffled_objects_five_objects": {
#       "exact_match,none": 0.224,
#       "exact_match_stderr,none": 0.02642136168734791,
#       "alias": " - bbh_fewshot_tracking_shuffled_objects_five_objects"
#     },
#     "bbh_fewshot_tracking_shuffled_objects_seven_objects": {
#       "exact_match,none": 0.14,
#       "exact_match_stderr,none": 0.021989409645240262,
#       "alias": " - bbh_fewshot_tracking_shuffled_objects_seven_objects"
#     },
#     "bbh_fewshot_tracking_shuffled_objects_three_objects": {
#       "exact_match,none": 0.348,
#       "exact_match_stderr,none": 0.03018656846451169,
#       "alias": " - bbh_fewshot_tracking_shuffled_objects_three_objects"
#     },
#     "bbh_fewshot_web_of_lies": {
#       "exact_match,none": 0.516,
#       "exact_match_stderr,none": 0.031669985030107414,
#       "alias": " - bbh_fewshot_web_of_lies"
#     },
#     "bbh_fewshot_word_sorting": {
#       "exact_match,none": 0.188,
#       "exact_match_stderr,none": 0.024760377727750502,
#       "alias": " - bbh_fewshot_word_sorting"
#     }
#   },
#   "groups": {
#     "bbh_fewshot": {
#       "exact_match,none": 0.40270311780064505,
#       "exact_match_stderr,none": 0.005624097426990939,
#       "alias": "bbh_fewshot"
#     }
#   },
#   "group_subtasks": {
#     "bbh_fewshot": [
#       "bbh_fewshot_penguins_in_a_table",
#       "bbh_fewshot_logical_deduction_seven_objects",
#       "bbh_fewshot_multistep_arithmetic_two",
#       "bbh_fewshot_disambiguation_qa",
#       "bbh_fewshot_causal_judgement",
#       "bbh_fewshot_dyck_languages",
#       "bbh_fewshot_snarks",
#       "bbh_fewshot_boolean_expressions",
#       "bbh_fewshot_formal_fallacies",
#       "bbh_fewshot_date_understanding",
#       "bbh_fewshot_navigate",
#       "bbh_fewshot_reasoning_about_colored_objects",
#       "bbh_fewshot_word_sorting",
#       "bbh_fewshot_ruin_names",
#       "bbh_fewshot_tracking_shuffled_objects_seven_objects",
#       "bbh_fewshot_geometric_shapes",
#       "bbh_fewshot_logical_deduction_five_objects",
#       "bbh_fewshot_logical_deduction_three_objects",
#       "bbh_fewshot_sports_understanding",
#       "bbh_fewshot_temporal_sequences",
#       "bbh_fewshot_salient_translation_error_detection",
#       "bbh_fewshot_movie_recommendation",
#       "bbh_fewshot_web_of_lies",
#       "bbh_fewshot_object_counting",
#       "bbh_fewshot_hyperbaton",
#       "bbh_fewshot_tracking_shuffled_objects_three_objects",
#       "bbh_fewshot_tracking_shuffled_objects_five_objects"
#     ]
#   },
#   "configs": {
#     "bbh_fewshot_boolean_expressions": {
#       "task": "bbh_fewshot_boolean_expressions",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "boolean_expressions",
#       "test_split": "test",
#       "doc_to_text": "Q: not ( ( not not True ) ) is\nA: False\n\nQ: True and False and not True and True is\nA: False\n\nQ: not not ( not ( False ) ) is\nA: True\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Evaluate the result of a random Boolean expression.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_causal_judgement": {
#       "task": "bbh_fewshot_causal_judgement",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "causal_judgement",
#       "test_split": "test",
#       "doc_to_text": "Q: How would a typical person answer each of the following questions about causation?\nFrank T., had an ongoing dispute with his neighbor over a stretch of land and one day decided to shoot his neighbor in the body. Frank T. had no experience with guns, his hand slipped on the barrel of the gun, and the shot went wild. Nonetheless, the bullet bounced off a large boulder several feet away and hit the neighbor's body, causing significant injury. Did Frank T. intentionally shoot his neighbor in the body?\nOptions:\n- Yes\n- No\nA: No\n\nQ: How would a typical person answer each of the following questions about causation?\nSuzy and Billy are working on a project that is very important for our nation's security. The boss tells them both: \"Be sure that you are here at exactly 9 am. It is absolutely essential that you arrive at that time.\" Both Billy and Suzy arrive at 9 am. As it happens, there was a motion detector installed in the room where they arrived. The motion detector was set up to be triggered if at least one person appeared in the room at the same time. So the motion detector went off. Did Billy cause the motion detector to go off?\nOptions:\n- Yes\n- No\nA: Yes\n\nQ: How would a typical person answer each of the following questions about causation?\nGeorge and his sister Lena reunite at their parents' house for Thanksgiving. Whereas George just got into medical school, Lena is unhappy in her marriage and recently lost her job. Over the course of the day, George and Lena get into a number of heated arguments. Later in the afternoon they play a game of darts. They split the first two games, and the third game is close until the end. Who will win comes down to George's last shot. If he hits a high point region, he wins; if he hits a low point region, Lena wins. George thinks of the difficult time Lena is having, and he really wants to let her win. He aims the dart at the low point region. He sets up his shot and the dart lands in the low point region. After his shot, Lena wins the game and is very happy. Did George hit the low point region intentionally?\nOptions:\n- Yes\n- No\nA: Yes\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Answer questions about causal attribution.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_date_understanding": {
#       "task": "bbh_fewshot_date_understanding",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "date_understanding",
#       "test_split": "test",
#       "doc_to_text": "Q: Today is Christmas Eve of 1937. What is the date 10 days ago in MM/DD/YYYY?\nOptions:\n(A) 12/14/2026\n(B) 12/14/1950\n(C) 12/14/2007\n(D) 12/14/1937\n(E) 07/14/1938\n(F) 12/14/1988\nA: (D)\n\nQ: Tomorrow is 11/12/2019. What is the date one year ago from today in MM/DD/YYYY?\nOptions:\n(A) 09/04/2018\n(B) 11/11/2018\n(C) 08/25/2018\n(D) 11/02/2018\n(E) 11/04/2018\nA: (B)\n\nQ: Jane and John married on Jan 2, 1958. It is their 5-year anniversary today. What is the date tomorrow in MM/DD/YYYY?\nOptions:\n(A) 01/11/1961\n(B) 01/03/1963\n(C) 01/18/1961\n(D) 10/14/1960\n(E) 01/03/1982\n(F) 12/03/1960\nA: (B)\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Infer the date from context.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_disambiguation_qa": {
#       "task": "bbh_fewshot_disambiguation_qa",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "disambiguation_qa",
#       "test_split": "test",
#       "doc_to_text": "Q: In the following sentences, explain the antecedent of the pronoun (which thing the pronoun refers to), or state that it is ambiguous.\nSentence: The chief told the counselor that they took the day off.\nOptions:\n(A) The chief took the day off\n(B) The counselor took the day off\n(C) Ambiguous\nA: (A)\n\nQ: In the following sentences, explain the antecedent of the pronoun (which thing the pronoun refers to), or state that it is ambiguous.\nSentence: The manager sent a message to the secretary, but he didn't reply yet.\nOptions:\n(A) The secretary didn't reply yet\n(B) The manager didn't reply yet\n(C) Ambiguous\nA: (A)\n\nQ: In the following sentences, explain the antecedent of the pronoun (which thing the pronoun refers to), or state that it is ambiguous.\nSentence: Bailey will plan to meet the director at his office\nOptions:\n(A) It will be Bailey's office\n(B) It will be the director's office\n(C) Ambiguous\nA: (C)\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Clarify the meaning of sentences with ambiguous pronouns.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_dyck_languages": {
#       "task": "bbh_fewshot_dyck_languages",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "dyck_languages",
#       "test_split": "test",
#       "doc_to_text": "Q: Complete the rest of the sequence, making sure that the parentheses are closed properly. Input: [ { [\nA: ] } ]\n\nQ: Complete the rest of the sequence, making sure that the parentheses are closed properly. Input: < > ( ( [ [ ( { } ) [ < > ] ]\nA: ] ) )\n\nQ: Complete the rest of the sequence, making sure that the parentheses are closed properly. Input: < [ < [ { < [ ] < { } > > } ] > { { ( ) } { < [ < > ] > }\nA: } ] >\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Correctly close a Dyck-n word.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_formal_fallacies": {
#       "task": "bbh_fewshot_formal_fallacies",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "formal_fallacies",
#       "test_split": "test",
#       "doc_to_text": "Q: \"It is not always easy to see who is related to whom -- and in which ways. The following argument pertains to this question: To begin with, Lesley is a close friend of Fernando. Moreover, being a close friend of Fernando or a schoolmate of Lowell is sufficient for being a great-grandfather of Leroy. It follows that Lesley is a great-grandfather of Leroy.\"\nIs the argument, given the explicitly stated premises, deductively valid or invalid?\nOptions:\n- valid\n- invalid\nA: valid\n\nQ: \"It is not always easy to see who is related to whom -- and in which ways. The following argument pertains to this question: Whoever is not a great-grandfather of Clyde is a stepbrother of Brian. Being an ancestor of Dana is sufficient for not being a great-grandfather of Clyde. We may conclude: Everyone who is an ancestor of Dana is a stepbrother of Brian, too.\"\nIs the argument, given the explicitly stated premises, deductively valid or invalid?\nOptions:\n- valid\n- invalid\nA: valid\n\nQ: \"It is not always easy to grasp who is consuming which products. The following argument pertains to this question: Every infrequent user of Paul Mitchell shampoo is either a rare consumer of Nioxin shampoo or a loyal buyer of Caress soap, or both. No regular consumer of Lush soap is a rare consumer of Nioxin shampoo and, in the same time, a loyal buyer of Caress soap. It follows that whoever is an infrequent user of Paul Mitchell shampoo is not a regular consumer of Lush soap.\"\nIs the argument, given the explicitly stated premises, deductively valid or invalid?\nOptions:\n- valid\n- invalid\nA: invalid\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Distinguish deductively valid arguments from formal fallacies.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_geometric_shapes": {
#       "task": "bbh_fewshot_geometric_shapes",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "geometric_shapes",
#       "test_split": "test",
#       "doc_to_text": "Q: This SVG path element <path d=\"M 31.00,73.00 L 32.00,59.00 L 44.00,50.00 L 49.00,41.00 L 64.00,37.00 L 71.00,55.00 L 64.00,76.00 L 52.00,61.00 L 31.00,73.00\"/> draws a\nOptions:\n(A) circle\n(B) heptagon\n(C) hexagon\n(D) kite\n(E) line\n(F) octagon\n(G) pentagon\n(H) rectangle\n(I) sector\n(J) triangle\nA: (F)\n\nQ: This SVG path element <path d=\"M 14.19,26.04 L 51.43,39.21 L 58.44,36.69 L 56.63,30.17 L 48.53,26.66 L 14.19,26.04\"/> draws a\nOptions:\n(A) circle\n(B) heptagon\n(C) hexagon\n(D) kite\n(E) line\n(F) octagon\n(G) pentagon\n(H) rectangle\n(I) sector\n(J) triangle\nA: (G)\n\nQ: This SVG path element <path d=\"M 41.00,43.00 L 37.00,34.00 L 41.00,33.00 L 45.00,34.00 L 41.00,43.00\"/> draws a\nOptions:\n(A) circle\n(B) heptagon\n(C) hexagon\n(D) kite\n(E) line\n(F) octagon\n(G) pentagon\n(H) rectangle\n(I) sector\n(J) triangle\nA: (D)\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Name geometric shapes from their SVG paths.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_hyperbaton": {
#       "task": "bbh_fewshot_hyperbaton",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "hyperbaton",
#       "test_split": "test",
#       "doc_to_text": "Q: Which sentence has the correct adjective order:\nOptions:\n(A) rubber terrible ship\n(B) terrible rubber ship\nA: (B)\n\nQ: Which sentence has the correct adjective order:\nOptions:\n(A) repulsive small Brazilian exercise ship\n(B) Brazilian repulsive exercise small ship\nA: (A)\n\nQ: Which sentence has the correct adjective order:\nOptions:\n(A) blue gold wonderful square shoe\n(B) wonderful square blue gold shoe\nA: (B)\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Order adjectives correctly in English sentences.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_logical_deduction_five_objects": {
#       "task": "bbh_fewshot_logical_deduction_five_objects",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
# ...
# |                        Tasks                         |Version|Filter|n-shot|  Metric   |Value |   |Stderr|
# |------------------------------------------------------|-------|------|-----:|-----------|-----:|---|-----:|
# |bbh_fewshot                                           |N/A    |none  |     3|exact_match|0.4027|±  |0.0056|
# | - bbh_fewshot_boolean_expressions                    |      1|none  |     3|exact_match|0.7840|±  |0.0261|
# | - bbh_fewshot_causal_judgement                       |      1|none  |     3|exact_match|0.5722|±  |0.0363|
# | - bbh_fewshot_date_understanding                     |      1|none  |     3|exact_match|0.3520|±  |0.0303|
# | - bbh_fewshot_disambiguation_qa                      |      1|none  |     3|exact_match|0.5760|±  |0.0313|
# | - bbh_fewshot_dyck_languages                         |      1|none  |     3|exact_match|0.1040|±  |0.0193|
# | - bbh_fewshot_formal_fallacies                       |      1|none  |     3|exact_match|0.5160|±  |0.0317|
# | - bbh_fewshot_geometric_shapes                       |      1|none  |     3|exact_match|0.3240|±  |0.0297|
# | - bbh_fewshot_hyperbaton                             |      1|none  |     3|exact_match|0.6200|±  |0.0308|
# | - bbh_fewshot_logical_deduction_five_objects         |      1|none  |     3|exact_match|0.3240|±  |0.0297|
# | - bbh_fewshot_logical_deduction_seven_objects        |      1|none  |     3|exact_match|0.2800|±  |0.0285|
# | - bbh_fewshot_logical_deduction_three_objects        |      1|none  |     3|exact_match|0.4720|±  |0.0316|
# | - bbh_fewshot_movie_recommendation                   |      1|none  |     3|exact_match|0.5160|±  |0.0317|
# | - bbh_fewshot_multistep_arithmetic_two               |      1|none  |     3|exact_match|0.0080|±  |0.0056|
# | - bbh_fewshot_navigate                               |      1|none  |     3|exact_match|0.5240|±  |0.0316|
# | - bbh_fewshot_object_counting                        |      1|none  |     3|exact_match|0.4000|±  |0.0310|
# | - bbh_fewshot_penguins_in_a_table                    |      1|none  |     3|exact_match|0.4041|±  |0.0408|
# | - bbh_fewshot_reasoning_about_colored_objects        |      1|none  |     3|exact_match|0.3640|±  |0.0305|
# | - bbh_fewshot_ruin_names                             |      1|none  |     3|exact_match|0.4600|±  |0.0316|
# | - bbh_fewshot_salient_translation_error_detection    |      1|none  |     3|exact_match|0.3600|±  |0.0304|
# | - bbh_fewshot_snarks                                 |      1|none  |     3|exact_match|0.5506|±  |0.0374|
# | - bbh_fewshot_sports_understanding                   |      1|none  |     3|exact_match|0.7880|±  |0.0259|
# | - bbh_fewshot_temporal_sequences                     |      1|none  |     3|exact_match|0.2440|±  |0.0272|
# | - bbh_fewshot_tracking_shuffled_objects_five_objects |      1|none  |     3|exact_match|0.2240|±  |0.0264|
# | - bbh_fewshot_tracking_shuffled_objects_seven_objects|      1|none  |     3|exact_match|0.1400|±  |0.0220|
# | - bbh_fewshot_tracking_shuffled_objects_three_objects|      1|none  |     3|exact_match|0.3480|±  |0.0302|
# | - bbh_fewshot_web_of_lies                            |      1|none  |     3|exact_match|0.5160|±  |0.0317|
# | - bbh_fewshot_word_sorting                           |      1|none  |     3|exact_match|0.1880|±  |0.0248|
#
# |  Groups   |Version|Filter|n-shot|  Metric   |Value |   |Stderr|
# |-----------|-------|------|-----:|-----------|-----:|---|-----:|
# |bbh_fewshot|N/A    |none  |     3|exact_match|0.4027|±  |0.0056|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:                                                bbh_fewshot/exact_match ▁
# wandb:                                         bbh_fewshot/exact_match_stderr ▁
# wandb:                            bbh_fewshot_boolean_expressions/exact_match ▁
# wandb:                     bbh_fewshot_boolean_expressions/exact_match_stderr ▁
# wandb:                               bbh_fewshot_causal_judgement/exact_match ▁
# wandb:                        bbh_fewshot_causal_judgement/exact_match_stderr ▁
# wandb:                             bbh_fewshot_date_understanding/exact_match ▁
# wandb:                      bbh_fewshot_date_understanding/exact_match_stderr ▁
# wandb:                              bbh_fewshot_disambiguation_qa/exact_match ▁
# wandb:                       bbh_fewshot_disambiguation_qa/exact_match_stderr ▁
# wandb:                                 bbh_fewshot_dyck_languages/exact_match ▁
# wandb:                          bbh_fewshot_dyck_languages/exact_match_stderr ▁
# wandb:                               bbh_fewshot_formal_fallacies/exact_match ▁
# wandb:                        bbh_fewshot_formal_fallacies/exact_match_stderr ▁
# wandb:                               bbh_fewshot_geometric_shapes/exact_match ▁
# wandb:                        bbh_fewshot_geometric_shapes/exact_match_stderr ▁
# wandb:                                     bbh_fewshot_hyperbaton/exact_match ▁
# wandb:                              bbh_fewshot_hyperbaton/exact_match_stderr ▁
# wandb:                 bbh_fewshot_logical_deduction_five_objects/exact_match ▁
# wandb:          bbh_fewshot_logical_deduction_five_objects/exact_match_stderr ▁
# wandb:                bbh_fewshot_logical_deduction_seven_objects/exact_match ▁
# wandb:         bbh_fewshot_logical_deduction_seven_objects/exact_match_stderr ▁
# wandb:                bbh_fewshot_logical_deduction_three_objects/exact_match ▁
# wandb:         bbh_fewshot_logical_deduction_three_objects/exact_match_stderr ▁
# wandb:                           bbh_fewshot_movie_recommendation/exact_match ▁
# wandb:                    bbh_fewshot_movie_recommendation/exact_match_stderr ▁
# wandb:                       bbh_fewshot_multistep_arithmetic_two/exact_match ▁
# wandb:                bbh_fewshot_multistep_arithmetic_two/exact_match_stderr ▁
# wandb:                                       bbh_fewshot_navigate/exact_match ▁
# wandb:                                bbh_fewshot_navigate/exact_match_stderr ▁
# wandb:                                bbh_fewshot_object_counting/exact_match ▁
# wandb:                         bbh_fewshot_object_counting/exact_match_stderr ▁
# wandb:                            bbh_fewshot_penguins_in_a_table/exact_match ▁
# wandb:                     bbh_fewshot_penguins_in_a_table/exact_match_stderr ▁
# wandb:                bbh_fewshot_reasoning_about_colored_objects/exact_match ▁
# wandb:         bbh_fewshot_reasoning_about_colored_objects/exact_match_stderr ▁
# wandb:                                     bbh_fewshot_ruin_names/exact_match ▁
# wandb:                              bbh_fewshot_ruin_names/exact_match_stderr ▁
# wandb:            bbh_fewshot_salient_translation_error_detection/exact_match ▁
# wandb:     bbh_fewshot_salient_translation_error_detection/exact_match_stderr ▁
# wandb:                                         bbh_fewshot_snarks/exact_match ▁
# wandb:                                  bbh_fewshot_snarks/exact_match_stderr ▁
# wandb:                           bbh_fewshot_sports_understanding/exact_match ▁
# wandb:                    bbh_fewshot_sports_understanding/exact_match_stderr ▁
# wandb:                             bbh_fewshot_temporal_sequences/exact_match ▁
# wandb:                      bbh_fewshot_temporal_sequences/exact_match_stderr ▁
# wandb:         bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match ▁
# wandb:  bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match_stderr ▁
# wandb:        bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match ▁
# wandb: bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match_stderr ▁
# wandb:        bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match ▁
# wandb: bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match_stderr ▁
# wandb:                                    bbh_fewshot_web_of_lies/exact_match ▁
# wandb:                             bbh_fewshot_web_of_lies/exact_match_stderr ▁
# wandb:                                   bbh_fewshot_word_sorting/exact_match ▁
# wandb:                            bbh_fewshot_word_sorting/exact_match_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:                                                      bbh_fewshot/alias bbh_fewshot
# wandb:                                                bbh_fewshot/exact_match 0.4027
# wandb:                                         bbh_fewshot/exact_match_stderr 0.00562
# wandb:                                  bbh_fewshot_boolean_expressions/alias  - bbh_fewshot_boole...
# wandb:                            bbh_fewshot_boolean_expressions/exact_match 0.784
# wandb:                     bbh_fewshot_boolean_expressions/exact_match_stderr 0.02608
# wandb:                                     bbh_fewshot_causal_judgement/alias  - bbh_fewshot_causa...
# wandb:                               bbh_fewshot_causal_judgement/exact_match 0.57219
# wandb:                        bbh_fewshot_causal_judgement/exact_match_stderr 0.03628
# wandb:                                   bbh_fewshot_date_understanding/alias  - bbh_fewshot_date_...
# wandb:                             bbh_fewshot_date_understanding/exact_match 0.352
# wandb:                      bbh_fewshot_date_understanding/exact_match_stderr 0.03027
# wandb:                                    bbh_fewshot_disambiguation_qa/alias  - bbh_fewshot_disam...
# wandb:                              bbh_fewshot_disambiguation_qa/exact_match 0.576
# wandb:                       bbh_fewshot_disambiguation_qa/exact_match_stderr 0.03132
# wandb:                                       bbh_fewshot_dyck_languages/alias  - bbh_fewshot_dyck_...
# wandb:                                 bbh_fewshot_dyck_languages/exact_match 0.104
# wandb:                          bbh_fewshot_dyck_languages/exact_match_stderr 0.01935
# wandb:                                     bbh_fewshot_formal_fallacies/alias  - bbh_fewshot_forma...
# wandb:                               bbh_fewshot_formal_fallacies/exact_match 0.516
# wandb:                        bbh_fewshot_formal_fallacies/exact_match_stderr 0.03167
# wandb:                                     bbh_fewshot_geometric_shapes/alias  - bbh_fewshot_geome...
# wandb:                               bbh_fewshot_geometric_shapes/exact_match 0.324
# wandb:                        bbh_fewshot_geometric_shapes/exact_match_stderr 0.02966
# wandb:                                           bbh_fewshot_hyperbaton/alias  - bbh_fewshot_hyper...
# wandb:                    bbh_fewshot_sports_understanding/exact_match_stderr 0.0259
# wandb:                                   bbh_fewshot_temporal_sequences/alias  - bbh_fewshot_tempo...
# wandb:                             bbh_fewshot_temporal_sequences/exact_match 0.244
# wandb:                      bbh_fewshot_temporal_sequences/exact_match_stderr 0.02722
# wandb:               bbh_fewshot_tracking_shuffled_objects_five_objects/alias  - bbh_fewshot_track...
# wandb:         bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match 0.224
# wandb:  bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match_stderr 0.02642
# wandb:              bbh_fewshot_tracking_shuffled_objects_seven_objects/alias  - bbh_fewshot_track...
# wandb:        bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match 0.14
# wandb: bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match_stderr 0.02199
# wandb:              bbh_fewshot_tracking_shuffled_objects_three_objects/alias  - bbh_fewshot_track...
# wandb:        bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match 0.348
# wandb: bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match_stderr 0.03019
# wandb:                                          bbh_fewshot_web_of_lies/alias  - bbh_fewshot_web_o...
# wandb:                                    bbh_fewshot_web_of_lies/exact_match 0.516
# wandb:                             bbh_fewshot_web_of_lies/exact_match_stderr 0.03167
# wandb:                                         bbh_fewshot_word_sorting/alias  - bbh_fewshot_word_...
# wandb:                                   bbh_fewshot_word_sorting/exact_match 0.188
# wandb:                            bbh_fewshot_word_sorting/exact_match_stderr 0.02476
# wandb:
# wandb: 🚀 View run Mistral-7B-Instruct-NF4-bbh at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/yiokzrro/workspace
# wandb: Synced 5 W&B file(s), 3 media file(s), 31 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240328_174846-yiokzrro/logs

# %% [markdown]
# ## AWQ Evaluation

# %% [markdown]
# ### Evaluate twhoool02/Llama-2-7b-chat-hf-AWQ

# %%
eval_model = "twhoool02/Llama-2-7b-chat-hf-AWQ"

# create directory to store results
results_dir = f"/content/drive/MyDrive/Evaluation/{eval_model}-awq"
os.makedirs(results_dir, exist_ok=True)

# %% [markdown]
# #### MMLU
#
# 5-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Llama-2-7b-chat-hf-AWQ,trust_remote_code=True,revision="af57a3ea9007748b0d9385ffca5a8164889b4901" \
    --tasks mmlu_stem,mmlu_social_sciences,mmlu_humanities,mmlu_other\
    --num_fewshot 5 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir_mmlu_awq \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Llama-2-7b-chat-hf-AWQ-mmlu1 \
    --use_cache results_dir_mmlu_awq \
    --cache_requests true \
    --show_config
# Out:
# 2024-03-29 10:55:19.846231: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-29 10:55:19.846276: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-29 10:55:19.847981: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-29 10:55:21.028953: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240329_105526-suymbfwg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Llama-2-7b-chat-hf-AWQ-mmlu1
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/suymbfwg/workspace
# 2024-03-29:10:55:28,210 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-29:10:55:34,545 INFO     [__main__.py:335] Selected Tasks: ['mmlu_humanities', 'mmlu_other', 'mmlu_social_sciences', 'mmlu_stem']
# 2024-03-29:10:55:34,546 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-29:10:55:34,547 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Llama-2-7b-chat-hf-AWQ', 'trust_remote_code': True, 'revision': 'af57a3ea9007748b0d9385ffca5a8164889b4901'}
# 2024-03-29:10:55:34,551 INFO     [huggingface.py:163] Using device 'cuda:0'
# config.json: 100% 957/957 [00:00<00:00, 2.78MB/s]
# We suggest you to set `torch_dtype=torch.float16` for better efficiency with AWQ.
# model.safetensors: 100% 3.89G/3.89G [00:09<00:00, 394MB/s]
# generation_config.json: 100% 183/183 [00:00<00:00, 574kB/s]
# tokenizer_config.json: 100% 1.76k/1.76k [00:00<00:00, 5.42MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 256MB/s]
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 7.23MB/s]
# special_tokens_map.json: 100% 414/414 [00:00<00:00, 1.32MB/s]
# 2024-03-29:10:55:52,890 INFO     [evaluator.py:195] Using cache at results_dir_mmlu_awq_rank0.db
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 5.86k/5.86k [00:00<00:00, 13.4MB/s]
# Downloading readme: 100% 1.11k/1.11k [00:00<00:00, 3.35MB/s]
# Downloading data: 100% 166M/166M [00:01<00:00, 95.0MB/s]
# Generating test split: 237 examples [00:00, 1980.19 examples/s]
# Generating validation split: 26 examples [00:00, 3672.40 examples/s]
# Generating dev split: 5 examples [00:00, 51.60 examples/s]
# Generating test split: 1534 examples [00:00, 8264.09 examples/s]
# Generating validation split: 170 examples [00:00, 10854.66 examples/s]
# Generating dev split: 5 examples [00:00, 57.23 examples/s]
# Generating test split: 108 examples [00:00, 1233.99 examples/s]
# Generating validation split: 11 examples [00:00, 1900.30 examples/s]
# Generating dev split: 5 examples [00:00, 57.39 examples/s]
# Generating test split: 346 examples [00:00, 3387.04 examples/s]
# Generating validation split: 38 examples [00:00, 5318.64 examples/s]
# Generating dev split: 5 examples [00:00, 54.60 examples/s]
# Generating test split: 324 examples [00:00, 3121.35 examples/s]
# Generating validation split: 35 examples [00:00, 6017.16 examples/s]
# Generating dev split: 5 examples [00:00, 58.21 examples/s]
# Generating test split: 311 examples [00:00, 3220.20 examples/s]
# Generating validation split: 34 examples [00:00, 7524.21 examples/s]
# Generating dev split: 5 examples [00:00, 58.41 examples/s]
# Generating test split: 171 examples [00:00, 1893.88 examples/s]
# Generating validation split: 19 examples [00:00, 4382.04 examples/s]
# Generating dev split: 5 examples [00:00, 57.93 examples/s]
# Generating test split: 204 examples [00:00, 2104.76 examples/s]
# Generating validation split: 22 examples [00:00, 3365.23 examples/s]
# Generating dev split: 5 examples [00:00, 57.55 examples/s]
# Generating test split: 165 examples [00:00, 1806.63 examples/s]
# Generating validation split: 18 examples [00:00, 2877.96 examples/s]
# Generating dev split: 5 examples [00:00, 60.11 examples/s]
# Generating test split: 163 examples [00:00, 1806.99 examples/s]
# Generating validation split: 18 examples [00:00, 3562.71 examples/s]
# Generating dev split: 5 examples [00:00, 60.69 examples/s]
# Generating test split: 126 examples [00:00, 1406.74 examples/s]
# Generating validation split: 14 examples [00:00, 3347.22 examples/s]
# Generating dev split: 5 examples [00:00, 59.36 examples/s]
# Generating test split: 121 examples [00:00, 1367.71 examples/s]
# Generating validation split: 13 examples [00:00, 3029.89 examples/s]
# Generating dev split: 5 examples [00:00, 59.70 examples/s]
# Generating test split: 895 examples [00:00, 6642.46 examples/s]
# Generating validation split: 100 examples [00:00, 10794.20 examples/s]
# Generating dev split: 5 examples [00:00, 52.24 examples/s]
# Generating test split: 100 examples [00:00, 1121.37 examples/s]
# Generating validation split: 11 examples [00:00, 3299.30 examples/s]
# Generating dev split: 5 examples [00:00, 58.63 examples/s]
# Generating test split: 306 examples [00:00, 3168.30 examples/s]
# Generating validation split: 33 examples [00:00, 6122.26 examples/s]
# Generating dev split: 5 examples [00:00, 58.71 examples/s]
# Generating test split: 272 examples [00:00, 2739.49 examples/s]
# Generating validation split: 31 examples [00:00, 5193.87 examples/s]
# Generating dev split: 5 examples [00:00, 59.16 examples/s]
# Generating test split: 234 examples [00:00, 2546.74 examples/s]
# Generating validation split: 25 examples [00:00, 4615.21 examples/s]
# Generating dev split: 5 examples [00:00, 60.94 examples/s]
# Generating test split: 100 examples [00:00, 1170.29 examples/s]
# Generating validation split: 10 examples [00:00, 3149.82 examples/s]
# Generating dev split: 5 examples [00:00, 57.63 examples/s]
# Generating test split: 103 examples [00:00, 1191.96 examples/s]
# Generating validation split: 11 examples [00:00, 2488.80 examples/s]
# Generating dev split: 5 examples [00:00, 58.49 examples/s]
# Generating test split: 783 examples [00:00, 6305.98 examples/s]
# Generating validation split: 86 examples [00:00, 11759.48 examples/s]
# Generating dev split: 5 examples [00:00, 57.69 examples/s]
# Generating test split: 100 examples [00:00, 1168.93 examples/s]
# Generating validation split: 11 examples [00:00, 3717.76 examples/s]
# Generating dev split: 5 examples [00:00, 57.02 examples/s]
# Generating test split: 282 examples [00:00, 2845.40 examples/s]
# Generating validation split: 31 examples [00:00, 4561.59 examples/s]
# Generating dev split: 5 examples [00:00, 60.61 examples/s]
# Generating test split: 223 examples [00:00, 2418.05 examples/s]
# Generating validation split: 23 examples [00:00, 4432.30 examples/s]
# Generating dev split: 5 examples [00:00, 58.42 examples/s]
# Generating test split: 173 examples [00:00, 1909.29 examples/s]
# Generating validation split: 22 examples [00:00, 5128.08 examples/s]
# Generating dev split: 5 examples [00:00, 60.82 examples/s]
# Generating test split: 166 examples [00:00, 1832.94 examples/s]
# Generating validation split: 18 examples [00:00, 3618.90 examples/s]
# Generating dev split: 5 examples [00:00, 58.75 examples/s]
# Generating test split: 265 examples [00:00, 2694.85 examples/s]
# Generating validation split: 29 examples [00:00, 6249.22 examples/s]
# Generating dev split: 5 examples [00:00, 59.88 examples/s]
# Generating test split: 110 examples [00:00, 1258.29 examples/s]
# Generating validation split: 12 examples [00:00, 2459.76 examples/s]
# Generating dev split: 5 examples [00:00, 58.26 examples/s]
# Generating test split: 545 examples [00:00, 4896.70 examples/s]
# Generating validation split: 60 examples [00:00, 7403.02 examples/s]
# Generating dev split: 5 examples [00:00, 56.84 examples/s]
# Generating test split: 198 examples [00:00, 2098.90 examples/s]
# Generating validation split: 22 examples [00:00, 6372.12 examples/s]
# Generating dev split: 5 examples [00:00, 59.65 examples/s]
# Generating test split: 245 examples [00:00, 2622.00 examples/s]
# Generating validation split: 27 examples [00:00, 3996.13 examples/s]
# Generating dev split: 5 examples [00:00, 58.98 examples/s]
# Generating test split: 612 examples [00:00, 5380.39 examples/s]
# Generating validation split: 69 examples [00:00, 8202.22 examples/s]
# Generating dev split: 5 examples [00:00, 58.95 examples/s]
# Generating test split: 238 examples [00:00, 2495.76 examples/s]
# Generating validation split: 26 examples [00:00, 4433.00 examples/s]
# Generating dev split: 5 examples [00:00, 58.66 examples/s]
# Generating test split: 114 examples [00:00, 1174.01 examples/s]
# Generating validation split: 12 examples [00:00, 2373.24 examples/s]
# Generating dev split: 5 examples [00:00, 49.39 examples/s]
# Generating test split: 131 examples [00:00, 1477.42 examples/s]
# Generating validation split: 12 examples [00:00, 2721.51 examples/s]
# Generating dev split: 5 examples [00:00, 59.03 examples/s]
# Generating test split: 193 examples [00:00, 2053.04 examples/s]
# Generating validation split: 21 examples [00:00, 5106.70 examples/s]
# Generating dev split: 5 examples [00:00, 55.83 examples/s]
# Generating test split: 390 examples [00:00, 3881.36 examples/s]
# Generating validation split: 43 examples [00:00, 7574.44 examples/s]
# Generating dev split: 5 examples [00:00, 58.42 examples/s]
# Generating test split: 100 examples [00:00, 1127.47 examples/s]
# Generating validation split: 11 examples [00:00, 2873.88 examples/s]
# Generating dev split: 5 examples [00:00, 59.97 examples/s]
# Generating test split: 201 examples [00:00, 2284.01 examples/s]
# Generating validation split: 22 examples [00:00, 3696.61 examples/s]
# Generating dev split: 5 examples [00:00, 59.39 examples/s]
# Generating test split: 310 examples [00:00, 3203.95 examples/s]
# Generating validation split: 32 examples [00:00, 6779.70 examples/s]
# Generating dev split: 5 examples [00:00, 59.83 examples/s]
# Generating test split: 112 examples [00:00, 1283.23 examples/s]
# Generating validation split: 11 examples [00:00, 3214.70 examples/s]
# Generating dev split: 5 examples [00:00, 58.45 examples/s]
# Generating test split: 100 examples [00:00, 1125.38 examples/s]
# Generating validation split: 11 examples [00:00, 2267.75 examples/s]
# Generating dev split: 5 examples [00:00, 57.77 examples/s]
# Generating test split: 235 examples [00:00, 2502.78 examples/s]
# Generating validation split: 26 examples [00:00, 6768.37 examples/s]
# Generating dev split: 5 examples [00:00, 58.06 examples/s]
# Generating test split: 102 examples [00:00, 1122.07 examples/s]
# Generating validation split: 11 examples [00:00, 3200.87 examples/s]
# Generating dev split: 5 examples [00:00, 59.32 examples/s]
# Generating test split: 216 examples [00:00, 2251.22 examples/s]
# Generating validation split: 23 examples [00:00, 4535.24 examples/s]
# Generating dev split: 5 examples [00:00, 57.73 examples/s]
# Generating test split: 144 examples [00:00, 1629.30 examples/s]
# Generating validation split: 16 examples [00:00, 2886.65 examples/s]
# Generating dev split: 5 examples [00:00, 57.71 examples/s]
# Generating test split: 100 examples [00:00, 1135.77 examples/s]
# Generating validation split: 11 examples [00:00, 2793.32 examples/s]
# Generating dev split: 5 examples [00:00, 59.27 examples/s]
# Generating test split: 152 examples [00:00, 1749.07 examples/s]
# Generating validation split: 16 examples [00:00, 4974.34 examples/s]
# Generating dev split: 5 examples [00:00, 58.53 examples/s]
# Generating test split: 100 examples [00:00, 1164.20 examples/s]
# Generating validation split: 11 examples [00:00, 2572.62 examples/s]
# Generating dev split: 5 examples [00:00, 58.50 examples/s]
# Generating test split: 100 examples [00:00, 1132.61 examples/s]
# Generating validation split: 9 examples [00:00, 3028.38 examples/s]
# Generating dev split: 5 examples [00:00, 59.83 examples/s]
# Generating test split: 145 examples [00:00, 1652.89 examples/s]
# Generating validation split: 16 examples [00:00, 3851.74 examples/s]
# Generating dev split: 5 examples [00:00, 57.84 examples/s]
# Generating test split: 203 examples [00:00, 1991.83 examples/s]
# Generating validation split: 22 examples [00:00, 3915.59 examples/s]
# Generating dev split: 5 examples [00:00, 60.35 examples/s]
# Generating test split: 270 examples [00:00, 2833.42 examples/s]
# Generating validation split: 29 examples [00:00, 6298.73 examples/s]
# Generating dev split: 5 examples [00:00, 58.67 examples/s]
# Generating test split: 151 examples [00:00, 1623.73 examples/s]
# Generating validation split: 17 examples [00:00, 3662.21 examples/s]
# Generating dev split: 5 examples [00:00, 58.12 examples/s]
# Generating test split: 100 examples [00:00, 1178.21 examples/s]
# Generating validation split: 8 examples [00:00, 1576.36 examples/s]
# Generating dev split: 5 examples [00:00, 58.46 examples/s]
# Generating test split: 378 examples [00:00, 3611.05 examples/s]
# Generating validation split: 41 examples [00:00, 6285.55 examples/s]
# Generating dev split: 5 examples [00:00, 59.71 examples/s]
# Generating test split: 135 examples [00:00, 1508.12 examples/s]
# Generating validation split: 14 examples [00:00, 4273.98 examples/s]
# Generating dev split: 5 examples [00:00, 59.11 examples/s]
# Generating test split: 100 examples [00:00, 1160.52 examples/s]
# Generating validation split: 11 examples [00:00, 3060.32 examples/s]
# Generating dev split: 5 examples [00:00, 59.55 examples/s]
# 2024-03-29:11:00:42,525 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 5
# 2024-03-29:11:00:42,526 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_anatomy from None to 5
# 2024-03-29:11:00:42,526 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 5
# 2024-03-29:11:00:42,526 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_chemistry from None to 5
# 2024-03-29:11:00:42,526 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_physics from None to 5
# 2024-03-29:11:00:42,526 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 5
# 2024-03-29:11:00:42,526 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 5
# 2024-03-29:11:00:42,526 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 5
# 2024-03-29:11:00:42,526 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 5
# 2024-03-29:11:00:42,526 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_computer_security from None to 5
# 2024-03-29:11:00:42,527 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_astronomy from None to 5
# 2024-03-29:11:00:42,527 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_mathematics from None to 5
# 2024-03-29:11:00:42,527 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_biology from None to 5
# 2024-03-29:11:00:42,527 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 5
# 2024-03-29:11:00:42,527 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_physics from None to 5
# 2024-03-29:11:00:42,527 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 5
# 2024-03-29:11:00:42,527 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_computer_science from None to 5
# 2024-03-29:11:00:42,527 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_machine_learning from None to 5
# 2024-03-29:11:00:42,527 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_biology from None to 5
# 2024-03-29:11:00:42,527 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_sociology from None to 5
# 2024-03-29:11:00:42,527 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_us_foreign_policy from None to 5
# 2024-03-29:11:00:42,527 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_macroeconomics from None to 5
# 2024-03-29:11:00:42,528 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_government_and_politics from None to 5
# 2024-03-29:11:00:42,528 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_human_sexuality from None to 5
# 2024-03-29:11:00:42,528 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_econometrics from None to 5
# 2024-03-29:11:00:42,528 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_microeconomics from None to 5
# 2024-03-29:11:00:42,528 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_psychology from None to 5
# 2024-03-29:11:00:42,528 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_security_studies from None to 5
# 2024-03-29:11:00:42,528 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_geography from None to 5
# 2024-03-29:11:00:42,528 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_psychology from None to 5
# 2024-03-29:11:00:42,528 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_public_relations from None to 5
# 2024-03-29:11:00:42,528 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_clinical_knowledge from None to 5
# 2024-03-29:11:00:42,528 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_virology from None to 5
# 2024-03-29:11:00:42,528 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_medicine from None to 5
# 2024-03-29:11:00:42,529 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_human_aging from None to 5
# 2024-03-29:11:00:42,529 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_accounting from None to 5
# 2024-03-29:11:00:42,529 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_medical_genetics from None to 5
# 2024-03-29:11:00:42,529 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_miscellaneous from None to 5
# 2024-03-29:11:00:42,529 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_management from None to 5
# 2024-03-29:11:00:42,529 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_global_facts from None to 5
# 2024-03-29:11:00:42,529 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_marketing from None to 5
# 2024-03-29:11:00:42,529 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_medicine from None to 5
# 2024-03-29:11:00:42,529 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_nutrition from None to 5
# 2024-03-29:11:00:42,529 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_business_ethics from None to 5
# 2024-03-29:11:00:42,529 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_moral_scenarios from None to 5
# 2024-03-29:11:00:42,529 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_international_law from None to 5
# 2024-03-29:11:00:42,530 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_formal_logic from None to 5
# 2024-03-29:11:00:42,530 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_logical_fallacies from None to 5
# 2024-03-29:11:00:42,530 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_european_history from None to 5
# 2024-03-29:11:00:42,530 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_us_history from None to 5
# 2024-03-29:11:00:42,530 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_world_religions from None to 5
# 2024-03-29:11:00:42,530 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_philosophy from None to 5
# 2024-03-29:11:00:42,530 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_prehistory from None to 5
# 2024-03-29:11:00:42,530 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_moral_disputes from None to 5
# 2024-03-29:11:00:42,530 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_jurisprudence from None to 5
# 2024-03-29:11:00:42,530 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_law from None to 5
# 2024-03-29:11:00:42,530 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_world_history from None to 5
# 2024-03-29:11:00:42,536 INFO     [task.py:395] Building contexts for mmlu_abstract_algebra on rank 0...
# 100% 100/100 [00:01<00:00, 65.42it/s]
# 2024-03-29:11:00:44,104 INFO     [task.py:395] Building contexts for mmlu_anatomy on rank 0...
# 100% 135/135 [00:02<00:00, 66.47it/s]
# 2024-03-29:11:00:46,187 INFO     [task.py:395] Building contexts for mmlu_elementary_mathematics on rank 0...
# 100% 378/378 [00:05<00:00, 66.74it/s]
# 2024-03-29:11:00:52,004 INFO     [task.py:395] Building contexts for mmlu_college_chemistry on rank 0...
# 100% 100/100 [00:01<00:00, 66.85it/s]
# 2024-03-29:11:00:53,539 INFO     [task.py:395] Building contexts for mmlu_high_school_physics on rank 0...
# 100% 151/151 [00:02<00:00, 66.16it/s]
# 2024-03-29:11:00:55,880 INFO     [task.py:395] Building contexts for mmlu_high_school_mathematics on rank 0...
# 100% 270/270 [00:04<00:00, 66.30it/s]
# 2024-03-29:11:01:00,053 INFO     [task.py:395] Building contexts for mmlu_high_school_chemistry on rank 0...
# 100% 203/203 [00:03<00:00, 66.51it/s]
# 2024-03-29:11:01:03,182 INFO     [task.py:395] Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:02<00:00, 66.88it/s]
# 2024-03-29:11:01:05,405 INFO     [task.py:395] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 66.65it/s]
# 2024-03-29:11:01:06,944 INFO     [task.py:395] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:01<00:00, 66.72it/s]
# 2024-03-29:11:01:08,482 INFO     [task.py:395] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:02<00:00, 67.02it/s]
# 2024-03-29:11:01:10,807 INFO     [task.py:395] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:01<00:00, 66.88it/s]
# 2024-03-29:11:01:12,341 INFO     [task.py:395] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:02<00:00, 66.38it/s]
# 2024-03-29:11:01:14,566 INFO     [task.py:395] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:03<00:00, 66.88it/s]
# 2024-03-29:11:01:17,878 INFO     [task.py:395] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:01<00:00, 66.35it/s]
# 2024-03-29:11:01:19,455 INFO     [task.py:395] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:03<00:00, 66.71it/s]
# 2024-03-29:11:01:23,066 INFO     [task.py:395] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 66.44it/s]
# 2024-03-29:11:01:24,609 INFO     [task.py:395] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:01<00:00, 66.60it/s]
# 2024-03-29:11:01:26,334 INFO     [task.py:395] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:04<00:00, 66.51it/s]
# 2024-03-29:11:01:31,112 INFO     [task.py:395] Building contexts for mmlu_sociology on rank 0...
# 100% 201/201 [00:03<00:00, 66.61it/s]
# 2024-03-29:11:01:34,206 INFO     [task.py:395] Building contexts for mmlu_us_foreign_policy on rank 0...
# 100% 100/100 [00:01<00:00, 66.44it/s]
# 2024-03-29:11:01:35,750 INFO     [task.py:395] Building contexts for mmlu_high_school_macroeconomics on rank 0...
# 100% 390/390 [00:05<00:00, 66.34it/s]
# 2024-03-29:11:01:41,774 INFO     [task.py:395] Building contexts for mmlu_high_school_government_and_politics on rank 0...
# 100% 193/193 [00:02<00:00, 66.00it/s]
# 2024-03-29:11:01:44,772 INFO     [task.py:395] Building contexts for mmlu_human_sexuality on rank 0...
# 100% 131/131 [00:01<00:00, 66.88it/s]
# 2024-03-29:11:01:46,780 INFO     [task.py:395] Building contexts for mmlu_econometrics on rank 0...
# 100% 114/114 [00:01<00:00, 66.67it/s]
# 2024-03-29:11:01:48,533 INFO     [task.py:395] Building contexts for mmlu_high_school_microeconomics on rank 0...
# 100% 238/238 [00:03<00:00, 66.65it/s]
# 2024-03-29:11:01:52,194 INFO     [task.py:395] Building contexts for mmlu_professional_psychology on rank 0...
# 100% 612/612 [00:09<00:00, 66.25it/s]
# 2024-03-29:11:02:01,668 INFO     [task.py:395] Building contexts for mmlu_security_studies on rank 0...
# 100% 245/245 [00:03<00:00, 66.27it/s]
# 2024-03-29:11:02:05,461 INFO     [task.py:395] Building contexts for mmlu_high_school_geography on rank 0...
# 100% 198/198 [00:02<00:00, 66.56it/s]
# 2024-03-29:11:02:08,511 INFO     [task.py:395] Building contexts for mmlu_high_school_psychology on rank 0...
# 100% 545/545 [00:08<00:00, 66.54it/s]
# 2024-03-29:11:02:17,214 INFO     [task.py:395] Building contexts for mmlu_public_relations on rank 0...
# 100% 110/110 [00:01<00:00, 65.96it/s]
# 2024-03-29:11:02:18,925 INFO     [task.py:395] Building contexts for mmlu_clinical_knowledge on rank 0...
# 100% 265/265 [00:03<00:00, 66.38it/s]
# 2024-03-29:11:02:23,016 INFO     [task.py:395] Building contexts for mmlu_virology on rank 0...
# 100% 166/166 [00:02<00:00, 66.60it/s]
# 2024-03-29:11:02:25,571 INFO     [task.py:395] Building contexts for mmlu_college_medicine on rank 0...
# 100% 173/173 [00:02<00:00, 66.62it/s]
# 2024-03-29:11:02:28,233 INFO     [task.py:395] Building contexts for mmlu_human_aging on rank 0...
# 100% 223/223 [00:03<00:00, 65.87it/s]
# 2024-03-29:11:02:31,704 INFO     [task.py:395] Building contexts for mmlu_professional_accounting on rank 0...
# 100% 282/282 [00:04<00:00, 66.42it/s]
# 2024-03-29:11:02:36,058 INFO     [task.py:395] Building contexts for mmlu_medical_genetics on rank 0...
# 100% 100/100 [00:01<00:00, 66.82it/s]
# 2024-03-29:11:02:37,595 INFO     [task.py:395] Building contexts for mmlu_miscellaneous on rank 0...
# 100% 783/783 [00:11<00:00, 66.39it/s]
# 2024-03-29:11:02:49,679 INFO     [task.py:395] Building contexts for mmlu_management on rank 0...
# 100% 103/103 [00:01<00:00, 66.85it/s]
# 2024-03-29:11:02:51,260 INFO     [task.py:395] Building contexts for mmlu_global_facts on rank 0...
# 100% 100/100 [00:01<00:00, 66.78it/s]
# 2024-03-29:11:02:52,805 INFO     [task.py:395] Building contexts for mmlu_marketing on rank 0...
# 100% 234/234 [00:03<00:00, 66.63it/s]
# 2024-03-29:11:02:56,405 INFO     [task.py:395] Building contexts for mmlu_professional_medicine on rank 0...
# 100% 272/272 [00:04<00:00, 66.40it/s]
# 2024-03-29:11:03:00,606 INFO     [task.py:395] Building contexts for mmlu_nutrition on rank 0...
# 100% 306/306 [00:04<00:00, 66.49it/s]
# 2024-03-29:11:03:05,324 INFO     [task.py:395] Building contexts for mmlu_business_ethics on rank 0...
# 100% 100/100 [00:01<00:00, 66.22it/s]
# 2024-03-29:11:03:06,873 INFO     [task.py:395] Building contexts for mmlu_moral_scenarios on rank 0...
# 100% 895/895 [00:13<00:00, 66.50it/s]
# 2024-03-29:11:03:20,667 INFO     [task.py:395] Building contexts for mmlu_international_law on rank 0...
# 100% 121/121 [00:01<00:00, 66.70it/s]
# 2024-03-29:11:03:22,528 INFO     [task.py:395] Building contexts for mmlu_formal_logic on rank 0...
# 100% 126/126 [00:01<00:00, 66.74it/s]
# 2024-03-29:11:03:24,464 INFO     [task.py:395] Building contexts for mmlu_logical_fallacies on rank 0...
# 100% 163/163 [00:02<00:00, 66.68it/s]
# 2024-03-29:11:03:26,971 INFO     [task.py:395] Building contexts for mmlu_high_school_european_history on rank 0...
# 100% 165/165 [00:02<00:00, 66.34it/s]
# 2024-03-29:11:03:29,529 INFO     [task.py:395] Building contexts for mmlu_high_school_us_history on rank 0...
# 100% 204/204 [00:03<00:00, 66.29it/s]
# 2024-03-29:11:03:32,690 INFO     [task.py:395] Building contexts for mmlu_world_religions on rank 0...
# 100% 171/171 [00:02<00:00, 66.48it/s]
# 2024-03-29:11:03:35,327 INFO     [task.py:395] Building contexts for mmlu_philosophy on rank 0...
# 100% 311/311 [00:04<00:00, 66.69it/s]
# 2024-03-29:11:03:40,110 INFO     [task.py:395] Building contexts for mmlu_prehistory on rank 0...
# 100% 324/324 [00:04<00:00, 65.90it/s]
# 2024-03-29:11:03:45,147 INFO     [task.py:395] Building contexts for mmlu_moral_disputes on rank 0...
# 100% 346/346 [00:05<00:00, 66.80it/s]
# 2024-03-29:11:03:50,457 INFO     [task.py:395] Building contexts for mmlu_jurisprudence on rank 0...
# 100% 108/108 [00:01<00:00, 66.30it/s]
# 2024-03-29:11:03:52,127 INFO     [task.py:395] Building contexts for mmlu_professional_law on rank 0...
# 100% 1534/1534 [00:23<00:00, 66.50it/s]
# 2024-03-29:11:04:16,127 INFO     [task.py:395] Building contexts for mmlu_high_school_world_history on rank 0...
# 100% 237/237 [00:03<00:00, 65.96it/s]
# 2024-03-29:11:04:19,815 INFO     [evaluator.py:379] Running loglikelihood requests
# 2024-03-29:11:04:19,837 INFO     [model.py:225] Loading 'loglikelihood' responses from cache 'results_dir_mmlu_awq_rank0.db' where possible...
# Checking cached requests: 100% 56168/56168 [00:08<00:00, 6433.54it/s]
# 2024-03-29:11:04:28,569 INFO     [model.py:249] Cached requests: 0, Requests remaining: 56168
# Running loglikelihood requests:   0% 0/56168 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 8
# Running loglikelihood requests:  25% 13953/56168 [09:23<12:19, 57.11it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 32
# Running loglikelihood requests:  50% 27825/56168 [12:57<06:01, 78.33it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Running loglikelihood requests:  50% 27952/56168 [13:10<06:00, 78.33it/s]Determined largest batch size: 32
# Running loglikelihood requests:  75% 41985/56168 [15:50<02:21, 99.92it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests: 100% 56168/56168 [17:55<00:00, 52.21it/s]
# {
#   "results": {
#     "mmlu_stem": {
#       "alias": "stem",
#       "acc,none": 0.3875673961306692,
#       "acc_stderr,none": 0.008543501061726504
#     },
#     "mmlu_abstract_algebra": {
#       "alias": " - abstract_algebra",
#       "acc,none": 0.3,
#       "acc_stderr,none": 0.046056618647183814
#     },
#     "mmlu_anatomy": {
#       "alias": " - anatomy",
#       "acc,none": 0.45925925925925926,
#       "acc_stderr,none": 0.04304979692464242
#     },
#     "mmlu_astronomy": {
#       "alias": " - astronomy",
#       "acc,none": 0.4934210526315789,
#       "acc_stderr,none": 0.040685900502249704
#     },
#     "mmlu_college_biology": {
#       "alias": " - college_biology",
#       "acc,none": 0.5069444444444444,
#       "acc_stderr,none": 0.04180806750294938
#     },
#     "mmlu_college_chemistry": {
#       "alias": " - college_chemistry",
#       "acc,none": 0.29,
#       "acc_stderr,none": 0.04560480215720684
#     },
#     "mmlu_college_computer_science": {
#       "alias": " - college_computer_science",
#       "acc,none": 0.42,
#       "acc_stderr,none": 0.049604496374885836
#     },
#     "mmlu_college_mathematics": {
#       "mmlu_high_school_world_history"
#     ],
#     "mmlu_other": [
#       "mmlu_clinical_knowledge",
#       "mmlu_virology",
#       "mmlu_college_medicine",
#       "mmlu_human_aging",
#       "mmlu_professional_accounting",
#       "mmlu_medical_genetics",
#       "mmlu_miscellaneous",
#       "mmlu_management",
#       "mmlu_global_facts",
#       "mmlu_marketing",
#       "mmlu_professional_medicine",
#       "mmlu_nutrition",
#       "mmlu_business_ethics"
#     ],
#     "mmlu_social_sciences": [
#       "mmlu_sociology",
#       "mmlu_us_foreign_policy",
#       "mmlu_high_school_macroeconomics",
#       "mmlu_high_school_government_and_politics",
#       "mmlu_human_sexuality",
#       "mmlu_econometrics",
#       "mmlu_high_school_microeconomics",
#       "mmlu_professional_psychology",
#       "mmlu_security_studies",
#       "mmlu_high_school_geography",
#       "mmlu_high_school_psychology",
#       "mmlu_public_relations"
#     ],
#     "mmlu_stem": [
#       "mmlu_abstract_algebra",
#       "mmlu_anatomy",
#       "mmlu_elementary_mathematics",
#       "mmlu_college_chemistry",
#       "mmlu_high_school_physics",
#       "mmlu_high_school_mathematics",
#       "mmlu_high_school_chemistry",
#       "mmlu_electrical_engineering",
#       "mmlu_high_school_computer_science",
#       "mmlu_computer_security",
#       "mmlu_astronomy",
#       "mmlu_college_mathematics",
#       "mmlu_college_biology",
#       "mmlu_high_school_statistics",
#       "mmlu_college_physics",
#       "mmlu_conceptual_physics",
#       "mmlu_college_computer_science",
#       "mmlu_machine_learning",
#       "mmlu_high_school_biology"
#     ]
#   },
#   "configs": {
#     "mmlu_abstract_algebra": {
#       "task": "mmlu_abstract_algebra",
#       "task_alias": "abstract_algebra",
#       "group": "mmlu_stem",
#       "group_alias": "stem",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "abstract_algebra",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about abstract algebra.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
#     "mmlu_anatomy": {
#       "task": "mmlu_anatomy",
#       "task_alias": "anatomy",
#       "group": "mmlu_stem",
#       "group_alias": "stem",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "anatomy",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about anatomy.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
#     "mmlu_astronomy": {
#       "task": "mmlu_astronomy",
#       "task_alias": "astronomy",
#       "group": "mmlu_stem",
#       "group_alias": "stem",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "astronomy",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about astronomy.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
#     "mmlu_business_ethics": {
#       "task": "mmlu_business_ethics",
#       "task_alias": "business_ethics",
#       "group": "mmlu_other",
#       "group_alias": "other",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "business_ethics",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about business ethics.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
#     "mmlu_clinical_knowledge": {
#       "task": "mmlu_clinical_knowledge",
#       "task_alias": "clinical_knowledge",
#       "group": "mmlu_other",
#       "group_alias": "other",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "clinical_knowledge",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
# ...
# wandb:                    mmlu_machine_learning/acc_stderr ▁
# wandb:                                 mmlu_management/acc ▁
# wandb:                          mmlu_management/acc_stderr ▁
# wandb:                                  mmlu_marketing/acc ▁
# wandb:                           mmlu_marketing/acc_stderr ▁
# wandb:                           mmlu_medical_genetics/acc ▁
# wandb:                    mmlu_medical_genetics/acc_stderr ▁
# wandb:                              mmlu_miscellaneous/acc ▁
# wandb:                       mmlu_miscellaneous/acc_stderr ▁
# wandb:                             mmlu_moral_disputes/acc ▁
# wandb:                      mmlu_moral_disputes/acc_stderr ▁
# wandb:                            mmlu_moral_scenarios/acc ▁
# wandb:                     mmlu_moral_scenarios/acc_stderr ▁
# wandb:                                  mmlu_nutrition/acc ▁
# wandb:                           mmlu_nutrition/acc_stderr ▁
# wandb:                                      mmlu_other/acc ▁
# wandb:                               mmlu_other/acc_stderr ▁
# wandb:                                 mmlu_philosophy/acc ▁
# wandb:                          mmlu_philosophy/acc_stderr ▁
# wandb:                                 mmlu_prehistory/acc ▁
# wandb:                          mmlu_prehistory/acc_stderr ▁
# wandb:                    mmlu_professional_accounting/acc ▁
# wandb:             mmlu_professional_accounting/acc_stderr ▁
# wandb:                           mmlu_professional_law/acc ▁
# wandb:                    mmlu_professional_law/acc_stderr ▁
# wandb:                      mmlu_professional_medicine/acc ▁
# wandb:               mmlu_professional_medicine/acc_stderr ▁
# wandb:                    mmlu_professional_psychology/acc ▁
# wandb:             mmlu_professional_psychology/acc_stderr ▁
# wandb:                           mmlu_public_relations/acc ▁
# wandb:                    mmlu_public_relations/acc_stderr ▁
# wandb:                           mmlu_security_studies/acc ▁
# wandb:                    mmlu_security_studies/acc_stderr ▁
# wandb:                            mmlu_social_sciences/acc ▁
# wandb:                     mmlu_social_sciences/acc_stderr ▁
# wandb:                                  mmlu_sociology/acc ▁
# wandb:                           mmlu_sociology/acc_stderr ▁
# wandb:                                       mmlu_stem/acc ▁
# wandb:                                mmlu_stem/acc_stderr ▁
# wandb:                          mmlu_us_foreign_policy/acc ▁
# wandb:                   mmlu_us_foreign_policy/acc_stderr ▁
# wandb:                                   mmlu_virology/acc ▁
# wandb:                            mmlu_virology/acc_stderr ▁
# wandb:                            mmlu_world_religions/acc ▁
# wandb:                     mmlu_world_religions/acc_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:                           mmlu_abstract_algebra/acc 0.3
# wandb:                    mmlu_abstract_algebra/acc_stderr 0.04606
# wandb:                         mmlu_abstract_algebra/alias  - abstract_algebra
# wandb:                                    mmlu_anatomy/acc 0.45926
# wandb:                             mmlu_anatomy/acc_stderr 0.04305
# wandb:                                  mmlu_anatomy/alias  - anatomy
# wandb:                                  mmlu_astronomy/acc 0.49342
# wandb:                           mmlu_astronomy/acc_stderr 0.04069
# wandb:                                mmlu_astronomy/alias  - astronomy
# wandb:                            mmlu_business_ethics/acc 0.48
# wandb:                     mmlu_business_ethics/acc_stderr 0.05021
# wandb:                          mmlu_business_ethics/alias  - business_ethics
# wandb:                         mmlu_clinical_knowledge/acc 0.49811
# wandb:                  mmlu_clinical_knowledge/acc_stderr 0.03077
# wandb:                       mmlu_clinical_knowledge/alias  - clinical_knowledg...
# wandb:                            mmlu_college_biology/acc 0.50694
# wandb:                     mmlu_college_biology/acc_stderr 0.04181
# wandb:                          mmlu_college_biology/alias  - college_biology
# wandb:                          mmlu_college_chemistry/acc 0.29
# wandb:                   mmlu_college_chemistry/acc_stderr 0.0456
# wandb:                        mmlu_college_chemistry/alias  - college_chemistry...
# wandb:                   mmlu_college_computer_science/acc 0.42
# wandb:            mmlu_college_computer_science/acc_stderr 0.0496
# wandb:                 mmlu_college_computer_science/alias  - college_computer_...
# wandb:                        mmlu_college_mathematics/acc 0.36
# wandb:                 mmlu_college_mathematics/acc_stderr 0.04824
# wandb:                      mmlu_college_mathematics/alias  - college_mathemati...
# wandb:                           mmlu_college_medicine/acc 0.40462
# wandb:                    mmlu_college_medicine/acc_stderr 0.03742
# wandb:                         mmlu_college_medicine/alias  - college_medicine
# wandb:                            mmlu_college_physics/acc 0.23529
# wandb:                     mmlu_college_physics/acc_stderr 0.04221
# wandb:                          mmlu_college_physics/alias  - college_physics
# wandb:                          mmlu_computer_security/acc 0.54
# wandb:                   mmlu_computer_security/acc_stderr 0.05009
# wandb:                        mmlu_computer_security/alias  - computer_security...
# wandb:                         mmlu_conceptual_physics/acc 0.41702
# wandb:                  mmlu_conceptual_physics/acc_stderr 0.03223
# wandb:                       mmlu_conceptual_physics/alias  - conceptual_physic...
# wandb:                               mmlu_econometrics/acc 0.37719
# wandb:                        mmlu_econometrics/acc_stderr 0.0456
# wandb:                             mmlu_econometrics/alias  - econometrics
# wandb:                     mmlu_electrical_engineering/acc 0.46207
# wandb:              mmlu_electrical_engineering/acc_stderr 0.04155
# wandb:                   mmlu_electrical_engineering/alias  - electrical_engine...
# wandb:                     mmlu_elementary_mathematics/acc 0.32275
# wandb:              mmlu_elementary_mathematics/acc_stderr 0.02408
# wandb:                   mmlu_elementary_mathematics/alias  - elementary_mathem...
# wandb:                               mmlu_formal_logic/acc 0.24603
# wandb:                        mmlu_formal_logic/acc_stderr 0.03852
# wandb:                             mmlu_formal_logic/alias  - formal_logic
# wandb:                               mmlu_global_facts/acc 0.36
# wandb:                        mmlu_global_facts/acc_stderr 0.04824
# wandb:                             mmlu_global_facts/alias  - global_facts
# wandb:                        mmlu_high_school_biology/acc 0.53548
# wandb:                 mmlu_high_school_biology/acc_stderr 0.02837
# wandb:                      mmlu_high_school_biology/alias  - high_school_biolo...
# wandb:                      mmlu_high_school_chemistry/acc 0.34975
# wandb:               mmlu_high_school_chemistry/acc_stderr 0.03355
# wandb:                    mmlu_high_school_chemistry/alias  - high_school_chemi...
# wandb:               mmlu_high_school_computer_science/acc 0.44
# wandb:        mmlu_high_school_computer_science/acc_stderr 0.04989
# wandb:             mmlu_high_school_computer_science/alias  - high_school_compu...
# wandb:               mmlu_high_school_european_history/acc 0.59394
# wandb:        mmlu_high_school_european_history/acc_stderr 0.03835
# wandb:             mmlu_high_school_european_history/alias  - high_school_europ...
# wandb:                      mmlu_high_school_geography/acc 0.58081
# wandb:               mmlu_high_school_geography/acc_stderr 0.03516
# wandb:                    mmlu_high_school_geography/alias  - high_school_geogr...
# wandb:        mmlu_high_school_government_and_politics/acc 0.68394
# wandb: mmlu_high_school_government_and_politics/acc_stderr 0.03355
# wandb:      mmlu_high_school_government_and_politics/alias  - high_school_gover...
# wandb:                 mmlu_high_school_macroeconomics/acc 0.41538
# wandb:          mmlu_high_school_macroeconomics/acc_stderr 0.02499
# wandb:               mmlu_high_school_macroeconomics/alias  - high_school_macro...
# wandb:                    mmlu_high_school_mathematics/acc 0.25556
# wandb:             mmlu_high_school_mathematics/acc_stderr 0.02659
# wandb:                  mmlu_high_school_mathematics/alias  - high_school_mathe...
# wandb:                 mmlu_high_school_microeconomics/acc 0.42437
# wandb:          mmlu_high_school_microeconomics/acc_stderr 0.0321
# wandb:               mmlu_high_school_microeconomics/alias  - high_school_micro...
# wandb:                        mmlu_high_school_physics/acc 0.35099
# wandb:                 mmlu_high_school_physics/acc_stderr 0.03897
# wandb:                      mmlu_high_school_physics/alias  - high_school_physi...
# wandb:                     mmlu_high_school_psychology/acc 0.67339
# wandb:              mmlu_high_school_psychology/acc_stderr 0.02011
# wandb:                   mmlu_high_school_psychology/alias  - high_school_psych...
# wandb:                     mmlu_high_school_statistics/acc 0.3287
# wandb:              mmlu_high_school_statistics/acc_stderr 0.03204
# wandb:                   mmlu_high_school_statistics/alias  - high_school_stati...
# wandb:                     mmlu_high_school_us_history/acc 0.62745
# wandb:              mmlu_high_school_us_history/acc_stderr 0.03393
# wandb:                   mmlu_high_school_us_history/alias  - high_school_us_hi...
# wandb:                  mmlu_high_school_world_history/acc 0.63291
# wandb:           mmlu_high_school_world_history/acc_stderr 0.03138
# wandb:                mmlu_high_school_world_history/alias  - high_school_world...
# wandb:                                mmlu_human_aging/acc 0.54709
# wandb:                         mmlu_human_aging/acc_stderr 0.03341
# wandb:                              mmlu_human_aging/alias  - human_aging
# wandb:                            mmlu_human_sexuality/acc 0.58015
# wandb:                     mmlu_human_sexuality/acc_stderr 0.04329
# wandb:                          mmlu_human_sexuality/alias  - human_sexuality
# wandb:                                 mmlu_humanities/acc 0.43061
# wandb:                          mmlu_humanities/acc_stderr 0.00689
# wandb:                               mmlu_humanities/alias humanities
# wandb:                          mmlu_international_law/acc 0.64463
# wandb:                   mmlu_international_law/acc_stderr 0.04369
# wandb:                        mmlu_international_law/alias  - international_law...
# wandb:                              mmlu_jurisprudence/acc 0.60185
# wandb:                       mmlu_jurisprudence/acc_stderr 0.04732
# wandb:                            mmlu_jurisprudence/alias  - jurisprudence
# wandb:                          mmlu_logical_fallacies/acc 0.55215
# wandb:                   mmlu_logical_fallacies/acc_stderr 0.03907
# wandb:                        mmlu_logical_fallacies/alias  - logical_fallacies...
# wandb:                           mmlu_machine_learning/acc 0.32143
# wandb:                    mmlu_machine_learning/acc_stderr 0.04433
# wandb:                         mmlu_machine_learning/alias  - machine_learning
# wandb:                                 mmlu_management/acc 0.65049
# wandb:                          mmlu_management/acc_stderr 0.04721
# wandb:                               mmlu_management/alias  - management
# wandb:                                  mmlu_marketing/acc 0.7094
# wandb:                           mmlu_marketing/acc_stderr 0.02975
# wandb:                                mmlu_marketing/alias  - marketing
# wandb:                           mmlu_medical_genetics/acc 0.5
# wandb:                    mmlu_medical_genetics/acc_stderr 0.05025
# wandb:                         mmlu_medical_genetics/alias  - medical_genetics
# wandb:                              mmlu_miscellaneous/acc 0.67305
# wandb:                       mmlu_miscellaneous/acc_stderr 0.01677
# wandb:                            mmlu_miscellaneous/alias  - miscellaneous
# wandb:                             mmlu_moral_disputes/acc 0.52023
# wandb:                      mmlu_moral_disputes/acc_stderr 0.0269
# wandb:                           mmlu_moral_disputes/alias  - moral_disputes
# wandb:                            mmlu_moral_scenarios/acc 0.24022
# wandb:                     mmlu_moral_scenarios/acc_stderr 0.01429
# wandb:                          mmlu_moral_scenarios/alias  - moral_scenarios
# wandb:                                  mmlu_nutrition/acc 0.49673
# wandb:                           mmlu_nutrition/acc_stderr 0.02863
# wandb:                                mmlu_nutrition/alias  - nutrition
# wandb:                                      mmlu_other/acc 0.5375
# wandb:                               mmlu_other/acc_stderr 0.00871
# wandb:                                    mmlu_other/alias other
# wandb:                                 mmlu_philosophy/acc 0.55305
# wandb:                          mmlu_philosophy/acc_stderr 0.02824
# wandb:                               mmlu_philosophy/alias  - philosophy
# wandb:                                 mmlu_prehistory/acc 0.5679
# wandb:                          mmlu_prehistory/acc_stderr 0.02756
# wandb:                               mmlu_prehistory/alias  - prehistory
# wandb:                    mmlu_professional_accounting/acc 0.36879
# wandb:             mmlu_professional_accounting/acc_stderr 0.02878
# wandb:                  mmlu_professional_accounting/alias  - professional_acco...
# wandb:                           mmlu_professional_law/acc 0.33898
# wandb:                    mmlu_professional_law/acc_stderr 0.01209
# wandb:                         mmlu_professional_law/alias  - professional_law
# wandb:                      mmlu_professional_medicine/acc 0.47426
# wandb:               mmlu_professional_medicine/acc_stderr 0.03033
# wandb:                    mmlu_professional_medicine/alias  - professional_medi...
# wandb:                    mmlu_professional_psychology/acc 0.45915
# wandb:             mmlu_professional_psychology/acc_stderr 0.02016
# wandb:                  mmlu_professional_psychology/alias  - professional_psyc...
# wandb:                           mmlu_public_relations/acc 0.53636
# wandb:                    mmlu_public_relations/acc_stderr 0.04776
# wandb:                         mmlu_public_relations/alias  - public_relations
# wandb:                           mmlu_security_studies/acc 0.51429
# wandb:                    mmlu_security_studies/acc_stderr 0.032
# wandb:                         mmlu_security_studies/alias  - security_studies
# wandb:                            mmlu_social_sciences/acc 0.53884
# wandb:                     mmlu_social_sciences/acc_stderr 0.0088
# wandb:                          mmlu_social_sciences/alias social_sciences
# wandb:                                  mmlu_sociology/acc 0.62687
# wandb:                           mmlu_sociology/acc_stderr 0.0342
# wandb:                                mmlu_sociology/alias  - sociology
# wandb:                                       mmlu_stem/acc 0.38757
# wandb:                                mmlu_stem/acc_stderr 0.00854
# wandb:                                     mmlu_stem/alias stem
# wandb:                          mmlu_us_foreign_policy/acc 0.7
# wandb:                   mmlu_us_foreign_policy/acc_stderr 0.04606
# wandb:                        mmlu_us_foreign_policy/alias  - us_foreign_policy...
# wandb:                                   mmlu_virology/acc 0.40361
# wandb:                            mmlu_virology/acc_stderr 0.03819
# wandb:                                 mmlu_virology/alias  - virology
# wandb:                            mmlu_world_religions/acc 0.67251
# wandb:                     mmlu_world_religions/acc_stderr 0.03599
# wandb:                          mmlu_world_religions/alias  - world_religions
# wandb:
# wandb: 🚀 View run Llama-2-7b-chat-hf-AWQ-mmlu1 at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/suymbfwg/workspace
# wandb: Synced 5 W&B file(s), 6 media file(s), 7 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240329_105526-suymbfwg/logs

# %% [markdown]
# #### HellaSwag
#
# 0-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Llama-2-7b-chat-hf-AWQ,trust_remote_code=True,revision="af57a3ea9007748b0d9385ffca5a8164889b4901" \
    --tasks hellaswag \
    --num_fewshot 0 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir_awq_hellaswag \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Llama-2-7b-chat-hf-AWQ-hellaswag1 \
    --use_cache results_dir_awq_hellaswag \
    --cache_requests true \
    --show_config
# Out:
# 2024-03-29 11:27:07.792106: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-29 11:27:07.792155: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-29 11:27:07.793707: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-29 11:27:08.985340: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240329_112714-dowlx51s
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Llama-2-7b-chat-hf-AWQ-hellaswag1
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/dowlx51s/workspace
# 2024-03-29:11:27:15,663 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-29:11:27:21,609 INFO     [__main__.py:335] Selected Tasks: ['hellaswag']
# 2024-03-29:11:27:21,610 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-29:11:27:21,610 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Llama-2-7b-chat-hf-AWQ', 'trust_remote_code': True, 'revision': 'af57a3ea9007748b0d9385ffca5a8164889b4901'}
# 2024-03-29:11:27:21,614 INFO     [huggingface.py:163] Using device 'cuda:0'
# We suggest you to set `torch_dtype=torch.float16` for better efficiency with AWQ.
# 2024-03-29:11:27:23,896 INFO     [evaluator.py:195] Using cache at results_dir_awq_hellaswag_rank0.db
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 4.36k/4.36k [00:00<00:00, 11.5MB/s]
# Downloading metadata: 100% 2.53k/2.53k [00:00<00:00, 9.39MB/s]
# Downloading readme: 100% 6.84k/6.84k [00:00<00:00, 17.2MB/s]
# Downloading data: 47.5MB [00:00, 74.2MB/s]
# Downloading data: 11.8MB [00:00, 66.0MB/s]
# Downloading data: 12.2MB [00:00, 65.0MB/s]
# Generating train split: 100% 39905/39905 [00:04<00:00, 9439.55 examples/s]
# Generating test split: 100% 10003/10003 [00:01<00:00, 9635.52 examples/s]
# Generating validation split: 100% 10042/10042 [00:01<00:00, 9682.17 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 6590.68 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 6964.81 examples/s]
# 2024-03-29:11:27:55,117 WARNING  [evaluator.py:239] Overwriting default num_fewshot of hellaswag from None to 0
# 2024-03-29:11:27:55,118 INFO     [task.py:395] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:04<00:00, 2159.99it/s]
# 2024-03-29:11:28:05,304 INFO     [evaluator.py:379] Running loglikelihood requests
# 2024-03-29:11:28:05,314 INFO     [model.py:225] Loading 'loglikelihood' responses from cache 'results_dir_awq_hellaswag_rank0.db' where possible...
# Checking cached requests: 100% 40168/40168 [00:05<00:00, 7545.40it/s]
# 2024-03-29:11:28:10,638 INFO     [model.py:249] Cached requests: 0, Requests remaining: 40168
# Running loglikelihood requests:   0% 0/40168 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests:  25% 9930/40168 [01:57<05:17, 95.39it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests: 100% 40168/40168 [05:45<00:00, 116.23it/s]
# {
#   "results": {
#     "hellaswag": {
#       "acc,none": 0.5727942640908186,
#       "acc_stderr,none": 0.0049366164289226435,
#       "acc_norm,none": 0.7483569010157339,
#       "acc_norm_stderr,none": 0.004330703120137891,
#       "alias": "hellaswag"
#     }
#   },
#   "group_subtasks": {
#     "hellaswag": []
#   },
#   "configs": {
#     "hellaswag": {
#       "task": "hellaswag",
#       "group": [
#         "multiple_choice"
#       ],
#       "dataset_path": "hellaswag",
#       "training_split": "train",
#       "validation_split": "validation",
#       "process_docs": "def process_docs(dataset: datasets.Dataset) -> datasets.Dataset:\n    def _process_doc(doc):\n        ctx = doc[\"ctx_a\"] + \" \" + doc[\"ctx_b\"].capitalize()\n        out_doc = {\n            \"query\": preprocess(doc[\"activity_label\"] + \": \" + ctx),\n            \"choices\": [preprocess(ending) for ending in doc[\"endings\"]],\n            \"gold\": int(doc[\"label\"]),\n        }\n        return out_doc\n\n    return dataset.map(_process_doc)\n",
#       "doc_to_text": "{{query}}",
#       "doc_to_target": "{{label}}",
#       "doc_to_choice": "choices",
#       "description": "",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         },
#         {
#           "metric": "acc_norm",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0
#       }
#     }
#   },
#   "versions": {
#     "hellaswag": 1.0
#   },
#   "n-shot": {
#     "hellaswag": 0
#   },
#   "config": {
#     "model": "hf",
#     "model_args": "pretrained=twhoool02/Llama-2-7b-chat-hf-AWQ,trust_remote_code=True,revision=af57a3ea9007748b0d9385ffca5a8164889b4901",
#     "batch_size": "auto:4",
#     "batch_sizes": [
#       64,
#       64,
#       64,
#       64,
#       64
#     ],
#     "device": "cuda:0",
#     "use_cache": "results_dir_awq_hellaswag",
#     "limit": null,
#     "bootstrap_iters": 100000,
#     "gen_kwargs": null
#   },
#   "git_hash": "ab7cc6b1",
#   "date": 1711711641.6098416,
#   "pretty_env_info": "PyTorch version: 2.2.1+cu121\nIs debug build: False\nCUDA used to build PyTorch: 12.1\nROCM used to build PyTorch: N/A\n\nOS: Ubuntu 22.04.3 LTS (x86_64)\nGCC version: (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0\nClang version: 14.0.0-1ubuntu1.1\nCMake version: version 3.27.9\nLibc version: glibc-2.35\n\nPython version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0] (64-bit runtime)\nPython platform: Linux-6.1.58+-x86_64-with-glibc2.35\nIs CUDA available: True\nCUDA runtime version: 12.2.140\nCUDA_MODULE_LOADING set to: LAZY\nGPU models and configuration: GPU 0: NVIDIA A100-SXM4-40GB\nNvidia driver version: 535.104.05\ncuDNN version: Probably one of the following:\n/usr/lib/x86_64-linux-gnu/libcudnn.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_train.so.8.9.6\nHIP runtime version: N/A\nMIOpen runtime version: N/A\nIs XNNPACK available: True\n\nCPU:\nArchitecture:                       x86_64\nCPU op-mode(s):                     32-bit, 64-bit\nAddress sizes:                      46 bits physical, 48 bits virtual\nByte Order:                         Little Endian\nCPU(s):                             12\nOn-line CPU(s) list:                0-11\nVendor ID:                          GenuineIntel\nModel name:                         Intel(R) Xeon(R) CPU @ 2.20GHz\nCPU family:                         6\nModel:                              85\nThread(s) per core:                 2\nCore(s) per socket:                 6\nSocket(s):                          1\nStepping:                           7\nBogoMIPS:                           4400.30\nFlags:                              fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp ibrs_enhanced fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat avx512_vnni md_clear arch_capabilities\nHypervisor vendor:                  KVM\nVirtualization type:                full\nL1d cache:                          192 KiB (6 instances)\nL1i cache:                          192 KiB (6 instances)\nL2 cache:                           6 MiB (6 instances)\nL3 cache:                           38.5 MiB (1 instance)\nNUMA node(s):                       1\nNUMA node0 CPU(s):                  0-11\nVulnerability Gather data sampling: Not affected\nVulnerability Itlb multihit:        Not affected\nVulnerability L1tf:                 Not affected\nVulnerability Mds:                  Vulnerable; SMT Host state unknown\nVulnerability Meltdown:             Not affected\nVulnerability Mmio stale data:      Vulnerable\nVulnerability Retbleed:             Vulnerable\nVulnerability Spec rstack overflow: Not affected\nVulnerability Spec store bypass:    Vulnerable\nVulnerability Spectre v1:           Vulnerable: __user pointer sanitization and usercopy barriers only; no swapgs barriers\nVulnerability Spectre v2:           Vulnerable, IBPB: disabled, STIBP: disabled, PBRSB-eIBRS: Vulnerable\nVulnerability Srbds:                Not affected\nVulnerability Tsx async abort:      Vulnerable\n\nVersions of relevant libraries:\n[pip3] numpy==1.25.2\n[pip3] torch==2.2.1+cu121\n[pip3] torchaudio==2.2.1+cu121\n[pip3] torchdata==0.7.1\n[pip3] torchsummary==1.5.1\n[pip3] torchtext==0.17.1\n[pip3] torchvision==0.17.1+cu121\n[pip3] triton==2.2.0\n[conda] Could not collect",
#   "transformers_version": "4.38.2",
#   "upper_git_hash": null
# }
# hf (pretrained=twhoool02/Llama-2-7b-chat-hf-AWQ,trust_remote_code=True,revision=af57a3ea9007748b0d9385ffca5a8164889b4901), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: auto:4 (64,64,64,64,64)
# |  Tasks  |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |---------|------:|------|-----:|--------|-----:|---|-----:|
# |hellaswag|      1|none  |     0|acc     |0.5728|±  |0.0049|
# |         |       |none  |     0|acc_norm|0.7484|±  |0.0043|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:             hellaswag/acc ▁
# wandb:        hellaswag/acc_norm ▁
# wandb: hellaswag/acc_norm_stderr ▁
# wandb:      hellaswag/acc_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:             hellaswag/acc 0.57279
# wandb:        hellaswag/acc_norm 0.74836
# wandb: hellaswag/acc_norm_stderr 0.00433
# wandb:      hellaswag/acc_stderr 0.00494
# wandb:           hellaswag/alias hellaswag
# wandb:
# wandb: 🚀 View run Llama-2-7b-chat-hf-AWQ-hellaswag1 at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/dowlx51s/workspace
# wandb: Synced 5 W&B file(s), 2 media file(s), 3 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240329_112714-dowlx51s/logs

# %% [markdown]
# #### BoolQ
#
# 0-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Llama-2-7b-chat-hf-AWQ,trust_remote_code=True,revision="af57a3ea9007748b0d9385ffca5a8164889b4901" \
    --tasks boolq\
    --num_fewshot 0 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir_awq_boolq \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Llama-2-7b-chat-hf-AWQ-boolq1 \
    --use_cache results_dir_awq_boolq \
    --cache_requests true \
    --show_config
# Out:
# 2024-03-29 11:35:02.693144: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-29 11:35:02.693206: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-29 11:35:02.694635: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-29 11:35:03.937566: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240329_113509-vgv9jx7v
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Llama-2-7b-chat-hf-AWQ-boolq1
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/vgv9jx7v/workspace
# 2024-03-29:11:35:10,608 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-29:11:35:16,643 INFO     [__main__.py:335] Selected Tasks: ['boolq']
# 2024-03-29:11:35:16,644 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-29:11:35:16,644 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Llama-2-7b-chat-hf-AWQ', 'trust_remote_code': True, 'revision': 'af57a3ea9007748b0d9385ffca5a8164889b4901'}
# 2024-03-29:11:35:16,648 INFO     [huggingface.py:163] Using device 'cuda:0'
# We suggest you to set `torch_dtype=torch.float16` for better efficiency with AWQ.
# 2024-03-29:11:35:18,780 INFO     [evaluator.py:195] Using cache at results_dir_awq_boolq_rank0.db
# 2024-03-29:11:35:18,785 WARNING  [task.py:763] [Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# 2024-03-29:11:35:18,785 WARNING  [task.py:775] [Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# Downloading data: 100% 3.85M/3.85M [00:00<00:00, 10.3MB/s]
# Downloading data: 100% 1.31M/1.31M [00:00<00:00, 3.29MB/s]
# Downloading data: 100% 1.31M/1.31M [00:00<00:00, 4.55MB/s]
# Generating train split: 100% 9427/9427 [00:00<00:00, 232615.23 examples/s]
# Generating validation split: 100% 3270/3270 [00:00<00:00, 295055.81 examples/s]
# Generating test split: 100% 3245/3245 [00:00<00:00, 304608.49 examples/s]
# 2024-03-29:11:35:29,884 WARNING  [evaluator.py:239] Overwriting default num_fewshot of boolq from None to 0
# 2024-03-29:11:35:29,885 INFO     [task.py:395] Building contexts for boolq on rank 0...
# 100% 3270/3270 [00:01<00:00, 1753.04it/s]
# 2024-03-29:11:35:32,463 INFO     [evaluator.py:379] Running loglikelihood requests
# 2024-03-29:11:35:32,465 INFO     [model.py:225] Loading 'loglikelihood' responses from cache 'results_dir_awq_boolq_rank0.db' where possible...
# Checking cached requests: 100% 6540/6540 [00:00<00:00, 7442.48it/s]
# 2024-03-29:11:35:33,344 INFO     [model.py:249] Cached requests: 0, Requests remaining: 6540
# Running loglikelihood requests:   0% 0/6540 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 16
# Running loglikelihood requests:  24% 1601/6540 [00:39<00:49, 98.96it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests: 100% 6540/6540 [01:15<00:00, 87.06it/s]
# {
#   "results": {
#     "boolq": {
#       "acc,none": 0.7954128440366972,
#       "acc_stderr,none": 0.007055503668871517,
#       "alias": "boolq"
#     }
#   },
#   "group_subtasks": {
#     "boolq": []
#   },
#   "configs": {
#     "boolq": {
#       "task": "boolq",
#       "group": [
#         "super-glue-lm-eval-v1"
#       ],
#       "dataset_path": "super_glue",
#       "dataset_name": "boolq",
#       "training_split": "train",
#       "validation_split": "validation",
#       "doc_to_text": "{{passage}}\nQuestion: {{question}}?\nAnswer:",
#       "doc_to_target": "label",
#       "doc_to_choice": [
#         "no",
#         "yes"
#       ],
#       "description": "",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "acc"
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": true,
#       "doc_to_decontamination_query": "passage",
#       "metadata": {
#         "version": 2.0
#       }
#     }
#   },
#   "versions": {
#     "boolq": 2.0
#   },
#   "n-shot": {
#     "boolq": 0
#   },
#   "config": {
#     "model": "hf",
#     "model_args": "pretrained=twhoool02/Llama-2-7b-chat-hf-AWQ,trust_remote_code=True,revision=af57a3ea9007748b0d9385ffca5a8164889b4901",
#     "batch_size": "auto:4",
#     "batch_sizes": [
#       16,
#       64,
#       64,
#       64,
#       64
#     ],
#     "device": "cuda:0",
#     "use_cache": "results_dir_awq_boolq",
#     "limit": null,
#     "bootstrap_iters": 100000,
#     "gen_kwargs": null
#   },
#   "git_hash": "ab7cc6b1",
#   "date": 1711712116.6443079,
#   "pretty_env_info": "PyTorch version: 2.2.1+cu121\nIs debug build: False\nCUDA used to build PyTorch: 12.1\nROCM used to build PyTorch: N/A\n\nOS: Ubuntu 22.04.3 LTS (x86_64)\nGCC version: (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0\nClang version: 14.0.0-1ubuntu1.1\nCMake version: version 3.27.9\nLibc version: glibc-2.35\n\nPython version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0] (64-bit runtime)\nPython platform: Linux-6.1.58+-x86_64-with-glibc2.35\nIs CUDA available: True\nCUDA runtime version: 12.2.140\nCUDA_MODULE_LOADING set to: LAZY\nGPU models and configuration: GPU 0: NVIDIA A100-SXM4-40GB\nNvidia driver version: 535.104.05\ncuDNN version: Probably one of the following:\n/usr/lib/x86_64-linux-gnu/libcudnn.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_train.so.8.9.6\nHIP runtime version: N/A\nMIOpen runtime version: N/A\nIs XNNPACK available: True\n\nCPU:\nArchitecture:                       x86_64\nCPU op-mode(s):                     32-bit, 64-bit\nAddress sizes:                      46 bits physical, 48 bits virtual\nByte Order:                         Little Endian\nCPU(s):                             12\nOn-line CPU(s) list:                0-11\nVendor ID:                          GenuineIntel\nModel name:                         Intel(R) Xeon(R) CPU @ 2.20GHz\nCPU family:                         6\nModel:                              85\nThread(s) per core:                 2\nCore(s) per socket:                 6\nSocket(s):                          1\nStepping:                           7\nBogoMIPS:                           4400.30\nFlags:                              fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp ibrs_enhanced fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat avx512_vnni md_clear arch_capabilities\nHypervisor vendor:                  KVM\nVirtualization type:                full\nL1d cache:                          192 KiB (6 instances)\nL1i cache:                          192 KiB (6 instances)\nL2 cache:                           6 MiB (6 instances)\nL3 cache:                           38.5 MiB (1 instance)\nNUMA node(s):                       1\nNUMA node0 CPU(s):                  0-11\nVulnerability Gather data sampling: Not affected\nVulnerability Itlb multihit:        Not affected\nVulnerability L1tf:                 Not affected\nVulnerability Mds:                  Vulnerable; SMT Host state unknown\nVulnerability Meltdown:             Not affected\nVulnerability Mmio stale data:      Vulnerable\nVulnerability Retbleed:             Vulnerable\nVulnerability Spec rstack overflow: Not affected\nVulnerability Spec store bypass:    Vulnerable\nVulnerability Spectre v1:           Vulnerable: __user pointer sanitization and usercopy barriers only; no swapgs barriers\nVulnerability Spectre v2:           Vulnerable, IBPB: disabled, STIBP: disabled, PBRSB-eIBRS: Vulnerable\nVulnerability Srbds:                Not affected\nVulnerability Tsx async abort:      Vulnerable\n\nVersions of relevant libraries:\n[pip3] numpy==1.25.2\n[pip3] torch==2.2.1+cu121\n[pip3] torchaudio==2.2.1+cu121\n[pip3] torchdata==0.7.1\n[pip3] torchsummary==1.5.1\n[pip3] torchtext==0.17.1\n[pip3] torchvision==0.17.1+cu121\n[pip3] triton==2.2.0\n[conda] Could not collect",
#   "transformers_version": "4.38.2",
#   "upper_git_hash": null
# }
# hf (pretrained=twhoool02/Llama-2-7b-chat-hf-AWQ,trust_remote_code=True,revision=af57a3ea9007748b0d9385ffca5a8164889b4901), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: auto:4 (16,64,64,64,64)
# |Tasks|Version|Filter|n-shot|Metric|Value |   |Stderr|
# |-----|------:|------|-----:|------|-----:|---|-----:|
# |boolq|      2|none  |     0|acc   |0.7954|±  |0.0071|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:        boolq/acc ▁
# wandb: boolq/acc_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:        boolq/acc 0.79541
# wandb: boolq/acc_stderr 0.00706
# wandb:      boolq/alias boolq
# wandb:
# wandb: 🚀 View run Llama-2-7b-chat-hf-AWQ-boolq1 at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/vgv9jx7v/workspace
# wandb: Synced 5 W&B file(s), 2 media file(s), 3 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240329_113509-vgv9jx7v/logs

# %% [markdown]
# #### BBH
#
# 3-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Llama-2-7b-chat-hf-AWQ,trust_remote_code=True,revision="af57a3ea9007748b0d9385ffca5a8164889b4901" \
    --tasks bbh_fewshot \
    --num_fewshot 3 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir_awq_bbh \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Llama-2-7b-chat-hf-AWQ-bbh1 \
    --use_cache results_dir_awq_bbh \
    --cache_requests true \
    --show_config
# Out:
# 2024-03-29 11:37:16.237668: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-29 11:37:16.237723: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-29 11:37:16.239194: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-29 11:37:17.441112: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240329_113723-1e9wpvxg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Llama-2-7b-chat-hf-AWQ-bbh1
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/1e9wpvxg/workspace
# 2024-03-29:11:37:24,206 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-03-29:11:37:30,486 INFO     [__main__.py:335] Selected Tasks: ['bbh_fewshot']
# 2024-03-29:11:37:30,487 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-29:11:37:30,488 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Llama-2-7b-chat-hf-AWQ', 'trust_remote_code': True, 'revision': 'af57a3ea9007748b0d9385ffca5a8164889b4901'}
# 2024-03-29:11:37:30,492 INFO     [huggingface.py:163] Using device 'cuda:0'
# We suggest you to set `torch_dtype=torch.float16` for better efficiency with AWQ.
# 2024-03-29:11:37:32,571 INFO     [evaluator.py:195] Using cache at results_dir_awq_bbh_rank0.db
# Downloading data: 100% 37.1k/37.1k [00:00<00:00, 102kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 46146.02 examples/s]
# 2024-03-29:11:37:38,895 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_five_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:37:38,895 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_five_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 25.1k/25.1k [00:00<00:00, 83.7kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 90114.82 examples/s]
# 2024-03-29:11:37:44,844 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_three_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:37:44,845 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_three_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.4k/10.4k [00:00<00:00, 37.3kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 111101.50 examples/s]
# 2024-03-29:11:37:50,544 WARNING  [task.py:322] [Task: bbh_fewshot_hyperbaton] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:37:50,544 WARNING  [task.py:322] [Task: bbh_fewshot_hyperbaton] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.6k/10.6k [00:00<00:00, 38.2kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 90223.37 examples/s]
# 2024-03-29:11:37:56,193 WARNING  [task.py:322] [Task: bbh_fewshot_object_counting] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:37:56,194 WARNING  [task.py:322] [Task: bbh_fewshot_object_counting] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 15.6k/15.6k [00:00<00:00, 55.8kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 91347.33 examples/s]
# 2024-03-29:11:38:01,866 WARNING  [task.py:322] [Task: bbh_fewshot_web_of_lies] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:38:01,866 WARNING  [task.py:322] [Task: bbh_fewshot_web_of_lies] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 21.7k/21.7k [00:00<00:00, 77.9kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 111740.84 examples/s]
# 2024-03-29:11:38:07,764 WARNING  [task.py:322] [Task: bbh_fewshot_movie_recommendation] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:38:07,764 WARNING  [task.py:322] [Task: bbh_fewshot_movie_recommendation] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 56.9k/56.9k [00:00<00:00, 203kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 73926.68 examples/s]
# 2024-03-29:11:38:13,075 WARNING  [task.py:322] [Task: bbh_fewshot_salient_translation_error_detection] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:38:13,076 WARNING  [task.py:322] [Task: bbh_fewshot_salient_translation_error_detection] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 35.6k/35.6k [00:00<00:00, 128kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 106163.41 examples/s]
# 2024-03-29:11:38:18,734 WARNING  [task.py:322] [Task: bbh_fewshot_temporal_sequences] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:38:18,734 WARNING  [task.py:322] [Task: bbh_fewshot_temporal_sequences] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 8.16k/8.16k [00:00<00:00, 28.8kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 99053.09 examples/s]
# 2024-03-29:11:38:24,347 WARNING  [task.py:322] [Task: bbh_fewshot_sports_understanding] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:38:24,348 WARNING  [task.py:322] [Task: bbh_fewshot_sports_understanding] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 21.6k/21.6k [00:00<00:00, 76.6kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 84358.49 examples/s]
# 2024-03-29:11:38:30,297 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_three_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:38:30,297 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_three_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 33.5k/33.5k [00:00<00:00, 123kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 83865.95 examples/s]
# 2024-03-29:11:38:35,905 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_five_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:38:35,905 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_five_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 20.2k/20.2k [00:00<00:00, 62.9kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 105173.12 examples/s]
# 2024-03-29:11:38:41,353 WARNING  [task.py:322] [Task: bbh_fewshot_geometric_shapes] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:38:41,353 WARNING  [task.py:322] [Task: bbh_fewshot_geometric_shapes] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 49.1k/49.1k [00:00<00:00, 93.4kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 76639.09 examples/s]
# 2024-03-29:11:38:47,133 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:38:47,133 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 15.6k/15.6k [00:00<00:00, 55.7kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 84101.38 examples/s]
# 2024-03-29:11:38:51,346 WARNING  [task.py:322] [Task: bbh_fewshot_ruin_names] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:38:51,347 WARNING  [task.py:322] [Task: bbh_fewshot_ruin_names] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 44.6k/44.6k [00:00<00:00, 160kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 108368.75 examples/s]
# 2024-03-29:11:38:57,133 WARNING  [task.py:322] [Task: bbh_fewshot_word_sorting] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:38:57,133 WARNING  [task.py:322] [Task: bbh_fewshot_word_sorting] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 20.4k/20.4k [00:00<00:00, 73.6kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 87366.77 examples/s]
# 2024-03-29:11:39:02,720 WARNING  [task.py:322] [Task: bbh_fewshot_reasoning_about_colored_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:39:02,720 WARNING  [task.py:322] [Task: bbh_fewshot_reasoning_about_colored_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.0k/10.0k [00:00<00:00, 36.1kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 92868.30 examples/s]
# 2024-03-29:11:39:08,264 WARNING  [task.py:322] [Task: bbh_fewshot_navigate] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:39:08,264 WARNING  [task.py:322] [Task: bbh_fewshot_navigate] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 18.0k/18.0k [00:00<00:00, 61.2kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 117698.51 examples/s]
# 2024-03-29:11:39:12,667 WARNING  [task.py:322] [Task: bbh_fewshot_date_understanding] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:39:12,667 WARNING  [task.py:322] [Task: bbh_fewshot_date_understanding] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 35.8k/35.8k [00:00<00:00, 128kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 86217.40 examples/s]
# 2024-03-29:11:39:18,301 WARNING  [task.py:322] [Task: bbh_fewshot_formal_fallacies] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:39:18,301 WARNING  [task.py:322] [Task: bbh_fewshot_formal_fallacies] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 4.70k/4.70k [00:00<00:00, 16.9kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 99053.09 examples/s]
# 2024-03-29:11:39:23,921 WARNING  [task.py:322] [Task: bbh_fewshot_boolean_expressions] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:39:23,921 WARNING  [task.py:322] [Task: bbh_fewshot_boolean_expressions] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 16.4k/16.4k [00:00<00:00, 58.6kB/s]
# Generating test split: 100% 178/178 [00:00<00:00, 48517.42 examples/s]
# 2024-03-29:11:39:29,515 WARNING  [task.py:322] [Task: bbh_fewshot_snarks] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:39:29,515 WARNING  [task.py:322] [Task: bbh_fewshot_snarks] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.0k/10.0k [00:00<00:00, 36.4kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 100399.85 examples/s]
# 2024-03-29:11:39:34,928 WARNING  [task.py:322] [Task: bbh_fewshot_dyck_languages] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:39:34,928 WARNING  [task.py:322] [Task: bbh_fewshot_dyck_languages] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 69.5k/69.5k [00:00<00:00, 232kB/s]
# Generating test split: 100% 187/187 [00:00<00:00, 57038.39 examples/s]
# 2024-03-29:11:39:41,651 WARNING  [task.py:322] [Task: bbh_fewshot_causal_judgement] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:39:41,651 WARNING  [task.py:322] [Task: bbh_fewshot_causal_judgement] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 16.7k/16.7k [00:00<00:00, 55.1kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 106034.58 examples/s]
# 2024-03-29:11:39:47,292 WARNING  [task.py:322] [Task: bbh_fewshot_disambiguation_qa] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:39:47,292 WARNING  [task.py:322] [Task: bbh_fewshot_disambiguation_qa] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 7.55k/7.55k [00:00<00:00, 27.2kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 94611.21 examples/s]
# 2024-03-29:11:39:52,959 WARNING  [task.py:322] [Task: bbh_fewshot_multistep_arithmetic_two] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:39:52,959 WARNING  [task.py:322] [Task: bbh_fewshot_multistep_arithmetic_two] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 44.0k/44.0k [00:00<00:00, 158kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 74172.46 examples/s]
# 2024-03-29:11:39:58,622 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:39:58,622 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.7k/10.7k [00:00<00:00, 38.9kB/s]
# Generating test split: 100% 146/146 [00:00<00:00, 55357.84 examples/s]
# 2024-03-29:11:40:04,182 WARNING  [task.py:322] [Task: bbh_fewshot_penguins_in_a_table] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:40:04,182 WARNING  [task.py:322] [Task: bbh_fewshot_penguins_in_a_table] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-03-29:11:40:04,187 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_penguins_in_a_table in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,187 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_logical_deduction_seven_objects in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,188 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_multistep_arithmetic_two in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,188 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_disambiguation_qa in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,188 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_causal_judgement in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,188 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_dyck_languages in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,188 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_snarks in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,188 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_boolean_expressions in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,189 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_formal_fallacies in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,189 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_date_understanding in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,189 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_navigate in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,189 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_reasoning_about_colored_objects in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,189 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_word_sorting in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,190 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_ruin_names in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,190 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_tracking_shuffled_objects_seven_objects in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,190 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_geometric_shapes in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,190 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_logical_deduction_five_objects in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,190 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_logical_deduction_three_objects in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,190 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_sports_understanding in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,190 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_temporal_sequences in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,191 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_salient_translation_error_detection in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,191 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_movie_recommendation in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,191 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_web_of_lies in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,191 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_object_counting in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,191 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_hyperbaton in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,191 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_tracking_shuffled_objects_three_objects in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,191 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_tracking_shuffled_objects_five_objects in its config. Manual configuration will be ignored.
# 2024-03-29:11:40:04,195 INFO     [task.py:395] Building contexts for bbh_fewshot_penguins_in_a_table on rank 0...
# 100% 146/146 [00:00<00:00, 1006.70it/s]
# 2024-03-29:11:40:04,363 INFO     [task.py:395] Building contexts for bbh_fewshot_logical_deduction_seven_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1018.45it/s]
# 2024-03-29:11:40:04,647 INFO     [task.py:395] Building contexts for bbh_fewshot_multistep_arithmetic_two on rank 0...
# 100% 250/250 [00:00<00:00, 1217.18it/s]
# 2024-03-29:11:40:04,888 INFO     [task.py:395] Building contexts for bbh_fewshot_disambiguation_qa on rank 0...
# 100% 250/250 [00:00<00:00, 1092.47it/s]
# 2024-03-29:11:40:05,154 INFO     [task.py:395] Building contexts for bbh_fewshot_causal_judgement on rank 0...
# 100% 187/187 [00:00<00:00, 962.59it/s]
# 2024-03-29:11:40:05,378 INFO     [task.py:395] Building contexts for bbh_fewshot_dyck_languages on rank 0...
# 100% 250/250 [00:00<00:00, 1184.27it/s]
# 2024-03-29:11:40:05,626 INFO     [task.py:395] Building contexts for bbh_fewshot_snarks on rank 0...
# 100% 178/178 [00:00<00:00, 1091.09it/s]
# 2024-03-29:11:40:05,815 INFO     [task.py:395] Building contexts for bbh_fewshot_boolean_expressions on rank 0...
# 100% 250/250 [00:00<00:00, 1227.64it/s]
# 2024-03-29:11:40:06,054 INFO     [task.py:395] Building contexts for bbh_fewshot_formal_fallacies on rank 0...
# 100% 250/250 [00:00<00:00, 1010.21it/s]
# 2024-03-29:11:40:06,340 INFO     [task.py:395] Building contexts for bbh_fewshot_date_understanding on rank 0...
# 100% 250/250 [00:00<00:00, 1131.33it/s]
# 2024-03-29:11:40:06,597 INFO     [task.py:395] Building contexts for bbh_fewshot_navigate on rank 0...
# 100% 250/250 [00:00<00:00, 1144.86it/s]
# 2024-03-29:11:40:06,852 INFO     [task.py:395] Building contexts for bbh_fewshot_reasoning_about_colored_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1032.01it/s]
# 2024-03-29:11:40:07,131 INFO     [task.py:395] Building contexts for bbh_fewshot_word_sorting on rank 0...
# 100% 250/250 [00:00<00:00, 1188.58it/s]
# 2024-03-29:11:40:07,378 INFO     [task.py:395] Building contexts for bbh_fewshot_ruin_names on rank 0...
# 100% 250/250 [00:00<00:00, 1129.10it/s]
# 2024-03-29:11:40:07,636 INFO     [task.py:395] Building contexts for bbh_fewshot_tracking_shuffled_objects_seven_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1028.20it/s]
# 2024-03-29:11:40:07,917 INFO     [task.py:395] Building contexts for bbh_fewshot_geometric_shapes on rank 0...
# 100% 250/250 [00:00<00:00, 1102.92it/s]
# 2024-03-29:11:40:08,181 INFO     [task.py:395] Building contexts for bbh_fewshot_logical_deduction_five_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1054.27it/s]
# 2024-03-29:11:40:08,457 INFO     [task.py:395] Building contexts for bbh_fewshot_logical_deduction_three_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1054.47it/s]
# 2024-03-29:11:40:08,732 INFO     [task.py:395] Building contexts for bbh_fewshot_sports_understanding on rank 0...
# 100% 250/250 [00:00<00:00, 1210.31it/s]
# 2024-03-29:11:40:08,975 INFO     [task.py:395] Building contexts for bbh_fewshot_temporal_sequences on rank 0...
# 100% 250/250 [00:00<00:00, 956.86it/s]
# 2024-03-29:11:40:09,274 INFO     [task.py:395] Building contexts for bbh_fewshot_salient_translation_error_detection on rank 0...
# 100% 250/250 [00:00<00:00, 749.11it/s]
# 2024-03-29:11:40:09,648 INFO     [task.py:395] Building contexts for bbh_fewshot_movie_recommendation on rank 0...
# 100% 250/250 [00:00<00:00, 1129.52it/s]
# 2024-03-29:11:40:09,907 INFO     [task.py:395] Building contexts for bbh_fewshot_web_of_lies on rank 0...
# 100% 250/250 [00:00<00:00, 1160.30it/s]
# 2024-03-29:11:40:10,159 INFO     [task.py:395] Building contexts for bbh_fewshot_object_counting on rank 0...
# 100% 250/250 [00:00<00:00, 1175.62it/s]
# 2024-03-29:11:40:10,408 INFO     [task.py:395] Building contexts for bbh_fewshot_hyperbaton on rank 0...
# 100% 250/250 [00:00<00:00, 1175.04it/s]
# 2024-03-29:11:40:10,657 INFO     [task.py:395] Building contexts for bbh_fewshot_tracking_shuffled_objects_three_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1025.08it/s]
# 2024-03-29:11:40:10,939 INFO     [task.py:395] Building contexts for bbh_fewshot_tracking_shuffled_objects_five_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1026.08it/s]
# 2024-03-29:11:40:11,220 INFO     [evaluator.py:379] Running generate_until requests
# 2024-03-29:11:40:11,222 INFO     [model.py:225] Loading 'generate_until' responses from cache 'results_dir_awq_bbh_rank0.db' where possible...
# Checking cached requests: 100% 6511/6511 [00:01<00:00, 6096.42it/s]
# 2024-03-29:11:40:12,291 INFO     [model.py:249] Cached requests: 0, Requests remaining: 6511
# Running generate_until requests:   0% 0/6511 [00:00<?, ?it/s]Passed argument batch_size = auto. Detecting largest batch size
# Determined Largest batch size: 8
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:410: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:415: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Running generate_until requests: 100% 6511/6511 [35:53<00:00,  3.02it/s]
# {
#   "results": {
#     "bbh_fewshot": {
#       "exact_match,none": 0.3337428966364614,
#       "exact_match_stderr,none": 0.005436618189240069,
#       "alias": "bbh_fewshot"
#     },
#     "bbh_fewshot_boolean_expressions": {
#       "exact_match,none": 0.744,
#       "exact_match_stderr,none": 0.027657108718204905,
#       "alias": " - bbh_fewshot_boolean_expressions"
#     },
#     "bbh_fewshot_causal_judgement": {
#       "exact_match,none": 0.5347593582887701,
#       "exact_match_stderr,none": 0.03657308098518922,
#       "alias": " - bbh_fewshot_causal_judgement"
#     },
#     "bbh_fewshot_date_understanding": {
#       "exact_match,none": 0.384,
#       "exact_match_stderr,none": 0.03082167911737537,
#       "alias": " - bbh_fewshot_date_understanding"
#     },
#     "bbh_fewshot_disambiguation_qa": {
#       "exact_match,none": 0.34,
#       "exact_match_stderr,none": 0.030020073605457907,
#       "alias": " - bbh_fewshot_disambiguation_qa"
#     },
#     "bbh_fewshot_dyck_languages": {
#       "exact_match,none": 0.06,
#       "exact_match_stderr,none": 0.015050117079158754,
#       "alias": " - bbh_fewshot_dyck_languages"
#     },
#     "bbh_fewshot_formal_fallacies": {
#       "exact_match,none": 0.5,
#       "exact_match_stderr,none": 0.031686212526223896,
#       "alias": " - bbh_fewshot_formal_fallacies"
#     },
#     "bbh_fewshot_geometric_shapes": {
#       "exact_match,none": 0.34,
#       "exact_match_stderr,none": 0.030020073605457907,
#       "alias": " - bbh_fewshot_geometric_shapes"
#     },
#     "bbh_fewshot_hyperbaton": {
#       "exact_match,none": 0.52,
#       "exact_match_stderr,none": 0.031660853408495185,
#       "alias": " - bbh_fewshot_hyperbaton"
#     },
#     "bbh_fewshot_logical_deduction_five_objects": {
#       "exact_match,none": 0.264,
#       "exact_match_stderr,none": 0.027934518957690908,
#       "alias": " - bbh_fewshot_logical_deduction_five_objects"
#     },
#     "bbh_fewshot_logical_deduction_seven_objects": {
#       "exact_match,none": 0.188,
#       "exact_match_stderr,none": 0.024760377727750502,
#       "alias": " - bbh_fewshot_logical_deduction_seven_objects"
#     },
#     "bbh_fewshot_logical_deduction_three_objects": {
#       "exact_match,none": 0.376,
#       "exact_match_stderr,none": 0.030696336267394583,
#       "alias": " - bbh_fewshot_logical_deduction_three_objects"
#     },
#     "bbh_fewshot_movie_recommendation": {
#       "exact_match,none": 0.556,
#       "exact_match_stderr,none": 0.03148684942554575,
#       "alias": " - bbh_fewshot_movie_recommendation"
#     },
#     "bbh_fewshot_multistep_arithmetic_two": {
#       "exact_match,none": 0.008,
#       "exact_match_stderr,none": 0.005645483676690161,
#       "alias": " - bbh_fewshot_multistep_arithmetic_two"
#     },
#     "bbh_fewshot_navigate": {
#       "exact_match,none": 0.468,
#       "exact_match_stderr,none": 0.031621252575725504,
#       "alias": " - bbh_fewshot_navigate"
#     },
#     "bbh_fewshot_object_counting": {
#       "exact_match,none": 0.296,
#       "exact_match_stderr,none": 0.028928939388379628,
#       "alias": " - bbh_fewshot_object_counting"
#     },
#     "bbh_fewshot_penguins_in_a_table": {
#       "exact_match,none": 0.2534246575342466,
#       "exact_match_stderr,none": 0.03612245461624573,
#       "alias": " - bbh_fewshot_penguins_in_a_table"
#     },
#     "bbh_fewshot_reasoning_about_colored_objects": {
#       "exact_match,none": 0.188,
#       "exact_match_stderr,none": 0.02476037772775051,
#       "alias": " - bbh_fewshot_reasoning_about_colored_objects"
#     },
#     "bbh_fewshot_ruin_names": {
#       "exact_match,none": 0.256,
#       "exact_match_stderr,none": 0.027657108718204912,
#       "alias": " - bbh_fewshot_ruin_names"
#     },
#     "bbh_fewshot_salient_translation_error_detection": {
#       "exact_match,none": 0.26,
#       "exact_match_stderr,none": 0.0277973157526443,
#       "alias": " - bbh_fewshot_salient_translation_error_detection"
#     },
#     "bbh_fewshot_snarks": {
#       "exact_match,none": 0.4943820224719101,
#       "exact_match_stderr,none": 0.03757992900475981,
#       "alias": " - bbh_fewshot_snarks"
#     },
#     "bbh_fewshot_sports_understanding": {
#       "exact_match,none": 0.576,
#       "exact_match_stderr,none": 0.03131803437491615,
#       "alias": " - bbh_fewshot_sports_understanding"
#     },
#     "bbh_fewshot_temporal_sequences": {
#       "exact_match,none": 0.148,
#       "exact_match_stderr,none": 0.022503547243806134,
#       "alias": " - bbh_fewshot_temporal_sequences"
#     },
#     "bbh_fewshot_tracking_shuffled_objects_five_objects": {
#       "exact_match,none": 0.176,
#       "exact_match_stderr,none": 0.02413349752545711,
#       "alias": " - bbh_fewshot_tracking_shuffled_objects_five_objects"
#     },
#     "bbh_fewshot_tracking_shuffled_objects_seven_objects": {
#       "exact_match,none": 0.124,
#       "exact_match_stderr,none": 0.02088638225867326,
#       "alias": " - bbh_fewshot_tracking_shuffled_objects_seven_objects"
#     },
#     "bbh_fewshot_tracking_shuffled_objects_three_objects": {
#       "exact_match,none": 0.332,
#       "exact_match_stderr,none": 0.029844039047465905,
#       "alias": " - bbh_fewshot_tracking_shuffled_objects_three_objects"
#     },
#     "bbh_fewshot_web_of_lies": {
#       "exact_match,none": 0.488,
#       "exact_match_stderr,none": 0.03167708558254708,
#       "alias": " - bbh_fewshot_web_of_lies"
#     },
#     "bbh_fewshot_word_sorting": {
#       "exact_match,none": 0.2,
#       "exact_match_stderr,none": 0.025348970020979078,
#       "alias": " - bbh_fewshot_word_sorting"
#     }
#   },
#   "groups": {
#     "bbh_fewshot": {
#       "exact_match,none": 0.3337428966364614,
#       "exact_match_stderr,none": 0.005436618189240069,
#       "alias": "bbh_fewshot"
#     }
#   },
#   "group_subtasks": {
#     "bbh_fewshot": [
#       "bbh_fewshot_penguins_in_a_table",
#       "bbh_fewshot_logical_deduction_seven_objects",
#       "bbh_fewshot_multistep_arithmetic_two",
#       "bbh_fewshot_disambiguation_qa",
#       "bbh_fewshot_causal_judgement",
#       "bbh_fewshot_dyck_languages",
#       "bbh_fewshot_snarks",
#       "bbh_fewshot_boolean_expressions",
#       "bbh_fewshot_formal_fallacies",
#       "bbh_fewshot_date_understanding",
#       "bbh_fewshot_navigate",
#       "bbh_fewshot_reasoning_about_colored_objects",
#       "bbh_fewshot_word_sorting",
#       "bbh_fewshot_ruin_names",
#       "bbh_fewshot_tracking_shuffled_objects_seven_objects",
#       "bbh_fewshot_geometric_shapes",
#       "bbh_fewshot_logical_deduction_five_objects",
#       "bbh_fewshot_logical_deduction_three_objects",
#       "bbh_fewshot_sports_understanding",
#       "bbh_fewshot_temporal_sequences",
#       "bbh_fewshot_salient_translation_error_detection",
#       "bbh_fewshot_movie_recommendation",
#       "bbh_fewshot_web_of_lies",
#       "bbh_fewshot_object_counting",
#       "bbh_fewshot_hyperbaton",
#       "bbh_fewshot_tracking_shuffled_objects_three_objects",
#       "bbh_fewshot_tracking_shuffled_objects_five_objects"
#     ]
#   },
#   "configs": {
#     "bbh_fewshot_boolean_expressions": {
#       "task": "bbh_fewshot_boolean_expressions",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "boolean_expressions",
#       "test_split": "test",
#       "doc_to_text": "Q: not ( ( not not True ) ) is\nA: False\n\nQ: True and False and not True and True is\nA: False\n\nQ: not not ( not ( False ) ) is\nA: True\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Evaluate the result of a random Boolean expression.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_causal_judgement": {
#       "task": "bbh_fewshot_causal_judgement",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "causal_judgement",
#       "test_split": "test",
#       "doc_to_text": "Q: How would a typical person answer each of the following questions about causation?\nFrank T., had an ongoing dispute with his neighbor over a stretch of land and one day decided to shoot his neighbor in the body. Frank T. had no experience with guns, his hand slipped on the barrel of the gun, and the shot went wild. Nonetheless, the bullet bounced off a large boulder several feet away and hit the neighbor's body, causing significant injury. Did Frank T. intentionally shoot his neighbor in the body?\nOptions:\n- Yes\n- No\nA: No\n\nQ: How would a typical person answer each of the following questions about causation?\nSuzy and Billy are working on a project that is very important for our nation's security. The boss tells them both: \"Be sure that you are here at exactly 9 am. It is absolutely essential that you arrive at that time.\" Both Billy and Suzy arrive at 9 am. As it happens, there was a motion detector installed in the room where they arrived. The motion detector was set up to be triggered if at least one person appeared in the room at the same time. So the motion detector went off. Did Billy cause the motion detector to go off?\nOptions:\n- Yes\n- No\nA: Yes\n\nQ: How would a typical person answer each of the following questions about causation?\nGeorge and his sister Lena reunite at their parents' house for Thanksgiving. Whereas George just got into medical school, Lena is unhappy in her marriage and recently lost her job. Over the course of the day, George and Lena get into a number of heated arguments. Later in the afternoon they play a game of darts. They split the first two games, and the third game is close until the end. Who will win comes down to George's last shot. If he hits a high point region, he wins; if he hits a low point region, Lena wins. George thinks of the difficult time Lena is having, and he really wants to let her win. He aims the dart at the low point region. He sets up his shot and the dart lands in the low point region. After his shot, Lena wins the game and is very happy. Did George hit the low point region intentionally?\nOptions:\n- Yes\n- No\nA: Yes\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Answer questions about causal attribution.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_date_understanding": {
#       "task": "bbh_fewshot_date_understanding",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "date_understanding",
#       "test_split": "test",
#       "doc_to_text": "Q: Today is Christmas Eve of 1937. What is the date 10 days ago in MM/DD/YYYY?\nOptions:\n(A) 12/14/2026\n(B) 12/14/1950\n(C) 12/14/2007\n(D) 12/14/1937\n(E) 07/14/1938\n(F) 12/14/1988\nA: (D)\n\nQ: Tomorrow is 11/12/2019. What is the date one year ago from today in MM/DD/YYYY?\nOptions:\n(A) 09/04/2018\n(B) 11/11/2018\n(C) 08/25/2018\n(D) 11/02/2018\n(E) 11/04/2018\nA: (B)\n\nQ: Jane and John married on Jan 2, 1958. It is their 5-year anniversary today. What is the date tomorrow in MM/DD/YYYY?\nOptions:\n(A) 01/11/1961\n(B) 01/03/1963\n(C) 01/18/1961\n(D) 10/14/1960\n(E) 01/03/1982\n(F) 12/03/1960\nA: (B)\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Infer the date from context.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_disambiguation_qa": {
#       "task": "bbh_fewshot_disambiguation_qa",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "disambiguation_qa",
#       "test_split": "test",
#       "doc_to_text": "Q: In the following sentences, explain the antecedent of the pronoun (which thing the pronoun refers to), or state that it is ambiguous.\nSentence: The chief told the counselor that they took the day off.\nOptions:\n(A) The chief took the day off\n(B) The counselor took the day off\n(C) Ambiguous\nA: (A)\n\nQ: In the following sentences, explain the antecedent of the pronoun (which thing the pronoun refers to), or state that it is ambiguous.\nSentence: The manager sent a message to the secretary, but he didn't reply yet.\nOptions:\n(A) The secretary didn't reply yet\n(B) The manager didn't reply yet\n(C) Ambiguous\nA: (A)\n\nQ: In the following sentences, explain the antecedent of the pronoun (which thing the pronoun refers to), or state that it is ambiguous.\nSentence: Bailey will plan to meet the director at his office\nOptions:\n(A) It will be Bailey's office\n(B) It will be the director's office\n(C) Ambiguous\nA: (C)\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Clarify the meaning of sentences with ambiguous pronouns.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_dyck_languages": {
#       "task": "bbh_fewshot_dyck_languages",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "dyck_languages",
#       "test_split": "test",
#       "doc_to_text": "Q: Complete the rest of the sequence, making sure that the parentheses are closed properly. Input: [ { [\nA: ] } ]\n\nQ: Complete the rest of the sequence, making sure that the parentheses are closed properly. Input: < > ( ( [ [ ( { } ) [ < > ] ]\nA: ] ) )\n\nQ: Complete the rest of the sequence, making sure that the parentheses are closed properly. Input: < [ < [ { < [ ] < { } > > } ] > { { ( ) } { < [ < > ] > }\nA: } ] >\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Correctly close a Dyck-n word.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_formal_fallacies": {
#       "task": "bbh_fewshot_formal_fallacies",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "formal_fallacies",
#       "test_split": "test",
#       "doc_to_text": "Q: \"It is not always easy to see who is related to whom -- and in which ways. The following argument pertains to this question: To begin with, Lesley is a close friend of Fernando. Moreover, being a close friend of Fernando or a schoolmate of Lowell is sufficient for being a great-grandfather of Leroy. It follows that Lesley is a great-grandfather of Leroy.\"\nIs the argument, given the explicitly stated premises, deductively valid or invalid?\nOptions:\n- valid\n- invalid\nA: valid\n\nQ: \"It is not always easy to see who is related to whom -- and in which ways. The following argument pertains to this question: Whoever is not a great-grandfather of Clyde is a stepbrother of Brian. Being an ancestor of Dana is sufficient for not being a great-grandfather of Clyde. We may conclude: Everyone who is an ancestor of Dana is a stepbrother of Brian, too.\"\nIs the argument, given the explicitly stated premises, deductively valid or invalid?\nOptions:\n- valid\n- invalid\nA: valid\n\nQ: \"It is not always easy to grasp who is consuming which products. The following argument pertains to this question: Every infrequent user of Paul Mitchell shampoo is either a rare consumer of Nioxin shampoo or a loyal buyer of Caress soap, or both. No regular consumer of Lush soap is a rare consumer of Nioxin shampoo and, in the same time, a loyal buyer of Caress soap. It follows that whoever is an infrequent user of Paul Mitchell shampoo is not a regular consumer of Lush soap.\"\nIs the argument, given the explicitly stated premises, deductively valid or invalid?\nOptions:\n- valid\n- invalid\nA: invalid\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Distinguish deductively valid arguments from formal fallacies.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_geometric_shapes": {
#       "task": "bbh_fewshot_geometric_shapes",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "geometric_shapes",
#       "test_split": "test",
#       "doc_to_text": "Q: This SVG path element <path d=\"M 31.00,73.00 L 32.00,59.00 L 44.00,50.00 L 49.00,41.00 L 64.00,37.00 L 71.00,55.00 L 64.00,76.00 L 52.00,61.00 L 31.00,73.00\"/> draws a\nOptions:\n(A) circle\n(B) heptagon\n(C) hexagon\n(D) kite\n(E) line\n(F) octagon\n(G) pentagon\n(H) rectangle\n(I) sector\n(J) triangle\nA: (F)\n\nQ: This SVG path element <path d=\"M 14.19,26.04 L 51.43,39.21 L 58.44,36.69 L 56.63,30.17 L 48.53,26.66 L 14.19,26.04\"/> draws a\nOptions:\n(A) circle\n(B) heptagon\n(C) hexagon\n(D) kite\n(E) line\n(F) octagon\n(G) pentagon\n(H) rectangle\n(I) sector\n(J) triangle\nA: (G)\n\nQ: This SVG path element <path d=\"M 41.00,43.00 L 37.00,34.00 L 41.00,33.00 L 45.00,34.00 L 41.00,43.00\"/> draws a\nOptions:\n(A) circle\n(B) heptagon\n(C) hexagon\n(D) kite\n(E) line\n(F) octagon\n(G) pentagon\n(H) rectangle\n(I) sector\n(J) triangle\nA: (D)\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Name geometric shapes from their SVG paths.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_hyperbaton": {
#       "task": "bbh_fewshot_hyperbaton",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "hyperbaton",
#       "test_split": "test",
#       "doc_to_text": "Q: Which sentence has the correct adjective order:\nOptions:\n(A) rubber terrible ship\n(B) terrible rubber ship\nA: (B)\n\nQ: Which sentence has the correct adjective order:\nOptions:\n(A) repulsive small Brazilian exercise ship\n(B) Brazilian repulsive exercise small ship\nA: (A)\n\nQ: Which sentence has the correct adjective order:\nOptions:\n(A) blue gold wonderful square shoe\n(B) wonderful square blue gold shoe\nA: (B)\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Order adjectives correctly in English sentences.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
# ...
# |                        Tasks                         |Version|Filter|n-shot|  Metric   |Value |   |Stderr|
# |------------------------------------------------------|-------|------|-----:|-----------|-----:|---|-----:|
# |bbh_fewshot                                           |N/A    |none  |     3|exact_match|0.3337|±  |0.0054|
# | - bbh_fewshot_boolean_expressions                    |      1|none  |     3|exact_match|0.7440|±  |0.0277|
# | - bbh_fewshot_causal_judgement                       |      1|none  |     3|exact_match|0.5348|±  |0.0366|
# | - bbh_fewshot_date_understanding                     |      1|none  |     3|exact_match|0.3840|±  |0.0308|
# | - bbh_fewshot_disambiguation_qa                      |      1|none  |     3|exact_match|0.3400|±  |0.0300|
# | - bbh_fewshot_dyck_languages                         |      1|none  |     3|exact_match|0.0600|±  |0.0151|
# | - bbh_fewshot_formal_fallacies                       |      1|none  |     3|exact_match|0.5000|±  |0.0317|
# | - bbh_fewshot_geometric_shapes                       |      1|none  |     3|exact_match|0.3400|±  |0.0300|
# | - bbh_fewshot_hyperbaton                             |      1|none  |     3|exact_match|0.5200|±  |0.0317|
# | - bbh_fewshot_logical_deduction_five_objects         |      1|none  |     3|exact_match|0.2640|±  |0.0279|
# | - bbh_fewshot_logical_deduction_seven_objects        |      1|none  |     3|exact_match|0.1880|±  |0.0248|
# | - bbh_fewshot_logical_deduction_three_objects        |      1|none  |     3|exact_match|0.3760|±  |0.0307|
# | - bbh_fewshot_movie_recommendation                   |      1|none  |     3|exact_match|0.5560|±  |0.0315|
# | - bbh_fewshot_multistep_arithmetic_two               |      1|none  |     3|exact_match|0.0080|±  |0.0056|
# | - bbh_fewshot_navigate                               |      1|none  |     3|exact_match|0.4680|±  |0.0316|
# | - bbh_fewshot_object_counting                        |      1|none  |     3|exact_match|0.2960|±  |0.0289|
# | - bbh_fewshot_penguins_in_a_table                    |      1|none  |     3|exact_match|0.2534|±  |0.0361|
# | - bbh_fewshot_reasoning_about_colored_objects        |      1|none  |     3|exact_match|0.1880|±  |0.0248|
# | - bbh_fewshot_ruin_names                             |      1|none  |     3|exact_match|0.2560|±  |0.0277|
# | - bbh_fewshot_salient_translation_error_detection    |      1|none  |     3|exact_match|0.2600|±  |0.0278|
# | - bbh_fewshot_snarks                                 |      1|none  |     3|exact_match|0.4944|±  |0.0376|
# | - bbh_fewshot_sports_understanding                   |      1|none  |     3|exact_match|0.5760|±  |0.0313|
# | - bbh_fewshot_temporal_sequences                     |      1|none  |     3|exact_match|0.1480|±  |0.0225|
# | - bbh_fewshot_tracking_shuffled_objects_five_objects |      1|none  |     3|exact_match|0.1760|±  |0.0241|
# | - bbh_fewshot_tracking_shuffled_objects_seven_objects|      1|none  |     3|exact_match|0.1240|±  |0.0209|
# | - bbh_fewshot_tracking_shuffled_objects_three_objects|      1|none  |     3|exact_match|0.3320|±  |0.0298|
# | - bbh_fewshot_web_of_lies                            |      1|none  |     3|exact_match|0.4880|±  |0.0317|
# | - bbh_fewshot_word_sorting                           |      1|none  |     3|exact_match|0.2000|±  |0.0253|
#
# |  Groups   |Version|Filter|n-shot|  Metric   |Value |   |Stderr|
# |-----------|-------|------|-----:|-----------|-----:|---|-----:|
# |bbh_fewshot|N/A    |none  |     3|exact_match|0.3337|±  |0.0054|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:                                                bbh_fewshot/exact_match ▁
# wandb:                                         bbh_fewshot/exact_match_stderr ▁
# wandb:                            bbh_fewshot_boolean_expressions/exact_match ▁
# wandb:                     bbh_fewshot_boolean_expressions/exact_match_stderr ▁
# wandb:                               bbh_fewshot_causal_judgement/exact_match ▁
# wandb:                        bbh_fewshot_causal_judgement/exact_match_stderr ▁
# wandb:                             bbh_fewshot_date_understanding/exact_match ▁
# wandb:                      bbh_fewshot_date_understanding/exact_match_stderr ▁
# wandb:                              bbh_fewshot_disambiguation_qa/exact_match ▁
# wandb:                       bbh_fewshot_disambiguation_qa/exact_match_stderr ▁
# wandb:                                 bbh_fewshot_dyck_languages/exact_match ▁
# wandb:                          bbh_fewshot_dyck_languages/exact_match_stderr ▁
# wandb:                               bbh_fewshot_formal_fallacies/exact_match ▁
# wandb:                        bbh_fewshot_formal_fallacies/exact_match_stderr ▁
# wandb:                               bbh_fewshot_geometric_shapes/exact_match ▁
# wandb:                        bbh_fewshot_geometric_shapes/exact_match_stderr ▁
# wandb:                                     bbh_fewshot_hyperbaton/exact_match ▁
# wandb:                              bbh_fewshot_hyperbaton/exact_match_stderr ▁
# wandb:                 bbh_fewshot_logical_deduction_five_objects/exact_match ▁
# wandb:          bbh_fewshot_logical_deduction_five_objects/exact_match_stderr ▁
# wandb:                bbh_fewshot_logical_deduction_seven_objects/exact_match ▁
# wandb:         bbh_fewshot_logical_deduction_seven_objects/exact_match_stderr ▁
# wandb:                bbh_fewshot_logical_deduction_three_objects/exact_match ▁
# wandb:         bbh_fewshot_logical_deduction_three_objects/exact_match_stderr ▁
# wandb:                           bbh_fewshot_movie_recommendation/exact_match ▁
# wandb:                    bbh_fewshot_movie_recommendation/exact_match_stderr ▁
# wandb:                       bbh_fewshot_multistep_arithmetic_two/exact_match ▁
# wandb:                bbh_fewshot_multistep_arithmetic_two/exact_match_stderr ▁
# wandb:                                       bbh_fewshot_navigate/exact_match ▁
# wandb:                                bbh_fewshot_navigate/exact_match_stderr ▁
# wandb:                                bbh_fewshot_object_counting/exact_match ▁
# wandb:                         bbh_fewshot_object_counting/exact_match_stderr ▁
# wandb:                            bbh_fewshot_penguins_in_a_table/exact_match ▁
# wandb:                     bbh_fewshot_penguins_in_a_table/exact_match_stderr ▁
# wandb:                bbh_fewshot_reasoning_about_colored_objects/exact_match ▁
# wandb:         bbh_fewshot_reasoning_about_colored_objects/exact_match_stderr ▁
# wandb:                                     bbh_fewshot_ruin_names/exact_match ▁
# wandb:                              bbh_fewshot_ruin_names/exact_match_stderr ▁
# wandb:            bbh_fewshot_salient_translation_error_detection/exact_match ▁
# wandb:     bbh_fewshot_salient_translation_error_detection/exact_match_stderr ▁
# wandb:                                         bbh_fewshot_snarks/exact_match ▁
# wandb:                                  bbh_fewshot_snarks/exact_match_stderr ▁
# wandb:                           bbh_fewshot_sports_understanding/exact_match ▁
# wandb:                    bbh_fewshot_sports_understanding/exact_match_stderr ▁
# wandb:                             bbh_fewshot_temporal_sequences/exact_match ▁
# wandb:                      bbh_fewshot_temporal_sequences/exact_match_stderr ▁
# wandb:         bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match ▁
# wandb:  bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match_stderr ▁
# wandb:        bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match ▁
# wandb: bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match_stderr ▁
# wandb:        bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match ▁
# wandb: bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match_stderr ▁
# wandb:                                    bbh_fewshot_web_of_lies/exact_match ▁
# wandb:                             bbh_fewshot_web_of_lies/exact_match_stderr ▁
# wandb:                                   bbh_fewshot_word_sorting/exact_match ▁
# wandb:                            bbh_fewshot_word_sorting/exact_match_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:                                                      bbh_fewshot/alias bbh_fewshot
# wandb:                                                bbh_fewshot/exact_match 0.33374
# wandb:                                         bbh_fewshot/exact_match_stderr 0.00544
# wandb:                                  bbh_fewshot_boolean_expressions/alias  - bbh_fewshot_boole...
# wandb:                            bbh_fewshot_boolean_expressions/exact_match 0.744
# wandb:                     bbh_fewshot_boolean_expressions/exact_match_stderr 0.02766
# wandb:                                     bbh_fewshot_causal_judgement/alias  - bbh_fewshot_causa...
# wandb:                               bbh_fewshot_causal_judgement/exact_match 0.53476
# wandb:                        bbh_fewshot_causal_judgement/exact_match_stderr 0.03657
# wandb:                                   bbh_fewshot_date_understanding/alias  - bbh_fewshot_date_...
# wandb:                             bbh_fewshot_date_understanding/exact_match 0.384
# wandb:                      bbh_fewshot_date_understanding/exact_match_stderr 0.03082
# wandb:                                    bbh_fewshot_disambiguation_qa/alias  - bbh_fewshot_disam...
# wandb:                              bbh_fewshot_disambiguation_qa/exact_match 0.34
# wandb:                       bbh_fewshot_disambiguation_qa/exact_match_stderr 0.03002
# wandb:                                       bbh_fewshot_dyck_languages/alias  - bbh_fewshot_dyck_...
# wandb:                                 bbh_fewshot_dyck_languages/exact_match 0.06
# wandb:                          bbh_fewshot_dyck_languages/exact_match_stderr 0.01505
# wandb:                                     bbh_fewshot_formal_fallacies/alias  - bbh_fewshot_forma...
# wandb:                               bbh_fewshot_formal_fallacies/exact_match 0.5
# wandb:                                               bbh_fewshot_snarks/alias  - bbh_fewshot_snark...
# wandb:                                         bbh_fewshot_snarks/exact_match 0.49438
# wandb:                                  bbh_fewshot_snarks/exact_match_stderr 0.03758
# wandb:                                 bbh_fewshot_sports_understanding/alias  - bbh_fewshot_sport...
# wandb:                           bbh_fewshot_sports_understanding/exact_match 0.576
# wandb:                    bbh_fewshot_sports_understanding/exact_match_stderr 0.03132
# wandb:                                   bbh_fewshot_temporal_sequences/alias  - bbh_fewshot_tempo...
# wandb:                             bbh_fewshot_temporal_sequences/exact_match 0.148
# wandb:                      bbh_fewshot_temporal_sequences/exact_match_stderr 0.0225
# wandb:               bbh_fewshot_tracking_shuffled_objects_five_objects/alias  - bbh_fewshot_track...
# wandb:         bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match 0.176
# wandb:  bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match_stderr 0.02413
# wandb:              bbh_fewshot_tracking_shuffled_objects_seven_objects/alias  - bbh_fewshot_track...
# wandb:        bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match 0.124
# wandb: bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match_stderr 0.02089
# wandb:              bbh_fewshot_tracking_shuffled_objects_three_objects/alias  - bbh_fewshot_track...
# wandb:        bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match 0.332
# wandb: bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match_stderr 0.02984
# wandb:                                          bbh_fewshot_web_of_lies/alias  - bbh_fewshot_web_o...
# wandb:                                    bbh_fewshot_web_of_lies/exact_match 0.488
# wandb:                             bbh_fewshot_web_of_lies/exact_match_stderr 0.03168
# wandb:                                         bbh_fewshot_word_sorting/alias  - bbh_fewshot_word_...
# wandb:                                   bbh_fewshot_word_sorting/exact_match 0.2
# wandb:                            bbh_fewshot_word_sorting/exact_match_stderr 0.02535
# wandb:
# wandb: 🚀 View run Llama-2-7b-chat-hf-AWQ-bbh1 at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/1e9wpvxg/workspace
# wandb: Synced 5 W&B file(s), 3 media file(s), 4 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240329_113723-1e9wpvxg/logs

# %% [markdown]
# # GPTQ Evaluation

# %% [markdown]
# ### Evaluate Llama-2-7b-hf-AutoGPTQ

# %%
eval_model = "twhoool02/Llama-2-7b-chat-hf-AutoGPTQ"

# create directory to store results
results_dir = f"/content/drive/MyDrive/Evaluation/{eval_model}"
os.makedirs(results_dir, exist_ok=True)

# %% [markdown]
# #### MMLU
#
# 5-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Llama-2-7b-chat-hf-AutoGPTQ,trust_remote_code=True,revision="b63b90c0fc11dfe983fb80172de0a8b8ae89224e" \
    --tasks mmlu_stem,mmlu_social_sciences,mmlu_humanities,mmlu_other \
    --num_fewshot 5 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir_gptq_mmlu \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Llama-2-7b-hf-AutoGPTQ-mmlu \
    --use_cache results_dir_gptq_mmlu \
    --cache_requests true \
    --show_config
# Out:
# 2024-04-03 23:00:59.674547: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-03 23:00:59.674599: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-03 23:00:59.676427: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-03 23:01:00.895826: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.6
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240403_230106-riufy7f1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Llama-2-7b-hf-AutoGPTQ-mmlu
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/riufy7f1
# 2024-04-03:23:01:07,766 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-04-03:23:01:13,870 INFO     [__main__.py:335] Selected Tasks: ['mmlu_humanities', 'mmlu_other', 'mmlu_social_sciences', 'mmlu_stem']
# 2024-04-03:23:01:13,871 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-04-03:23:01:13,872 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Llama-2-7b-chat-hf-AutoGPTQ', 'trust_remote_code': True, 'revision': 'b63b90c0fc11dfe983fb80172de0a8b8ae89224e'}
# 2024-04-03:23:01:13,876 INFO     [huggingface.py:163] Using device 'cuda:0'
# config.json: 100% 1.29k/1.29k [00:00<00:00, 3.48MB/s]
# model.safetensors: 100% 3.90G/3.90G [00:13<00:00, 296MB/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4193: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# The cos_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class
# The sin_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class
# generation_config.json: 100% 183/183 [00:00<00:00, 592kB/s]
# tokenizer_config.json: 100% 1.76k/1.76k [00:00<00:00, 5.82MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 175MB/s]
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 1.85MB/s]
# special_tokens_map.json: 100% 437/437 [00:00<00:00, 1.11MB/s]
# 2024-04-03:23:01:37,423 INFO     [evaluator.py:195] Using cache at results_dir_gptq_mmlu_rank0.db
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 5.86k/5.86k [00:00<00:00, 14.1MB/s]
# Downloading readme: 100% 1.11k/1.11k [00:00<00:00, 3.51MB/s]
# Downloading data: 100% 166M/166M [00:01<00:00, 86.3MB/s]
# Generating test split: 311 examples [00:00, 2656.27 examples/s]
# Generating validation split: 34 examples [00:00, 7136.38 examples/s]
# Generating dev split: 5 examples [00:00, 51.31 examples/s]
# Generating test split: 126 examples [00:00, 1381.41 examples/s]
# Generating validation split: 14 examples [00:00, 3198.62 examples/s]
# Generating dev split: 5 examples [00:00, 59.98 examples/s]
# Generating test split: 163 examples [00:00, 1820.82 examples/s]
# Generating validation split: 18 examples [00:00, 3426.87 examples/s]
# Generating dev split: 5 examples [00:00, 58.12 examples/s]
# Generating test split: 108 examples [00:00, 1244.38 examples/s]
# Generating validation split: 11 examples [00:00, 1952.24 examples/s]
# Generating dev split: 5 examples [00:00, 55.53 examples/s]
# Generating test split: 171 examples [00:00, 1834.29 examples/s]
# Generating validation split: 19 examples [00:00, 4201.82 examples/s]
# Generating dev split: 5 examples [00:00, 57.18 examples/s]
# Generating test split: 895 examples [00:00, 6052.58 examples/s]
# Generating validation split: 100 examples [00:00, 10589.27 examples/s]
# Generating dev split: 5 examples [00:00, 57.45 examples/s]
# Generating test split: 1534 examples [00:00, 8243.46 examples/s]
# Generating validation split: 170 examples [00:00, 10892.30 examples/s]
# Generating dev split: 5 examples [00:00, 56.91 examples/s]
# Generating test split: 204 examples [00:00, 2104.38 examples/s]
# Generating validation split: 22 examples [00:00, 3285.55 examples/s]
# Generating dev split: 5 examples [00:00, 57.16 examples/s]
# Generating test split: 324 examples [00:00, 3170.28 examples/s]
# Generating validation split: 35 examples [00:00, 5929.66 examples/s]
# Generating dev split: 5 examples [00:00, 58.97 examples/s]
# Generating test split: 346 examples [00:00, 3373.81 examples/s]
# Generating validation split: 38 examples [00:00, 5125.20 examples/s]
# Generating dev split: 5 examples [00:00, 58.59 examples/s]
# Generating test split: 165 examples [00:00, 1810.74 examples/s]
# Generating validation split: 18 examples [00:00, 2850.57 examples/s]
# Generating dev split: 5 examples [00:00, 59.72 examples/s]
# Generating test split: 121 examples [00:00, 1374.83 examples/s]
# Generating validation split: 13 examples [00:00, 2787.77 examples/s]
# Generating dev split: 5 examples [00:00, 58.88 examples/s]
# Generating test split: 237 examples [00:00, 2360.53 examples/s]
# Generating validation split: 26 examples [00:00, 3611.83 examples/s]
# Generating dev split: 5 examples [00:00, 57.81 examples/s]
# Generating test split: 166 examples [00:00, 1881.01 examples/s]
# Generating validation split: 18 examples [00:00, 3590.50 examples/s]
# Generating dev split: 5 examples [00:00, 59.57 examples/s]
# Generating test split: 234 examples [00:00, 2501.48 examples/s]
# Generating validation split: 25 examples [00:00, 4452.93 examples/s]
# Generating dev split: 5 examples [00:00, 58.97 examples/s]
# Generating test split: 272 examples [00:00, 2647.50 examples/s]
# Generating validation split: 31 examples [00:00, 5235.70 examples/s]
# Generating dev split: 5 examples [00:00, 58.63 examples/s]
# Generating test split: 306 examples [00:00, 3189.62 examples/s]
# Generating validation split: 33 examples [00:00, 6090.74 examples/s]
# Generating dev split: 5 examples [00:00, 59.79 examples/s]
# Generating test split: 783 examples [00:00, 6148.06 examples/s]
# Generating validation split: 86 examples [00:00, 11238.48 examples/s]
# Generating dev split: 5 examples [00:00, 58.17 examples/s]
# Generating test split: 100 examples [00:00, 1178.35 examples/s]
# Generating validation split: 10 examples [00:00, 3034.29 examples/s]
# Generating dev split: 5 examples [00:00, 58.22 examples/s]
# Generating test split: 100 examples [00:00, 1099.21 examples/s]
# Generating validation split: 11 examples [00:00, 3411.52 examples/s]
# Generating dev split: 5 examples [00:00, 58.21 examples/s]
# Generating test split: 223 examples [00:00, 2429.20 examples/s]
# Generating validation split: 23 examples [00:00, 4379.78 examples/s]
# Generating dev split: 5 examples [00:00, 59.87 examples/s]
# Generating test split: 103 examples [00:00, 1184.27 examples/s]
# Generating validation split: 11 examples [00:00, 2436.75 examples/s]
# Generating dev split: 5 examples [00:00, 55.12 examples/s]
# Generating test split: 265 examples [00:00, 2730.45 examples/s]
# Generating validation split: 29 examples [00:00, 6080.52 examples/s]
# Generating dev split: 5 examples [00:00, 54.83 examples/s]
# Generating test split: 173 examples [00:00, 1920.04 examples/s]
# Generating validation split: 22 examples [00:00, 5067.53 examples/s]
# Generating dev split: 5 examples [00:00, 59.53 examples/s]
# Generating test split: 100 examples [00:00, 1135.24 examples/s]
# Generating validation split: 11 examples [00:00, 2927.87 examples/s]
# Generating dev split: 5 examples [00:00, 55.97 examples/s]
# Generating test split: 282 examples [00:00, 2822.80 examples/s]
# Generating validation split: 31 examples [00:00, 4371.12 examples/s]
# Generating dev split: 5 examples [00:00, 59.70 examples/s]
# Generating test split: 201 examples [00:00, 2237.54 examples/s]
# Generating validation split: 22 examples [00:00, 3500.96 examples/s]
# Generating dev split: 5 examples [00:00, 59.22 examples/s]
# Generating test split: 110 examples [00:00, 1250.28 examples/s]
# Generating validation split: 12 examples [00:00, 2425.27 examples/s]
# Generating dev split: 5 examples [00:00, 59.24 examples/s]
# Generating test split: 238 examples [00:00, 2452.12 examples/s]
# Generating validation split: 26 examples [00:00, 4324.37 examples/s]
# Generating dev split: 5 examples [00:00, 58.34 examples/s]
# Generating test split: 100 examples [00:00, 1117.00 examples/s]
# Generating validation split: 11 examples [00:00, 2388.68 examples/s]
# Generating dev split: 5 examples [00:00, 59.18 examples/s]
# Generating test split: 245 examples [00:00, 2626.49 examples/s]
# Generating validation split: 27 examples [00:00, 3641.12 examples/s]
# Generating dev split: 5 examples [00:00, 57.38 examples/s]
# Generating test split: 545 examples [00:00, 4998.34 examples/s]
# Generating validation split: 60 examples [00:00, 7351.98 examples/s]
# Generating dev split: 5 examples [00:00, 58.23 examples/s]
# Generating test split: 193 examples [00:00, 2110.23 examples/s]
# Generating validation split: 21 examples [00:00, 5277.12 examples/s]
# Generating dev split: 5 examples [00:00, 59.84 examples/s]
# Generating test split: 612 examples [00:00, 5276.83 examples/s]
# Generating validation split: 69 examples [00:00, 7898.45 examples/s]
# Generating dev split: 5 examples [00:00, 58.60 examples/s]
# Generating test split: 390 examples [00:00, 3609.21 examples/s]
# Generating validation split: 43 examples [00:00, 7129.79 examples/s]
# Generating dev split: 5 examples [00:00, 56.90 examples/s]
# Generating test split: 114 examples [00:00, 1312.44 examples/s]
# Generating validation split: 12 examples [00:00, 2976.97 examples/s]
# Generating dev split: 5 examples [00:00, 58.45 examples/s]
# Generating test split: 198 examples [00:00, 2095.60 examples/s]
# Generating validation split: 22 examples [00:00, 6127.14 examples/s]
# Generating dev split: 5 examples [00:00, 59.95 examples/s]
# Generating test split: 131 examples [00:00, 1481.75 examples/s]
# Generating validation split: 12 examples [00:00, 2630.34 examples/s]
# Generating dev split: 5 examples [00:00, 57.38 examples/s]
# Generating test split: 203 examples [00:00, 2229.01 examples/s]
# Generating validation split: 22 examples [00:00, 3917.91 examples/s]
# Generating dev split: 5 examples [00:00, 60.07 examples/s]
# Generating test split: 270 examples [00:00, 2783.62 examples/s]
# Generating validation split: 29 examples [00:00, 6246.97 examples/s]
# Generating dev split: 5 examples [00:00, 56.68 examples/s]
# Generating test split: 100 examples [00:00, 1100.52 examples/s]
# Generating validation split: 11 examples [00:00, 2615.35 examples/s]
# Generating dev split: 5 examples [00:00, 56.50 examples/s]
# Generating test split: 151 examples [00:00, 1643.86 examples/s]
# Generating validation split: 17 examples [00:00, 3636.25 examples/s]
# Generating dev split: 5 examples [00:00, 57.51 examples/s]
# Generating test split: 152 examples [00:00, 1758.25 examples/s]
# Generating validation split: 16 examples [00:00, 4956.34 examples/s]
# Generating dev split: 5 examples [00:00, 58.93 examples/s]
# Generating test split: 100 examples [00:00, 1068.79 examples/s]
# Generating validation split: 11 examples [00:00, 2260.19 examples/s]
# Generating dev split: 5 examples [00:00, 56.44 examples/s]
# Generating test split: 102 examples [00:00, 1153.56 examples/s]
# Generating validation split: 11 examples [00:00, 3148.02 examples/s]
# Generating dev split: 5 examples [00:00, 59.35 examples/s]
# Generating test split: 100 examples [00:00, 1150.82 examples/s]
# Generating validation split: 9 examples [00:00, 2994.51 examples/s]
# Generating dev split: 5 examples [00:00, 59.22 examples/s]
# Generating test split: 100 examples [00:00, 1180.00 examples/s]
# Generating validation split: 11 examples [00:00, 3007.65 examples/s]
# Generating dev split: 5 examples [00:00, 59.24 examples/s]
# Generating test split: 100 examples [00:00, 1156.47 examples/s]
# Generating validation split: 11 examples [00:00, 2515.67 examples/s]
# Generating dev split: 5 examples [00:00, 58.79 examples/s]
# Generating test split: 216 examples [00:00, 2273.62 examples/s]
# Generating validation split: 23 examples [00:00, 4209.86 examples/s]
# Generating dev split: 5 examples [00:00, 58.12 examples/s]
# Generating test split: 112 examples [00:00, 1314.79 examples/s]
# Generating validation split: 11 examples [00:00, 3127.74 examples/s]
# Generating dev split: 5 examples [00:00, 57.91 examples/s]
# Generating test split: 145 examples [00:00, 1669.59 examples/s]
# Generating validation split: 16 examples [00:00, 3989.83 examples/s]
# Generating dev split: 5 examples [00:00, 58.93 examples/s]
# Generating test split: 144 examples [00:00, 1643.22 examples/s]
# Generating validation split: 16 examples [00:00, 2880.70 examples/s]
# Generating dev split: 5 examples [00:00, 59.09 examples/s]
# Generating test split: 378 examples [00:00, 3649.84 examples/s]
# Generating validation split: 41 examples [00:00, 6211.31 examples/s]
# Generating dev split: 5 examples [00:00, 59.57 examples/s]
# Generating test split: 100 examples [00:00, 1158.95 examples/s]
# Generating validation split: 8 examples [00:00, 1565.04 examples/s]
# Generating dev split: 5 examples [00:00, 53.58 examples/s]
# Generating test split: 135 examples [00:00, 1542.91 examples/s]
# Generating validation split: 14 examples [00:00, 4152.19 examples/s]
# Generating dev split: 5 examples [00:00, 54.08 examples/s]
# Generating test split: 310 examples [00:00, 3202.69 examples/s]
# Generating validation split: 32 examples [00:00, 6651.03 examples/s]
# Generating dev split: 5 examples [00:00, 58.55 examples/s]
# Generating test split: 235 examples [00:00, 2537.70 examples/s]
# Generating validation split: 26 examples [00:00, 6772.99 examples/s]
# Generating dev split: 5 examples [00:00, 58.04 examples/s]
# 2024-04-03:23:06:28,154 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 5
# 2024-04-03:23:06:28,154 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_biology from None to 5
# 2024-04-03:23:06:28,155 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_anatomy from None to 5
# 2024-04-03:23:06:28,155 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_chemistry from None to 5
# 2024-04-03:23:06:28,155 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 5
# 2024-04-03:23:06:28,155 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_biology from None to 5
# 2024-04-03:23:06:28,155 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 5
# 2024-04-03:23:06:28,155 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_machine_learning from None to 5
# 2024-04-03:23:06:28,155 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 5
# 2024-04-03:23:06:28,155 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_computer_security from None to 5
# 2024-04-03:23:06:28,155 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 5
# 2024-04-03:23:06:28,155 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 5
# 2024-04-03:23:06:28,155 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_physics from None to 5
# 2024-04-03:23:06:28,156 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_computer_science from None to 5
# 2024-04-03:23:06:28,156 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_astronomy from None to 5
# 2024-04-03:23:06:28,156 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_physics from None to 5
# 2024-04-03:23:06:28,156 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_mathematics from None to 5
# 2024-04-03:23:06:28,156 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 5
# 2024-04-03:23:06:28,156 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 5
# 2024-04-03:23:06:28,156 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_human_sexuality from None to 5
# 2024-04-03:23:06:28,156 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_geography from None to 5
# 2024-04-03:23:06:28,156 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_econometrics from None to 5
# 2024-04-03:23:06:28,156 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_macroeconomics from None to 5
# 2024-04-03:23:06:28,156 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_psychology from None to 5
# 2024-04-03:23:06:28,157 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_government_and_politics from None to 5
# 2024-04-03:23:06:28,157 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_psychology from None to 5
# 2024-04-03:23:06:28,157 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_security_studies from None to 5
# 2024-04-03:23:06:28,157 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_us_foreign_policy from None to 5
# 2024-04-03:23:06:28,157 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_microeconomics from None to 5
# 2024-04-03:23:06:28,157 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_public_relations from None to 5
# 2024-04-03:23:06:28,157 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_sociology from None to 5
# 2024-04-03:23:06:28,157 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_accounting from None to 5
# 2024-04-03:23:06:28,157 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_medical_genetics from None to 5
# 2024-04-03:23:06:28,157 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_college_medicine from None to 5
# 2024-04-03:23:06:28,157 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_clinical_knowledge from None to 5
# 2024-04-03:23:06:28,157 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_management from None to 5
# 2024-04-03:23:06:28,158 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_human_aging from None to 5
# 2024-04-03:23:06:28,158 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_business_ethics from None to 5
# 2024-04-03:23:06:28,158 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_global_facts from None to 5
# 2024-04-03:23:06:28,158 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_miscellaneous from None to 5
# 2024-04-03:23:06:28,158 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_nutrition from None to 5
# 2024-04-03:23:06:28,158 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_medicine from None to 5
# 2024-04-03:23:06:28,158 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_marketing from None to 5
# 2024-04-03:23:06:28,158 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_virology from None to 5
# 2024-04-03:23:06:28,158 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_world_history from None to 5
# 2024-04-03:23:06:28,158 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_international_law from None to 5
# 2024-04-03:23:06:28,158 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_european_history from None to 5
# 2024-04-03:23:06:28,159 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_moral_disputes from None to 5
# 2024-04-03:23:06:28,159 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_prehistory from None to 5
# 2024-04-03:23:06:28,159 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_high_school_us_history from None to 5
# 2024-04-03:23:06:28,159 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_professional_law from None to 5
# 2024-04-03:23:06:28,159 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_moral_scenarios from None to 5
# 2024-04-03:23:06:28,159 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_world_religions from None to 5
# 2024-04-03:23:06:28,159 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_jurisprudence from None to 5
# 2024-04-03:23:06:28,159 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_logical_fallacies from None to 5
# 2024-04-03:23:06:28,159 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_formal_logic from None to 5
# 2024-04-03:23:06:28,159 WARNING  [evaluator.py:239] Overwriting default num_fewshot of mmlu_philosophy from None to 5
# 2024-04-03:23:06:28,165 INFO     [task.py:395] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:03<00:00, 65.88it/s]
# 2024-04-03:23:06:31,823 INFO     [task.py:395] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:04<00:00, 66.31it/s]
# 2024-04-03:23:06:36,616 INFO     [task.py:395] Building contexts for mmlu_anatomy on rank 0...
# 100% 135/135 [00:02<00:00, 65.99it/s]
# 2024-04-03:23:06:38,714 INFO     [task.py:395] Building contexts for mmlu_college_chemistry on rank 0...
# 100% 100/100 [00:01<00:00, 66.50it/s]
# 2024-04-03:23:06:40,256 INFO     [task.py:395] Building contexts for mmlu_elementary_mathematics on rank 0...
# 100% 378/378 [00:05<00:00, 66.38it/s]
# 2024-04-03:23:06:46,094 INFO     [task.py:395] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:02<00:00, 66.39it/s]
# 2024-04-03:23:06:48,319 INFO     [task.py:395] Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:02<00:00, 66.23it/s]
# 2024-04-03:23:06:50,565 INFO     [task.py:395] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:01<00:00, 66.48it/s]
# 2024-04-03:23:06:52,293 INFO     [task.py:395] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:03<00:00, 65.92it/s]
# 2024-04-03:23:06:55,652 INFO     [task.py:395] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:01<00:00, 66.47it/s]
# 2024-04-03:23:06:57,196 INFO     [task.py:395] Building contexts for mmlu_abstract_algebra on rank 0...
# 100% 100/100 [00:01<00:00, 66.65it/s]
# 2024-04-03:23:06:58,734 INFO     [task.py:395] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 66.19it/s]
# 2024-04-03:23:07:00,284 INFO     [task.py:395] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:01<00:00, 65.92it/s]
# 2024-04-03:23:07:01,871 INFO     [task.py:395] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 65.38it/s]
# 2024-04-03:23:07:03,442 INFO     [task.py:395] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:02<00:00, 66.05it/s]
# 2024-04-03:23:07:05,802 INFO     [task.py:395] Building contexts for mmlu_high_school_physics on rank 0...
# 100% 151/151 [00:02<00:00, 66.19it/s]
# 2024-04-03:23:07:08,142 INFO     [task.py:395] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:01<00:00, 65.75it/s]
# 2024-04-03:23:07:09,702 INFO     [task.py:395] Building contexts for mmlu_high_school_mathematics on rank 0...
# 100% 270/270 [00:04<00:00, 65.90it/s]
# 2024-04-03:23:07:13,906 INFO     [task.py:395] Building contexts for mmlu_high_school_chemistry on rank 0...
# 100% 203/203 [00:03<00:00, 64.70it/s]
# 2024-04-03:23:07:17,122 INFO     [task.py:395] Building contexts for mmlu_human_sexuality on rank 0...
# 100% 131/131 [00:01<00:00, 66.25it/s]
# 2024-04-03:23:07:19,151 INFO     [task.py:395] Building contexts for mmlu_high_school_geography on rank 0...
# 100% 198/198 [00:02<00:00, 66.33it/s]
# 2024-04-03:23:07:22,211 INFO     [task.py:395] Building contexts for mmlu_econometrics on rank 0...
# 100% 114/114 [00:01<00:00, 66.11it/s]
# 2024-04-03:23:07:23,981 INFO     [task.py:395] Building contexts for mmlu_high_school_macroeconomics on rank 0...
# 100% 390/390 [00:05<00:00, 65.34it/s]
# 2024-04-03:23:07:30,099 INFO     [task.py:395] Building contexts for mmlu_professional_psychology on rank 0...
# 100% 612/612 [00:09<00:00, 65.77it/s]
# 2024-04-03:23:07:39,641 INFO     [task.py:395] Building contexts for mmlu_high_school_government_and_politics on rank 0...
# 100% 193/193 [00:02<00:00, 66.22it/s]
# 2024-04-03:23:07:42,631 INFO     [task.py:395] Building contexts for mmlu_high_school_psychology on rank 0...
# 100% 545/545 [00:08<00:00, 66.15it/s]
# 2024-04-03:23:07:51,075 INFO     [task.py:395] Building contexts for mmlu_security_studies on rank 0...
# 100% 245/245 [00:03<00:00, 65.90it/s]
# 2024-04-03:23:07:54,889 INFO     [task.py:395] Building contexts for mmlu_us_foreign_policy on rank 0...
# 100% 100/100 [00:01<00:00, 66.16it/s]
# 2024-04-03:23:07:56,439 INFO     [task.py:395] Building contexts for mmlu_high_school_microeconomics on rank 0...
# 100% 238/238 [00:03<00:00, 66.02it/s]
# 2024-04-03:23:08:00,135 INFO     [task.py:395] Building contexts for mmlu_public_relations on rank 0...
# 100% 110/110 [00:01<00:00, 65.64it/s]
# 2024-04-03:23:08:01,854 INFO     [task.py:395] Building contexts for mmlu_sociology on rank 0...
# 100% 201/201 [00:03<00:00, 65.90it/s]
# 2024-04-03:23:08:04,980 INFO     [task.py:395] Building contexts for mmlu_professional_accounting on rank 0...
# 100% 282/282 [00:04<00:00, 61.45it/s]
# 2024-04-03:23:08:09,678 INFO     [task.py:395] Building contexts for mmlu_medical_genetics on rank 0...
# 100% 100/100 [00:01<00:00, 65.78it/s]
# 2024-04-03:23:08:11,237 INFO     [task.py:395] Building contexts for mmlu_college_medicine on rank 0...
# 100% 173/173 [00:02<00:00, 65.60it/s]
# 2024-04-03:23:08:13,941 INFO     [task.py:395] Building contexts for mmlu_clinical_knowledge on rank 0...
# 100% 265/265 [00:04<00:00, 65.91it/s]
# 2024-04-03:23:08:18,065 INFO     [task.py:395] Building contexts for mmlu_management on rank 0...
# 100% 103/103 [00:01<00:00, 66.06it/s]
# 2024-04-03:23:08:19,664 INFO     [task.py:395] Building contexts for mmlu_human_aging on rank 0...
# 100% 223/223 [00:03<00:00, 65.98it/s]
# 2024-04-03:23:08:23,129 INFO     [task.py:395] Building contexts for mmlu_business_ethics on rank 0...
# 100% 100/100 [00:01<00:00, 65.77it/s]
# 2024-04-03:23:08:24,689 INFO     [task.py:395] Building contexts for mmlu_global_facts on rank 0...
# 100% 100/100 [00:01<00:00, 64.60it/s]
# 2024-04-03:23:08:26,276 INFO     [task.py:395] Building contexts for mmlu_miscellaneous on rank 0...
# 100% 783/783 [00:11<00:00, 65.92it/s]
# 2024-04-03:23:08:38,454 INFO     [task.py:395] Building contexts for mmlu_nutrition on rank 0...
# 100% 306/306 [00:04<00:00, 65.90it/s]
# 2024-04-03:23:08:43,213 INFO     [task.py:395] Building contexts for mmlu_professional_medicine on rank 0...
# 100% 272/272 [00:04<00:00, 65.58it/s]
# 2024-04-03:23:08:47,471 INFO     [task.py:395] Building contexts for mmlu_marketing on rank 0...
# 100% 234/234 [00:03<00:00, 64.87it/s]
# 2024-04-03:23:08:51,168 INFO     [task.py:395] Building contexts for mmlu_virology on rank 0...
# 100% 166/166 [00:02<00:00, 65.55it/s]
# 2024-04-03:23:08:53,764 INFO     [task.py:395] Building contexts for mmlu_high_school_world_history on rank 0...
# 100% 237/237 [00:03<00:00, 65.18it/s]
# 2024-04-03:23:08:57,499 INFO     [task.py:395] Building contexts for mmlu_international_law on rank 0...
# 100% 121/121 [00:01<00:00, 65.50it/s]
# 2024-04-03:23:08:59,394 INFO     [task.py:395] Building contexts for mmlu_high_school_european_history on rank 0...
# 100% 165/165 [00:02<00:00, 64.56it/s]
# 2024-04-03:23:09:02,025 INFO     [task.py:395] Building contexts for mmlu_moral_disputes on rank 0...
# 100% 346/346 [00:05<00:00, 65.10it/s]
# 2024-04-03:23:09:07,475 INFO     [task.py:395] Building contexts for mmlu_prehistory on rank 0...
# 100% 324/324 [00:04<00:00, 65.30it/s]
# 2024-04-03:23:09:12,563 INFO     [task.py:395] Building contexts for mmlu_high_school_us_history on rank 0...
# 100% 204/204 [00:03<00:00, 64.44it/s]
# 2024-04-03:23:09:15,817 INFO     [task.py:395] Building contexts for mmlu_professional_law on rank 0...
# 100% 1534/1534 [00:23<00:00, 65.44it/s]
# 2024-04-03:23:09:39,882 INFO     [task.py:395] Building contexts for mmlu_moral_scenarios on rank 0...
# 100% 895/895 [00:13<00:00, 65.69it/s]
# 2024-04-03:23:09:53,853 INFO     [task.py:395] Building contexts for mmlu_world_religions on rank 0...
# 100% 171/171 [00:02<00:00, 65.77it/s]
# 2024-04-03:23:09:56,519 INFO     [task.py:395] Building contexts for mmlu_jurisprudence on rank 0...
# 100% 108/108 [00:01<00:00, 54.17it/s]
# 2024-04-03:23:09:58,554 INFO     [task.py:395] Building contexts for mmlu_logical_fallacies on rank 0...
# 100% 163/163 [00:02<00:00, 65.20it/s]
# 2024-04-03:23:10:01,118 INFO     [task.py:395] Building contexts for mmlu_formal_logic on rank 0...
# 100% 126/126 [00:01<00:00, 64.79it/s]
# 2024-04-03:23:10:03,112 INFO     [task.py:395] Building contexts for mmlu_philosophy on rank 0...
# 100% 311/311 [00:04<00:00, 65.09it/s]
# 2024-04-03:23:10:08,011 INFO     [evaluator.py:379] Running loglikelihood requests
# 2024-04-03:23:10:08,033 INFO     [model.py:225] Loading 'loglikelihood' responses from cache 'results_dir_gptq_mmlu_rank0.db' where possible...
# Checking cached requests: 100% 56168/56168 [00:09<00:00, 6222.14it/s]
# 2024-04-03:23:10:17,061 INFO     [model.py:249] Cached requests: 0, Requests remaining: 56168
# Running loglikelihood requests:   0% 0/56168 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 8
# Running loglikelihood requests:  25% 13953/56168 [09:39<12:31, 56.17it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Running loglikelihood requests:  25% 13984/56168 [09:49<12:31, 56.17it/s]Determined largest batch size: 32
# Running loglikelihood requests:  50% 27825/56168 [13:20<06:12, 76.05it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Running loglikelihood requests:  50% 27952/56168 [13:33<06:11, 76.05it/s]Determined largest batch size: 32
# Running loglikelihood requests:  75% 41985/56168 [16:18<02:26, 96.85it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Running loglikelihood requests:  75% 42112/56168 [16:30<02:25, 96.85it/s]Determined largest batch size: 64
# Running loglikelihood requests: 100% 56168/56168 [18:29<00:00, 50.64it/s]
# {
#   "results": {
#     "mmlu_stem": {
#       "alias": "stem",
#       "acc,none": 0.38661592134475103,
#       "acc_stderr,none": 0.008514393740132553
#     },
#     "mmlu_abstract_algebra": {
#       "alias": " - abstract_algebra",
#       "acc,none": 0.31,
#       "acc_stderr,none": 0.04648231987117316
#     },
#     "mmlu_anatomy": {
#       "alias": " - anatomy",
#       "acc,none": 0.4444444444444444,
#       "acc_stderr,none": 0.04292596718256981
#     },
#     "mmlu_astronomy": {
#       "alias": " - astronomy",
#       "acc,none": 0.4868421052631579,
#       "acc_stderr,none": 0.04067533136309173
#     },
#     "mmlu_college_biology": {
#       "alias": " - college_biology",
#       "acc,none": 0.5069444444444444,
#       "acc_stderr,none": 0.04180806750294938
#     },
#     "mmlu_college_chemistry": {
#       "alias": " - college_chemistry",
#       "acc,none": 0.34,
#       "acc_stderr,none": 0.04760952285695235
#     },
#     "mmlu_college_computer_science": {
#       "alias": " - college_computer_science",
#       "acc,none": 0.44,
#       "acc_stderr,none": 0.04988876515698589
#     },
#     "mmlu_college_mathematics": {
#       "alias": " - college_mathematics",
#       "acc,none": 0.33,
#       "acc_stderr,none": 0.04725815626252604
#     },
#     "mmlu_college_physics": {
#       "alias": " - college_physics",
#       "acc,none": 0.20588235294117646,
#       "acc_stderr,none": 0.040233822736177455
#     },
#     "mmlu_computer_security": {
#       "alias": " - computer_security",
#       "acc,none": 0.58,
#       "acc_stderr,none": 0.049604496374885836
#     },
#     "mmlu_conceptual_physics": {
#       "alias": " - conceptual_physics",
#       "acc,none": 0.4127659574468085,
#       "acc_stderr,none": 0.03218471141400351
#     },
#     "mmlu_electrical_engineering": {
#       "alias": " - electrical_engineering",
#       "acc,none": 0.503448275862069,
#       "acc_stderr,none": 0.04166567577101579
#     },
#     "mmlu_elementary_mathematics": {
#       "alias": " - elementary_mathematics",
#       "acc,none": 0.2857142857142857,
#       "acc_stderr,none": 0.02326651221373056
#     },
#     "mmlu_high_school_biology": {
#       "alias": " - high_school_biology",
#       "acc,none": 0.5387096774193548,
#       "acc_stderr,none": 0.028358634859836935
#     },
#     "mmlu_high_school_chemistry": {
#       "alias": " - high_school_chemistry",
#       "acc,none": 0.3694581280788177,
#       "acc_stderr,none": 0.03395970381998573
#     },
#     "mmlu_high_school_computer_science": {
#       "alias": " - high_school_computer_science",
#       "acc,none": 0.42,
#       "acc_stderr,none": 0.049604496374885836
#     },
#     "mmlu_high_school_mathematics": {
#       "alias": " - high_school_mathematics",
#       "acc,none": 0.27037037037037037,
#       "acc_stderr,none": 0.027080372815145668
#     },
#     "mmlu_high_school_physics": {
#       "alias": " - high_school_physics",
#       "acc,none": 0.31125827814569534,
#       "acc_stderr,none": 0.03780445850526732
#     },
#     "mmlu_high_school_statistics": {
#       "alias": " - high_school_statistics",
#       "acc,none": 0.3287037037037037,
#       "acc_stderr,none": 0.03203614084670058
#     },
#     "mmlu_machine_learning": {
#       "alias": " - machine_learning",
#       "acc,none": 0.3392857142857143,
#       "acc_stderr,none": 0.04493949068613539
#     },
#     "mmlu_social_sciences": {
#       "alias": "social_sciences",
#       "acc,none": 0.5424114397140072,
#       "acc_stderr,none": 0.008818173628945807
#     },
#     "mmlu_econometrics": {
#       "alias": " - econometrics",
#       "acc,none": 0.3508771929824561,
#       "acc_stderr,none": 0.044895393502707
#     },
#     "mmlu_high_school_geography": {
#       "alias": " - high_school_geography",
#       "acc,none": 0.5909090909090909,
#       "acc_stderr,none": 0.03502975799413007
#     },
#     "mmlu_high_school_government_and_politics": {
#       "alias": " - high_school_government_and_politics",
#       "acc,none": 0.689119170984456,
#       "acc_stderr,none": 0.03340361906276586
#     },
#     "mmlu_high_school_macroeconomics": {
#       "alias": " - high_school_macroeconomics",
#       "acc,none": 0.4307692307692308,
#       "acc_stderr,none": 0.025106820660539753
#     },
#     "mmlu_high_school_microeconomics": {
#       "alias": " - high_school_microeconomics",
#       "acc,none": 0.4327731092436975,
#       "acc_stderr,none": 0.032183581077426124
#     },
#     "mmlu_high_school_psychology": {
#       "alias": " - high_school_psychology",
#       "acc,none": 0.6495412844036698,
#       "acc_stderr,none": 0.020456077599824457
#     },
#     "mmlu_human_sexuality": {
#       "alias": " - human_sexuality",
#       "acc,none": 0.5725190839694656,
#       "acc_stderr,none": 0.043389203057924014
#     },
#     "mmlu_professional_psychology": {
#       "alias": " - professional_psychology",
#       "acc,none": 0.4738562091503268,
#       "acc_stderr,none": 0.020200164564804588
#     },
#     "mmlu_public_relations": {
#       "alias": " - public_relations",
#       "acc,none": 0.509090909090909,
#       "acc_stderr,none": 0.04788339768702861
#     },
#     "mmlu_security_studies": {
#       "alias": " - security_studies",
#       "acc,none": 0.5551020408163265,
#       "acc_stderr,none": 0.031814251181977865
#     },
#     "mmlu_sociology": {
#       "alias": " - sociology",
#       "acc,none": 0.6218905472636815,
#       "acc_stderr,none": 0.034288678487786564
#     },
#     "mmlu_us_foreign_policy": {
#       "alias": " - us_foreign_policy",
#       "acc,none": 0.72,
#       "acc_stderr,none": 0.04512608598542128
#     },
#     "mmlu_other": {
#       "alias": "other",
#       "acc,none": 0.5368522690698423,
#       "acc_stderr,none": 0.008755693835293435
#     },
#     "mmlu_business_ethics": {
#       "alias": " - business_ethics",
#       "acc,none": 0.5,
#       "acc_stderr,none": 0.050251890762960605
#     },
#     "mmlu_clinical_knowledge": {
#       "alias": " - clinical_knowledge",
#       "acc,none": 0.5094339622641509,
#       "acc_stderr,none": 0.030767394707808093
#     },
#     "mmlu_college_medicine": {
#       "alias": " - college_medicine",
#       "acc,none": 0.4046242774566474,
#       "acc_stderr,none": 0.03742461193887248
#     },
#     "mmlu_global_facts": {

#       "group": "mmlu_stem",
#       "group_alias": "stem",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "abstract_algebra",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about abstract algebra.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
#     "mmlu_anatomy": {
#       "task": "mmlu_anatomy",
#       "task_alias": "anatomy",
#       "group": "mmlu_stem",
#       "group_alias": "stem",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "anatomy",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about anatomy.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
#     "mmlu_astronomy": {
#       "task": "mmlu_astronomy",
#       "task_alias": "astronomy",
#       "group": "mmlu_stem",
#       "group_alias": "stem",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "astronomy",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about astronomy.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 0.0
#       }
#     },
#     "mmlu_business_ethics": {
#       "task": "mmlu_business_ethics",
#       "task_alias": "business_ethics",
#       "group": "mmlu_other",
#       "group_alias": "other",
#       "dataset_path": "hails/mmlu_no_train",
#       "dataset_name": "business_ethics",
#       "test_split": "test",
#       "fewshot_split": "dev",
#       "doc_to_text": "{{question.strip()}}\nA. {{choices[0]}}\nB. {{choices[1]}}\nC. {{choices[2]}}\nD. {{choices[3]}}\nAnswer:",
#       "doc_to_target": "answer",
#       "doc_to_choice": [
#         "A",
#         "B",
#         "C",
#         "D"
#       ],
#       "description": "The following are multiple choice questions (with answers) about business ethics.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "fewshot_config": {
#         "sampler": "first_n"
#       },
#       "num_fewshot": 5,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
# ...
# wandb:                                 mmlu_management/acc ▁
# wandb:                          mmlu_management/acc_stderr ▁
# wandb:                                  mmlu_marketing/acc ▁
# wandb:                           mmlu_marketing/acc_stderr ▁
# wandb:                           mmlu_medical_genetics/acc ▁
# wandb:                    mmlu_medical_genetics/acc_stderr ▁
# wandb:                              mmlu_miscellaneous/acc ▁
# wandb:                       mmlu_miscellaneous/acc_stderr ▁
# wandb:                             mmlu_moral_disputes/acc ▁
# wandb:                      mmlu_moral_disputes/acc_stderr ▁
# wandb:                            mmlu_moral_scenarios/acc ▁
# wandb:                     mmlu_moral_scenarios/acc_stderr ▁
# wandb:                                  mmlu_nutrition/acc ▁
# wandb:                           mmlu_nutrition/acc_stderr ▁
# wandb:                                      mmlu_other/acc ▁
# wandb:                               mmlu_other/acc_stderr ▁
# wandb:                                 mmlu_philosophy/acc ▁
# wandb:                          mmlu_philosophy/acc_stderr ▁
# wandb:                                 mmlu_prehistory/acc ▁
# wandb:                          mmlu_prehistory/acc_stderr ▁
# wandb:                    mmlu_professional_accounting/acc ▁
# wandb:             mmlu_professional_accounting/acc_stderr ▁
# wandb:                           mmlu_professional_law/acc ▁
# wandb:                    mmlu_professional_law/acc_stderr ▁
# wandb:                      mmlu_professional_medicine/acc ▁
# wandb:               mmlu_professional_medicine/acc_stderr ▁
# wandb:                    mmlu_professional_psychology/acc ▁
# wandb:             mmlu_professional_psychology/acc_stderr ▁
# wandb:                           mmlu_public_relations/acc ▁
# wandb:                    mmlu_public_relations/acc_stderr ▁
# wandb:                           mmlu_security_studies/acc ▁
# wandb:                    mmlu_security_studies/acc_stderr ▁
# wandb:                            mmlu_social_sciences/acc ▁
# wandb:                     mmlu_social_sciences/acc_stderr ▁
# wandb:                                  mmlu_sociology/acc ▁
# wandb:                           mmlu_sociology/acc_stderr ▁
# wandb:                                       mmlu_stem/acc ▁
# wandb:                                mmlu_stem/acc_stderr ▁
# wandb:                          mmlu_us_foreign_policy/acc ▁
# wandb:                   mmlu_us_foreign_policy/acc_stderr ▁
# wandb:                                   mmlu_virology/acc ▁
# wandb:                            mmlu_virology/acc_stderr ▁
# wandb:                            mmlu_world_religions/acc ▁
# wandb:                     mmlu_world_religions/acc_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:                           mmlu_abstract_algebra/acc 0.31
# wandb:                    mmlu_abstract_algebra/acc_stderr 0.04648
# wandb:                         mmlu_abstract_algebra/alias  - abstract_algebra
# wandb:                                    mmlu_anatomy/acc 0.44444
# wandb:                             mmlu_anatomy/acc_stderr 0.04293
# wandb:                                  mmlu_anatomy/alias  - anatomy
# wandb:                                  mmlu_astronomy/acc 0.48684
# wandb:                           mmlu_astronomy/acc_stderr 0.04068
# wandb:                                mmlu_astronomy/alias  - astronomy
# wandb:                            mmlu_business_ethics/acc 0.5
# wandb:                     mmlu_business_ethics/acc_stderr 0.05025
# wandb:                          mmlu_business_ethics/alias  - business_ethics
# wandb:                         mmlu_clinical_knowledge/acc 0.50943
# wandb:                  mmlu_clinical_knowledge/acc_stderr 0.03077
# wandb:                       mmlu_clinical_knowledge/alias  - clinical_knowledg...
# wandb:                            mmlu_college_biology/acc 0.50694
# wandb:                     mmlu_college_biology/acc_stderr 0.04181
# wandb:                          mmlu_college_biology/alias  - college_biology
# wandb:                          mmlu_college_chemistry/acc 0.34
# wandb:                   mmlu_college_chemistry/acc_stderr 0.04761
# wandb:                        mmlu_college_chemistry/alias  - college_chemistry...
# wandb:                   mmlu_college_computer_science/acc 0.44
# wandb:            mmlu_college_computer_science/acc_stderr 0.04989
# wandb:                 mmlu_college_computer_science/alias  - college_computer_...
# wandb:                        mmlu_college_mathematics/acc 0.33
# wandb:                 mmlu_college_mathematics/acc_stderr 0.04726
# wandb:                      mmlu_college_mathematics/alias  - college_mathemati...
# wandb:                           mmlu_college_medicine/acc 0.40462
# wandb:                    mmlu_college_medicine/acc_stderr 0.03742
# wandb:                         mmlu_college_medicine/alias  - college_medicine
# wandb:                            mmlu_college_physics/acc 0.20588
# wandb:                     mmlu_college_physics/acc_stderr 0.04023
# wandb:                          mmlu_college_physics/alias  - college_physics
# wandb:                          mmlu_computer_security/acc 0.58
# wandb:                   mmlu_computer_security/acc_stderr 0.0496
# wandb:                        mmlu_computer_security/alias  - computer_security...
# wandb:                         mmlu_conceptual_physics/acc 0.41277
# wandb:                  mmlu_conceptual_physics/acc_stderr 0.03218
# wandb:                       mmlu_conceptual_physics/alias  - conceptual_physic...
# wandb:                               mmlu_econometrics/acc 0.35088
# wandb:                        mmlu_econometrics/acc_stderr 0.0449
# wandb:                             mmlu_econometrics/alias  - econometrics
# wandb:                     mmlu_electrical_engineering/acc 0.50345
# wandb:              mmlu_electrical_engineering/acc_stderr 0.04167
# wandb:                   mmlu_electrical_engineering/alias  - electrical_engine...
# wandb:                     mmlu_elementary_mathematics/acc 0.28571
# wandb:              mmlu_elementary_mathematics/acc_stderr 0.02327
# wandb:                   mmlu_elementary_mathematics/alias  - elementary_mathem...
# wandb:                            mmlu_human_sexuality/acc 0.57252
# wandb:                     mmlu_human_sexuality/acc_stderr 0.04339
# wandb:                          mmlu_human_sexuality/alias  - human_sexuality
# wandb:                                 mmlu_humanities/acc 0.4255
# wandb:                          mmlu_humanities/acc_stderr 0.00685
# wandb:                               mmlu_humanities/alias humanities
# wandb:                          mmlu_international_law/acc 0.65289
# wandb:                   mmlu_international_law/acc_stderr 0.04346
# wandb:                        mmlu_international_law/alias  - international_law...
# wandb:                              mmlu_jurisprudence/acc 0.53704
# wandb:                       mmlu_jurisprudence/acc_stderr 0.0482
# wandb:                            mmlu_jurisprudence/alias  - jurisprudence
# wandb:                          mmlu_logical_fallacies/acc 0.53988
# wandb:                   mmlu_logical_fallacies/acc_stderr 0.03916
# wandb:                        mmlu_logical_fallacies/alias  - logical_fallacies...
# wandb:                           mmlu_machine_learning/acc 0.33929
# wandb:                    mmlu_machine_learning/acc_stderr 0.04494
# wandb:                         mmlu_machine_learning/alias  - machine_learning
# wandb:                                 mmlu_management/acc 0.61165
# wandb:                          mmlu_management/acc_stderr 0.04826
# wandb:                               mmlu_management/alias  - management
# wandb:                                  mmlu_marketing/acc 0.71795
# wandb:                           mmlu_marketing/acc_stderr 0.02948
# wandb:                                mmlu_marketing/alias  - marketing
# wandb:                           mmlu_medical_genetics/acc 0.55
# wandb:                    mmlu_medical_genetics/acc_stderr 0.05
# wandb:                         mmlu_medical_genetics/alias  - medical_genetics
# wandb:                              mmlu_miscellaneous/acc 0.64879
# wandb:                       mmlu_miscellaneous/acc_stderr 0.01707
# wandb:                            mmlu_miscellaneous/alias  - miscellaneous
# wandb:                             mmlu_moral_disputes/acc 0.5289
# wandb:                      mmlu_moral_disputes/acc_stderr 0.02687
# wandb:                           mmlu_moral_disputes/alias  - moral_disputes
# wandb:                            mmlu_moral_scenarios/acc 0.23017
# wandb:                     mmlu_moral_scenarios/acc_stderr 0.01408
# wandb:                          mmlu_moral_scenarios/alias  - moral_scenarios
# wandb:                                  mmlu_nutrition/acc 0.50654
# wandb:                           mmlu_nutrition/acc_stderr 0.02863
# wandb:                                mmlu_nutrition/alias  - nutrition
# wandb:                                      mmlu_other/acc 0.53685
# wandb:                               mmlu_other/acc_stderr 0.00876
# wandb:                                    mmlu_other/alias other
# wandb:                                 mmlu_philosophy/acc 0.55949
# wandb:                          mmlu_philosophy/acc_stderr 0.0282
# wandb:                               mmlu_philosophy/alias  - philosophy
# wandb:                                 mmlu_prehistory/acc 0.54938
# wandb:                          mmlu_prehistory/acc_stderr 0.02768
# wandb:                               mmlu_prehistory/alias  - prehistory
# wandb:                    mmlu_professional_accounting/acc 0.36525
# wandb:             mmlu_professional_accounting/acc_stderr 0.02872
# wandb:                  mmlu_professional_accounting/alias  - professional_acco...
# wandb:                           mmlu_professional_law/acc 0.33051
# wandb:                    mmlu_professional_law/acc_stderr 0.01201
# wandb:                         mmlu_professional_law/alias  - professional_law
# wandb:                      mmlu_professional_medicine/acc 0.44853
# wandb:               mmlu_professional_medicine/acc_stderr 0.03021
# wandb:                    mmlu_professional_medicine/alias  - professional_medi...
# wandb:                    mmlu_professional_psychology/acc 0.47386
# wandb:             mmlu_professional_psychology/acc_stderr 0.0202
# wandb:                  mmlu_professional_psychology/alias  - professional_psyc...
# wandb:                           mmlu_public_relations/acc 0.50909
# wandb:                    mmlu_public_relations/acc_stderr 0.04788
# wandb:                         mmlu_public_relations/alias  - public_relations
# wandb:                           mmlu_security_studies/acc 0.5551
# wandb:                    mmlu_security_studies/acc_stderr 0.03181
# wandb:                         mmlu_security_studies/alias  - security_studies
# wandb:                            mmlu_social_sciences/acc 0.54241
# wandb:                     mmlu_social_sciences/acc_stderr 0.00882
# wandb:                          mmlu_social_sciences/alias social_sciences
# wandb:                                  mmlu_sociology/acc 0.62189
# wandb:                           mmlu_sociology/acc_stderr 0.03429
# wandb:                                mmlu_sociology/alias  - sociology
# wandb:                                       mmlu_stem/acc 0.38662
# wandb:                                mmlu_stem/acc_stderr 0.00851
# wandb:                                     mmlu_stem/alias stem
# wandb:                          mmlu_us_foreign_policy/acc 0.72
# wandb:                   mmlu_us_foreign_policy/acc_stderr 0.04513
# wandb:                        mmlu_us_foreign_policy/alias  - us_foreign_policy...
# wandb:                                   mmlu_virology/acc 0.46386
# wandb:                            mmlu_virology/acc_stderr 0.03882
# wandb:                                 mmlu_virology/alias  - virology
# wandb:                            mmlu_world_religions/acc 0.69591
# wandb:                     mmlu_world_religions/acc_stderr 0.03528
# wandb:                          mmlu_world_religions/alias  - world_religions
# wandb:
# wandb: 🚀 View run Llama-2-7b-hf-AutoGPTQ-mmlu at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/riufy7f1
# wandb: ⭐️ View project at: https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: Synced 5 W&B file(s), 6 media file(s), 26 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240403_230106-riufy7f1/logs

# %% [markdown]
# #### HellaSwag
#
# 0-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Llama-2-7b-chat-hf-AutoGPTQ,trust_remote_code=True,revision="b63b90c0fc11dfe983fb80172de0a8b8ae89224e"\
    --tasks hellaswag \
    --num_fewshot 0 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir_gptq_hellaswag \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Llama-2-7b-hf-AutoGPTQ-hellaswag \
    --use_cache results_dir_gptq_hellaswag \
    --cache_requests true \
    --show_config
# Out:
# 2024-04-03 19:23:26.463951: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-03 19:23:26.464002: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-03 19:23:26.465467: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-03 19:23:27.671195: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240403_192333-fk49ju70
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Llama-2-7b-hf-AutoGPTQ-hellaswag
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/fk49ju70/workspace
# 2024-04-03:19:23:34,348 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-04-03:19:23:40,577 INFO     [__main__.py:335] Selected Tasks: ['hellaswag']
# 2024-04-03:19:23:40,577 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-04-03:19:23:40,578 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Llama-2-7b-chat-hf-AutoGPTQ', 'trust_remote_code': True, 'revision': 'b63b90c0fc11dfe983fb80172de0a8b8ae89224e'}
# 2024-04-03:19:23:40,582 INFO     [huggingface.py:163] Using device 'cuda:0'
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4193: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# The cos_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class
# The sin_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class
# 2024-04-03:19:23:43,599 INFO     [evaluator.py:195] Using cache at results_dir_gptq_hellaswag_rank0.db
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 4.36k/4.36k [00:00<00:00, 12.0MB/s]
# Downloading metadata: 100% 2.53k/2.53k [00:00<00:00, 8.59MB/s]
# Downloading readme: 100% 6.84k/6.84k [00:00<00:00, 17.3MB/s]
# Downloading data: 47.5MB [00:00, 71.4MB/s]
# Downloading data: 11.8MB [00:00, 66.3MB/s]
# Downloading data: 12.2MB [00:00, 65.0MB/s]
# Generating train split: 100% 39905/39905 [00:04<00:00, 9576.91 examples/s]
# Generating test split: 100% 10003/10003 [00:01<00:00, 9594.11 examples/s]
# Generating validation split: 100% 10042/10042 [00:01<00:00, 9507.66 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 6325.32 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 6509.61 examples/s]
# 2024-04-03:19:24:22,613 WARNING  [evaluator.py:239] Overwriting default num_fewshot of hellaswag from None to 0
# 2024-04-03:19:24:22,615 INFO     [task.py:395] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [00:04<00:00, 2166.13it/s]
# 2024-04-03:19:24:32,757 INFO     [evaluator.py:379] Running loglikelihood requests
# 2024-04-03:19:24:32,768 INFO     [model.py:225] Loading 'loglikelihood' responses from cache 'results_dir_gptq_hellaswag_rank0.db' where possible...
# Checking cached requests: 100% 40168/40168 [00:05<00:00, 7276.60it/s]
# 2024-04-03:19:24:38,289 INFO     [model.py:249] Cached requests: 0, Requests remaining: 40168
# Running loglikelihood requests:   0% 0/40168 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests:  25% 9930/40168 [01:55<05:06, 98.67it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests: 100% 40168/40168 [05:35<00:00, 119.65it/s]
# {
#   "results": {
#     "hellaswag": {
#       "acc,none": 0.5646285600477993,
#       "acc_stderr,none": 0.00494792269268883,
#       "acc_norm,none": 0.746265684126668,
#       "acc_norm_stderr,none": 0.004342580277662822,
#       "alias": "hellaswag"
#     }
#   },
#   "group_subtasks": {
#     "hellaswag": []
#   },
#   "configs": {
#     "hellaswag": {
#       "task": "hellaswag",
#       "group": [
#         "multiple_choice"
#       ],
#       "dataset_path": "hellaswag",
#       "training_split": "train",
#       "validation_split": "validation",
#       "process_docs": "def process_docs(dataset: datasets.Dataset) -> datasets.Dataset:\n    def _process_doc(doc):\n        ctx = doc[\"ctx_a\"] + \" \" + doc[\"ctx_b\"].capitalize()\n        out_doc = {\n            \"query\": preprocess(doc[\"activity_label\"] + \": \" + ctx),\n            \"choices\": [preprocess(ending) for ending in doc[\"endings\"]],\n            \"gold\": int(doc[\"label\"]),\n        }\n        return out_doc\n\n    return dataset.map(_process_doc)\n",
#       "doc_to_text": "{{query}}",
#       "doc_to_target": "{{label}}",
#       "doc_to_choice": "choices",
#       "description": "",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "acc",
#           "aggregation": "mean",
#           "higher_is_better": true
#         },
#         {
#           "metric": "acc_norm",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0
#       }
#     }
#   },
#   "versions": {
#     "hellaswag": 1.0
#   },
#   "n-shot": {
#     "hellaswag": 0
#   },
#   "config": {
#     "model": "hf",
#     "model_args": "pretrained=twhoool02/Llama-2-7b-chat-hf-AutoGPTQ,trust_remote_code=True,revision=b63b90c0fc11dfe983fb80172de0a8b8ae89224e",
#     "batch_size": "auto:4",
#     "batch_sizes": [
#       64,
#       64,
#       64,
#       64,
#       64
#     ],
#     "device": "cuda:0",
#     "use_cache": "results_dir_gptq_hellaswag",
#     "limit": null,
#     "bootstrap_iters": 100000,
#     "gen_kwargs": null
#   },
#   "git_hash": "9516087b",
#   "date": 1712172220.5776796,
#   "pretty_env_info": "PyTorch version: 2.2.1+cu121\nIs debug build: False\nCUDA used to build PyTorch: 12.1\nROCM used to build PyTorch: N/A\n\nOS: Ubuntu 22.04.3 LTS (x86_64)\nGCC version: (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0\nClang version: 14.0.0-1ubuntu1.1\nCMake version: version 3.27.9\nLibc version: glibc-2.35\n\nPython version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0] (64-bit runtime)\nPython platform: Linux-6.1.58+-x86_64-with-glibc2.35\nIs CUDA available: True\nCUDA runtime version: 12.2.140\nCUDA_MODULE_LOADING set to: LAZY\nGPU models and configuration: GPU 0: NVIDIA A100-SXM4-40GB\nNvidia driver version: 535.104.05\ncuDNN version: Probably one of the following:\n/usr/lib/x86_64-linux-gnu/libcudnn.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_train.so.8.9.6\nHIP runtime version: N/A\nMIOpen runtime version: N/A\nIs XNNPACK available: True\n\nCPU:\nArchitecture:                       x86_64\nCPU op-mode(s):                     32-bit, 64-bit\nAddress sizes:                      46 bits physical, 48 bits virtual\nByte Order:                         Little Endian\nCPU(s):                             12\nOn-line CPU(s) list:                0-11\nVendor ID:                          GenuineIntel\nModel name:                         Intel(R) Xeon(R) CPU @ 2.20GHz\nCPU family:                         6\nModel:                              85\nThread(s) per core:                 2\nCore(s) per socket:                 6\nSocket(s):                          1\nStepping:                           7\nBogoMIPS:                           4400.40\nFlags:                              fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp ibrs_enhanced fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat avx512_vnni md_clear arch_capabilities\nHypervisor vendor:                  KVM\nVirtualization type:                full\nL1d cache:                          192 KiB (6 instances)\nL1i cache:                          192 KiB (6 instances)\nL2 cache:                           6 MiB (6 instances)\nL3 cache:                           38.5 MiB (1 instance)\nNUMA node(s):                       1\nNUMA node0 CPU(s):                  0-11\nVulnerability Gather data sampling: Not affected\nVulnerability Itlb multihit:        Not affected\nVulnerability L1tf:                 Not affected\nVulnerability Mds:                  Vulnerable; SMT Host state unknown\nVulnerability Meltdown:             Not affected\nVulnerability Mmio stale data:      Vulnerable\nVulnerability Retbleed:             Vulnerable\nVulnerability Spec rstack overflow: Not affected\nVulnerability Spec store bypass:    Vulnerable\nVulnerability Spectre v1:           Vulnerable: __user pointer sanitization and usercopy barriers only; no swapgs barriers\nVulnerability Spectre v2:           Vulnerable, IBPB: disabled, STIBP: disabled, PBRSB-eIBRS: Vulnerable\nVulnerability Srbds:                Not affected\nVulnerability Tsx async abort:      Vulnerable\n\nVersions of relevant libraries:\n[pip3] numpy==1.25.2\n[pip3] torch==2.2.1+cu121\n[pip3] torchaudio==2.2.1+cu121\n[pip3] torchdata==0.7.1\n[pip3] torchsummary==1.5.1\n[pip3] torchtext==0.17.1\n[pip3] torchvision==0.17.1+cu121\n[pip3] triton==2.2.0\n[conda] Could not collect",
#   "transformers_version": "4.38.2",
#   "upper_git_hash": null
# }
# hf (pretrained=twhoool02/Llama-2-7b-chat-hf-AutoGPTQ,trust_remote_code=True,revision=b63b90c0fc11dfe983fb80172de0a8b8ae89224e), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: auto:4 (64,64,64,64,64)
# |  Tasks  |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |---------|------:|------|-----:|--------|-----:|---|-----:|
# |hellaswag|      1|none  |     0|acc     |0.5646|±  |0.0049|
# |         |       |none  |     0|acc_norm|0.7463|±  |0.0043|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:             hellaswag/acc ▁
# wandb:        hellaswag/acc_norm ▁
# wandb: hellaswag/acc_norm_stderr ▁
# wandb:      hellaswag/acc_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:             hellaswag/acc 0.56463
# wandb:        hellaswag/acc_norm 0.74627
# wandb: hellaswag/acc_norm_stderr 0.00434
# wandb:      hellaswag/acc_stderr 0.00495
# wandb:           hellaswag/alias hellaswag
# wandb:
# wandb: 🚀 View run Llama-2-7b-hf-AutoGPTQ-hellaswag at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/fk49ju70/workspace
# wandb: Synced 5 W&B file(s), 2 media file(s), 4 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240403_192333-fk49ju70/logs

# %% [markdown]
# #### BoolQ
#
# 0-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Llama-2-7b-chat-hf-AutoGPTQ,trust_remote_code=True,revision="b63b90c0fc11dfe983fb80172de0a8b8ae89224e" \
    --tasks boolq \
    --num_fewshot 0 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir_gptq_boolq \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Llama-2-7b-hf-AutoGPTQ-boolq \
    --use_cache results_dir_gptq_boolq \
    --cache_requests true \
    --show_config
# Out:
# 2024-04-03 19:31:26.400476: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-03 19:31:26.400536: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-03 19:31:26.402049: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-03 19:31:27.622097: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240403_193133-syuthoup
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Llama-2-7b-hf-AutoGPTQ-boolq
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/syuthoup/workspace
# 2024-04-03:19:31:34,384 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-04-03:19:31:40,827 INFO     [__main__.py:335] Selected Tasks: ['boolq']
# 2024-04-03:19:31:40,828 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-04-03:19:31:40,829 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Llama-2-7b-chat-hf-AutoGPTQ', 'trust_remote_code': True, 'revision': 'b63b90c0fc11dfe983fb80172de0a8b8ae89224e'}
# 2024-04-03:19:31:40,833 INFO     [huggingface.py:163] Using device 'cuda:0'
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4193: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# The cos_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class
# The sin_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class
# 2024-04-03:19:31:43,629 INFO     [evaluator.py:195] Using cache at results_dir_gptq_boolq_rank0.db
# 2024-04-03:19:31:43,634 WARNING  [task.py:763] [Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# 2024-04-03:19:31:43,634 WARNING  [task.py:775] [Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# Downloading data: 100% 3.85M/3.85M [00:03<00:00, 1.13MB/s]
# Downloading data: 100% 1.31M/1.31M [00:02<00:00, 501kB/s]
# Downloading data: 100% 1.31M/1.31M [00:02<00:00, 459kB/s]
# Generating train split: 100% 9427/9427 [00:00<00:00, 235541.85 examples/s]
# Generating validation split: 100% 3270/3270 [00:00<00:00, 295513.53 examples/s]
# Generating test split: 100% 3245/3245 [00:00<00:00, 287190.17 examples/s]
# 2024-04-03:19:32:01,473 WARNING  [evaluator.py:239] Overwriting default num_fewshot of boolq from None to 0
# 2024-04-03:19:32:01,474 INFO     [task.py:395] Building contexts for boolq on rank 0...
# 100% 3270/3270 [00:01<00:00, 1734.23it/s]
# 2024-04-03:19:32:04,073 INFO     [evaluator.py:379] Running loglikelihood requests
# 2024-04-03:19:32:04,075 INFO     [model.py:225] Loading 'loglikelihood' responses from cache 'results_dir_gptq_boolq_rank0.db' where possible...
# Checking cached requests: 100% 6540/6540 [00:00<00:00, 7260.51it/s]
# 2024-04-03:19:32:04,977 INFO     [model.py:249] Cached requests: 0, Requests remaining: 6540
# Running loglikelihood requests:   0% 0/6540 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 16
# Running loglikelihood requests:  24% 1601/6540 [00:38<00:47, 103.41it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests: 100% 6540/6540 [01:14<00:00, 87.81it/s]
# {
#   "results": {
#     "boolq": {
#       "acc,none": 0.7844036697247706,
#       "acc_stderr,none": 0.007192552329179311,
#       "alias": "boolq"
#     }
#   },
#   "group_subtasks": {
#     "boolq": []
#   },
#   "configs": {
#     "boolq": {
#       "task": "boolq",
#       "group": [
#         "super-glue-lm-eval-v1"
#       ],
#       "dataset_path": "super_glue",
#       "dataset_name": "boolq",
#       "training_split": "train",
#       "validation_split": "validation",
#       "doc_to_text": "{{passage}}\nQuestion: {{question}}?\nAnswer:",
#       "doc_to_target": "label",
#       "doc_to_choice": [
#         "no",
#         "yes"
#       ],
#       "description": "",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "acc"
#         }
#       ],
#       "output_type": "multiple_choice",
#       "repeats": 1,
#       "should_decontaminate": true,
#       "doc_to_decontamination_query": "passage",
#       "metadata": {
#         "version": 2.0
#       }
#     }
#   },
#   "versions": {
#     "boolq": 2.0
#   },
#   "n-shot": {
#     "boolq": 0
#   },
#   "config": {
#     "model": "hf",
#     "model_args": "pretrained=twhoool02/Llama-2-7b-chat-hf-AutoGPTQ,trust_remote_code=True,revision=b63b90c0fc11dfe983fb80172de0a8b8ae89224e",
#     "batch_size": "auto:4",
#     "batch_sizes": [
#       16,
#       64,
#       64,
#       64,
#       64
#     ],
#     "device": "cuda:0",
#     "use_cache": "results_dir_gptq_boolq",
#     "limit": null,
#     "bootstrap_iters": 100000,
#     "gen_kwargs": null
#   },
#   "git_hash": "9516087b",
#   "date": 1712172700.8284423,
#   "pretty_env_info": "PyTorch version: 2.2.1+cu121\nIs debug build: False\nCUDA used to build PyTorch: 12.1\nROCM used to build PyTorch: N/A\n\nOS: Ubuntu 22.04.3 LTS (x86_64)\nGCC version: (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0\nClang version: 14.0.0-1ubuntu1.1\nCMake version: version 3.27.9\nLibc version: glibc-2.35\n\nPython version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0] (64-bit runtime)\nPython platform: Linux-6.1.58+-x86_64-with-glibc2.35\nIs CUDA available: True\nCUDA runtime version: 12.2.140\nCUDA_MODULE_LOADING set to: LAZY\nGPU models and configuration: GPU 0: NVIDIA A100-SXM4-40GB\nNvidia driver version: 535.104.05\ncuDNN version: Probably one of the following:\n/usr/lib/x86_64-linux-gnu/libcudnn.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_adv_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_cnn_train.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_infer.so.8.9.6\n/usr/lib/x86_64-linux-gnu/libcudnn_ops_train.so.8.9.6\nHIP runtime version: N/A\nMIOpen runtime version: N/A\nIs XNNPACK available: True\n\nCPU:\nArchitecture:                       x86_64\nCPU op-mode(s):                     32-bit, 64-bit\nAddress sizes:                      46 bits physical, 48 bits virtual\nByte Order:                         Little Endian\nCPU(s):                             12\nOn-line CPU(s) list:                0-11\nVendor ID:                          GenuineIntel\nModel name:                         Intel(R) Xeon(R) CPU @ 2.20GHz\nCPU family:                         6\nModel:                              85\nThread(s) per core:                 2\nCore(s) per socket:                 6\nSocket(s):                          1\nStepping:                           7\nBogoMIPS:                           4400.40\nFlags:                              fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp ibrs_enhanced fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat avx512_vnni md_clear arch_capabilities\nHypervisor vendor:                  KVM\nVirtualization type:                full\nL1d cache:                          192 KiB (6 instances)\nL1i cache:                          192 KiB (6 instances)\nL2 cache:                           6 MiB (6 instances)\nL3 cache:                           38.5 MiB (1 instance)\nNUMA node(s):                       1\nNUMA node0 CPU(s):                  0-11\nVulnerability Gather data sampling: Not affected\nVulnerability Itlb multihit:        Not affected\nVulnerability L1tf:                 Not affected\nVulnerability Mds:                  Vulnerable; SMT Host state unknown\nVulnerability Meltdown:             Not affected\nVulnerability Mmio stale data:      Vulnerable\nVulnerability Retbleed:             Vulnerable\nVulnerability Spec rstack overflow: Not affected\nVulnerability Spec store bypass:    Vulnerable\nVulnerability Spectre v1:           Vulnerable: __user pointer sanitization and usercopy barriers only; no swapgs barriers\nVulnerability Spectre v2:           Vulnerable, IBPB: disabled, STIBP: disabled, PBRSB-eIBRS: Vulnerable\nVulnerability Srbds:                Not affected\nVulnerability Tsx async abort:      Vulnerable\n\nVersions of relevant libraries:\n[pip3] numpy==1.25.2\n[pip3] torch==2.2.1+cu121\n[pip3] torchaudio==2.2.1+cu121\n[pip3] torchdata==0.7.1\n[pip3] torchsummary==1.5.1\n[pip3] torchtext==0.17.1\n[pip3] torchvision==0.17.1+cu121\n[pip3] triton==2.2.0\n[conda] Could not collect",
#   "transformers_version": "4.38.2",
#   "upper_git_hash": null
# }
# hf (pretrained=twhoool02/Llama-2-7b-chat-hf-AutoGPTQ,trust_remote_code=True,revision=b63b90c0fc11dfe983fb80172de0a8b8ae89224e), gen_kwargs: (None), limit: None, num_fewshot: 0, batch_size: auto:4 (16,64,64,64,64)
# |Tasks|Version|Filter|n-shot|Metric|Value |   |Stderr|
# |-----|------:|------|-----:|------|-----:|---|-----:|
# |boolq|      2|none  |     0|acc   |0.7844|±  |0.0072|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:        boolq/acc ▁
# wandb: boolq/acc_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:        boolq/acc 0.7844
# wandb: boolq/acc_stderr 0.00719
# wandb:      boolq/alias boolq
# wandb:
# wandb: 🚀 View run Llama-2-7b-hf-AutoGPTQ-boolq at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/syuthoup/workspace
# wandb: Synced 5 W&B file(s), 2 media file(s), 4 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240403_193133-syuthoup/logs

# %% [markdown]
# #### BBH
#
# 3-Shot is used when running this evaluation to match the values used in the document [Llama 2: Open Foundation and Fine-Tuned Chat Models](https://arxiv.org/abs/2307.09288)

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Llama-2-7b-chat-hf-AutoGPTQ,trust_remote_code=True,revision="b63b90c0fc11dfe983fb80172de0a8b8ae89224e" \
    --tasks bbh_fewshot \
    --num_fewshot 3 \
    --device cuda:0 \
    --batch_size auto:4 \
    --verbosity INFO \
    --output_path results_dir_gptq_boolq \
    --log_samples \
    --wandb_args project=quantized_model_evaluation,name=Llama-2-7b-hf-AutoGPTQ-bbh\
    --use_cache results_dir_gptq_boolq \
    --cache_requests true \
    --show_config
# Out:
# 2024-04-03 19:33:54.408547: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-03 19:33:54.408605: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-03 19:33:54.410113: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-03 19:33:55.626938: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: ted-whooley (atu-twhool02). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.5
# wandb: Run data is saved locally in /content/lm-evaluation-harness/wandb/run-20240403_193401-ratm6i5x
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Llama-2-7b-hf-AutoGPTQ-bbh
# wandb: ⭐️ View project at https://wandb.ai/atu-twhool02/quantized_model_evaluation
# wandb: 🚀 View run at https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/ratm6i5x/workspace
# 2024-04-03:19:34:03,425 INFO     [__main__.py:251] Verbosity set to INFO
# 2024-04-03:19:34:09,517 WARNING  [__main__.py:316] File results_dir_gptq_boolq/results.json already exists. Results will be overwritten.
# 2024-04-03:19:34:09,518 INFO     [__main__.py:335] Selected Tasks: ['bbh_fewshot']
# 2024-04-03:19:34:09,519 INFO     [evaluator.py:131] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-04-03:19:34:09,519 INFO     [evaluator.py:177] Initializing hf model, with arguments: {'pretrained': 'twhoool02/Llama-2-7b-chat-hf-AutoGPTQ', 'trust_remote_code': True, 'revision': 'b63b90c0fc11dfe983fb80172de0a8b8ae89224e'}
# 2024-04-03:19:34:09,523 INFO     [huggingface.py:163] Using device 'cuda:0'
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4193: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# The cos_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class
# The sin_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class
# 2024-04-03:19:34:12,517 INFO     [evaluator.py:195] Using cache at results_dir_gptq_boolq_rank0.db
# Downloading data: 100% 16.7k/16.7k [00:01<00:00, 10.2kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 34467.69 examples/s]
# 2024-04-03:19:34:19,921 WARNING  [task.py:322] [Task: bbh_fewshot_disambiguation_qa] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:34:19,921 WARNING  [task.py:322] [Task: bbh_fewshot_disambiguation_qa] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.4k/10.4k [00:01<00:00, 7.76kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 119088.70 examples/s]
# 2024-04-03:19:34:27,455 WARNING  [task.py:322] [Task: bbh_fewshot_hyperbaton] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:34:27,455 WARNING  [task.py:322] [Task: bbh_fewshot_hyperbaton] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 10.0k/10.0k [00:01<00:00, 7.56kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 95646.81 examples/s]
# 2024-04-03:19:34:33,596 WARNING  [task.py:322] [Task: bbh_fewshot_dyck_languages] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:34:33,596 WARNING  [task.py:322] [Task: bbh_fewshot_dyck_languages] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 35.8k/35.8k [00:01<00:00, 22.9kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 79546.05 examples/s]
# 2024-04-03:19:34:40,265 WARNING  [task.py:322] [Task: bbh_fewshot_formal_fallacies] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:34:40,265 WARNING  [task.py:322] [Task: bbh_fewshot_formal_fallacies] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 49.1k/49.1k [00:02<00:00, 24.5kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 57699.66 examples/s]
# 2024-04-03:19:34:47,290 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:34:47,290 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 21.7k/21.7k [00:01<00:00, 12.5kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 94017.39 examples/s]
# 2024-04-03:19:34:54,660 WARNING  [task.py:322] [Task: bbh_fewshot_movie_recommendation] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:34:54,660 WARNING  [task.py:322] [Task: bbh_fewshot_movie_recommendation] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 25.1k/25.1k [00:01<00:00, 16.1kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 83418.93 examples/s]
# 2024-04-03:19:35:01,246 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_three_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:35:01,246 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_three_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 44.0k/44.0k [00:01<00:00, 26.9kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 71341.41 examples/s]
# 2024-04-03:19:35:08,046 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:35:08,046 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_seven_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 33.5k/33.5k [00:01<00:00, 21.0kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 66788.28 examples/s]
# 2024-04-03:19:35:15,018 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_five_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:35:15,018 WARNING  [task.py:322] [Task: bbh_fewshot_logical_deduction_five_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 44.6k/44.6k [00:02<00:00, 20.0kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 88278.83 examples/s]
# 2024-04-03:19:35:21,727 WARNING  [task.py:322] [Task: bbh_fewshot_word_sorting] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:35:21,727 WARNING  [task.py:322] [Task: bbh_fewshot_word_sorting] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 16.4k/16.4k [00:01<00:00, 12.3kB/s]
# Generating test split: 100% 178/178 [00:00<00:00, 60702.99 examples/s]
# 2024-04-03:19:35:28,088 WARNING  [task.py:322] [Task: bbh_fewshot_snarks] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:35:28,089 WARNING  [task.py:322] [Task: bbh_fewshot_snarks] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 15.6k/15.6k [00:01<00:00, 9.96kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 85794.14 examples/s]
# 2024-04-03:19:35:34,797 WARNING  [task.py:322] [Task: bbh_fewshot_ruin_names] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:35:34,797 WARNING  [task.py:322] [Task: bbh_fewshot_ruin_names] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 69.5k/69.5k [00:01<00:00, 38.1kB/s]
# Generating test split: 100% 187/187 [00:00<00:00, 47842.80 examples/s]
# 2024-04-03:19:35:41,807 WARNING  [task.py:322] [Task: bbh_fewshot_causal_judgement] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:35:41,807 WARNING  [task.py:322] [Task: bbh_fewshot_causal_judgement] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100%
B/s]
# Generating test split: 100% 250/250 [00:00<00:00, 68574.72 examples/s]
# 2024-04-03:19:37:07,521 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_five_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:37:07,521 WARNING  [task.py:322] [Task: bbh_fewshot_tracking_shuffled_objects_five_objects] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading data: 100% 4.70k/4.70k [00:01<00:00, 3.20kB/s]
# Generating test split: 100% 250/250 [00:00<00:00, 113286.08 examples/s]
# 2024-04-03:19:37:13,093 WARNING  [task.py:322] [Task: bbh_fewshot_boolean_expressions] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:37:13,094 WARNING  [task.py:322] [Task: bbh_fewshot_boolean_expressions] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-03:19:37:13,101 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_boolean_expressions in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,101 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_tracking_shuffled_objects_five_objects in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,101 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_multistep_arithmetic_two in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,101 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_sports_understanding in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,101 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_penguins_in_a_table in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,101 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_web_of_lies in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,102 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_geometric_shapes in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,102 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_logical_deduction_three_objects in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,102 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_reasoning_about_colored_objects in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,102 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_navigate in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,102 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_temporal_sequences in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,102 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_object_counting in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,102 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_salient_translation_error_detection in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,102 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_date_understanding in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,102 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_causal_judgement in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,102 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_ruin_names in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,102 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_snarks in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,102 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_word_sorting in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,103 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_logical_deduction_five_objects in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,103 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_logical_deduction_seven_objects in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,103 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_tracking_shuffled_objects_three_objects in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,103 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_movie_recommendation in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,103 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_tracking_shuffled_objects_seven_objects in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,103 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_formal_fallacies in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,103 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_dyck_languages in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,103 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_hyperbaton in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,103 INFO     [evaluator.py:235] num_fewshot has been set to 0 for bbh_fewshot_disambiguation_qa in its config. Manual configuration will be ignored.
# 2024-04-03:19:37:13,107 INFO     [task.py:395] Building contexts for bbh_fewshot_boolean_expressions on rank 0...
# 100% 250/250 [00:00<00:00, 1195.75it/s]
# 2024-04-03:19:37:13,355 INFO     [task.py:395] Building contexts for bbh_fewshot_tracking_shuffled_objects_five_objects on rank 0...
# 100% 250/250 [00:00<00:00, 990.82it/s]
# 2024-04-03:19:37:13,645 INFO     [task.py:395] Building contexts for bbh_fewshot_multistep_arithmetic_two on rank 0...
# 100% 250/250 [00:00<00:00, 1233.58it/s]
# 2024-04-03:19:37:13,885 INFO     [task.py:395] Building contexts for bbh_fewshot_sports_understanding on rank 0...
# 100% 250/250 [00:00<00:00, 1174.60it/s]
# 2024-04-03:19:37:14,135 INFO     [task.py:395] Building contexts for bbh_fewshot_penguins_in_a_table on rank 0...
# 100% 146/146 [00:00<00:00, 1036.87it/s]
# 2024-04-03:19:37:14,298 INFO     [task.py:395] Building contexts for bbh_fewshot_web_of_lies on rank 0...
# 100% 250/250 [00:00<00:00, 1156.94it/s]
# 2024-04-03:19:37:14,551 INFO     [task.py:395] Building contexts for bbh_fewshot_geometric_shapes on rank 0...
# 100% 250/250 [00:00<00:00, 1106.67it/s]
# 2024-04-03:19:37:14,815 INFO     [task.py:395] Building contexts for bbh_fewshot_logical_deduction_three_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1051.39it/s]
# 2024-04-03:19:37:15,091 INFO     [task.py:395] Building contexts for bbh_fewshot_reasoning_about_colored_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1041.31it/s]
# 2024-04-03:19:37:15,370 INFO     [task.py:395] Building contexts for bbh_fewshot_navigate on rank 0...
# 100% 250/250 [00:00<00:00, 1147.70it/s]
# 2024-04-03:19:37:15,625 INFO     [task.py:395] Building contexts for bbh_fewshot_temporal_sequences on rank 0...
# 100% 250/250 [00:00<00:00, 970.90it/s]
# 2024-04-03:19:37:15,921 INFO     [task.py:395] Building contexts for bbh_fewshot_object_counting on rank 0...
# 100% 250/250 [00:00<00:00, 1177.66it/s]
# 2024-04-03:19:37:16,170 INFO     [task.py:395] Building contexts for bbh_fewshot_salient_translation_error_detection on rank 0...
# 100% 250/250 [00:00<00:00, 753.03it/s]
# 2024-04-03:19:37:16,545 INFO     [task.py:395] Building contexts for bbh_fewshot_date_understanding on rank 0...
# 100% 250/250 [00:00<00:00, 1147.00it/s]
# 2024-04-03:19:37:16,800 INFO     [task.py:395] Building contexts for bbh_fewshot_causal_judgement on rank 0...
# 100% 187/187 [00:00<00:00, 954.83it/s]
# 2024-04-03:19:37:17,026 INFO     [task.py:395] Building contexts for bbh_fewshot_ruin_names on rank 0...
# 100% 250/250 [00:00<00:00, 1127.94it/s]
# 2024-04-03:19:37:17,285 INFO     [task.py:395] Building contexts for bbh_fewshot_snarks on rank 0...
# 100% 178/178 [00:00<00:00, 1073.18it/s]
# 2024-04-03:19:37:17,478 INFO     [task.py:395] Building contexts for bbh_fewshot_word_sorting on rank 0...
# 100% 250/250 [00:00<00:00, 1192.94it/s]
# 2024-04-03:19:37:17,725 INFO     [task.py:395] Building contexts for bbh_fewshot_logical_deduction_five_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1040.53it/s]
# 2024-04-03:19:37:18,003 INFO     [task.py:395] Building contexts for bbh_fewshot_logical_deduction_seven_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1058.83it/s]
# 2024-04-03:19:37:18,278 INFO     [task.py:395] Building contexts for bbh_fewshot_tracking_shuffled_objects_three_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1023.31it/s]
# 2024-04-03:19:37:18,560 INFO     [task.py:395] Building contexts for bbh_fewshot_movie_recommendation on rank 0...
# 100% 250/250 [00:00<00:00, 1138.41it/s]
# 2024-04-03:19:37:18,818 INFO     [task.py:395] Building contexts for bbh_fewshot_tracking_shuffled_objects_seven_objects on rank 0...
# 100% 250/250 [00:00<00:00, 1037.40it/s]
# 2024-04-03:19:37:19,097 INFO     [task.py:395] Building contexts for bbh_fewshot_formal_fallacies on rank 0...
# 100% 250/250 [00:00<00:00, 1011.11it/s]
# 2024-04-03:19:37:19,383 INFO     [task.py:395] Building contexts for bbh_fewshot_dyck_languages on rank 0...
# 100% 250/250 [00:00<00:00, 1195.19it/s]
# 2024-04-03:19:37:19,629 INFO     [task.py:395] Building contexts for bbh_fewshot_hyperbaton on rank 0...
# 100% 250/250 [00:00<00:00, 1181.35it/s]
# 2024-04-03:19:37:19,878 INFO     [task.py:395] Building contexts for bbh_fewshot_disambiguation_qa on rank 0...
# 100% 250/250 [00:00<00:00, 1090.52it/s]
# 2024-04-03:19:37:20,144 INFO     [evaluator.py:379] Running generate_until requests
# 2024-04-03:19:37:20,147 INFO     [model.py:225] Loading 'generate_until' responses from cache 'results_dir_gptq_boolq_rank0.db' where possible...
# Checking cached requests: 100% 6511/6511 [00:00<00:00, 6827.18it/s]
# 2024-04-03:19:37:21,102 INFO     [model.py:249] Cached requests: 0, Requests remaining: 6511
# Running generate_until requests:   0% 0/6511 [00:00<?, ?it/s]Passed argument batch_size = auto. Detecting largest batch size
# Determined Largest batch size: 8
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:410: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:415: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Running generate_until requests: 100% 6511/6511 [53:17<00:00,  2.04it/s]
# {
#   "results": {
#     "bbh_fewshot": {
#       "exact_match,none": 0.33143910305636615,
#       "exact_match_stderr,none": 0.005427339102448659,
#       "alias": "bbh_fewshot"
#     },
#     "bbh_fewshot_boolean_expressions": {
#       "exact_match,none": 0.704,
#       "exact_match_stderr,none": 0.028928939388379635,
#       "alias": " - bbh_fewshot_boolean_expressions"
#     },
#     "bbh_fewshot_causal_judgement": {
#       "exact_match,none": 0.5561497326203209,
#       "exact_match_stderr,none": 0.03642987131924726,
#       "alias": " - bbh_fewshot_causal_judgement"
#     },
#     "bbh_fewshot_date_understanding": {
#       "exact_match,none": 0.336,
#       "exact_match_stderr,none": 0.02993325909419152,
#       "alias": " - bbh_fewshot_date_understanding"
#     },
#     "bbh_fewshot_disambiguation_qa": {
#       "exact_match,none": 0.268,
#       "exact_match_stderr,none": 0.02806876238252669,
#       "alias": " - bbh_fewshot_disambiguation_qa"
#     },
#     "bbh_fewshot_dyck_languages": {
#       "exact_match,none": 0.052,
#       "exact_match_stderr,none": 0.014070391025641655,
#       "alias": " - bbh_fewshot_dyck_languages"
#     },
#     "bbh_fewshot_formal_fallacies": {
#       "exact_match,none": 0.448,
#       "exact_match_stderr,none": 0.03151438761115355,
#       "alias": " - bbh_fewshot_formal_fallacies"
#     },
#     "bbh_fewshot_geometric_shapes": {
#       "exact_match,none": 0.32,
#       "exact_match_stderr,none": 0.029561724955241044,
#       "alias": " - bbh_fewshot_geometric_shapes"
#     },
#     "bbh_fewshot_hyperbaton": {
#       "exact_match,none": 0.508,
#       "exact_match_stderr,none": 0.031682156431413803,
#       "alias": " - bbh_fewshot_hyperbaton"
#     },
#     "bbh_fewshot_logical_deduction_five_objects": {
#       "exact_match,none": 0.264,
#       "exact_match_stderr,none": 0.027934518957690908,
#       "alias": " - bbh_fewshot_logical_deduction_five_objects"
#     },
#     "bbh_fewshot_logical_deduction_seven_objects": {
#       "exact_match,none": 0.192,
#       "exact_match_stderr,none": 0.02496069198917201,
#       "alias": " - bbh_fewshot_logical_deduction_seven_objects"
#     },
#     "bbh_fewshot_logical_deduction_three_objects": {
#       "exact_match,none": 0.404,
#       "exact_match_stderr,none": 0.031096688184825295,
#       "alias": " - bbh_fewshot_logical_deduction_three_objects"
#     },
#     "bbh_fewshot_movie_recommendation": {
#       "exact_match,none": 0.528,
#       "exact_match_stderr,none": 0.031636489531544396,
#       "alias": " - bbh_fewshot_movie_recommendation"
#     },
#     "bbh_fewshot_multistep_arithmetic_two": {
#       "exact_match,none": 0.008,
#       "exact_match_stderr,none": 0.005645483676690162,
#       "alias": " - bbh_fewshot_multistep_arithmetic_two"
#     },
#     "bbh_fewshot_navigate": {
#       "exact_match,none": 0.536,
#       "exact_match_stderr,none": 0.03160397514522375,
#       "alias": " - bbh_fewshot_navigate"
#     },
#     "bbh_fewshot_object_counting": {
#       "exact_match,none": 0.272,
#       "exact_match_stderr,none": 0.028200088296310002,
#       "alias": " - bbh_fewshot_object_counting"
#     },
#     "bbh_fewshot_penguins_in_a_table": {
#       "exact_match,none": 0.3013698630136986,
#       "exact_match_stderr,none": 0.03810566694037848,
#       "alias": " - bbh_fewshot_penguins_in_a_table"
#     },
#     "bbh_fewshot_reasoning_about_colored_objects": {
#       "exact_match,none": 0.192,
#       "exact_match_stderr,none": 0.024960691989172012,
#       "alias": " - bbh_fewshot_reasoning_about_colored_objects"
#     },
#     "bbh_fewshot_ruin_names": {
#       "exact_match,none": 0.248,
#       "exact_match_stderr,none": 0.027367497504863548,
#       "alias": " - bbh_fewshot_ruin_names"
#     },
#     "bbh_fewshot_salient_translation_error_detection": {
#       "exact_match,none": 0.34,
#       "exact_match_stderr,none": 0.030020073605457907,
#       "alias": " - bbh_fewshot_salient_translation_error_detection"
#     },
#     "bbh_fewshot_snarks": {
#       "exact_match,none": 0.5337078651685393,
#       "exact_match_stderr,none": 0.037496800603689866,
#       "alias": " - bbh_fewshot_snarks"
#     },
#     "bbh_fewshot_sports_understanding": {
#       "exact_match,none": 0.58,
#       "exact_match_stderr,none": 0.03127799950463661,
#       "alias": " - bbh_fewshot_sports_understanding"
#     },
#     "bbh_fewshot_temporal_sequences": {
#       "exact_match,none": 0.116,
#       "exact_match_stderr,none": 0.020293429803083865,
#       "alias": " - bbh_fewshot_temporal_sequences"
#     },
#     "bbh_fewshot_tracking_shuffled_objects_five_objects": {
#       "exact_match,none": 0.18,
#       "exact_match_stderr,none": 0.02434689065029352,
#       "alias": " - bbh_fewshot_tracking_shuffled_objects_five_objects"
#     },
#     "bbh_fewshot_tracking_shuffled_objects_seven_objects": {
#       "exact_match,none": 0.104,
#       "exact_match_stderr,none": 0.01934510097484389,
#       "alias": " - bbh_fewshot_tracking_shuffled_objects_seven_objects"
#     },
#     "bbh_fewshot_tracking_shuffled_objects_three_objects": {
#       "exact_match,none": 0.348,
#       "exact_match_stderr,none": 0.030186568464511697,
#       "alias": " - bbh_fewshot_tracking_shuffled_objects_three_objects"
#     },
#     "bbh_fewshot_web_of_lies": {
#       "exact_match,none": 0.488,
#       "exact_match_stderr,none": 0.03167708558254708,
#       "alias": " - bbh_fewshot_web_of_lies"
#     },
#     "bbh_fewshot_word_sorting": {
#       "exact_match,none": 0.224,
#       "exact_match_stderr,none": 0.02642136168734791,
#       "alias": " - bbh_fewshot_word_sorting"
#     }
#   },
#   "groups": {
#     "bbh_fewshot": {
#       "exact_match,none": 0.33143910305636615,
#       "exact_match_stderr,none": 0.005427339102448659,
#       "alias": "bbh_fewshot"
#     }
#   },
#   "group_subtasks": {
#     "bbh_fewshot": [
#       "bbh_fewshot_boolean_expressions",
#       "bbh_fewshot_tracking_shuffled_objects_five_objects",
#       "bbh_fewshot_multistep_arithmetic_two",
#       "bbh_fewshot_sports_understanding",
#       "bbh_fewshot_penguins_in_a_table",
#       "bbh_fewshot_web_of_lies",
#       "bbh_fewshot_geometric_shapes",
#       "bbh_fewshot_logical_deduction_three_objects",
#       "bbh_fewshot_reasoning_about_colored_objects",
#       "bbh_fewshot_navigate",
#       "bbh_fewshot_temporal_sequences",
#       "bbh_fewshot_object_counting",
#       "bbh_fewshot_salient_translation_error_detection",
#       "bbh_fewshot_date_understanding",
#       "bbh_fewshot_causal_judgement",
#       "bbh_fewshot_ruin_names",
#       "bbh_fewshot_snarks",
#       "bbh_fewshot_word_sorting",
#       "bbh_fewshot_logical_deduction_five_objects",
#       "bbh_fewshot_logical_deduction_seven_objects",
#       "bbh_fewshot_tracking_shuffled_objects_three_objects",
#       "bbh_fewshot_movie_recommendation",
#       "bbh_fewshot_tracking_shuffled_objects_seven_objects",
#       "bbh_fewshot_formal_fallacies",
#       "bbh_fewshot_dyck_languages",
#       "bbh_fewshot_hyperbaton",
#       "bbh_fewshot_disambiguation_qa"
#     ]
#   },
#   "configs": {
#     "bbh_fewshot_boolean_expressions": {
#       "task": "bbh_fewshot_boolean_expressions",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "boolean_expressions",
#       "test_split": "test",
#       "doc_to_text": "Q: not ( ( not not True ) ) is\nA: False\n\nQ: True and False and not True and True is\nA: False\n\nQ: not not ( not ( False ) ) is\nA: True\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Evaluate the result of a random Boolean expression.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_causal_judgement": {
#       "task": "bbh_fewshot_causal_judgement",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "causal_judgement",
#       "test_split": "test",
#       "doc_to_text": "Q: How would a typical person answer each of the following questions about causation?\nFrank T., had an ongoing dispute with his neighbor over a stretch of land and one day decided to shoot his neighbor in the body. Frank T. had no experience with guns, his hand slipped on the barrel of the gun, and the shot went wild. Nonetheless, the bullet bounced off a large boulder several feet away and hit the neighbor's body, causing significant injury. Did Frank T. intentionally shoot his neighbor in the body?\nOptions:\n- Yes\n- No\nA: No\n\nQ: How would a typical person answer each of the following questions about causation?\nSuzy and Billy are working on a project that is very important for our nation's security. The boss tells them both: \"Be sure that you are here at exactly 9 am. It is absolutely essential that you arrive at that time.\" Both Billy and Suzy arrive at 9 am. As it happens, there was a motion detector installed in the room where they arrived. The motion detector was set up to be triggered if at least one person appeared in the room at the same time. So the motion detector went off. Did Billy cause the motion detector to go off?\nOptions:\n- Yes\n- No\nA: Yes\n\nQ: How would a typical person answer each of the following questions about causation?\nGeorge and his sister Lena reunite at their parents' house for Thanksgiving. Whereas George just got into medical school, Lena is unhappy in her marriage and recently lost her job. Over the course of the day, George and Lena get into a number of heated arguments. Later in the afternoon they play a game of darts. They split the first two games, and the third game is close until the end. Who will win comes down to George's last shot. If he hits a high point region, he wins; if he hits a low point region, Lena wins. George thinks of the difficult time Lena is having, and he really wants to let her win. He aims the dart at the low point region. He sets up his shot and the dart lands in the low point region. After his shot, Lena wins the game and is very happy. Did George hit the low point region intentionally?\nOptions:\n- Yes\n- No\nA: Yes\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Answer questions about causal attribution.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_date_understanding": {
#       "task": "bbh_fewshot_date_understanding",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "date_understanding",
#       "test_split": "test",
#       "doc_to_text": "Q: Today is Christmas Eve of 1937. What is the date 10 days ago in MM/DD/YYYY?\nOptions:\n(A) 12/14/2026\n(B) 12/14/1950\n(C) 12/14/2007\n(D) 12/14/1937\n(E) 07/14/1938\n(F) 12/14/1988\nA: (D)\n\nQ: Tomorrow is 11/12/2019. What is the date one year ago from today in MM/DD/YYYY?\nOptions:\n(A) 09/04/2018\n(B) 11/11/2018\n(C) 08/25/2018\n(D) 11/02/2018\n(E) 11/04/2018\nA: (B)\n\nQ: Jane and John married on Jan 2, 1958. It is their 5-year anniversary today. What is the date tomorrow in MM/DD/YYYY?\nOptions:\n(A) 01/11/1961\n(B) 01/03/1963\n(C) 01/18/1961\n(D) 10/14/1960\n(E) 01/03/1982\n(F) 12/03/1960\nA: (B)\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Infer the date from context.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_disambiguation_qa": {
#       "task": "bbh_fewshot_disambiguation_qa",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "disambiguation_qa",
#       "test_split": "test",
#       "doc_to_text": "Q: In the following sentences, explain the antecedent of the pronoun (which thing the pronoun refers to), or state that it is ambiguous.\nSentence: The chief told the counselor that they took the day off.\nOptions:\n(A) The chief took the day off\n(B) The counselor took the day off\n(C) Ambiguous\nA: (A)\n\nQ: In the following sentences, explain the antecedent of the pronoun (which thing the pronoun refers to), or state that it is ambiguous.\nSentence: The manager sent a message to the secretary, but he didn't reply yet.\nOptions:\n(A) The secretary didn't reply yet\n(B) The manager didn't reply yet\n(C) Ambiguous\nA: (A)\n\nQ: In the following sentences, explain the antecedent of the pronoun (which thing the pronoun refers to), or state that it is ambiguous.\nSentence: Bailey will plan to meet the director at his office\nOptions:\n(A) It will be Bailey's office\n(B) It will be the director's office\n(C) Ambiguous\nA: (C)\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Clarify the meaning of sentences with ambiguous pronouns.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_dyck_languages": {
#       "task": "bbh_fewshot_dyck_languages",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "dyck_languages",
#       "test_split": "test",
#       "doc_to_text": "Q: Complete the rest of the sequence, making sure that the parentheses are closed properly. Input: [ { [\nA: ] } ]\n\nQ: Complete the rest of the sequence, making sure that the parentheses are closed properly. Input: < > ( ( [ [ ( { } ) [ < > ] ]\nA: ] ) )\n\nQ: Complete the rest of the sequence, making sure that the parentheses are closed properly. Input: < [ < [ { < [ ] < { } > > } ] > { { ( ) } { < [ < > ] > }\nA: } ] >\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Correctly close a Dyck-n word.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_formal_fallacies": {
#       "task": "bbh_fewshot_formal_fallacies",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "formal_fallacies",
#       "test_split": "test",
#       "doc_to_text": "Q: \"It is not always easy to see who is related to whom -- and in which ways. The following argument pertains to this question: To begin with, Lesley is a close friend of Fernando. Moreover, being a close friend of Fernando or a schoolmate of Lowell is sufficient for being a great-grandfather of Leroy. It follows that Lesley is a great-grandfather of Leroy.\"\nIs the argument, given the explicitly stated premises, deductively valid or invalid?\nOptions:\n- valid\n- invalid\nA: valid\n\nQ: \"It is not always easy to see who is related to whom -- and in which ways. The following argument pertains to this question: Whoever is not a great-grandfather of Clyde is a stepbrother of Brian. Being an ancestor of Dana is sufficient for not being a great-grandfather of Clyde. We may conclude: Everyone who is an ancestor of Dana is a stepbrother of Brian, too.\"\nIs the argument, given the explicitly stated premises, deductively valid or invalid?\nOptions:\n- valid\n- invalid\nA: valid\n\nQ: \"It is not always easy to grasp who is consuming which products. The following argument pertains to this question: Every infrequent user of Paul Mitchell shampoo is either a rare consumer of Nioxin shampoo or a loyal buyer of Caress soap, or both. No regular consumer of Lush soap is a rare consumer of Nioxin shampoo and, in the same time, a loyal buyer of Caress soap. It follows that whoever is an infrequent user of Paul Mitchell shampoo is not a regular consumer of Lush soap.\"\nIs the argument, given the explicitly stated premises, deductively valid or invalid?\nOptions:\n- valid\n- invalid\nA: invalid\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Distinguish deductively valid arguments from formal fallacies.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_geometric_shapes": {
#       "task": "bbh_fewshot_geometric_shapes",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "geometric_shapes",
#       "test_split": "test",
#       "doc_to_text": "Q: This SVG path element <path d=\"M 31.00,73.00 L 32.00,59.00 L 44.00,50.00 L 49.00,41.00 L 64.00,37.00 L 71.00,55.00 L 64.00,76.00 L 52.00,61.00 L 31.00,73.00\"/> draws a\nOptions:\n(A) circle\n(B) heptagon\n(C) hexagon\n(D) kite\n(E) line\n(F) octagon\n(G) pentagon\n(H) rectangle\n(I) sector\n(J) triangle\nA: (F)\n\nQ: This SVG path element <path d=\"M 14.19,26.04 L 51.43,39.21 L 58.44,36.69 L 56.63,30.17 L 48.53,26.66 L 14.19,26.04\"/> draws a\nOptions:\n(A) circle\n(B) heptagon\n(C) hexagon\n(D) kite\n(E) line\n(F) octagon\n(G) pentagon\n(H) rectangle\n(I) sector\n(J) triangle\nA: (G)\n\nQ: This SVG path element <path d=\"M 41.00,43.00 L 37.00,34.00 L 41.00,33.00 L 45.00,34.00 L 41.00,43.00\"/> draws a\nOptions:\n(A) circle\n(B) heptagon\n(C) hexagon\n(D) kite\n(E) line\n(F) octagon\n(G) pentagon\n(H) rectangle\n(I) sector\n(J) triangle\nA: (D)\n\nQ: {{input}}\nA:",
#       "doc_to_target": "{{target}}",
#       "description": "Name geometric shapes from their SVG paths.\n\n",
#       "target_delimiter": " ",
#       "fewshot_delimiter": "\n\n",
#       "num_fewshot": 0,
#       "metric_list": [
#         {
#           "metric": "exact_match",
#           "aggregation": "mean",
#           "higher_is_better": true
#         }
#       ],
#       "output_type": "generate_until",
#       "generation_kwargs": {
#         "until": [
#           "</s>",
#           "Q",
#           "\n\n"
#         ],
#         "do_sample": false,
#         "temperature": 0.0
#       },
#       "repeats": 1,
#       "should_decontaminate": false,
#       "metadata": {
#         "version": 1.0,
#         "num_fewshot": 3
#       }
#     },
#     "bbh_fewshot_hyperbaton": {
#       "task": "bbh_fewshot_hyperbaton",
#       "group": "bbh_fewshot",
#       "dataset_path": "lukaemon/bbh",
#       "dataset_name": "hyperbaton",
#       "test_split": "test",
# ...
# |                        Tasks                         |Version|Filter|n-shot|  Metric   |Value |   |Stderr|
# |------------------------------------------------------|-------|------|-----:|-----------|-----:|---|-----:|
# |bbh_fewshot                                           |N/A    |none  |     3|exact_match|0.3314|±  |0.0054|
# | - bbh_fewshot_boolean_expressions                    |      1|none  |     3|exact_match|0.7040|±  |0.0289|
# | - bbh_fewshot_causal_judgement                       |      1|none  |     3|exact_match|0.5561|±  |0.0364|
# | - bbh_fewshot_date_understanding                     |      1|none  |     3|exact_match|0.3360|±  |0.0299|
# | - bbh_fewshot_disambiguation_qa                      |      1|none  |     3|exact_match|0.2680|±  |0.0281|
# | - bbh_fewshot_dyck_languages                         |      1|none  |     3|exact_match|0.0520|±  |0.0141|
# | - bbh_fewshot_formal_fallacies                       |      1|none  |     3|exact_match|0.4480|±  |0.0315|
# | - bbh_fewshot_geometric_shapes                       |      1|none  |     3|exact_match|0.3200|±  |0.0296|
# | - bbh_fewshot_hyperbaton                             |      1|none  |     3|exact_match|0.5080|±  |0.0317|
# | - bbh_fewshot_logical_deduction_five_objects         |      1|none  |     3|exact_match|0.2640|±  |0.0279|
# | - bbh_fewshot_logical_deduction_seven_objects        |      1|none  |     3|exact_match|0.1920|±  |0.0250|
# | - bbh_fewshot_logical_deduction_three_objects        |      1|none  |     3|exact_match|0.4040|±  |0.0311|
# | - bbh_fewshot_movie_recommendation                   |      1|none  |     3|exact_match|0.5280|±  |0.0316|
# | - bbh_fewshot_multistep_arithmetic_two               |      1|none  |     3|exact_match|0.0080|±  |0.0056|
# | - bbh_fewshot_navigate                               |      1|none  |     3|exact_match|0.5360|±  |0.0316|
# | - bbh_fewshot_object_counting                        |      1|none  |     3|exact_match|0.2720|±  |0.0282|
# | - bbh_fewshot_penguins_in_a_table                    |      1|none  |     3|exact_match|0.3014|±  |0.0381|
# | - bbh_fewshot_reasoning_about_colored_objects        |      1|none  |     3|exact_match|0.1920|±  |0.0250|
# | - bbh_fewshot_ruin_names                             |      1|none  |     3|exact_match|0.2480|±  |0.0274|
# | - bbh_fewshot_salient_translation_error_detection    |      1|none  |     3|exact_match|0.3400|±  |0.0300|
# | - bbh_fewshot_snarks                                 |      1|none  |     3|exact_match|0.5337|±  |0.0375|
# | - bbh_fewshot_sports_understanding                   |      1|none  |     3|exact_match|0.5800|±  |0.0313|
# | - bbh_fewshot_temporal_sequences                     |      1|none  |     3|exact_match|0.1160|±  |0.0203|
# | - bbh_fewshot_tracking_shuffled_objects_five_objects |      1|none  |     3|exact_match|0.1800|±  |0.0243|
# | - bbh_fewshot_tracking_shuffled_objects_seven_objects|      1|none  |     3|exact_match|0.1040|±  |0.0193|
# | - bbh_fewshot_tracking_shuffled_objects_three_objects|      1|none  |     3|exact_match|0.3480|±  |0.0302|
# | - bbh_fewshot_web_of_lies                            |      1|none  |     3|exact_match|0.4880|±  |0.0317|
# | - bbh_fewshot_word_sorting                           |      1|none  |     3|exact_match|0.2240|±  |0.0264|
#
# |  Groups   |Version|Filter|n-shot|  Metric   |Value |   |Stderr|
# |-----------|-------|------|-----:|-----------|-----:|---|-----:|
# |bbh_fewshot|N/A    |none  |     3|exact_match|0.3314|±  |0.0054|
#
# wandb:
# wandb:
# wandb: Run history:
# wandb:                                                bbh_fewshot/exact_match ▁
# wandb:                                         bbh_fewshot/exact_match_stderr ▁
# wandb:                            bbh_fewshot_boolean_expressions/exact_match ▁
# wandb:                     bbh_fewshot_boolean_expressions/exact_match_stderr ▁
# wandb:                               bbh_fewshot_causal_judgement/exact_match ▁
# wandb:                        bbh_fewshot_causal_judgement/exact_match_stderr ▁
# wandb:                             bbh_fewshot_date_understanding/exact_match ▁
# wandb:                      bbh_fewshot_date_understanding/exact_match_stderr ▁
# wandb:                              bbh_fewshot_disambiguation_qa/exact_match ▁
# wandb:                       bbh_fewshot_disambiguation_qa/exact_match_stderr ▁
# wandb:                                 bbh_fewshot_dyck_languages/exact_match ▁
# wandb:                          bbh_fewshot_dyck_languages/exact_match_stderr ▁
# wandb:                               bbh_fewshot_formal_fallacies/exact_match ▁
# wandb:                        bbh_fewshot_formal_fallacies/exact_match_stderr ▁
# wandb:                               bbh_fewshot_geometric_shapes/exact_match ▁
# wandb:                        bbh_fewshot_geometric_shapes/exact_match_stderr ▁
# wandb:                                     bbh_fewshot_hyperbaton/exact_match ▁
# wandb:                              bbh_fewshot_hyperbaton/exact_match_stderr ▁
# wandb:                 bbh_fewshot_logical_deduction_five_objects/exact_match ▁
# wandb:          bbh_fewshot_logical_deduction_five_objects/exact_match_stderr ▁
# wandb:                bbh_fewshot_logical_deduction_seven_objects/exact_match ▁
# wandb:         bbh_fewshot_logical_deduction_seven_objects/exact_match_stderr ▁
# wandb:                bbh_fewshot_logical_deduction_three_objects/exact_match ▁
# wandb:         bbh_fewshot_logical_deduction_three_objects/exact_match_stderr ▁
# wandb:                           bbh_fewshot_movie_recommendation/exact_match ▁
# wandb:                    bbh_fewshot_movie_recommendation/exact_match_stderr ▁
# wandb:                       bbh_fewshot_multistep_arithmetic_two/exact_match ▁
# wandb:                bbh_fewshot_multistep_arithmetic_two/exact_match_stderr ▁
# wandb:                                       bbh_fewshot_navigate/exact_match ▁
# wandb:                                bbh_fewshot_navigate/exact_match_stderr ▁
# wandb:                                bbh_fewshot_object_counting/exact_match ▁
# wandb:                         bbh_fewshot_object_counting/exact_match_stderr ▁
# wandb:                            bbh_fewshot_penguins_in_a_table/exact_match ▁
# wandb:                     bbh_fewshot_penguins_in_a_table/exact_match_stderr ▁
# wandb:                bbh_fewshot_reasoning_about_colored_objects/exact_match ▁
# wandb:         bbh_fewshot_reasoning_about_colored_objects/exact_match_stderr ▁
# wandb:                                     bbh_fewshot_ruin_names/exact_match ▁
# wandb:                              bbh_fewshot_ruin_names/exact_match_stderr ▁
# wandb:            bbh_fewshot_salient_translation_error_detection/exact_match ▁
# wandb:     bbh_fewshot_salient_translation_error_detection/exact_match_stderr ▁
# wandb:                                         bbh_fewshot_snarks/exact_match ▁
# wandb:                                  bbh_fewshot_snarks/exact_match_stderr ▁
# wandb:                           bbh_fewshot_sports_understanding/exact_match ▁
# wandb:                    bbh_fewshot_sports_understanding/exact_match_stderr ▁
# wandb:                             bbh_fewshot_temporal_sequences/exact_match ▁
# wandb:                      bbh_fewshot_temporal_sequences/exact_match_stderr ▁
# wandb:         bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match ▁
# wandb:  bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match_stderr ▁
# wandb:        bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match ▁
# wandb: bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match_stderr ▁
# wandb:        bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match ▁
# wandb: bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match_stderr ▁
# wandb:                                    bbh_fewshot_web_of_lies/exact_match ▁
# wandb:                             bbh_fewshot_web_of_lies/exact_match_stderr ▁
# wandb:                                   bbh_fewshot_word_sorting/exact_match ▁
# wandb:                            bbh_fewshot_word_sorting/exact_match_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:                                                      bbh_fewshot/alias bbh_fewshot
# wandb:                                                bbh_fewshot/exact_match 0.33144
# wandb:                                         bbh_fewshot/exact_match_stderr 0.00543
# wandb:                                  bbh_fewshot_boolean_expressions/alias  - bbh_fewshot_boole...
# wandb:                            bbh_fewshot_boolean_expressions/exact_match 0.704
# wandb:                     bbh_fewshot_boolean_expressions/exact_match_stderr 0.02893
# wandb:                                     bbh_fewshot_causal_judgement/alias  - bbh_fewshot_causa...
# wandb:                         bbh_fewshot_object_counting/exact_match_stderr 0.0282
# wandb:                                  bbh_fewshot_penguins_in_a_table/alias  - bbh_fewshot_pengu...
# wandb:                            bbh_fewshot_penguins_in_a_table/exact_match 0.30137
# wandb:                     bbh_fewshot_penguins_in_a_table/exact_match_stderr 0.03811
# wandb:                      bbh_fewshot_reasoning_about_colored_objects/alias  - bbh_fewshot_reaso...
# wandb:                bbh_fewshot_reasoning_about_colored_objects/exact_match 0.192
# wandb:         bbh_fewshot_reasoning_about_colored_objects/exact_match_stderr 0.02496
# wandb:                                           bbh_fewshot_ruin_names/alias  - bbh_fewshot_ruin_...
# wandb:                                     bbh_fewshot_ruin_names/exact_match 0.248
# wandb:                              bbh_fewshot_ruin_names/exact_match_stderr 0.02737
# wandb:                  bbh_fewshot_salient_translation_error_detection/alias  - bbh_fewshot_salie...
# wandb:            bbh_fewshot_salient_translation_error_detection/exact_match 0.34
# wandb:     bbh_fewshot_salient_translation_error_detection/exact_match_stderr 0.03002
# wandb:                                               bbh_fewshot_snarks/alias  - bbh_fewshot_snark...
# wandb:                                         bbh_fewshot_snarks/exact_match 0.53371
# wandb:                                  bbh_fewshot_snarks/exact_match_stderr 0.0375
# wandb:                                 bbh_fewshot_sports_understanding/alias  - bbh_fewshot_sport...
# wandb:                           bbh_fewshot_sports_understanding/exact_match 0.58
# wandb:                    bbh_fewshot_sports_understanding/exact_match_stderr 0.03128
# wandb:                                   bbh_fewshot_temporal_sequences/alias  - bbh_fewshot_tempo...
# wandb:                             bbh_fewshot_temporal_sequences/exact_match 0.116
# wandb:                      bbh_fewshot_temporal_sequences/exact_match_stderr 0.02029
# wandb:               bbh_fewshot_tracking_shuffled_objects_five_objects/alias  - bbh_fewshot_track...
# wandb:         bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match 0.18
# wandb:  bbh_fewshot_tracking_shuffled_objects_five_objects/exact_match_stderr 0.02435
# wandb:              bbh_fewshot_tracking_shuffled_objects_seven_objects/alias  - bbh_fewshot_track...
# wandb:        bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match 0.104
# wandb: bbh_fewshot_tracking_shuffled_objects_seven_objects/exact_match_stderr 0.01935
# wandb:              bbh_fewshot_tracking_shuffled_objects_three_objects/alias  - bbh_fewshot_track...
# wandb:        bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match 0.348
# wandb: bbh_fewshot_tracking_shuffled_objects_three_objects/exact_match_stderr 0.03019
# wandb:                                          bbh_fewshot_web_of_lies/alias  - bbh_fewshot_web_o...
# wandb:                                    bbh_fewshot_web_of_lies/exact_match 0.488
# wandb:                             bbh_fewshot_web_of_lies/exact_match_stderr 0.03168
# wandb:                                         bbh_fewshot_word_sorting/alias  - bbh_fewshot_word_...
# wandb:                                   bbh_fewshot_word_sorting/exact_match 0.224
# wandb:                            bbh_fewshot_word_sorting/exact_match_stderr 0.02642
# wandb:
# wandb: 🚀 View run Llama-2-7b-hf-AutoGPTQ-bbh at: https://wandb.ai/atu-twhool02/quantized_model_evaluation/runs/ratm6i5x/workspace
# wandb: Synced 5 W&B file(s), 3 media file(s), 30 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240403_193401-ratm6i5x/logs

# %% [markdown]
# ## Evaluate Falcon-7B-finetuned-guanaco-NF4-QLORA - works

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Falcon-7B-finetuned-guanaco-NF4-QLORA\
    --tasks hellaswag,mmlu_stem \
    --num_fewshot 5 \
    --device cuda:0 \
    --batch_size auto:4
# Out:
# 2024-03-03 13:55:01.907433: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-03 13:55:01.907481: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-03 13:55:01.908785: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-03 13:55:03.129415: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-03:13:55:06,338 INFO     [__main__.py:217] Verbosity set to INFO
# 2024-03-03:13:55:06,338 INFO     [__init__.py:369] lm_eval.tasks.initialize_tasks() is deprecated and no longer necessary. It will be removed in v0.4.2 release. TaskManager will instead be used.
# 2024-03-03:13:55:12,054 INFO     [__main__.py:293] Selected Tasks: ['hellaswag', 'mmlu_stem']
# 2024-03-03:13:55:12,054 INFO     [__main__.py:294] Loading selected tasks...
# 2024-03-03:13:55:12,055 INFO     [evaluator.py:135] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-03:13:55:12,103 INFO     [huggingface.py:162] Using device 'cuda:0'
# config.json: 100% 1.30k/1.30k [00:00<00:00, 3.19MB/s]
# model.safetensors.index.json: 100% 16.9k/16.9k [00:00<00:00, 57.7MB/s]
# Downloading shards:   0% 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 10.5M/4.98G [00:00<02:11, 37.9MB/s]
# model-00001-of-00003.safetensors:   0% 21.0M/4.98G [00:00<01:51, 44.5MB/s]
# model-00001-of-00003.safetensors:   1% 31.5M/4.98G [00:00<01:42, 48.5MB/s]
# model-00001-of-00003.safetensors:   1% 41.9M/4.98G [00:00<01:35, 51.8MB/s]
# model-00001-of-00003.safetensors:   1% 52.4M/4.98G [00:00<01:23, 59.3MB/s]
# model-00001-of-00003.safetensors:   1% 62.9M/4.98G [00:01<01:15, 65.2MB/s]
# model-00001-of-00003.safetensors:   1% 73.4M/4.98G [00:01<01:10, 69.8MB/s]
# model-00001-of-00003.safetensors:   2% 83.9M/4.98G [00:01<01:07, 72.7MB/s]
# model-00001-of-00003.safetensors:   2% 94.4M/4.98G [00:01<01:05, 74.9MB/s]
# model-00001-of-00003.safetensors:   2% 105M/4.98G [00:01<01:03, 76.7MB/s]
# model-00001-of-00003.safetensors:   2% 115M/4.98G [00:01<01:02, 78.0MB/s]
# model-00001-of-00003.safetensors:   3% 126M/4.98G [00:01<01:01, 78.7MB/s]
# model-00001-of-00003.safetensors:   3% 136M/4.98G [00:02<01:00, 80.0MB/s]
# model-00001-of-00003.safetensors:   3% 147M/4.98G [00:02<01:00, 80.5MB/s]
# model-00001-of-00003.safetensors:   3% 157M/4.98G [00:02<00:59, 80.8MB/s]
# model-00001-of-00003.safetensors:   3% 168M/4.98G [00:02<00:59, 80.3MB/s]
# model-00001-of-00003.safetensors:   4% 178M/4.98G [00:02<01:01, 78.2MB/s]
# model-00001-of-00003.safetensors:   4% 189M/4.98G [00:02<01:09, 68.8MB/s]
# model-00001-of-00003.safetensors:   4% 199M/4.98G [00:02<01:13, 65.0MB/s]
# model-00001-of-00003.safetensors:   4% 210M/4.98G [00:03<01:10, 67.7MB/s]
# model-00001-of-00003.safetensors:   4% 220M/4.98G [00:03<01:22, 57.8MB/s]
# model-00001-of-00003.safetensors:   5% 231M/4.98G [00:03<01:31, 51.8MB/s]
# model-00001-of-00003.safetensors:   5% 241M/4.98G [00:03<01:32, 51.3MB/s]
# model-00001-of-00003.safetensors:   5% 252M/4.98G [00:04<01:37, 48.6MB/s]
# model-00001-of-00003.safetensors:   5% 262M/4.98G [00:04<01:42, 46.2MB/s]
# model-00001-of-00003.safetensors:   5% 273M/4.98G [00:04<01:37, 48.1MB/s]
# model-00001-of-00003.safetensors:   6% 283M/4.98G [00:04<01:36, 48.8MB/s]
# model-00001-of-00003.safetensors:   6% 294M/4.98G [00:04<01:39, 47.0MB/s]
# model-00001-of-00003.safetensors:   6% 304M/4.98G [00:05<01:37, 48.2MB/s]
# model-00001-of-00003.safetensors:   6% 315M/4.98G [00:05<01:40, 46.6MB/s]
# model-00001-of-00003.safetensors:   7% 325M/4.98G [00:05<01:36, 48.2MB/s]
# model-00001-of-00003.safetensors:   7% 336M/4.98G [00:05<01:34, 49.4MB/s]
# model-00001-of-00003.safetensors:   7% 346M/4.98G [00:06<01:37, 47.5MB/s]
# model-00001-of-00003.safetensors:   7% 357M/4.98G [00:06<01:34, 49.1MB/s]
# model-00001-of-00003.safetensors:   7% 367M/4.98G [00:06<01:32, 49.8MB/s]
# model-00001-of-00003.safetensors:   8% 377M/4.98G [00:06<01:33, 49.0MB/s]
# model-00001-of-00003.safetensors:   8% 388M/4.98G [00:06<01:33, 49.0MB/s]
# model-00001-of-00003.safetensors:   8% 398M/4.98G [00:07<01:31, 50.2MB/s]
# model-00001-of-00003.safetensors:   8% 409M/4.98G [00:07<01:29, 50.9MB/s]
# model-00001-of-00003.safetensors:   8% 419M/4.98G [00:07<01:28, 51.4MB/s]
# model-00001-of-00003.safetensors:   9% 430M/4.98G [00:07<01:31, 49.6MB/s]
# model-00001-of-00003.safetensors:   9% 440M/4.98G [00:07<01:30, 50.2MB/s]
# model-00001-of-00003.safetensors:   9% 451M/4.98G [00:08<01:30, 50.0MB/s]
# model-00001-of-00003.safetensors:   9% 461M/4.98G [00:08<01:28, 50.9MB/s]
# model-00001-of-00003.safetensors:   9% 472M/4.98G [00:08<01:29, 50.5MB/s]
# model-00001-of-00003.safetensors:  10% 482M/4.98G [00:08<01:28, 50.6MB/s]
# model-00001-of-00003.safetensors:  10% 493M/4.98G [00:08<01:27, 51.6MB/s]
# model-00001-of-00003.safetensors:  10% 503M/4.98G [00:09<01:25, 52.4MB/s]
# model-00001-of-00003.safetensors:  10% 514M/4.98G [00:09<01:24, 52.6MB/s]
# model-00001-of-00003.safetensors:  11% 524M/4.98G [00:09<01:25, 52.1MB/s]
# model-00001-of-00003.safetensors:  11% 535M/4.98G [00:09<01:26, 51.2MB/s]
# model-00001-of-00003.safetensors:  11% 545M/4.98G [00:09<01:25, 51.9MB/s]
# model-00001-of-00003.safetensors:  11% 556M/4.98G [00:10<01:24, 52.4MB/s]
# model-00001-of-00003.safetensors:  11% 566M/4.98G [00:10<01:31, 48.2MB/s]
# model-00001-of-00003.safetensors:  12% 577M/4.98G [00:10<01:20, 54.7MB/s]
# model-00001-of-00003.safetensors:  12% 587M/4.98G [00:10<01:22, 53.4MB/s]
# model-00001-of-00003.safetensors:  12% 598M/4.98G [00:10<01:21, 53.5MB/s]
# model-00001-of-00003.safetensors:  33% 1.63G/4.98G [00:38<01:30, 37.3MB/s]
# model-00001-of-00003.safetensors:  33% 1.64G/4.98G [00:39<01:32, 36.3MB/s]
# model-00001-of-00003.safetensors:  33% 1.65G/4.98G [00:39<01:29, 37.1MB/s]
# model-00001-of-00003.safetensors:  33% 1.66G/4.98G [00:39<01:31, 36.2MB/s]
# model-00001-of-00003.safetensors:  33% 1.67G/4.98G [00:39<01:29, 37.1MB/s]
# model-00001-of-00003.safetensors:  34% 1.68G/4.98G [00:40<01:31, 36.0MB/s]
# model-00001-of-00003.safetensors:  34% 1.69G/4.98G [00:40<01:28, 37.1MB/s]
# model-00001-of-00003.safetensors:  34% 1.70G/4.98G [00:40<01:30, 36.2MB/s]
# model-00001-of-00003.safetensors:  34% 1.71G/4.98G [00:41<01:28, 37.0MB/s]
# model-00001-of-00003.safetensors:  35% 1.72G/4.98G [00:41<01:28, 37.0MB/s]
# model-00001-of-00003.safetensors:  35% 1.73G/4.98G [00:41<01:28, 36.9MB/s]
# model-00001-of-00003.safetensors:  35% 1.74G/4.98G [00:41<01:25, 37.7MB/s]
# model-00001-of-00003.safetensors:  35% 1.75G/4.98G [00:42<01:27, 36.7MB/s]
# model-00001-of-00003.safetensors:  35% 1.76G/4.98G [00:42<01:26, 37.3MB/s]
# model-00001-of-00003.safetensors:  36% 1.77G/4.98G [00:42<01:24, 38.0MB/s]
# model-00001-of-00003.safetensors:  36% 1.78G/4.98G [00:42<01:25, 37.4MB/s]
# model-00001-of-00003.safetensors:  36% 1.79G/4.98G [00:43<01:24, 37.5MB/s]
# model-00001-of-00003.safetensors:  36% 1.80G/4.98G [00:43<01:23, 38.3MB/s]
# model-00001-of-00003.safetensors:  36% 1.81G/4.98G [00:43<01:21, 38.9MB/s]
# model-00001-of-00003.safetensors:  37% 1.82G/4.98G [00:44<01:21, 38.6MB/s]
# model-00001-of-00003.safetensors:  37% 1.84G/4.98G [00:44<01:22, 38.1MB/s]
# model-00001-of-00003.safetensors:  37% 1.85G/4.98G [00:44<01:21, 38.6MB/s]
# model-00001-of-00003.safetensors:  37% 1.86G/4.98G [00:44<01:19, 39.1MB/s]
# model-00001-of-00003.safetensors:  37% 1.87G/4.98G [00:45<01:18, 39.6MB/s]
# model-00001-of-00003.safetensors:  38% 1.88G/4.98G [00:45<01:17, 40.0MB/s]
# model-00001-of-00003.safetensors:  38% 1.89G/4.98G [00:45<01:16, 40.3MB/s]
# model-00001-of-00003.safetensors:  38% 1.90G/4.98G [00:45<01:16, 40.4MB/s]
# model-00001-of-00003.safetensors:  38% 1.91G/4.98G [00:46<01:15, 40.8MB/s]
# model-00001-of-00003.safetensors:  39% 1.92G/4.98G [00:46<01:13, 41.7MB/s]
# model-00001-of-00003.safetensors:  39% 1.93G/4.98G [00:46<01:10, 43.2MB/s]
# model-00001-of-00003.safetensors:  39% 1.94G/4.98G [00:46<01:11, 42.7MB/s]
# model-00001-of-00003.safetensors:  39% 1.95G/4.98G [00:47<01:11, 42.4MB/s]
# model-00003-of-00003.safetensors:  99% 3.87G/3.89G [00:50<00:00, 79.8MB/s]
# model-00003-of-00003.safetensors: 100% 3.88G/3.89G [00:50<00:00, 79.5MB/s]
# model-00003-of-00003.safetensors: 100% 3.89G/3.89G [00:50<00:00, 76.5MB/s]
# Downloading shards: 100% 3/3 [03:48<00:00, 76.14s/it]
# Loading checkpoint shards: 100% 3/3 [00:04<00:00,  1.65s/it]
# generation_config.json: 100% 113/113 [00:00<00:00, 600kB/s]
# tokenizer_config.json: 100% 2.81k/2.81k [00:00<00:00, 12.6MB/s]
# tokenizer.json: 100% 2.73M/2.73M [00:00<00:00, 10.2MB/s]
# special_tokens_map.json: 100% 427/427 [00:00<00:00, 2.78MB/s]
# 2024-03-03:13:59:08,119 INFO     [evaluator.py:193] get_task_dict has been updated to accept an optional argument, `task_manager`Read more here:https://github.com/EleutherAI/lm-evaluation-harness/blob/main/docs/interface.md#external-library-usage
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 4.36k/4.36k [00:00<00:00, 17.7MB/s]
# Downloading metadata: 100% 2.53k/2.53k [00:00<00:00, 16.1MB/s]
# Downloading readme: 100% 6.84k/6.84k [00:00<00:00, 27.5MB/s]
# Downloading data: 47.5MB [00:00, 70.0MB/s]
# Downloading data: 11.8MB [00:00, 54.4MB/s]
# Downloading data: 12.2MB [00:00, 51.6MB/s]
# Generating train split: 100% 39905/39905 [00:04<00:00, 9413.26 examples/s]
# Generating test split: 100% 10003/10003 [00:01<00:00, 9537.28 examples/s]
# Generating validation split: 100% 10042/10042 [00:01<00:00, 9539.86 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 6304.85 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 5562.32 examples/s]
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 5.86k/5.86k [00:00<00:00, 21.1MB/s]
# Downloading readme: 100% 1.11k/1.11k [00:00<00:00, 6.85MB/s]
# Downloading data: 100% 166M/166M [00:02<00:00, 82.6MB/s]
# Generating test split: 235 examples [00:00, 2435.15 examples/s]
# Generating validation split: 26 examples [00:00, 7102.97 examples/s]
# Generating dev split: 5 examples [00:00, 50.97 examples/s]
# Generating test split: 216 examples [00:00, 2226.04 examples/s]
# Generating validation split: 23 examples [00:00, 4891.69 examples/s]
# Generating dev split: 5 examples [00:00, 58.69 examples/s]
# Generating test split: 100 examples [00:00, 1168.17 examples/s]
# Generating validation split: 8 examples [00:00, 1588.90 examples/s]
# Generating dev split: 5 examples [00:00, 58.67 examples/s]
# Generating test split: 100 examples [00:00, 1174.51 examples/s]
# Generating validation split: 11 examples [00:00, 3086.94 examples/s]
# Generating dev split: 5 examples [00:00, 57.79 examples/s]
# Generating test split: 100 examples [00:00, 1112.50 examples/s]
# Generating validation split: 11 examples [00:00, 2313.92 examples/s]
# Generating dev split: 5 examples [00:00, 57.35 examples/s]
# Generating test split: 100 examples [00:00, 1172.85 examples/s]
# Generating validation split: 9 examples [00:00, 3116.64 examples/s]
# Generating dev split: 5 examples [00:00, 58.56 examples/s]
# Generating test split: 270 examples [00:00, 2825.57 examples/s]
# Generating validation split: 29 examples [00:00, 6514.29 examples/s]
# Generating dev split: 5 examples [00:00, 59.33 examples/s]
# Generating test split: 112 examples [00:00, 1322.16 examples/s]
# Generating validation split: 11 examples [00:00, 3338.69 examples/s]
# Generating dev split: 5 examples [00:00, 59.38 examples/s]
# Generating test split: 203 examples [00:00, 2205.92 examples/s]
# Generating validation split: 22 examples [00:00, 4018.23 examples/s]
# Generating dev split: 5 examples [00:00, 60.36 examples/s]
# Generating test split: 100 examples [00:00, 1176.93 examples/s]
# Generating validation split: 11 examples [00:00, 2544.39 examples/s]
# Generating dev split: 5 examples [00:00, 58.37 examples/s]
# Generating test split: 378 examples [00:00, 3651.82 examples/s]
# Generating validation split: 41 examples [00:00, 6484.41 examples/s]
# Generating dev split: 5 examples [00:00, 59.17 examples/s]
# Generating test split: 100 examples [00:00, 1130.22 examples/s]
# Generating validation split: 11 examples [00:00, 2911.42 examples/s]
# Generating dev split: 5 examples [00:00, 60.27 examples/s]
# Generating test split: 102 examples [00:00, 1131.10 examples/s]
# Generating validation split: 11 examples [00:00, 3427.74 examples/s]
# Generating dev split: 5 examples [00:00, 57.77 examples/s]
# Generating test split: 135 examples [00:00, 1565.07 examples/s]
# Generating validation split: 14 examples [00:00, 4440.09 examples/s]
# Generating dev split: 5 examples [00:00, 60.13 examples/s]
# Generating test split: 151 examples [00:00, 1659.09 examples/s]
# Generating validation split: 17 examples [00:00, 3938.75 examples/s]
# Generating dev split: 5 examples [00:00, 57.50 examples/s]
# Generating test split: 144 examples [00:00, 1660.67 examples/s]
# Generating validation split: 16 examples [00:00, 3042.52 examples/s]
# Generating dev split: 5 examples [00:00, 58.48 examples/s]
# Generating test split: 145 examples [00:00, 1687.16 examples/s]
# Generating validation split: 16 examples [00:00, 4135.37 examples/s]
# Generating dev split: 5 examples [00:00, 59.07 examples/s]
# Generating test split: 310 examples [00:00, 3194.67 examples/s]
# Generating validation split: 32 examples [00:00, 7014.62 examples/s]
# Generating dev split: 5 examples [00:00, 58.93 examples/s]
# Generating test split: 152 examples [00:00, 1750.39 examples/s]
# Generating validation split: 16 examples [00:00, 5295.00 examples/s]
# Generating dev split: 5 examples [00:00, 56.84 examples/s]
# 2024-03-03:14:00:25,482 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_astronomy from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_biology from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_biology from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_physics from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_anatomy from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_physics from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_mathematics from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_computer_security from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_machine_learning from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_computer_science from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_chemistry from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 5
# 2024-03-03:14:00:25,483 WARNING  [evaluator.py:225] Overwriting default num_fewshot of hellaswag from None to 5
# 2024-03-03:14:00:25,486 INFO     [task.py:386] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:02<00:00, 67.53it/s]
# 2024-03-03:14:00:27,744 INFO     [task.py:386] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:04<00:00, 67.36it/s]
# 2024-03-03:14:00:32,360 INFO     [task.py:386] Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:02<00:00, 68.14it/s]
# 2024-03-03:14:00:34,495 INFO     [task.py:386] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:02<00:00, 68.58it/s]
# 2024-03-03:14:00:36,602 INFO     [task.py:386] Building contexts for mmlu_high_school_physics on rank 0...
# 100% 151/151 [00:02<00:00, 68.42it/s]
# 2024-03-03:14:00:38,816 INFO     [task.py:386] Building contexts for mmlu_anatomy on rank 0...
# 100% 135/135 [00:01<00:00, 68.25it/s]
# 2024-03-03:14:00:40,800 INFO     [task.py:386] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:01<00:00, 68.37it/s]
# 2024-03-03:14:00:42,297 INFO     [task.py:386] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:01<00:00, 67.95it/s]
# 2024-03-03:14:00:43,774 INFO     [task.py:386] Building contexts for mmlu_elementary_mathematics on rank 0...
# 100% 378/378 [00:05<00:00, 68.23it/s]
# 2024-03-03:14:00:49,331 INFO     [task.py:386] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:01<00:00, 68.07it/s]
# 2024-03-03:14:00:50,806 INFO     [task.py:386] Building contexts for mmlu_high_school_chemistry on rank 0...
# 100% 203/203 [00:03<00:00, 67.63it/s]
# 2024-03-03:14:00:53,817 INFO     [task.py:386] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:01<00:00, 68.12it/s]
# 2024-03-03:14:00:55,466 INFO     [task.py:386] Building contexts for mmlu_high_school_mathematics on rank 0...
# 100% 270/270 [00:03<00:00, 68.15it/s]
# 2024-03-03:14:00:59,440 INFO     [task.py:386] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 68.13it/s]
# 2024-03-03:14:01:00,913 INFO     [task.py:386] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 68.33it/s]
# 2024-03-03:14:01:02,382 INFO     [task.py:386] Building contexts for mmlu_abstract_algebra on rank 0...
# 100% 100/100 [00:01<00:00, 67.79it/s]
# 2024-03-03:14:01:03,862 INFO     [task.py:386] Building contexts for mmlu_college_chemistry on rank 0...
# 100% 100/100 [00:01<00:00, 67.77it/s]
# 2024-03-03:14:01:05,343 INFO     [task.py:386] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:03<00:00, 67.46it/s]
# 2024-03-03:14:01:08,555 INFO     [task.py:386] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:03<00:00, 68.21it/s]
# 2024-03-03:14:01:12,012 INFO     [task.py:386] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [01:45<00:00, 94.94it/s]
# 2024-03-03:14:02:58,893 INFO     [evaluator.py:359] Running loglikelihood requests
# Running loglikelihood requests:   0% 0/52780 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 32
# Running loglikelihood requests:  30% 15949/52780 [10:09<21:08, 29.03it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Running loglikelihood requests:  30% 15980/52780 [10:19<21:07, 29.03it/s]Determined largest batch size: 64
# Running loglikelihood requests: 100% 52780/52780 [31:14<00:00, 28.16it/s]
# hf (pretrained=twhoool02/Falcon-7B-finetuned-guanaco-NF4-QLORA), gen_kwargs: (None), limit: None, num_fewshot: 5, batch_size: auto:4 (32,64,64,64,64)
# |             Tasks             |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |-------------------------------|-------|------|-----:|--------|-----:|---|-----:|
# |stem                           |N/A    |none  |     5|acc     |0.2594|±  |0.0078|
# | - abstract_algebra            |      0|none  |     5|acc     |0.2600|±  |0.0441|
# | - anatomy                     |      0|none  |     5|acc     |0.2667|±  |0.0382|
# | - astronomy                   |      0|none  |     5|acc     |0.2039|±  |0.0328|
# | - college_biology             |      0|none  |     5|acc     |0.2014|±  |0.0335|
# | - college_chemistry           |      0|none  |     5|acc     |0.2100|±  |0.0409|
# | - college_computer_science    |      0|none  |     5|acc     |0.2700|±  |0.0446|
# | - college_mathematics         |      0|none  |     5|acc     |0.2700|±  |0.0446|
# | - college_physics             |      0|none  |     5|acc     |0.2157|±  |0.0409|
# | - computer_security           |      0|none  |     5|acc     |0.2700|±  |0.0446|
# | - conceptual_physics          |      0|none  |     5|acc     |0.3149|±  |0.0304|
# | - electrical_engineering      |      0|none  |     5|acc     |0.2759|±  |0.0372|
# | - elementary_mathematics      |      0|none  |     5|acc     |0.2778|±  |0.0231|
# | - high_school_biology         |      0|none  |     5|acc     |0.2742|±  |0.0254|
# | - high_school_chemistry       |      0|none  |     5|acc     |0.2759|±  |0.0314|
# | - high_school_computer_science|      0|none  |     5|acc     |0.2400|±  |0.0429|
# | - high_school_mathematics     |      0|none  |     5|acc     |0.2593|±  |0.0267|
# | - high_school_physics         |      0|none  |     5|acc     |0.2781|±  |0.0366|
# | - high_school_statistics      |      0|none  |     5|acc     |0.1620|±  |0.0251|
# | - machine_learning            |      0|none  |     5|acc     |0.3661|±  |0.0457|
# |hellaswag                      |      1|none  |     5|acc     |0.5827|±  |0.0049|
# |                               |       |none  |     5|acc_norm|0.7748|±  |0.0042|
#
# |Groups|Version|Filter|n-shot|Metric|Value |   |Stderr|
# |------|-------|------|-----:|------|-----:|---|-----:|
# |stem  |N/A    |none  |     5|acc   |0.2594|±  |0.0078|

# %% [markdown]
# ## Evaluate llama-2-7b-finetuned-guanaco-NF4-QLORA - works

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/llama-2-7b-finetuned-guanaco-NF4-QLORA \
    --tasks hellaswag,mmlu_stem \
    --num_fewshot 5 \
    --device cuda:0 \
    --batch_size auto:4
# Out:
# 2024-03-03 14:38:05.888026: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-03 14:38:05.888076: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-03 14:38:05.889325: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-03 14:38:07.038584: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-03:14:38:10,267 INFO     [__main__.py:217] Verbosity set to INFO
# 2024-03-03:14:38:10,267 INFO     [__init__.py:369] lm_eval.tasks.initialize_tasks() is deprecated and no longer necessary. It will be removed in v0.4.2 release. TaskManager will instead be used.
# 2024-03-03:14:38:15,934 INFO     [__main__.py:293] Selected Tasks: ['hellaswag', 'mmlu_stem']
# 2024-03-03:14:38:15,934 INFO     [__main__.py:294] Loading selected tasks...
# 2024-03-03:14:38:15,935 INFO     [evaluator.py:135] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-03:14:38:15,976 INFO     [huggingface.py:162] Using device 'cuda:0'
# config.json: 100% 684/684 [00:00<00:00, 1.64MB/s]
# model.safetensors.index.json: 100% 23.9k/23.9k [00:00<00:00, 72.1MB/s]
# Downloading shards:   0% 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0% 0.00/4.94G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 10.5M/4.94G [00:00<01:03, 77.6MB/s]
# model-00001-of-00003.safetensors:   0% 21.0M/4.94G [00:00<01:07, 73.4MB/s]
# model-00001-of-00003.safetensors:   1% 31.5M/4.94G [00:00<01:02, 78.4MB/s]
# model-00001-of-00003.safetensors:   1% 41.9M/4.94G [00:00<01:01, 79.6MB/s]
# model-00001-of-00003.safetensors:   1% 52.4M/4.94G [00:00<01:14, 65.9MB/s]
# model-00001-of-00003.safetensors:   1% 62.9M/4.94G [00:00<01:07, 72.4MB/s]
# model-00001-of-00003.safetensors:   1% 73.4M/4.94G [00:01<01:56, 41.9MB/s]
# model-00001-of-00003.safetensors:   2% 83.9M/4.94G [00:01<01:47, 45.1MB/s]
# model-00001-of-00003.safetensors:   2% 94.4M/4.94G [00:01<01:33, 51.9MB/s]
# model-00001-of-00003.safetensors:   2% 105M/4.94G [00:01<01:47, 45.0MB/s]
# model-00001-of-00003.safetensors:   2% 115M/4.94G [00:02<01:42, 47.1MB/s]
# model-00001-of-00003.safetensors:   3% 126M/4.94G [00:02<01:28, 54.3MB/s]
# model-00001-of-00003.safetensors:   3% 136M/4.94G [00:02<01:40, 48.0MB/s]
# model-00001-of-00003.safetensors:   3% 147M/4.94G [00:02<01:28, 54.1MB/s]
# model-00001-of-00003.safetensors:   3% 157M/4.94G [00:02<01:19, 60.2MB/s]
# model-00001-of-00003.safetensors:   3% 168M/4.94G [00:02<01:13, 65.3MB/s]
# model-00001-of-00003.safetensors:   4% 178M/4.94G [00:03<01:08, 69.3MB/s]
# model-00001-of-00003.safetensors:   4% 189M/4.94G [00:03<01:05, 72.6MB/s]
# model-00001-of-00003.safetensors:   4% 199M/4.94G [00:03<01:15, 62.6MB/s]
# model-00001-of-00003.safetensors:   4% 210M/4.94G [00:03<01:15, 63.0MB/s]
# model-00001-of-00003.safetensors:   4% 220M/4.94G [00:03<01:10, 67.0MB/s]
# model-00001-of-00003.safetensors:   5% 231M/4.94G [00:03<01:14, 63.4MB/s]
# model-00001-of-00003.safetensors:   5% 241M/4.94G [00:04<01:10, 66.7MB/s]
# model-00001-of-00003.safetensors:   5% 252M/4.94G [00:04<01:07, 69.9MB/s]
# model-00001-of-00003.safetensors:   5% 262M/4.94G [00:04<01:03, 73.7MB/s]
# model-00001-of-00003.safetensors:   6% 273M/4.94G [00:04<01:04, 72.3MB/s]
# model-00001-of-00003.safetensors:   6% 283M/4.94G [00:04<00:59, 77.7MB/s]
# model-00001-of-00003.safetensors:   6% 294M/4.94G [00:04<00:58, 79.3MB/s]
# model-00001-of-00003.safetensors:   6% 304M/4.94G [00:04<00:57, 80.0MB/s]
# model-00001-of-00003.safetensors:   6% 315M/4.94G [00:04<00:57, 80.3MB/s]
# model-00001-of-00003.safetensors:   7% 325M/4.94G [00:05<01:11, 64.8MB/s]
# model-00001-of-00003.safetensors:   7% 336M/4.94G [00:05<01:05, 70.2MB/s]
# model-00001-of-00003.safetensors:   7% 346M/4.94G [00:05<01:02, 73.1MB/s]
# model-00001-of-00003.safetensors:   7% 357M/4.94G [00:05<01:06, 68.6MB/s]
# model-00001-of-00003.safetensors:   7% 367M/4.94G [00:05<01:03, 71.9MB/s]
# model-00001-of-00003.safetensors:   8% 377M/4.94G [00:05<01:01, 74.5MB/s]
# model-00001-of-00003.safetensors:   8% 388M/4.94G [00:06<00:59, 76.4MB/s]
# model-00001-of-00003.safetensors:   8% 398M/4.94G [00:06<01:00, 75.6MB/s]
# model-00001-of-00003.safetensors:   8% 409M/4.94G [00:06<01:11, 63.7MB/s]
# model-00001-of-00003.safetensors:   8% 419M/4.94G [00:06<01:07, 66.6MB/s]
# model-00001-of-00003.safetensors:   9% 430M/4.94G [00:06<01:04, 70.3MB/s]
# model-00001-of-00003.safetensors:   9% 440M/4.94G [00:06<01:05, 69.1MB/s]
# model-00001-of-00003.safetensors:   9% 451M/4.94G [00:07<01:10, 63.4MB/s]
# model-00001-of-00003.safetensors:   9% 461M/4.94G [00:07<01:05, 67.9MB/s]
# model-00001-of-00003.safetensors:  10% 472M/4.94G [00:07<01:02, 71.5MB/s]
# model-00001-of-00003.safetensors:  10% 482M/4.94G [00:07<01:14, 59.4MB/s]
# model-00001-of-00003.safetensors:  10% 493M/4.94G [00:07<01:14, 59.4MB/s]
# model-00001-of-00003.safetensors:  10% 503M/4.94G [00:07<01:17, 57.5MB/s]
# model-00001-of-00003.safetensors:  10% 514M/4.94G [00:08<01:21, 54.6MB/s]
# model-00001-of-00003.safetensors:  11% 524M/4.94G [00:08<01:13, 60.4MB/s]
# model-00001-of-00003.safetensors:  11% 535M/4.94G [00:08<01:13, 59.6MB/s]
# model-00001-of-00003.safetensors:  11% 556M/4.94G [00:08<01:01, 71.8MB/s]
# model-00001-of-00003.safetensors:  11% 566M/4.94G [00:08<01:06, 66.2MB/s]
# model-00001-of-00003.safetensors:  12% 577M/4.94G [00:08<01:07, 64.8MB/s]
# model-00001-of-00003.safetensors:  12% 587M/4.94G [00:09<01:03, 68.5MB/s]
# model-00001-of-00003.safetensors:  12% 598M/4.94G [00:09<01:09, 62.6MB/s]
# model-00001-of-00003.safetensors:  12% 608M/4.94G [00:09<01:17, 56.1MB/s]
# model-00001-of-00003.safetensors:  13% 619M/4.94G [00:09<01:10, 61.6MB/s]
# model-00001-of-00003.safetensors:  13% 629M/4.94G [00:09<01:05, 66.0MB/s]
# model-00001-of-00003.safetensors:  13% 640M/4.94G [00:09<01:04, 66.9MB/s]
# model-00001-of-00003.safetensors:  13% 650M/4.94G [00:10<01:00, 70.7MB/s]
# model-00001-of-00003.safetensors:  34% 1.68G/4.94G [00:25<00:43, 75.6MB/s]
# model-00001-of-00003.safetensors:  34% 1.69G/4.94G [00:26<00:42, 77.0MB/s]
# model-00001-of-00003.safetensors:  34% 1.70G/4.94G [00:26<00:41, 78.4MB/s]
# model-00001-of-00003.safetensors:  35% 1.71G/4.94G [00:26<00:40, 79.1MB/s]
# model-00001-of-00003.safetensors:  35% 1.72G/4.94G [00:26<00:40, 79.5MB/s]
# model-00001-of-00003.safetensors:  35% 1.73G/4.94G [00:26<00:40, 80.0MB/s]
# model-00001-of-00003.safetensors:  35% 1.74G/4.94G [00:26<00:39, 80.4MB/s]
# model-00001-of-00003.safetensors:  35% 1.75G/4.94G [00:26<00:39, 80.6MB/s]
# model-00001-of-00003.safetensors:  36% 1.76G/4.94G [00:26<00:40, 78.7MB/s]
# model-00001-of-00003.safetensors:  36% 1.77G/4.94G [00:27<00:39, 79.4MB/s]
# model-00001-of-00003.safetensors:  36% 1.78G/4.94G [00:27<00:41, 76.2MB/s]
# model-00001-of-00003.safetensors:  36% 1.79G/4.94G [00:27<00:43, 72.7MB/s]
# model-00001-of-00003.safetensors:  37% 1.80G/4.94G [00:27<00:42, 74.6MB/s]
# model-00001-of-00003.safetensors:  37% 1.81G/4.94G [00:27<00:56, 54.9MB/s]
# model-00001-of-00003.safetensors:  37% 1.82G/4.94G [00:28<00:59, 52.1MB/s]
# model-00001-of-00003.safetensors:  37% 1.84G/4.94G [00:28<00:53, 58.4MB/s]
# model-00001-of-00003.safetensors:  37% 1.85G/4.94G [00:28<00:48, 63.8MB/s]
# model-00001-of-00003.safetensors:  38% 1.86G/4.94G [00:28<00:45, 68.3MB/s]
# model-00001-of-00003.safetensors:  38% 1.87G/4.94G [00:28<00:46, 66.7MB/s]
# model-00001-of-00003.safetensors:  38% 1.88G/4.94G [00:28<00:45, 67.2MB/s]
# model-00001-of-00003.safetensors:  38% 1.89G/4.94G [00:28<00:42, 71.6MB/s]
# model-00001-of-00003.safetensors:  38% 1.90G/4.94G [00:29<00:49, 62.0MB/s]
# model-00001-of-00003.safetensors:  39% 1.91G/4.94G [00:29<01:00, 50.5MB/s]
# model-00001-of-00003.safetensors:  39% 1.92G/4.94G [00:29<00:53, 57.0MB/s]
# model-00001-of-00003.safetensors:  39% 1.93G/4.94G [00:29<01:00, 49.7MB/s]
# model-00001-of-00003.safetensors:  39% 1.94G/4.94G [00:30<01:02, 47.9MB/s]
# model-00001-of-00003.safetensors:  39% 1.95G/4.94G [00:30<00:55, 54.3MB/s]
# model-00001-of-00003.safetensors:  40% 1.96G/4.94G [00:30<00:49, 60.5MB/s]
# model-00001-of-00003.safetensors:  40% 1.97G/4.94G [00:30<00:49, 59.6MB/s]
# model-00001-of-00003.safetensors:  40% 1.98G/4.94G [00:30<00:45, 64.8MB/s]
# model-00001-of-00003.safetensors:  40% 1.99G/4.94G [00:30<00:52, 56.1MB/s]
# model-00001-of-00003.safetensors:  41% 2.00G/4.94G [00:30<00:47, 61.8MB/s]
# model-00001-of-00003.safetensors:  41% 2.01G/4.94G [00:31<00:44, 65.8MB/s]
# model-00001-of-00003.safetensors:  41% 2.02G/4.94G [00:31<00:44, 65.4MB/s]
# model-00001-of-00003.safetensors:  41% 2.03G/4.94G [00:31<00:48, 60.0MB/s]
# model-00001-of-00003.safetensors:  41% 2.04G/4.94G [00:31<00:44, 64.7MB/s]
# model-00001-of-00003.safetensors:  42% 2.06G/4.94G [00:31<00:42, 68.6MB/s]
# model-00001-of-00003.safetensors:  42% 2.07G/4.94G [00:31<00:40, 71.1MB/s]
# model-00001-of-00003.safetensors:  42% 2.08G/4.94G [00:31<00:38, 74.2MB/s]
# model-00001-of-00003.safetensors:  42% 2.09G/4.94G [00:32<00:37, 76.2MB/s]
# model-00001-of-00003.safetensors:  42% 2.10G/4.94G [00:32<00:41, 69.2MB/s]
# model-00001-of-00003.safetensors:  43% 2.11G/4.94G [00:32<00:39, 72.0MB/s]
# model-00001-of-00003.safetensors:  43% 2.12G/4.94G [00:32<00:39, 71.2MB/s]
# model-00001-of-00003.safetensors:  43% 2.13G/4.94G [00:32<00:38, 72.1MB/s]
# model-00001-of-00003.safetensors:  43% 2.14G/4.94G [00:32<00:37, 75.4MB/s]
# model-00001-of-00003.safetensors:  44% 2.15G/4.94G [00:32<00:36, 77.1MB/s]
# model-00001-of-00003.safetensors:  44% 2.16G/4.94G [00:33<00:35, 78.3MB/s]
# model-00001-of-00003.safetensors:  44% 2.17G/4.94G [00:33<00:34, 79.3MB/s]
# model-00001-of-00003.safetensors:  44% 2.18G/4.94G [00:33<00:34, 79.7MB/s]
# model-00001-of-00003.safetensors:  44% 2.19G/4.94G [00:33<00:34, 80.3MB/s]
# model-00001-of-00003.safetensors:  45% 2.20G/4.94G [00:33<00:36, 75.9MB/s]
# model-00001-of-00003.safetensors:  45% 2.21G/4.94G [00:33<00:40, 66.9MB/s]
# model-00001-of-00003.safetensors:  45% 2.22G/4.94G [00:33<00:37, 71.7MB/s]
# model-00001-of-00003.safetensors:  45% 2.23G/4.94G [00:34<00:38, 70.8MB/s]
# model-00001-of-00003.safetensors:  45% 2.24G/4.94G [00:34<00:46, 57.5MB/s]
# model-00001-of-00003.safetensors:  46% 2.25G/4.94G [00:34<00:43, 61.8MB/s]
# model-00001-of-00003.safetensors:  46% 2.26G/4.94G [00:34<00:39, 68.0MB/s]
# model-00001-of-00003.safetensors:  46% 2.28G/4.94G [00:34<00:37, 71.5MB/s]
# model-00001-of-00003.safetensors:  46% 2.29G/4.94G [00:34<00:35, 74.1MB/s]
# model-00001-of-00003.safetensors:  46% 2.30G/4.94G [00:35<00:35, 75.2MB/s]
# model-00001-of-00003.safetensors:  47% 2.31G/4.94G [00:35<00:39, 67.2MB/s]
# model-00001-of-00003.safetensors:  47% 2.32G/4.94G [00:35<00:37, 70.6MB/s]
# model-00001-of-00003.safetensors:  47% 2.33G/4.94G [00:35<00:39, 66.3MB/s]
# model-00001-of-00003.safetensors:  47% 2.34G/4.94G [00:35<00:36, 71.1MB/s]
# model-00001-of-00003.safetensors:  48% 2.35G/4.94G [00:35<00:34, 74.7MB/s]
# model-00001-of-00003.safetensors:  48% 2.36G/4.94G [00:35<00:33, 76.1MB/s]
# model-00001-of-00003.safetensors:  48% 2.37G/4.94G [00:36<00:35, 72.0MB/s]
# model-00001-of-00003.safetensors:  48% 2.38G/4.94G [00:36<00:34, 74.7MB/s]
# model-00001-of-00003.safetensors:  48% 2.39G/4.94G [00:36<00:33, 76.5MB/s]
# model-00001-of-00003.safetensors:  49% 2.40G/4.94G [00:36<00:43, 57.7MB/s]
# model-00001-of-00003.safetensors:  49% 2.41G/4.94G [00:36<00:40, 62.9MB/s]
# model-00001-of-00003.safetensors:  49% 2.42G/4.94G [00:37<00:48, 51.9MB/s]
# model-00001-of-00003.safetensors:  49% 2.43G/4.94G [00:37<00:46, 54.5MB/s]
# model-00001-of-00003.safetensors:  49% 2.44G/4.94G [00:37<00:41, 60.6MB/s]
# model-00001-of-00003.safetensors:  50% 2.45G/4.94G [00:37<00:42, 58.6MB/s]
# model-00001-of-00003.safetensors:  50% 2.46G/4.94G [00:37<00:40, 61.2MB/s]
# model-00001-of-00003.safetensors:  50% 2.47G/4.94G [00:37<00:37, 66.2MB/s]
# model-00001-of-00003.safetensors:  50% 2.49G/4.94G [00:37<00:34, 70.1MB/s]
# model-00001-of-00003.safetensors:  51% 2.50G/4.94G [00:38<00:33, 72.8MB/s]
# model-00001-of-00003.safetensors:  51% 2.51G/4.94G [00:38<00:32, 75.5MB/s]
# model-00001-of-00003.safetensors:  51% 2.52G/4.94G [00:38<00:31, 77.3MB/s]
# model-00001-of-00003.safetensors:  51% 2.53G/4.94G [00:38<00:30, 78.4MB/s]
# model-00001-of-00003.safetensors:  51% 2.54G/4.94G [00:38<00:30, 79.3MB/s]
# model-00001-of-00003.safetensors:  52% 2.55G/4.94G [00:38<00:35, 67.6MB/s]
# model-00001-of-00003.safetensors:  52% 2.56G/4.94G [00:38<00:33, 70.9MB/s]
# model-00001-of-00003.safetensors:  52% 2.57G/4.94G [00:39<00:39, 60.1MB/s]
# model-00001-of-00003.safetensors:  52% 2.58G/4.94G [00:39<00:45, 52.1MB/s]
# model-00001-of-00003.safetensors:  52% 2.59G/4.94G [00:39<00:40, 58.6MB/s]
# model-00001-of-00003.safetensors:  53% 2.60G/4.94G [00:39<00:54, 42.6MB/s]
# model-00001-of-00003.safetensors:  53% 2.61G/4.94G [00:40<00:46, 49.7MB/s]
# model-00001-of-00003.safetensors:  53% 2.62G/4.94G [00:40<00:47, 49.0MB/s]
# model-00001-of-00003.safetensors:  53% 2.63G/4.94G [00:40<00:41, 55.7MB/s]
# model-00001-of-00003.safetensors:  54% 2.64G/4.94G [00:40<00:42, 54.4MB/s]
# model-00001-of-00003.safetensors:  54% 2.65G/4.94G [00:40<00:37, 60.3MB/s]
# model-00001-of-00003.safetensors:  54% 2.66G/4.94G [00:41<00:41, 54.6MB/s]
# model-00001-of-00003.safetensors:  54% 2.67G/4.94G [00:41<00:43, 51.7MB/s]
# model-00001-of-00003.safetensors:  54% 2.68G/4.94G [00:41<00:39, 57.5MB/s]
# model-00001-of-00003.safetensors:  55% 2.69G/4.94G [00:41<00:35, 63.3MB/s]
# model-00001-of-00003.safetensors:  55% 2.71G/4.94G [00:41<00:38, 58.5MB/s]
# model-00001-of-00003.safetensors:  55% 2.72G/4.94G [00:41<00:34, 64.0MB/s]
# model-00001-of-00003.safetensors:  55% 2.73G/4.94G [00:42<00:34, 63.7MB/s]
# model-00001-of-00003.safetensors:  55% 2.74G/4.94G [00:42<00:38, 57.2MB/s]
# model-00001-of-00003.safetensors:  56% 2.75G/4.94G [00:42<00:41, 53.3MB/s]
# model-00001-of-00003.safetensors:  56% 2.76G/4.94G [00:42<00:40, 54.4MB/s]
# model-00001-of-00003.safetensors:  56% 2.77G/4.94G [00:42<00:41, 52.6MB/s]
# model-00001-of-00003.safetensors:  56% 2.78G/4.94G [00:42<00:36, 58.8MB/s]
# model-00001-of-00003.safetensors:  56% 2.79G/4.94G [00:43<00:38, 55.8MB/s]
# model-00001-of-00003.safetensors:  57% 2.80G/4.94G [00:43<00:34, 61.5MB/s]
# model-00001-of-00003.safetensors:  57% 2.81G/4.94G [00:43<00:32, 66.3MB/s]
# model-00001-of-00003.safetensors:  57% 2.82G/4.94G [00:43<00:41, 51.1MB/s]
# model-00001-of-00003.safetensors:  57% 2.83G/4.94G [00:43<00:35, 59.0MB/s]
# model-00001-of-00003.safetensors:  58% 2.84G/4.94G [00:44<00:40, 52.3MB/s]
# model-00001-of-00003.safetensors:  58% 2.85G/4.94G [00:44<00:43, 48.5MB/s]
# model-00001-of-00003.safetensors:  58% 2.86G/4.94G [00:44<00:37, 55.0MB/s]
# model-00001-of-00003.safetensors:  58% 2.87G/4.94G [00:44<00:41, 49.4MB/s]
# model-00001-of-00003.safetensors:  58% 2.88G/4.94G [00:44<00:36, 56.0MB/s]
# model-00001-of-00003.safetensors:  59% 2.89G/4.94G [00:45<00:33, 61.6MB/s]
# model-00001-of-00003.safetensors:  59% 2.90G/4.94G [00:45<00:37, 54.9MB/s]
# model-00001-of-00003.safetensors:  59% 2.92G/4.94G [00:45<00:34, 58.0MB/s]
# model-00001-of-00003.safetensors:  59% 2.93G/4.94G [00:45<00:31, 64.0MB/s]
# model-00001-of-00003.safetensors:  59% 2.94G/4.94G [00:45<00:30, 66.6MB/s]
# model-00001-of-00003.safetensors:  60% 2.95G/4.94G [00:45<00:29, 67.8MB/s]
# model-00001-of-00003.safetensors:  60% 2.96G/4.94G [00:45<00:27, 71.4MB/s]
# model-00001-of-00003.safetensors:  60% 2.97G/4.94G [00:46<00:26, 74.2MB/s]
# model-00001-of-00003.safetensors:  60% 2.98G/4.94G [00:46<00:34, 56.6MB/s]
# model-00001-of-00003.safetensors:  61% 2.99G/4.94G [00:46<00:32, 59.8MB/s]
# model-00001-of-00003.safetensors:  61% 3.00G/4.94G [00:46<00:31, 61.1MB/s]
# model-00001-of-00003.safetensors:  61% 3.01G/4.94G [00:46<00:31, 62.2MB/s]
# model-00002-of-00003.safetensors:   3% 157M/4.95G [00:02<01:03, 75.4MB/s]
# model-00002-of-00003.safetensors:   3% 168M/4.95G [00:02<01:02, 76.1MB/s]
# model-00002-of-00003.safetensors:   4% 178M/4.95G [00:02<01:03, 74.7MB/s]
# model-00002-of-00003.safetensors:   4% 189M/4.95G [00:02<01:03, 74.5MB/s]
# model-00002-of-00003.safetensors:   4% 199M/4.95G [00:02<01:03, 74.4MB/s]
# model-00002-of-00003.safetensors:   4% 210M/4.95G [00:02<01:02, 76.3MB/s]
# model-00002-of-00003.safetensors:   4% 220M/4.95G [00:02<01:00, 77.7MB/s]
# model-00002-of-00003.safetensors:   5% 231M/4.95G [00:03<00:59, 78.8MB/s]
# model-00002-of-00003.safetensors:   5% 241M/4.95G [00:03<01:03, 73.8MB/s]
# model-00002-of-00003.safetensors:   5% 252M/4.95G [00:03<01:01, 76.8MB/s]
# model-00002-of-00003.safetensors:   5% 262M/4.95G [00:03<01:16, 61.0MB/s]
# model-00002-of-00003.safetensors:   6% 273M/4.95G [00:03<01:20, 58.4MB/s]
# model-00002-of-00003.safetensors:   6% 283M/4.95G [00:03<01:13, 63.6MB/s]
# model-00002-of-00003.safetensors:   6% 294M/4.95G [00:04<01:08, 68.0MB/s]
# model-00002-of-00003.safetensors:   6% 304M/4.95G [00:04<01:22, 56.2MB/s]
# model-00002-of-00003.safetensors:   6% 315M/4.95G [00:04<01:14, 61.9MB/s]
# model-00002-of-00003.safetensors:   7% 325M/4.95G [00:04<01:09, 66.6MB/s]
# model-00002-of-00003.safetensors:   7% 336M/4.95G [00:04<01:05, 70.5MB/s]
# model-00002-of-00003.safetensors:   7% 346M/4.95G [00:04<01:15, 60.6MB/s]
# model-00002-of-00003.safetensors:   7% 357M/4.95G [00:05<01:10, 65.0MB/s]
# model-00002-of-00003.safetensors:   7% 367M/4.95G [00:05<01:05, 69.8MB/s]
# model-00002-of-00003.safetensors:   8% 377M/4.95G [00:05<01:15, 60.6MB/s]
# model-00002-of-00003.safetensors:   8% 388M/4.95G [00:05<01:10, 64.8MB/s]
# model-00002-of-00003.safetensors:   8% 398M/4.95G [00:05<01:05, 69.2MB/s]
# model-00002-of-00003.safetensors:   8% 409M/4.95G [00:05<01:03, 71.4MB/s]
# model-00002-of-00003.safetensors:   8% 419M/4.95G [00:05<01:01, 74.1MB/s]
# model-00002-of-00003.safetensors:   9% 430M/4.95G [00:06<00:59, 75.8MB/s]
# model-00002-of-00003.safetensors:   9% 440M/4.95G [00:06<00:58, 77.5MB/s]
# model-00002-of-00003.safetensors:   9% 451M/4.95G [00:06<00:57, 78.1MB/s]
# model-00002-of-00003.safetensors:   9% 461M/4.95G [00:06<00:58, 76.3MB/s]
# model-00002-of-00003.safetensors:  10% 472M/4.95G [00:06<00:57, 78.1MB/s]
# model-00002-of-00003.safetensors:  10% 482M/4.95G [00:06<01:15, 59.3MB/s]
# model-00002-of-00003.safetensors:  10% 493M/4.95G [00:06<01:08, 64.6MB/s]
# model-00003-of-00003.safetensors:  96% 3.44G/3.59G [00:51<00:02, 68.5MB/s]
# model-00003-of-00003.safetensors:  96% 3.45G/3.59G [00:51<00:01, 71.6MB/s]
# model-00003-of-00003.safetensors:  96% 3.46G/3.59G [00:51<00:01, 71.9MB/s]
# model-00003-of-00003.safetensors:  97% 3.47G/3.59G [00:51<00:01, 72.4MB/s]
# model-00003-of-00003.safetensors:  97% 3.48G/3.59G [00:51<00:01, 74.8MB/s]
# model-00003-of-00003.safetensors:  97% 3.49G/3.59G [00:51<00:01, 64.3MB/s]
# model-00003-of-00003.safetensors:  98% 3.50G/3.59G [00:52<00:01, 70.0MB/s]
# model-00003-of-00003.safetensors:  98% 3.51G/3.59G [00:52<00:01, 70.9MB/s]
# model-00003-of-00003.safetensors:  98% 3.52G/3.59G [00:52<00:00, 74.8MB/s]
# model-00003-of-00003.safetensors:  98% 3.53G/3.59G [00:52<00:00, 76.2MB/s]
# model-00003-of-00003.safetensors:  99% 3.54G/3.59G [00:52<00:00, 76.9MB/s]
# model-00003-of-00003.safetensors:  99% 3.55G/3.59G [00:52<00:00, 78.1MB/s]
# model-00003-of-00003.safetensors:  99% 3.57G/3.59G [00:52<00:00, 80.2MB/s]
# model-00003-of-00003.safetensors: 100% 3.58G/3.59G [00:52<00:00, 80.8MB/s]
# model-00003-of-00003.safetensors: 100% 3.59G/3.59G [00:53<00:00, 67.5MB/s]
# Downloading shards: 100% 3/3 [03:26<00:00, 68.76s/it]
# Loading checkpoint shards: 100% 3/3 [00:04<00:00,  1.57s/it]
# generation_config.json: 100% 183/183 [00:00<00:00, 1.06MB/s]
# tokenizer_config.json: 100% 1.09k/1.09k [00:00<00:00, 5.97MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 7.69MB/s]
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 5.77MB/s]
# added_tokens.json: 100% 21.0/21.0 [00:00<00:00, 149kB/s]
# special_tokens_map.json: 100% 437/437 [00:00<00:00, 2.57MB/s]
# 2024-03-03:14:41:50,100 INFO     [evaluator.py:193] get_task_dict has been updated to accept an optional argument, `task_manager`Read more here:https://github.com/EleutherAI/lm-evaluation-harness/blob/main/docs/interface.md#external-library-usage
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2024-03-03:14:42:28,915 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_astronomy from None to 5
# 2024-03-03:14:42:28,915 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_biology from None to 5
# 2024-03-03:14:42:28,915 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 5
# 2024-03-03:14:42:28,915 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_biology from None to 5
# 2024-03-03:14:42:28,915 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_physics from None to 5
# 2024-03-03:14:42:28,915 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_anatomy from None to 5
# 2024-03-03:14:42:28,915 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_physics from None to 5
# 2024-03-03:14:42:28,916 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_mathematics from None to 5
# 2024-03-03:14:42:28,916 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 5
# 2024-03-03:14:42:28,916 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_computer_security from None to 5
# 2024-03-03:14:42:28,916 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 5
# 2024-03-03:14:42:28,916 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_machine_learning from None to 5
# 2024-03-03:14:42:28,916 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 5
# 2024-03-03:14:42:28,916 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 5
# 2024-03-03:14:42:28,916 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_computer_science from None to 5
# 2024-03-03:14:42:28,916 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 5
# 2024-03-03:14:42:28,916 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_chemistry from None to 5
# 2024-03-03:14:42:28,916 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 5
# 2024-03-03:14:42:28,916 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 5
# 2024-03-03:14:42:28,916 WARNING  [evaluator.py:225] Overwriting default num_fewshot of hellaswag from None to 5
# 2024-03-03:14:42:28,919 INFO     [task.py:386] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:02<00:00, 67.51it/s]
# 2024-03-03:14:42:31,178 INFO     [task.py:386] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:04<00:00, 68.22it/s]
# 2024-03-03:14:42:35,737 INFO     [task.py:386] Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:02<00:00, 68.53it/s]
# 2024-03-03:14:42:37,860 INFO     [task.py:386] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:02<00:00, 68.30it/s]
# 2024-03-03:14:42:39,976 INFO     [task.py:386] Building contexts for mmlu_high_school_physics on rank 0...
# 100% 151/151 [00:02<00:00, 68.43it/s]
# 2024-03-03:14:42:42,190 INFO     [task.py:386] Building contexts for mmlu_anatomy on rank 0...
# 100% 135/135 [00:01<00:00, 68.61it/s]
# 2024-03-03:14:42:44,165 INFO     [task.py:386] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:01<00:00, 68.29it/s]
# 2024-03-03:14:42:45,663 INFO     [task.py:386] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:01<00:00, 68.58it/s]
# 2024-03-03:14:42:47,127 INFO     [task.py:386] Building contexts for mmlu_elementary_mathematics on rank 0...
# 100% 378/378 [00:05<00:00, 68.69it/s]
# 2024-03-03:14:42:52,648 INFO     [task.py:386] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:01<00:00, 68.39it/s]
# 2024-03-03:14:42:54,115 INFO     [task.py:386] Building contexts for mmlu_high_school_chemistry on rank 0...
# 100% 203/203 [00:02<00:00, 68.48it/s]
# 2024-03-03:14:42:57,090 INFO     [task.py:386] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:01<00:00, 68.47it/s]
# 2024-03-03:14:42:58,731 INFO     [task.py:386] Building contexts for mmlu_high_school_mathematics on rank 0...
# 100% 270/270 [00:03<00:00, 69.03it/s]
# 2024-03-03:14:43:02,656 INFO     [task.py:386] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 56.23it/s]
# 2024-03-03:14:43:04,440 INFO     [task.py:386] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 67.75it/s]
# 2024-03-03:14:43:05,921 INFO     [task.py:386] Building contexts for mmlu_abstract_algebra on rank 0...
# 100% 100/100 [00:01<00:00, 68.31it/s]
# 2024-03-03:14:43:07,390 INFO     [task.py:386] Building contexts for mmlu_college_chemistry on rank 0...
# 100% 100/100 [00:01<00:00, 68.86it/s]
# 2024-03-03:14:43:08,848 INFO     [task.py:386] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:03<00:00, 68.40it/s]
# 2024-03-03:14:43:12,016 INFO     [task.py:386] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:03<00:00, 68.45it/s]
# 2024-03-03:14:43:15,461 INFO     [task.py:386] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [01:43<00:00, 97.38it/s]
# 2024-03-03:14:44:59,736 INFO     [evaluator.py:359] Running loglikelihood requests
# Running loglikelihood requests:   0% 0/52780 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 16
# Running loglikelihood requests:  28% 14804/52780 [11:38<26:07, 24.23it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Running loglikelihood requests:  28% 14819/52780 [11:49<26:06, 24.23it/s]Determined largest batch size: 32
# Running loglikelihood requests:  54% 28239/52780 [21:20<15:03, 27.16it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 32
# Running loglikelihood requests:  76% 40075/52780 [29:56<08:29, 24.94it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 32
# Running loglikelihood requests: 100% 52736/52780 [36:59<00:00, 61.27it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests: 100% 52780/52780 [37:06<00:00, 23.70it/s]
# hf (pretrained=twhoool02/llama-2-7b-finetuned-guanaco-NF4-QLORA), gen_kwargs: (None), limit: None, num_fewshot: 5, batch_size: auto:4 (16,32,32,32,64)
# |             Tasks             |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |-------------------------------|-------|------|-----:|--------|-----:|---|-----:|
# |stem                           |N/A    |none  |     5|acc     |0.3511|±  |0.0084|
# | - abstract_algebra            |      0|none  |     5|acc     |0.2800|±  |0.0451|
# | - anatomy                     |      0|none  |     5|acc     |0.4370|±  |0.0428|
# | - astronomy                   |      0|none  |     5|acc     |0.3947|±  |0.0398|
# | - college_biology             |      0|none  |     5|acc     |0.4583|±  |0.0417|
# | - college_chemistry           |      0|none  |     5|acc     |0.3300|±  |0.0473|
# | - college_computer_science    |      0|none  |     5|acc     |0.3900|±  |0.0490|
# | - college_mathematics         |      0|none  |     5|acc     |0.3000|±  |0.0461|
# | - college_physics             |      0|none  |     5|acc     |0.1863|±  |0.0387|
# | - computer_security           |      0|none  |     5|acc     |0.5900|±  |0.0494|
# | - conceptual_physics          |      0|none  |     5|acc     |0.4255|±  |0.0323|
# | - electrical_engineering      |      0|none  |     5|acc     |0.3724|±  |0.0403|
# | - elementary_mathematics      |      0|none  |     5|acc     |0.2778|±  |0.0231|
# | - high_school_biology         |      0|none  |     5|acc     |0.4710|±  |0.0284|
# | - high_school_chemistry       |      0|none  |     5|acc     |0.3399|±  |0.0333|
# | - high_school_computer_science|      0|none  |     5|acc     |0.4400|±  |0.0499|
# | - high_school_mathematics     |      0|none  |     5|acc     |0.2481|±  |0.0263|
# | - high_school_physics         |      0|none  |     5|acc     |0.2980|±  |0.0373|
# | - high_school_statistics      |      0|none  |     5|acc     |0.2037|±  |0.0275|
# | - machine_learning            |      0|none  |     5|acc     |0.3571|±  |0.0455|
# |hellaswag                      |      1|none  |     5|acc     |0.5842|±  |0.0049|
# |                               |       |none  |     5|acc_norm|0.7811|±  |0.0041|
#
# |Groups|Version|Filter|n-shot|Metric|Value |   |Stderr|
# |------|-------|------|-----:|------|-----:|---|-----:|
# |stem  |N/A    |none  |     5|acc   |0.3511|±  |0.0084|

# %% [markdown]
# ## Evaluate Mistral-7B-v0.1-finetuned-guanaco-NF4-QLORA - working

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Mistral-7B-v0.1-finetuned-guanaco-NF4-QLORA \
    --tasks hellaswag,mmlu_stem \
    --num_fewshot 5 \
    --device cuda:0 \
    --batch_size auto:4
# Out:
# 2024-03-03 15:24:29.737385: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-03 15:24:29.737437: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-03 15:24:29.738700: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-03 15:24:30.869822: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-03:15:24:34,149 INFO     [__main__.py:217] Verbosity set to INFO
# 2024-03-03:15:24:34,150 INFO     [__init__.py:369] lm_eval.tasks.initialize_tasks() is deprecated and no longer necessary. It will be removed in v0.4.2 release. TaskManager will instead be used.
# 2024-03-03:15:24:39,759 INFO     [__main__.py:293] Selected Tasks: ['hellaswag', 'mmlu_stem']
# 2024-03-03:15:24:39,759 INFO     [__main__.py:294] Loading selected tasks...
# 2024-03-03:15:24:39,760 INFO     [evaluator.py:135] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-03:15:24:39,800 INFO     [huggingface.py:162] Using device 'cuda:0'
# config.json: 100% 641/641 [00:00<00:00, 1.69MB/s]
# model.safetensors.index.json: 100% 23.9k/23.9k [00:00<00:00, 85.6MB/s]
# Downloading shards:   0% 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0% 0.00/4.94G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 10.5M/4.94G [00:00<03:16, 25.1MB/s]
# model-00001-of-00003.safetensors:   0% 21.0M/4.94G [00:00<02:14, 36.7MB/s]
# model-00001-of-00003.safetensors:   1% 31.5M/4.94G [00:00<01:49, 44.9MB/s]
# model-00001-of-00003.safetensors:   1% 41.9M/4.94G [00:00<01:38, 49.8MB/s]
# model-00001-of-00003.safetensors:   1% 52.4M/4.94G [00:01<01:25, 57.2MB/s]
# model-00001-of-00003.safetensors:   1% 62.9M/4.94G [00:01<01:16, 63.7MB/s]
# model-00001-of-00003.safetensors:   1% 73.4M/4.94G [00:01<01:10, 68.6MB/s]
# model-00001-of-00003.safetensors:   2% 83.9M/4.94G [00:01<01:07, 72.0MB/s]
# model-00001-of-00003.safetensors:   2% 94.4M/4.94G [00:01<01:05, 74.5MB/s]
# model-00001-of-00003.safetensors:   2% 105M/4.94G [00:01<01:03, 76.5MB/s]
# model-00001-of-00003.safetensors:   2% 115M/4.94G [00:01<01:01, 77.9MB/s]
# model-00001-of-00003.safetensors:   3% 126M/4.94G [00:01<01:01, 78.8MB/s]
# model-00001-of-00003.safetensors:   3% 136M/4.94G [00:02<01:00, 79.6MB/s]
# model-00001-of-00003.safetensors:   3% 147M/4.94G [00:02<00:59, 80.1MB/s]
# model-00001-of-00003.safetensors:   3% 157M/4.94G [00:02<01:00, 79.2MB/s]
# model-00001-of-00003.safetensors:   3% 168M/4.94G [00:02<00:58, 81.2MB/s]
# model-00001-of-00003.safetensors:   4% 178M/4.94G [00:02<00:59, 80.6MB/s]
# model-00001-of-00003.safetensors:   4% 189M/4.94G [00:02<00:58, 80.8MB/s]
# model-00001-of-00003.safetensors:   4% 199M/4.94G [00:02<00:58, 80.9MB/s]
# model-00001-of-00003.safetensors:   4% 210M/4.94G [00:03<00:58, 81.0MB/s]
# model-00001-of-00003.safetensors:   4% 220M/4.94G [00:03<00:58, 80.9MB/s]
# model-00001-of-00003.safetensors:   5% 231M/4.94G [00:03<00:57, 81.4MB/s]
# model-00001-of-00003.safetensors:   5% 241M/4.94G [00:03<00:57, 81.5MB/s]
# model-00001-of-00003.safetensors:   5% 252M/4.94G [00:03<00:57, 81.0MB/s]
# model-00001-of-00003.safetensors:   5% 262M/4.94G [00:03<00:57, 81.4MB/s]
# model-00001-of-00003.safetensors:   6% 273M/4.94G [00:03<00:57, 81.3MB/s]
# model-00001-of-00003.safetensors:   6% 283M/4.94G [00:03<00:57, 81.5MB/s]
# model-00001-of-00003.safetensors:   6% 294M/4.94G [00:04<00:56, 81.7MB/s]
# model-00001-of-00003.safetensors:   6% 304M/4.94G [00:04<00:57, 81.2MB/s]
# model-00001-of-00003.safetensors:   6% 315M/4.94G [00:04<00:56, 81.3MB/s]
# model-00001-of-00003.safetensors:   7% 325M/4.94G [00:04<00:56, 81.3MB/s]
# model-00001-of-00003.safetensors:   7% 336M/4.94G [00:04<00:56, 81.1MB/s]
# model-00001-of-00003.safetensors:   7% 346M/4.94G [00:04<00:56, 80.7MB/s]
# model-00001-of-00003.safetensors:   7% 357M/4.94G [00:04<01:10, 64.8MB/s]
# model-00001-of-00003.safetensors:   7% 367M/4.94G [00:05<01:06, 69.1MB/s]
# model-00001-of-00003.safetensors:   8% 377M/4.94G [00:05<01:06, 68.5MB/s]
# model-00001-of-00003.safetensors:   8% 388M/4.94G [00:05<01:03, 71.3MB/s]
# model-00001-of-00003.safetensors:   8% 398M/4.94G [00:05<01:01, 74.3MB/s]
# model-00001-of-00003.safetensors:   8% 409M/4.94G [00:05<00:59, 76.7MB/s]
# model-00001-of-00003.safetensors:   8% 419M/4.94G [00:05<00:58, 76.8MB/s]
# model-00001-of-00003.safetensors:   9% 430M/4.94G [00:05<00:56, 79.5MB/s]
# model-00001-of-00003.safetensors:   9% 440M/4.94G [00:06<00:57, 78.2MB/s]
# model-00001-of-00003.safetensors:   9% 451M/4.94G [00:06<00:57, 77.6MB/s]
# model-00001-of-00003.safetensors:   9% 461M/4.94G [00:06<00:57, 77.6MB/s]
# model-00001-of-00003.safetensors:  10% 472M/4.94G [00:06<00:58, 76.6MB/s]
# model-00001-of-00003.safetensors:  10% 482M/4.94G [00:06<00:57, 77.0MB/s]
# model-00001-of-00003.safetensors:  10% 493M/4.94G [00:06<00:56, 78.3MB/s]
# model-00001-of-00003.safetensors:  10% 503M/4.94G [00:06<00:56, 78.8MB/s]
# model-00001-of-00003.safetensors:  10% 514M/4.94G [00:06<00:55, 79.5MB/s]
# model-00001-of-00003.safetensors:  11% 524M/4.94G [00:07<00:55, 80.1MB/s]
# model-00001-of-00003.safetensors:  11% 535M/4.94G [00:07<00:59, 73.7MB/s]
# model-00001-of-00003.safetensors:  11% 545M/4.94G [00:07<01:12, 60.9MB/s]
# model-00001-of-00003.safetensors:  32% 1.59G/4.94G [00:22<00:41, 81.4MB/s]
# model-00001-of-00003.safetensors:  32% 1.60G/4.94G [00:22<00:40, 81.5MB/s]
# model-00001-of-00003.safetensors:  33% 1.61G/4.94G [00:22<00:40, 81.3MB/s]
# model-00001-of-00003.safetensors:  33% 1.63G/4.94G [00:22<00:53, 61.7MB/s]
# model-00001-of-00003.safetensors:  33% 1.64G/4.94G [00:22<00:49, 66.7MB/s]
# model-00001-of-00003.safetensors:  33% 1.65G/4.94G [00:22<00:46, 70.4MB/s]
# model-00001-of-00003.safetensors:  34% 1.66G/4.94G [00:22<00:44, 73.4MB/s]
# model-00001-of-00003.safetensors:  34% 1.67G/4.94G [00:23<00:43, 75.8MB/s]
# model-00001-of-00003.safetensors:  34% 1.68G/4.94G [00:23<00:42, 77.2MB/s]
# model-00001-of-00003.safetensors:  34% 1.69G/4.94G [00:23<00:41, 78.5MB/s]
# model-00001-of-00003.safetensors:  34% 1.70G/4.94G [00:23<00:41, 79.1MB/s]
# model-00001-of-00003.safetensors:  35% 1.71G/4.94G [00:23<00:40, 79.8MB/s]
# model-00001-of-00003.safetensors:  35% 1.72G/4.94G [00:23<00:42, 76.4MB/s]
# model-00001-of-00003.safetensors:  35% 1.73G/4.94G [00:23<00:40, 78.5MB/s]
# model-00001-of-00003.safetensors:  35% 1.74G/4.94G [00:23<00:39, 80.2MB/s]
# model-00001-of-00003.safetensors:  35% 1.75G/4.94G [00:24<00:42, 75.5MB/s]
# model-00001-of-00003.safetensors:  36% 1.76G/4.94G [00:24<00:41, 76.8MB/s]
# model-00001-of-00003.safetensors:  36% 1.77G/4.94G [00:24<00:40, 78.6MB/s]
# model-00001-of-00003.safetensors:  36% 1.78G/4.94G [00:24<00:39, 79.6MB/s]
# model-00001-of-00003.safetensors:  36% 1.79G/4.94G [00:24<00:49, 64.1MB/s]
# model-00001-of-00003.safetensors:  36% 1.80G/4.94G [00:24<00:45, 68.4MB/s]
# model-00001-of-00003.safetensors:  37% 1.81G/4.94G [00:25<00:45, 68.8MB/s]
# model-00001-of-00003.safetensors:  37% 1.82G/4.94G [00:25<00:45, 68.7MB/s]
# model-00001-of-00003.safetensors:  37% 1.84G/4.94G [00:25<00:43, 71.9MB/s]
# model-00001-of-00003.safetensors:  37% 1.85G/4.94G [00:25<00:55, 55.7MB/s]
# model-00001-of-00003.safetensors:  38% 1.86G/4.94G [00:25<00:50, 61.5MB/s]
# model-00001-of-00003.safetensors:  38% 1.87G/4.94G [00:25<00:46, 66.5MB/s]
# model-00001-of-00003.safetensors:  38% 1.88G/4.94G [00:26<00:55, 55.7MB/s]
# model-00001-of-00003.safetensors:  38% 1.89G/4.94G [00:26<00:49, 62.0MB/s]
# model-00001-of-00003.safetensors:  38% 1.90G/4.94G [00:26<00:48, 62.4MB/s]
# model-00001-of-00003.safetensors:  39% 1.91G/4.94G [00:26<00:47, 63.7MB/s]
# model-00001-of-00003.safetensors:  39% 1.92G/4.94G [00:26<00:45, 66.7MB/s]
# model-00001-of-00003.safetensors:  59% 2.94G/4.94G [00:41<00:24, 81.6MB/s]
# model-00001-of-00003.safetensors:  60% 2.95G/4.94G [00:41<00:26, 74.8MB/s]
# model-00001-of-00003.safetensors:  60% 2.96G/4.94G [00:41<00:26, 76.4MB/s]
# model-00001-of-00003.safetensors:  60% 2.97G/4.94G [00:41<00:27, 72.5MB/s]
# model-00001-of-00003.safetensors:  60% 2.98G/4.94G [00:42<00:37, 52.2MB/s]
# model-00001-of-00003.safetensors:  60% 2.99G/4.94G [00:42<00:33, 58.6MB/s]
# model-00001-of-00003.safetensors:  61% 3.00G/4.94G [00:42<00:30, 63.0MB/s]
# model-00001-of-00003.safetensors:  61% 3.01G/4.94G [00:42<00:33, 57.2MB/s]
# model-00001-of-00003.safetensors:  61% 3.02G/4.94G [00:42<00:30, 62.8MB/s]
# model-00001-of-00003.safetensors:  61% 3.03G/4.94G [00:42<00:29, 65.1MB/s]
# model-00001-of-00003.safetensors:  62% 3.04G/4.94G [00:43<00:36, 51.7MB/s]
# model-00001-of-00003.safetensors:  62% 3.05G/4.94G [00:43<00:32, 58.0MB/s]
# model-00001-of-00003.safetensors:  62% 3.06G/4.94G [00:43<00:33, 57.0MB/s]
# model-00001-of-00003.safetensors:  62% 3.07G/4.94G [00:43<00:33, 56.3MB/s]
# model-00001-of-00003.safetensors:  62% 3.08G/4.94G [00:43<00:33, 56.2MB/s]
# model-00001-of-00003.safetensors:  63% 3.09G/4.94G [00:44<00:31, 59.1MB/s]
# model-00001-of-00003.safetensors:  63% 3.10G/4.94G [00:44<00:31, 58.1MB/s]
# model-00001-of-00003.safetensors:  63% 3.11G/4.94G [00:44<00:30, 59.0MB/s]
# model-00001-of-00003.safetensors:  63% 3.12G/4.94G [00:44<00:29, 61.4MB/s]
# model-00001-of-00003.safetensors:  63% 3.14G/4.94G [00:44<00:30, 59.6MB/s]
# model-00001-of-00003.safetensors:  64% 3.15G/4.94G [00:44<00:30, 59.8MB/s]
# model-00001-of-00003.safetensors:  64% 3.16G/4.94G [00:45<00:28, 62.5MB/s]
# model-00001-of-00003.safetensors:  64% 3.17G/4.94G [00:45<00:29, 61.0MB/s]
# model-00001-of-00003.safetensors:  64% 3.18G/4.94G [00:45<00:27, 63.3MB/s]
# model-00001-of-00003.safetensors:  64% 3.19G/4.94G [00:45<00:28, 62.2MB/s]
# model-00001-of-00003.safetensors:  65% 3.20G/4.94G [00:45<00:28, 61.1MB/s]
# model-00001-of-00003.safetensors:  65% 3.21G/4.94G [00:45<00:26, 64.3MB/s]
# model-00001-of-00003.safetensors:  65% 3.22G/4.94G [00:46<00:27, 62.2MB/s]
# model-00001-of-00003.safetensors:  65% 3.23G/4.94G [00:46<00:26, 65.6MB/s]
# model-00001-of-00003.safetensors:  66% 3.24G/4.94G [00:46<00:26, 63.2MB/s]
# model-00001-of-00003.safetensors:  66% 3.25G/4.94G [00:46<00:25, 66.0MB/s]
# model-00001-of-00003.safetensors:  66% 3.26G/4.94G [00:46<00:26, 63.6MB/s]
# model-00003-of-00003.safetensors: 100% 4.54G/4.54G [01:04<00:00, 70.3MB/s]
# Downloading shards: 100% 3/3 [03:35<00:00, 71.88s/it]
# Loading checkpoint shards: 100% 3/3 [00:04<00:00,  1.66s/it]
# generation_config.json: 100% 111/111 [00:00<00:00, 678kB/s]
# tokenizer_config.json: 100% 1.14k/1.14k [00:00<00:00, 7.54MB/s]
# tokenizer.model: 100% 493k/493k [00:00<00:00, 54.1MB/s]
# tokenizer.json: 100% 1.80M/1.80M [00:00<00:00, 8.89MB/s]
# added_tokens.json: 100% 21.0/21.0 [00:00<00:00, 145kB/s]
# special_tokens_map.json: 100% 437/437 [00:00<00:00, 3.18MB/s]
# 2024-03-03:15:28:24,005 INFO     [evaluator.py:193] get_task_dict has been updated to accept an optional argument, `task_manager`Read more here:https://github.com/EleutherAI/lm-evaluation-harness/blob/main/docs/interface.md#external-library-usage
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2024-03-03:15:29:01,431 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_astronomy from None to 5
# 2024-03-03:15:29:01,431 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_biology from None to 5
# 2024-03-03:15:29:01,431 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 5
# 2024-03-03:15:29:01,431 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_biology from None to 5
# 2024-03-03:15:29:01,431 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_physics from None to 5
# 2024-03-03:15:29:01,431 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_anatomy from None to 5
# 2024-03-03:15:29:01,431 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_physics from None to 5
# 2024-03-03:15:29:01,432 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_mathematics from None to 5
# 2024-03-03:15:29:01,432 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 5
# 2024-03-03:15:29:01,432 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_computer_security from None to 5
# 2024-03-03:15:29:01,432 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 5
# 2024-03-03:15:29:01,432 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_machine_learning from None to 5
# 2024-03-03:15:29:01,432 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 5
# 2024-03-03:15:29:01,432 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 5
# 2024-03-03:15:29:01,432 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_computer_science from None to 5
# 2024-03-03:15:29:01,432 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 5
# 2024-03-03:15:29:01,432 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_chemistry from None to 5
# 2024-03-03:15:29:01,432 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 5
# 2024-03-03:15:29:01,432 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 5
# 2024-03-03:15:29:01,432 WARNING  [evaluator.py:225] Overwriting default num_fewshot of hellaswag from None to 5
# 2024-03-03:15:29:01,435 INFO     [task.py:386] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:02<00:00, 67.59it/s]
# 2024-03-03:15:29:03,691 INFO     [task.py:386] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:04<00:00, 67.96it/s]
# 2024-03-03:15:29:08,267 INFO     [task.py:386] Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:02<00:00, 68.02it/s]
# 2024-03-03:15:29:10,406 INFO     [task.py:386] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:02<00:00, 67.08it/s]
# 2024-03-03:15:29:12,560 INFO     [task.py:386] Building contexts for mmlu_high_school_physics on rank 0...
# 100% 151/151 [00:02<00:00, 67.77it/s]
# 2024-03-03:15:29:14,796 INFO     [task.py:386] Building contexts for mmlu_anatomy on rank 0...
# 100% 135/135 [00:01<00:00, 68.09it/s]
# 2024-03-03:15:29:16,785 INFO     [task.py:386] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:01<00:00, 68.16it/s]
# 2024-03-03:15:29:18,288 INFO     [task.py:386] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:01<00:00, 67.95it/s]
# 2024-03-03:15:29:19,765 INFO     [task.py:386] Building contexts for mmlu_elementary_mathematics on rank 0...
# 100% 378/378 [00:05<00:00, 67.68it/s]
# 2024-03-03:15:29:25,367 INFO     [task.py:386] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:01<00:00, 68.12it/s]
# 2024-03-03:15:29:26,840 INFO     [task.py:386] Building contexts for mmlu_high_school_chemistry on rank 0...
# 100% 203/203 [00:02<00:00, 68.19it/s]
# 2024-03-03:15:29:29,827 INFO     [task.py:386] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:01<00:00, 67.33it/s]
# 2024-03-03:15:29:31,497 INFO     [task.py:386] Building contexts for mmlu_high_school_mathematics on rank 0...
# 100% 270/270 [00:03<00:00, 67.56it/s]
# 2024-03-03:15:29:35,506 INFO     [task.py:386] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 54.76it/s]
# 2024-03-03:15:29:37,338 INFO     [task.py:386] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 66.90it/s]
# 2024-03-03:15:29:38,838 INFO     [task.py:386] Building contexts for mmlu_abstract_algebra on rank 0...
# 100% 100/100 [00:01<00:00, 67.13it/s]
# 2024-03-03:15:29:40,333 INFO     [task.py:386] Building contexts for mmlu_college_chemistry on rank 0...
# 100% 100/100 [00:01<00:00, 67.23it/s]
# 2024-03-03:15:29:41,828 INFO     [task.py:386] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:03<00:00, 67.97it/s]
# 2024-03-03:15:29:45,016 INFO     [task.py:386] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:03<00:00, 67.75it/s]
# 2024-03-03:15:29:48,497 INFO     [task.py:386] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [01:45<00:00, 95.24it/s]
# 2024-03-03:15:31:35,074 INFO     [evaluator.py:359] Running loglikelihood requests
# Running loglikelihood requests:   0% 0/52780 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 16
# Running loglikelihood requests:  31% 16145/52780 [11:11<29:21, 20.80it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Running loglikelihood requests:  31% 16160/52780 [11:27<29:20, 20.80it/s]Determined largest batch size: 64
# Running loglikelihood requests: 100% 52780/52780 [35:16<00:00, 24.94it/s]
# hf (pretrained=twhoool02/Mistral-7B-v0.1-finetuned-guanaco-NF4-QLORA), gen_kwargs: (None), limit: None, num_fewshot: 5, batch_size: auto:4 (16,64,64,64,64)
# |             Tasks             |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |-------------------------------|-------|------|-----:|--------|-----:|---|-----:|
# |stem                           |N/A    |none  |     5|acc     |0.5046|±  |0.0086|
# | - abstract_algebra            |      0|none  |     5|acc     |0.3400|±  |0.0476|
# | - anatomy                     |      0|none  |     5|acc     |0.5630|±  |0.0428|
# | - astronomy                   |      0|none  |     5|acc     |0.6053|±  |0.0398|
# | - college_biology             |      0|none  |     5|acc     |0.6875|±  |0.0388|
# | - college_chemistry           |      0|none  |     5|acc     |0.4600|±  |0.0501|
# | - college_computer_science    |      0|none  |     5|acc     |0.5100|±  |0.0502|
# | - college_mathematics         |      0|none  |     5|acc     |0.3900|±  |0.0490|
# | - college_physics             |      0|none  |     5|acc     |0.3235|±  |0.0466|
# | - computer_security           |      0|none  |     5|acc     |0.7800|±  |0.0416|
# | - conceptual_physics          |      0|none  |     5|acc     |0.5319|±  |0.0326|
# | - electrical_engineering      |      0|none  |     5|acc     |0.5448|±  |0.0415|
# | - elementary_mathematics      |      0|none  |     5|acc     |0.3783|±  |0.0250|
# | - high_school_biology         |      0|none  |     5|acc     |0.7452|±  |0.0248|
# | - high_school_chemistry       |      0|none  |     5|acc     |0.5025|±  |0.0352|
# | - high_school_computer_science|      0|none  |     5|acc     |0.6500|±  |0.0479|
# | - high_school_mathematics     |      0|none  |     5|acc     |0.3407|±  |0.0289|
# | - high_school_physics         |      0|none  |     5|acc     |0.3245|±  |0.0382|
# | - high_school_statistics      |      0|none  |     5|acc     |0.4861|±  |0.0341|
# | - machine_learning            |      0|none  |     5|acc     |0.4643|±  |0.0473|
# |hellaswag                      |      1|none  |     5|acc     |0.6219|±  |0.0048|
# |                               |       |none  |     5|acc_norm|0.8206|±  |0.0038|
#
# |Groups|Version|Filter|n-shot|Metric|Value |   |Stderr|
# |------|-------|------|-----:|------|-----:|---|-----:|
# |stem  |N/A    |none  |     5|acc   |0.5046|±  |0.0086|

# %% [markdown]
# ## Evaluate Falcon-7B-AutoGPTQ - not working

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Falcon-7B-AutoGPTQ \
    --tasks hellaswag,mmlu_stem \
    --num_fewshot 5 \
    --device cuda:0 \
    --batch_size 32
# Out:
# 2024-03-03 13:18:23.158786: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-03 13:18:23.158828: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-03 13:18:23.160135: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-03 13:18:24.287288: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-03:13:18:28,128 INFO     [__main__.py:217] Verbosity set to INFO
# 2024-03-03:13:18:28,128 INFO     [__init__.py:369] lm_eval.tasks.initialize_tasks() is deprecated and no longer necessary. It will be removed in v0.4.2 release. TaskManager will instead be used.
# 2024-03-03:13:18:33,907 INFO     [__main__.py:293] Selected Tasks: ['hellaswag', 'mmlu_stem']
# 2024-03-03:13:18:33,907 INFO     [__main__.py:294] Loading selected tasks...
# 2024-03-03:13:18:33,908 INFO     [evaluator.py:135] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-03:13:18:33,933 INFO     [huggingface.py:162] Using device 'cuda:0'
# 2024-03-03:13:18:35,347 WARNING  [qlinear_cuda.py:18] CUDA extension not installed.
# 2024-03-03:13:18:35,348 WARNING  [qlinear_cuda_old.py:17] CUDA extension not installed.
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:4193: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# 2024-03-03:13:18:38,691 INFO     [evaluator.py:193] get_task_dict has been updated to accept an optional argument, `task_manager`Read more here:https://github.com/EleutherAI/lm-evaluation-harness/blob/main/docs/interface.md#external-library-usage
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_astronomy from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_biology from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_biology from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_physics from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_anatomy from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_physics from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_mathematics from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_computer_security from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_machine_learning from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_computer_science from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_college_chemistry from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 5
# 2024-03-03:13:20:00,564 WARNING  [evaluator.py:225] Overwriting default num_fewshot of hellaswag from None to 5
# 2024-03-03:13:20:00,567 INFO     [task.py:386] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:02<00:00, 68.05it/s]
# 2024-03-03:13:20:02,808 INFO     [task.py:386] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:04<00:00, 68.51it/s]
# 2024-03-03:13:20:07,348 INFO     [task.py:386] Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:02<00:00, 68.48it/s]
# 2024-03-03:13:20:09,473 INFO     [task.py:386] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:02<00:00, 68.67it/s]
# 2024-03-03:13:20:11,577 INFO     [task.py:386] Building contexts for mmlu_high_school_physics on rank 0...
# 100% 151/151 [00:02<00:00, 68.67it/s]
# 2024-03-03:13:20:13,783 INFO     [task.py:386] Building contexts for mmlu_anatomy on rank 0...
# 100% 135/135 [00:01<00:00, 68.76it/s]
# 2024-03-03:13:20:15,754 INFO     [task.py:386] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:01<00:00, 68.09it/s]
# 2024-03-03:13:20:17,257 INFO     [task.py:386] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:01<00:00, 68.13it/s]
# 2024-03-03:13:20:18,730 INFO     [task.py:386] Building contexts for mmlu_elementary_mathematics on rank 0...
# 100% 378/378 [00:05<00:00, 68.75it/s]
# 2024-03-03:13:20:24,245 INFO     [task.py:386] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:01<00:00, 68.88it/s]
# 2024-03-03:13:20:25,703 INFO     [task.py:386] Building contexts for mmlu_high_school_chemistry on rank 0...
# 100% 203/203 [00:02<00:00, 68.57it/s]
# 2024-03-03:13:20:28,673 INFO     [task.py:386] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:01<00:00, 68.64it/s]
# 2024-03-03:13:20:30,310 INFO     [task.py:386] Building contexts for mmlu_high_school_mathematics on rank 0...
# 100% 270/270 [00:03<00:00, 68.39it/s]
# 2024-03-03:13:20:34,271 INFO     [task.py:386] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 56.37it/s]
# 2024-03-03:13:20:36,050 INFO     [task.py:386] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 67.84it/s]
# 2024-03-03:13:20:37,530 INFO     [task.py:386] Building contexts for mmlu_abstract_algebra on rank 0...
# 100% 100/100 [00:01<00:00, 68.16it/s]
# 2024-03-03:13:20:39,002 INFO     [task.py:386] Building contexts for mmlu_college_chemistry on rank 0...
# 100% 100/100 [00:01<00:00, 68.70it/s]
# 2024-03-03:13:20:40,462 INFO     [task.py:386] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:03<00:00, 68.08it/s]
# 2024-03-03:13:20:43,646 INFO     [task.py:386] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:03<00:00, 68.31it/s]
# 2024-03-03:13:20:47,098 INFO     [task.py:386] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [01:44<00:00, 95.88it/s]
# 2024-03-03:13:22:32,970 INFO     [evaluator.py:359] Running loglikelihood requests
# Running loglikelihood requests:   0% 0/52780 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/usr/local/bin/lm_eval", line 8, in <module>
#     sys.exit(cli_evaluate())
#   File "/content/lm-evaluation-harness/lm-evaluation-harness/lm_eval/__main__.py", line 300, in cli_evaluate
#     results = evaluator.simple_evaluate(
#   File "/content/lm-evaluation-harness/lm-evaluation-harness/lm_eval/utils.py", line 288, in _wrapper
#     return fn(*args, **kwargs)
#   File "/content/lm-evaluation-harness/lm-evaluation-harness/lm_eval/evaluator.py", line 233, in simple_evaluate
#     results = evaluate(
#   File "/content/lm-evaluation-harness/lm-evaluation-harness/lm_eval/utils.py", line 288, in _wrapper
#     return fn(*args, **kwargs)
#   File "/content/lm-evaluation-harness/lm-evaluation-harness/lm_eval/evaluator.py", line 370, in evaluate
#     resps = getattr(lm, reqtype)(cloned_reqs)
#   File "/content/lm-evaluation-harness/lm-evaluation-harness/lm_eval/api/model.py", line 323, in loglikelihood
#     return self._loglikelihood_tokens(new_reqs)
#   File "/content/lm-evaluation-harness/lm-evaluation-harness/lm_eval/models/huggingface.py", line 1025, in _loglikelihood_tokens
#     self._model_call(batched_inps, **call_kwargs), dim=-1
#   File "/content/lm-evaluation-harness/lm-evaluation-harness/lm_eval/models/huggingface.py", line 744, in _model_call
#     return self.model(inps).logits
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/models/falcon/modeling_falcon.py", line 1282, in forward
#     transformer_outputs = self.transformer(
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/models/falcon/modeling_falcon.py", line 1161, in forward
#     outputs = block(
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/models/falcon/modeling_falcon.py", line 811, in forward
#     attn_outputs = self.self_attention(
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/models/falcon/modeling_falcon.py", line 409, in forward
#     fused_qkv = self.query_key_value(hidden_states)  # [batch_size, seq_length, 3 x hidden_size]
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/auto_gptq/nn_modules/qlinear/qlinear_cuda_old.py", line 316, in forward
#     weight = weight.reshape(-1, self.group_size, weight.shape[2])
# RuntimeError: shape '[-1, 128, 4672]' is invalid for input of size 21229568
# Running loglikelihood requests:   0% 0/52780 [00:01<?, ?it/s]

# %% [markdown]
# ## Evaluate Mistral-7B-AutoGPTQ - not working

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Mistral-7B-AutoGPTQ \
    --tasks hellaswag,mmlu_stem \
    --num_fewshot 5 \
    --device cuda:0 \
    --batch_size auto:4
# Out:
# 2024-03-03 12:05:41.794566: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-03 12:05:41.794617: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-03 12:05:41.795793: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-03 12:05:42.890805: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-03:12:05:46,879 INFO     [__main__.py:217] Verbosity set to INFO
# 2024-03-03:12:05:46,879 INFO     [__init__.py:369] lm_eval.tasks.initialize_tasks() is deprecated and no longer necessary. It will be removed in v0.4.2 release. TaskManager will instead be used.
# 2024-03-03:12:05:52,497 INFO     [__main__.py:293] Selected Tasks: ['hellaswag', 'mmlu_stem']
# 2024-03-03:12:05:52,497 INFO     [__main__.py:294] Loading selected tasks...
# 2024-03-03:12:05:52,498 INFO     [evaluator.py:135] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-03:12:05:52,526 INFO     [huggingface.py:162] Using device 'cuda:0'
# 2024-03-03:12:05:53,947 WARNING  [qlinear_cuda.py:18] CUDA extension not installed.
# 2024-03-03:12:05:53,948 WARNING  [qlinear_cuda_old.py:17] CUDA extension not installed.
# Traceback (most recent call last):
#   File "/usr/local/bin/lm_eval", line 8, in <module>
#     sys.exit(cli_evaluate())
#   File "/content/lm-evaluation-harness/lm_eval/__main__.py", line 300, in cli_evaluate
#     results = evaluator.simple_evaluate(
#   File "/content/lm-evaluation-harness/lm_eval/utils.py", line 288, in _wrapper
#     return fn(*args, **kwargs)
#   File "/content/lm-evaluation-harness/lm_eval/evaluator.py", line 166, in simple_evaluate
#     lm = lm_eval.api.registry.get_model(model).create_from_arg_string(
#   File "/content/lm-evaluation-harness/lm_eval/api/model.py", line 134, in create_from_arg_string
#     return cls(**args, **args2)
#   File "/content/lm-evaluation-harness/lm_eval/models/huggingface.py", line 201, in __init__
#     self._create_model(
#   File "/content/lm-evaluation-harness/lm_eval/models/huggingface.py", line 524, in _create_model
#     self._model = self.AUTO_MODEL_CLASS.from_pretrained(
#   File "/usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py", line 561, in from_pretrained
#     return model_class.from_pretrained(
#   File "/usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py", line 3234, in from_pretrained
#     raise EnvironmentError(
# OSError: twhoool02/Mistral-7B-AutoGPTQ does not appear to have a file named pytorch_model.bin, tf_model.h5, model.ckpt or flax_model.msgpack.

# %% [markdown]
# ## Evaluate Llama-2-7b-chat-hf-AWQ - working

# %%
# !lm_eval --model hf \
    --model_args pretrained=twhoool02/Llama-2-7b-chat-hf-AWQ \
    --tasks hellaswag,mmlu_stem \
    --num_fewshot 5 \
    --device cuda:0 \
    --batch_size auto:4
# Out:
# 2024-03-16 13:15:06.722580: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-16 13:15:06.722633: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-16 13:15:06.724408: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-16 13:15:07.993472: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-16:13:15:11,543 INFO     [__main__.py:225] Verbosity set to INFO
# 2024-03-16:13:15:11,543 INFO     [__init__.py:373] lm_eval.tasks.initialize_tasks() is deprecated and no longer necessary. It will be removed in v0.4.2 release. TaskManager will instead be used.
# 2024-03-16:13:15:17,383 INFO     [__main__.py:311] Selected Tasks: ['hellaswag', 'mmlu_stem']
# 2024-03-16:13:15:17,383 INFO     [__main__.py:312] Loading selected tasks...
# 2024-03-16:13:15:17,385 INFO     [evaluator.py:129] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-03-16:13:15:17,427 INFO     [huggingface.py:162] Using device 'cuda:0'
# We suggest you to set `torch_dtype=torch.float16` for better efficiency with AWQ.
# model.safetensors: 100% 3.89G/3.89G [00:21<00:00, 182MB/s]
# generation_config.json: 100% 183/183 [00:00<00:00, 994kB/s]
# tokenizer_config.json: 100% 1.76k/1.76k [00:00<00:00, 9.30MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 19.9MB/s]
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 23.7MB/s]
# special_tokens_map.json: 100% 414/414 [00:00<00:00, 2.18MB/s]
# 2024-03-16:13:15:43,104 INFO     [evaluator.py:190] get_task_dict has been updated to accept an optional argument, `task_manager`Read more here:https://github.com/EleutherAI/lm-evaluation-harness/blob/main/docs/interface.md#external-library-usage
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 4.36k/4.36k [00:00<00:00, 17.6MB/s]
# Downloading metadata: 100% 2.53k/2.53k [00:00<00:00, 14.7MB/s]
# Downloading readme: 100% 6.84k/6.84k [00:00<00:00, 27.7MB/s]
# Downloading data: 47.5MB [00:00, 62.6MB/s]
# Downloading data: 11.8MB [00:00, 40.6MB/s]
# Downloading data: 12.2MB [00:00, 39.9MB/s]
# Generating train split: 100% 39905/39905 [00:04<00:00, 9440.44 examples/s]
# Generating test split: 100% 10003/10003 [00:01<00:00, 9470.20 examples/s]
# Generating validation split: 100% 10042/10042 [00:01<00:00, 9450.77 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 6229.41 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 6538.75 examples/s]
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for hails/mmlu_no_train contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hails/mmlu_no_train
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 5.86k/5.86k [00:00<00:00, 24.9MB/s]
# Downloading readme: 100% 1.11k/1.11k [00:00<00:00, 6.78MB/s]
# Downloading data: 100% 166M/166M [00:01<00:00, 87.3MB/s]
# Generating test split: 100 examples [00:00, 1083.05 examples/s]
# Generating validation split: 11 examples [00:00, 2235.66 examples/s]
# Generating dev split: 5 examples [00:00, 50.65 examples/s]
# Generating test split: 235 examples [00:00, 2509.51 examples/s]
# Generating validation split: 26 examples [00:00, 6913.83 examples/s]
# Generating dev split: 5 examples [00:00, 57.50 examples/s]
# Generating test split: 100 examples [00:00, 1137.10 examples/s]
# Generating validation split: 9 examples [00:00, 2985.03 examples/s]
# Generating dev split: 5 examples [00:00, 59.15 examples/s]
# Generating test split: 270 examples [00:00, 2828.25 examples/s]
# Generating validation split: 29 examples [00:00, 6374.99 examples/s]
# Generating dev split: 5 examples [00:00, 57.19 examples/s]
# Generating test split: 310 examples [00:00, 3211.37 examples/s]
# Generating validation split: 32 examples [00:00, 6627.71 examples/s]
# Generating dev split: 5 examples [00:00, 57.85 examples/s]
# Generating test split: 100 examples [00:00, 1167.72 examples/s]
# Generating validation split: 11 examples [00:00, 2905.74 examples/s]
# Generating dev split: 5 examples [00:00, 58.32 examples/s]
# Generating test split: 100 examples [00:00, 1188.53 examples/s]
# Generating validation split: 8 examples [00:00, 1585.07 examples/s]
# Generating dev split: 5 examples [00:00, 56.59 examples/s]
# Generating test split: 112 examples [00:00, 1310.58 examples/s]
# Generating validation split: 11 examples [00:00, 3254.61 examples/s]
# Generating dev split: 5 examples [00:00, 59.30 examples/s]
# Generating test split: 203 examples [00:00, 2198.95 examples/s]
# Generating validation split: 22 examples [00:00, 3959.61 examples/s]
# Generating dev split: 5 examples [00:00, 53.10 examples/s]
# Generating test split: 100 examples [00:00, 1137.42 examples/s]
# Generating validation split: 11 examples [00:00, 2854.15 examples/s]
# Generating dev split: 5 examples [00:00, 59.42 examples/s]
# Generating test split: 100 examples [00:00, 1169.48 examples/s]
# Generating validation split: 11 examples [00:00, 2456.86 examples/s]
# Generating dev split: 5 examples [00:00, 56.68 examples/s]
# Generating test split: 145 examples [00:00, 1670.74 examples/s]
# Generating validation split: 16 examples [00:00, 3948.51 examples/s]
# Generating dev split: 5 examples [00:00, 58.63 examples/s]
# Generating test split: 216 examples [00:00, 2207.35 examples/s]
# Generating validation split: 23 examples [00:00, 4615.74 examples/s]
# Generating dev split: 5 examples [00:00, 57.62 examples/s]
# Generating test split: 152 examples [00:00, 1740.58 examples/s]
# Generating validation split: 16 examples [00:00, 4988.02 examples/s]
# Generating dev split: 5 examples [00:00, 58.35 examples/s]
# Generating test split: 151 examples [00:00, 1607.40 examples/s]
# Generating validation split: 17 examples [00:00, 3741.38 examples/s]
# Generating dev split: 5 examples [00:00, 57.56 examples/s]
# Generating test split: 102 examples [00:00, 1138.91 examples/s]
# Generating validation split: 11 examples [00:00, 3328.09 examples/s]
# Generating dev split: 5 examples [00:00, 58.69 examples/s]
# Generating test split: 378 examples [00:00, 3644.65 examples/s]
# Generating validation split: 41 examples [00:00, 6302.60 examples/s]
# Generating dev split: 5 examples [00:00, 59.68 examples/s]
# Generating test split: 144 examples [00:00, 1647.37 examples/s]
# Generating validation split: 16 examples [00:00, 2849.51 examples/s]
# Generating dev split: 5 examples [00:00, 58.21 examples/s]
# Generating test split: 135 examples [00:00, 1550.64 examples/s]
# Generating validation split: 14 examples [00:00, 4412.40 examples/s]
# Generating dev split: 5 examples [00:00, 59.84 examples/s]
# 2024-03-16:13:16:39,248 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_anatomy from None to 5
# 2024-03-16:13:16:39,248 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_college_biology from None to 5
# 2024-03-16:13:16:39,248 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_elementary_mathematics from None to 5
# 2024-03-16:13:16:39,248 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_college_physics from None to 5
# 2024-03-16:13:16:39,248 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_high_school_physics from None to 5
# 2024-03-16:13:16:39,248 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_astronomy from None to 5
# 2024-03-16:13:16:39,248 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_high_school_statistics from None to 5
# 2024-03-16:13:16:39,248 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_electrical_engineering from None to 5
# 2024-03-16:13:16:39,248 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_computer_security from None to 5
# 2024-03-16:13:16:39,248 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_college_mathematics from None to 5
# 2024-03-16:13:16:39,248 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_high_school_chemistry from None to 5
# 2024-03-16:13:16:39,249 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_machine_learning from None to 5
# 2024-03-16:13:16:39,249 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_college_chemistry from None to 5
# 2024-03-16:13:16:39,249 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_abstract_algebra from None to 5
# 2024-03-16:13:16:39,249 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_high_school_biology from None to 5
# 2024-03-16:13:16:39,249 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_high_school_mathematics from None to 5
# 2024-03-16:13:16:39,249 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_high_school_computer_science from None to 5
# 2024-03-16:13:16:39,249 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_conceptual_physics from None to 5
# 2024-03-16:13:16:39,249 WARNING  [evaluator.py:222] Overwriting default num_fewshot of mmlu_college_computer_science from None to 5
# 2024-03-16:13:16:39,249 WARNING  [evaluator.py:222] Overwriting default num_fewshot of hellaswag from None to 5
# 2024-03-16:13:16:39,252 INFO     [task.py:395] Building contexts for mmlu_anatomy on rank 0...
# 100% 135/135 [00:02<00:00, 56.09it/s]
# 2024-03-16:13:16:41,665 INFO     [task.py:395] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:02<00:00, 65.70it/s]
# 2024-03-16:13:16:43,864 INFO     [task.py:395] Building contexts for mmlu_elementary_mathematics on rank 0...
# 100% 378/378 [00:05<00:00, 65.46it/s]
# 2024-03-16:13:16:49,656 INFO     [task.py:395] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:01<00:00, 64.82it/s]
# 2024-03-16:13:16:51,235 INFO     [task.py:395] Building contexts for mmlu_high_school_physics on rank 0...
# 100% 151/151 [00:02<00:00, 65.79it/s]
# 2024-03-16:13:16:53,538 INFO     [task.py:395] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:02<00:00, 65.74it/s]
# 2024-03-16:13:16:55,857 INFO     [task.py:395] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:03<00:00, 65.73it/s]
# 2024-03-16:13:16:59,154 INFO     [task.py:395] Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:02<00:00, 65.47it/s]
# 2024-03-16:13:17:01,376 INFO     [task.py:395] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:01<00:00, 65.48it/s]
# 2024-03-16:13:17:02,908 INFO     [task.py:395] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:01<00:00, 65.55it/s]
# 2024-03-16:13:17:04,439 INFO     [task.py:395] Building contexts for mmlu_high_school_chemistry on rank 0...
# 100% 203/203 [00:03<00:00, 65.49it/s]
# 2024-03-16:13:17:07,549 INFO     [task.py:395] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:01<00:00, 65.07it/s]
# 2024-03-16:13:17:09,276 INFO     [task.py:395] Building contexts for mmlu_college_chemistry on rank 0...
# 100% 100/100 [00:01<00:00, 65.39it/s]
# 2024-03-16:13:17:10,810 INFO     [task.py:395] Building contexts for mmlu_abstract_algebra on rank 0...
# 100% 100/100 [00:01<00:00, 65.03it/s]
# 2024-03-16:13:17:12,353 INFO     [task.py:395] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:04<00:00, 65.34it/s]
# 2024-03-16:13:17:17,113 INFO     [task.py:395] Building contexts for mmlu_high_school_mathematics on rank 0...
# 100% 270/270 [00:04<00:00, 65.34it/s]
# 2024-03-16:13:17:21,258 INFO     [task.py:395] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 65.03it/s]
# 2024-03-16:13:17:22,802 INFO     [task.py:395] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:03<00:00, 65.33it/s]
# 2024-03-16:13:17:26,410 INFO     [task.py:395] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:01<00:00, 65.15it/s]
# 2024-03-16:13:17:27,950 INFO     [task.py:395] Building contexts for hellaswag on rank 0...
# 100% 10042/10042 [01:46<00:00, 94.28it/s]
# 2024-03-16:13:19:15,587 INFO     [evaluator.py:357] Running loglikelihood requests
# Running loglikelihood requests:   0% 0/52780 [00:00<?, ?it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 16
# Running loglikelihood requests:  28% 14753/52780 [09:54<23:47, 26.63it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 32
# Running loglikelihood requests:  53% 28206/52780 [18:06<13:36, 30.11it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Running loglikelihood requests:  53% 28237/52780 [18:19<13:35, 30.11it/s]Determined largest batch size: 32
# Running loglikelihood requests:  76% 40066/52780 [25:33<06:57, 30.48it/s]Passed argument batch_size = auto:4.0. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests: 100% 52780/52780 [31:41<00:00, 27.76it/s]
# hf (pretrained=twhoool02/Llama-2-7b-chat-hf-AWQ), gen_kwargs: (None), limit: None, num_fewshot: 5, batch_size: auto:4 (16,32,32,64,64)
# |             Tasks             |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |-------------------------------|-------|------|-----:|--------|-----:|---|-----:|
# |stem                           |N/A    |none  |     5|acc     |0.3876|±  |0.0085|
# | - abstract_algebra            |      0|none  |     5|acc     |0.3000|±  |0.0461|
# | - anatomy                     |      0|none  |     5|acc     |0.4593|±  |0.0430|
# | - astronomy                   |      0|none  |     5|acc     |0.4934|±  |0.0407|
# | - college_biology             |      0|none  |     5|acc     |0.5069|±  |0.0418|
# | - college_chemistry           |      0|none  |     5|acc     |0.2900|±  |0.0456|
# | - college_computer_science    |      0|none  |     5|acc     |0.4200|±  |0.0496|
# | - college_mathematics         |      0|none  |     5|acc     |0.3600|±  |0.0482|
# | - college_physics             |      0|none  |     5|acc     |0.2353|±  |0.0422|
# | - computer_security           |      0|none  |     5|acc     |0.5400|±  |0.0501|
# | - conceptual_physics          |      0|none  |     5|acc     |0.4170|±  |0.0322|
# | - electrical_engineering      |      0|none  |     5|acc     |0.4621|±  |0.0415|
# | - elementary_mathematics      |      0|none  |     5|acc     |0.3228|±  |0.0241|
# | - high_school_biology         |      0|none  |     5|acc     |0.5355|±  |0.0284|
# | - high_school_chemistry       |      0|none  |     5|acc     |0.3498|±  |0.0336|
# | - high_school_computer_science|      0|none  |     5|acc     |0.4400|±  |0.0499|
# | - high_school_mathematics     |      0|none  |     5|acc     |0.2556|±  |0.0266|
# | - high_school_physics         |      0|none  |     5|acc     |0.3510|±  |0.0390|
# | - high_school_statistics      |      0|none  |     5|acc     |0.3287|±  |0.0320|
# | - machine_learning            |      0|none  |     5|acc     |0.3214|±  |0.0443|
# |hellaswag                      |      1|none  |     5|acc     |0.5834|±  |0.0049|
# |                               |       |none  |     5|acc_norm|0.7693|±  |0.0042|
#
# |Groups|Version|Filter|n-shot|Metric|Value |   |Stderr|
# |------|-------|------|-----:|------|-----:|---|-----:|
# |stem  |N/A    |none  |     5|acc   |0.3876|±  |0.0085|
